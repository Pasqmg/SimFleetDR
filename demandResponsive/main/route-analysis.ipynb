# %%
import geopy.distance

from main import itinerary, request, scheduler
from main.database import Database
from main.insertion import Insertion

VERBOSE = 1

# %%
def request_from_db(database):
    """
    Creation of Request objects from customer information in the configuration file
    """
    db = database
    customers = db.get_customers()
    requests = []
    for customer in customers:
        customer_id = customer
        passenger_id = customer_id
        attributes = db.get_customer_dic(passenger_id)

        coords = db.get_customer_origin(customer_id)
        origin_id = db.get_stop_id([coords[1], coords[0]])

        coords = db.get_customer_destination(customer_id)
        destination_id = db.get_stop_id([coords[1], coords[0]])

        req = request.Request(db, passenger_id, origin_id, destination_id,
                              attributes.get("origin_time_ini"), attributes.get("origin_time_end"),
                              attributes.get("destination_time_ini"), attributes.get("destination_time_end"),
                              attributes.get("npass"))

        requests.append(req)
        if VERBOSE > 1:
            print("Created request from configuration file:")
            print(req.to_string())
    return requests


def itinerary_from_db(database):
    """
    Creation of initial Itinerary objects from vehicle information in the configuration file.
    Initial itineraries contain as first and last stop the warehouse where the vehicle is stored.

    Initialization of itinerary_insertion_dic, a data structure reflecting the insertions contained in each itinerary.
    """
    db = database
    transports = db.get_transports()
    itineraries = []
    itinerary_insertion_dic = {}
    for transport in transports:
        vehicle_id = transport

        coords = db.get_transport_origin(vehicle_id)
        start_stop_id = db.get_stop_id([coords[1], coords[0]])

        coords = db.get_transport_destination(vehicle_id)
        end_stop_id = db.get_stop_id([coords[1], coords[0]])

        attributes = db.get_transport_dic(vehicle_id)

        I = itinerary.Itinerary(db, vehicle_id, attributes.get("capacity"), start_stop_id, end_stop_id,
                                attributes.get("start_time"), attributes.get("end_time"))
        itineraries.append(I)
        itinerary_insertion_dic[vehicle_id] = []
        if VERBOSE > 1:
            print("Created itinerary from configuration file:")
            print(I.to_string())
            print(I.start_stop.to_string())
            print(I.end_stop.to_string())
    return itineraries, itinerary_insertion_dic

# %%
database = Database()
# Out:
# Loading STOPS_FILE from ../data/input/ADCAIJ/stops_in_borders3.json
# Loading ROUTES_FILE from ../data/input/ADCAIJ/routes_in_borders3.json
# Routes loaded in 82.19657278060913s

# %%
# config_file = "150r-2000m-60_900-1_5p+10v-8cap-0_960.json" # GUIMABUS
# config_file = "100r-2000m-60_900-1-5p+8v-8cap-22id-0_960.json" # VALENCIA
config_file = "600r-500m-60_360-1_5p+20v-8cap-0_420.json" # ADCAIJ
database.load_config(config_file)
# Out:
# Loading CONFIG from ../data/configs/ADCAIJ/600r-500m-60_360-1_5p+20v-8cap-0_420.json

# %%
# Load itineraries from config file
itineraries, itinerary_insertion_dic = itinerary_from_db(database)

# Load requests from config file
requests = request_from_db(database)

# Create and initialize scheduler object
sche = scheduler.Scheduler(database)
sche.pending_requests = requests
sche.itineraries = itineraries
sche.itinerary_insertion_dic = itinerary_insertion_dic

# Schedule all requests by order of issuance
sche.schedule_all_requests_by_time_order(verbose=1)
output = sche.simulation_stats()
# Out:
# Printing all itineraries:
#
# Vehicle with ID veh_01_925113110225 has 52 stops scheduled
# 	Departure from stop 925113110225 at time 63.96
# 	--> stop 5250500102, npass 0 -> 1, request_002_1, [65.00, 66.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040204, npass 1 -> 0, request_002_1, [67.76, 68.76] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010214, npass 0 -> 1, request_001_1, [75.66, 76.66] (arr, dep), 1.00 min, 0.00 min, customers waited 10.66 min
# 	--> stop 5252020202, npass 1 -> 3, request_003_2, [83.79, 85.79] (arr, dep), 2.00 min, 0.00 min, customers waited 18.79 min
# 	--> stop 5403110202, npass 3 -> 4, request_021_1, [88.63, 89.63] (arr, dep), 1.00 min, 0.00 min, customers waited 11.63 min
# 	--> stop 5904210202, npass 4 -> 2, request_003_2, [95.17, 97.17] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 92501650201, npass 2 -> 1, request_021_1, [109.26, 110.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400112, npass 1 -> 0, request_001_1, [114.26, 115.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300111, npass 0 -> 2, request_068_2, [120.98, 122.98] (arr, dep), 2.00 min, 0.00 min, customers waited 18.98 min
# 	--> stop 5254020107, npass 2 -> 3, request_097_1, [132.53, 133.53] (arr, dep), 1.00 min, 0.00 min, customers waited 14.53 min
# 	--> stop 5250060205, npass 3 -> 1, request_068_2, [141.81, 143.91] (arr, dep), 2.09 min, 0.09 min
# 	--> stop 5250600110, npass 1 -> 2, request_155_1, [150.00, 151.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5251300107, npass 2 -> 1, request_097_1, [161.57, 162.57] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300103, npass 1 -> 2, request_175_1, [166.66, 167.66] (arr, dep), 1.00 min, 0.00 min, customers waited 7.66 min
# 	--> stop 5201110204, npass 2 -> 3, request_179_1, [174.48, 175.48] (arr, dep), 1.00 min, 0.00 min, customers waited 13.48 min
# 	--> stop 5251400214, npass 3 -> 4, request_185_1, [182.09, 183.09] (arr, dep), 1.00 min, 0.00 min, customers waited 19.09 min
# 	--> stop 5250500121, npass 4 -> 3, request_155_1, [189.17, 190.17] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500118, npass 3 -> 2, request_179_1, [192.41, 193.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500112, npass 2 -> 3, request_244_1, [198.50, 199.50] (arr, dep), 1.00 min, 0.00 min, customers waited 5.50 min
# 	--> stop 5252010127, npass 3 -> 2, request_175_1, [206.04, 207.04] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010105, npass 2 -> 1, request_185_1, [212.85, 213.85] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040137, npass 1 -> 6, request_255_5, [221.86, 226.86] (arr, dep), 5.00 min, 0.00 min, customers waited 18.86 min
# 	--> stop 5252040137, npass 6 -> 5, request_244_1, [226.86, 227.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700112, npass 5 -> 6, request_296_1, [243.68, 244.68] (arr, dep), 1.00 min, 0.00 min, customers waited 17.68 min
# 	--> stop 925114700202, npass 6 -> 1, request_255_5, [248.33, 253.33] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 925114700206, npass 1 -> 3, request_318_2, [255.59, 257.59] (arr, dep), 2.00 min, 0.00 min, customers waited 19.59 min
# 	--> stop 5251400120, npass 3 -> 4, request_337_1, [260.57, 261.57] (arr, dep), 1.00 min, 0.00 min, customers waited 19.57 min
# 	--> stop 5250720229, npass 4 -> 5, request_374_1, [276.33, 277.33] (arr, dep), 1.00 min, 0.00 min, customers waited 19.33 min
# 	--> stop 5206020118, npass 5 -> 4, request_296_1, [281.07, 282.07] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060103, npass 4 -> 3, request_337_1, [285.80, 286.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010107, npass 3 -> 1, request_318_2, [296.22, 298.22] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010209, npass 1 -> 0, request_374_1, [306.43, 307.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010117, npass 0 -> 1, request_459_1, [309.91, 310.91] (arr, dep), 1.00 min, 0.00 min, customers waited 16.91 min
# 	--> stop 5253010204, npass 1 -> 2, request_483_1, [312.10, 313.10] (arr, dep), 1.00 min, 0.00 min, customers waited 10.10 min
# 	--> stop 5252060140, npass 2 -> 5, request_464_3, [313.74, 316.74] (arr, dep), 3.00 min, 0.00 min, customers waited 18.74 min
# 	--> stop 5252010111, npass 5 -> 7, request_496_2, [320.32, 322.32] (arr, dep), 2.00 min, 0.00 min, customers waited 11.32 min
# 	--> stop 5252010111, npass 7 -> 6, request_483_1, [322.32, 323.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010205, npass 6 -> 5, request_459_1, [330.99, 331.99] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040140, npass 5 -> 6, request_542_1, [332.71, 333.71] (arr, dep), 1.00 min, 0.00 min, customers waited 1.71 min
# 	--> stop 5254020107, npass 6 -> 3, request_464_3, [338.16, 341.16] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5256120203, npass 3 -> 4, request_535_1, [346.89, 347.89] (arr, dep), 1.00 min, 0.00 min, customers waited 18.89 min
# 	--> stop 5904210201, npass 4 -> 2, request_496_2, [353.04, 355.04] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5256120209, npass 2 -> 1, request_535_1, [355.67, 356.67] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130106, npass 1 -> 0, request_542_1, [363.48, 364.48] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040207, npass 0 -> 1, request_581_1, [372.89, 373.89] (arr, dep), 1.00 min, 0.00 min, customers waited 19.89 min
# 	--> stop 5206020205, npass 1 -> 2, request_590_1, [376.34, 377.34] (arr, dep), 1.00 min, 0.00 min, customers waited 18.34 min
# 	--> stop 5252010122, npass 2 -> 5, request_597_3, [380.61, 383.61] (arr, dep), 3.00 min, 0.00 min, customers waited 17.61 min
# 	--> stop 5201110120, npass 5 -> 4, request_590_1, [389.79, 390.79] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 4 -> 3, request_581_1, [398.44, 399.44] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500124, npass 3 -> 0, request_597_3, [409.32, 412.32] (arr, dep), 3.00 min, 0.00 min
# 	End in stop 925113110225 at time 424.06
# 	Vehicle currently at stop 925113110225
# 	Busy time: 360.00 (85.72%), Waiting time: 64.06 (15.25%), Busy+Wait: 100.97%
# Itinerary km: 208.56, cost: 208.56
# Total customers: 25, total waiting: 348.87 min, avg: 13.95 min, stdev: 6.38 min
#
#
# {'request_002_1': {'wait': 0, 'on-board': 2.7633333333333354, 'trip_kms': 1.441, 'min_kms': 1.441}, 'request_001_1': {'wait': 10.663333333333341, 'on-board': 38.599999999999994, 'trip_kms': 22.2201, 'min_kms': 11.1319}, 'request_003_2': {'wait': 18.79166666666667, 'on-board': 11.381666666666675, 'trip_kms': 5.3177, 'min_kms': 4.1061000000000005}, 'request_021_1': {'wait': 11.631666666666675, 'on-board': 20.625, 'trip_kms': 13.4997, 'min_kms': 8.312299999999999}, 'request_068_2': {'wait': 18.980000000000004, 'on-board': 20.83333333333333, 'trip_kms': 15.234300000000001, 'min_kms': 14.3408}, 'request_097_1': {'wait': 14.525000000000006, 'on-board': 29.043333333333322, 'trip_kms': 18.512900000000002, 'min_kms': 7.2163}, 'request_155_1': {'wait': 0, 'on-board': 39.16833333333332, 'trip_kms': 21.179199999999998, 'min_kms': 7.0262}, 'request_175_1': {'wait': 7.661666666666662, 'on-board': 39.383333333333326, 'trip_kms': 21.6827, 'min_kms': 7.421}, 'request_179_1': {'wait': 13.47666666666666, 'on-board': 17.931666666666672, 'trip_kms': 9.831199999999999, 'min_kms': 7.4684}, 'request_185_1': {'wait': 19.095, 'on-board': 30.758333333333326, 'trip_kms': 17.7209, 'min_kms': 10.4904}, 'request_244_1': {'wait': 5.50333333333333, 'on-board': 28.359999999999985, 'trip_kms': 14.8304, 'min_kms': 5.0297}, 'request_255_5': {'wait': 18.863333333333316, 'on-board': 26.468333333333334, 'trip_kms': 14.4844, 'min_kms': 11.5311}, 'request_296_1': {'wait': 17.676666666666648, 'on-board': 37.393333333333345, 'trip_kms': 19.1912, 'min_kms': 16.6616}, 'request_318_2': {'wait': 19.59499999999997, 'on-board': 40.62666666666672, 'trip_kms': 27.049299999999995, 'min_kms': 16.6756}, 'request_337_1': {'wait': 19.569999999999993, 'on-board': 25.23333333333335, 'trip_kms': 17.248299999999997, 'min_kms': 16.8191}, 'request_374_1': {'wait': 19.33499999999998, 'on-board': 30.091666666666697, 'trip_kms': 17.5449, 'min_kms': 10.3446}, 'request_459_1': {'wait': 16.906666666666695, 'on-board': 21.07833333333332, 'trip_kms': 9.5793, 'min_kms': 5.206600000000001}, 'request_483_1': {'wait': 10.098333333333358, 'on-board': 10.2233333333333, 'trip_kms': 2.6517, 'min_kms': 2.5542}, 'request_464_3': {'wait': 18.73666666666668, 'on-board': 24.426666666666677, 'trip_kms': 12.3263, 'min_kms': 8.62}, 'request_496_2': {'wait': 11.321666666666658, 'on-board': 32.71833333333336, 'trip_kms': 17.2833, 'min_kms': 11.6253}, 'request_542_1': {'wait': 1.7100000000000364, 'on-board': 30.76666666666665, 'trip_kms': 15.7257, 'min_kms': 5.505}, 'request_535_1': {'wait': 18.89166666666671, 'on-board': 8.781666666666638, 'trip_kms': 3.9259999999999997, 'min_kms': 2.7105}, 'request_581_1': {'wait': 19.885000000000048, 'on-board': 25.55166666666662, 'trip_kms': 14.9101, 'min_kms': 9.7023}, 'request_590_1': {'wait': 18.343333333333362, 'on-board': 13.449999999999989, 'trip_kms': 7.4441999999999995, 'min_kms': 4.140899999999999}, 'request_597_3': {'wait': 17.61166666666668, 'on-board': 28.71333333333331, 'trip_kms': 18.881, 'min_kms': 12.243}}
# {'num_stops': 52, 'begin_time': 63.96333333333333, 'end_time': 424.06166666666667, 'total_time': 420, 'busy_time': 360.0033333333333, 'wait_time': 64.05833333333334, 'busy_percent': 85.71507936507935, 'wait_percent': 15.251984126984128, 'usage_percent': 100.96706349206347, 'itinerary_kms': 208.55880000000002, 'cost': 208.55880000000002, 'total_requests': 25, 'total_wait': 348.8733333333335, 'avg_wait': 13.95493333333334, 'std_wait': 6.381488932494951}
# Vehicle with ID veh_02_925113110225 has 52 stops scheduled
# 	Departure from stop 925113110225 at time 53.12
# 	--> stop 5251400206, npass 0 -> 2, request_005_2, [67.00, 69.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5251400210, npass 2 -> 3, request_006_1, [72.16, 73.16] (arr, dep), 1.00 min, 0.00 min, customers waited 5.16 min
# 	--> stop 5250740213, npass 3 -> 5, request_004_2, [83.62, 85.62] (arr, dep), 2.00 min, 0.00 min, customers waited 17.62 min
# 	--> stop 5250500208, npass 5 -> 4, request_006_1, [93.56, 94.56] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 4 -> 5, request_064_1, [102.94, 103.94] (arr, dep), 1.00 min, 0.00 min, customers waited 3.94 min
# 	--> stop 5259030211, npass 5 -> 3, request_004_2, [107.63, 109.63] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010106, npass 3 -> 5, request_053_2, [112.91, 114.91] (arr, dep), 2.00 min, 0.00 min, customers waited 19.91 min
# 	--> stop 5250060218, npass 5 -> 4, request_064_1, [126.13, 127.13] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710202, npass 4 -> 2, request_005_2, [137.81, 139.81] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250710130, npass 2 -> 0, request_053_2, [141.89, 143.89] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250710128, npass 0 -> 1, request_111_1, [146.79, 147.79] (arr, dep), 1.00 min, 0.00 min, customers waited 19.79 min
# 	--> stop 5250720121, npass 1 -> 2, request_126_1, [153.04, 154.04] (arr, dep), 1.00 min, 0.00 min, customers waited 17.04 min
# 	--> stop 5250720229, npass 2 -> 3, request_157_1, [154.81, 155.81] (arr, dep), 1.00 min, 0.00 min, customers waited 4.81 min
# 	--> stop 5250720128, npass 3 -> 2, request_126_1, [157.18, 158.18] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600115, npass 2 -> 3, request_174_1, [165.19, 166.19] (arr, dep), 1.00 min, 0.00 min, customers waited 7.19 min
# 	--> stop 5250600111, npass 3 -> 4, request_156_1, [168.41, 169.41] (arr, dep), 1.00 min, 0.00 min, customers waited 18.41 min
# 	--> stop 5250070121, npass 4 -> 3, request_157_1, [170.06, 171.06] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040137, npass 3 -> 4, request_193_1, [177.03, 178.03] (arr, dep), 1.00 min, 0.00 min, customers waited 12.03 min
# 	--> stop 5252040136, npass 4 -> 3, request_111_1, [179.41, 180.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010122, npass 3 -> 2, request_174_1, [182.52, 183.52] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010207, npass 2 -> 3, request_229_1, [184.20, 185.20] (arr, dep), 1.00 min, 0.00 min, customers waited 1.20 min
# 	--> stop 5259030211, npass 3 -> 2, request_156_1, [186.46, 187.46] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925218000218, npass 2 -> 1, request_193_1, [191.80, 192.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020132, npass 1 -> 2, request_224_1, [198.52, 199.52] (arr, dep), 1.00 min, 0.00 min, customers waited 18.52 min
# 	--> stop 5252020202, npass 2 -> 5, request_250_3, [202.95, 205.95] (arr, dep), 3.00 min, 0.00 min, customers waited 3.95 min
# 	--> stop 5253010219, npass 5 -> 4, request_229_1, [209.34, 210.34] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010209, npass 4 -> 3, request_224_1, [216.96, 217.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010119, npass 3 -> 4, request_264_1, [221.74, 223.15] (arr, dep), 1.41 min, 0.41 min, customers waited 15.74 min
# 	--> stop 5252040210, npass 4 -> 5, request_299_1, [227.00, 228.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925218210235, npass 5 -> 4, request_264_1, [228.47, 229.47] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500118, npass 4 -> 5, request_297_1, [240.80, 241.80] (arr, dep), 1.00 min, 0.00 min, customers waited 13.80 min
# 	--> stop 5250060127, npass 5 -> 2, request_250_3, [242.98, 245.98] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5254020227, npass 2 -> 3, request_306_1, [247.37, 248.37] (arr, dep), 1.00 min, 0.00 min, customers waited 18.37 min
# 	--> stop 5251400115, npass 3 -> 2, request_306_1, [256.02, 257.02] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92501650109, npass 2 -> 1, request_299_1, [261.28, 262.28] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 2, request_344_1, [263.52, 264.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5256120113, npass 2 -> 1, request_297_1, [277.22, 278.22] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010106, npass 1 -> 2, request_400_1, [280.22, 281.22] (arr, dep), 1.00 min, 0.00 min, customers waited 11.22 min
# 	--> stop 5250750108, npass 2 -> 1, request_344_1, [296.35, 297.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020127, npass 1 -> 2, request_442_1, [304.88, 305.88] (arr, dep), 1.00 min, 0.00 min, customers waited 17.88 min
# 	--> stop 925114100204, npass 2 -> 1, request_400_1, [314.42, 315.42] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100116, npass 1 -> 4, request_486_3, [315.54, 318.54] (arr, dep), 3.00 min, 0.00 min, customers waited 11.54 min
# 	--> stop 925114800115, npass 4 -> 7, request_501_3, [325.01, 328.01] (arr, dep), 3.00 min, 0.00 min, customers waited 13.01 min
# 	--> stop 5251400118, npass 7 -> 6, request_442_1, [330.19, 331.19] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254010109, npass 6 -> 3, request_486_3, [340.26, 343.26] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500117, npass 3 -> 0, request_501_3, [349.30, 352.30] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500122, npass 0 -> 1, request_552_1, [355.48, 356.48] (arr, dep), 1.00 min, 0.00 min, customers waited 19.48 min
# 	--> stop 5254010108, npass 1 -> 4, request_593_3, [361.08, 364.08] (arr, dep), 3.00 min, 0.00 min, customers waited 1.08 min
# 	--> stop 5250060119, npass 4 -> 3, request_552_1, [369.57, 370.57] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060117, npass 3 -> 0, request_593_3, [377.05, 380.05] (arr, dep), 3.00 min, 0.00 min
# 	End in stop 925113110225 at time 390.95
# 	Vehicle currently at stop 925113110225
# 	Busy time: 337.42 (80.34%), Waiting time: 53.53 (12.75%), Busy+Wait: 93.08%
# Itinerary km: 190.52, cost: 190.52
# Total customers: 25, total waiting: 291.20 min, avg: 11.65 min, stdev: 7.05 min
#
#
# {'request_005_2': {'wait': 0, 'on-board': 70.80666666666667, 'trip_kms': 47.885999999999996, 'min_kms': 19.054599999999997}, 'request_006_1': {'wait': 5.156666666666666, 'on-board': 21.39833333333334, 'trip_kms': 13.741, 'min_kms': 2.7942}, 'request_004_2': {'wait': 17.620000000000005, 'on-board': 24.00666666666666, 'trip_kms': 17.0492, 'min_kms': 7.8393999999999995}, 'request_064_1': {'wait': 3.9383333333333326, 'on-board': 23.189999999999998, 'trip_kms': 16.9696, 'min_kms': 7.3232}, 'request_053_2': {'wait': 19.914999999999992, 'on-board': 28.975000000000023, 'trip_kms': 19.6214, 'min_kms': 14.5157}, 'request_111_1': {'wait': 19.788333333333355, 'on-board': 32.625, 'trip_kms': 17.0696, 'min_kms': 11.4619}, 'request_126_1': {'wait': 17.035000000000025, 'on-board': 4.143333333333345, 'trip_kms': 1.3162, 'min_kms': 1.3496}, 'request_157_1': {'wait': 4.810000000000031, 'on-board': 15.25333333333333, 'trip_kms': 7.6498, 'min_kms': 6.0056}, 'request_174_1': {'wait': 7.185000000000031, 'on-board': 17.329999999999984, 'trip_kms': 8.686, 'min_kms': 7.3635}, 'request_156_1': {'wait': 18.40500000000003, 'on-board': 18.053333333333313, 'trip_kms': 8.803899999999999, 'min_kms': 5.274100000000001}, 'request_193_1': {'wait': 12.03333333333336, 'on-board': 14.761666666666656, 'trip_kms': 6.400399999999999, 'min_kms': 2.5585999999999998}, 'request_229_1': {'wait': 1.200000000000017, 'on-board': 25.13833333333332, 'trip_kms': 11.9166, 'min_kms': 2.6385}, 'request_224_1': {'wait': 18.51666666666668, 'on-board': 18.444999999999993, 'trip_kms': 9.1828, 'min_kms': 7.4331000000000005}, 'request_250_3': {'wait': 3.948333333333352, 'on-board': 40.03, 'trip_kms': 22.889599999999998, 'min_kms': 8.1139}, 'request_264_1': {'wait': 15.740000000000009, 'on-board': 6.731666666666655, 'trip_kms': 2.5243, 'min_kms': 2.0257}, 'request_299_1': {'wait': 0, 'on-board': 34.28000000000003, 'trip_kms': 19.142699999999998, 'min_kms': 9.9281}, 'request_297_1': {'wait': 13.803333333333342, 'on-board': 36.41166666666669, 'trip_kms': 18.172400000000003, 'min_kms': 12.4354}, 'request_306_1': {'wait': 18.370000000000033, 'on-board': 8.65166666666667, 'trip_kms': 4.0766, 'min_kms': 4.0766}, 'request_344_1': {'wait': 19.52333333333337, 'on-board': 32.82333333333332, 'trip_kms': 20.9105, 'min_kms': 13.0718}, 'request_400_1': {'wait': 11.216666666666697, 'on-board': 34.206666666666706, 'trip_kms': 23.8001, 'min_kms': 8.7054}, 'request_442_1': {'wait': 17.883333333333383, 'on-board': 25.310000000000002, 'trip_kms': 12.174700000000001, 'min_kms': 7.2277}, 'request_486_3': {'wait': 11.540000000000077, 'on-board': 24.7233333333333, 'trip_kms': 10.5298, 'min_kms': 10.0427}, 'request_501_3': {'wait': 13.006666666666717, 'on-board': 24.291666666666686, 'trip_kms': 9.849, 'min_kms': 4.3054}, 'request_552_1': {'wait': 19.48166666666674, 'on-board': 14.088333333333367, 'trip_kms': 8.1373, 'min_kms': 7.5107}, 'request_593_3': {'wait': 1.0783333333334326, 'on-board': 15.971666666666692, 'trip_kms': 7.1095, 'min_kms': 3.7575}}
# {'num_stops': 52, 'begin_time': 53.11833333333333, 'end_time': 390.95333333333343, 'total_time': 420, 'busy_time': 337.4216666666667, 'wait_time': 53.53166666666666, 'busy_percent': 80.33849206349205, 'wait_percent': 12.745634920634918, 'usage_percent': 93.08412698412698, 'itinerary_kms': 190.5235, 'cost': 190.5235, 'total_requests': 25, 'total_wait': 291.1950000000007, 'avg_wait': 11.647800000000027, 'std_wait': 7.051044409951702}
# Vehicle with ID veh_03_925113110225 has 40 stops scheduled
# 	Departure from stop 925113110225 at time 63.23
# 	--> stop 5104010119, npass 0 -> 3, request_008_3, [69.00, 72.00] (arr, dep), 3.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250500119, npass 3 -> 7, request_007_4, [85.93, 89.93] (arr, dep), 4.00 min, 0.00 min, customers waited 17.93 min
# 	--> stop 5251310106, npass 7 -> 3, request_007_4, [98.69, 102.69] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5403010125, npass 3 -> 6, request_057_3, [109.64, 112.64] (arr, dep), 3.00 min, 0.00 min, customers waited 15.64 min
# 	--> stop 5259010102, npass 6 -> 7, request_079_1, [114.38, 115.38] (arr, dep), 1.00 min, 0.00 min, customers waited 6.38 min
# 	--> stop 5250720222, npass 7 -> 4, request_008_3, [128.28, 131.28] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250710204, npass 4 -> 1, request_057_3, [135.02, 138.02] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5254020226, npass 1 -> 0, request_079_1, [153.75, 154.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600101, npass 0 -> 1, request_148_1, [163.66, 164.66] (arr, dep), 1.00 min, 0.00 min, customers waited 18.66 min
# 	--> stop 5259010102, npass 1 -> 0, request_148_1, [168.90, 169.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010205, npass 0 -> 3, request_188_3, [172.69, 175.69] (arr, dep), 3.00 min, 0.00 min, customers waited 8.69 min
# 	--> stop 5256120113, npass 3 -> 7, request_180_4, [181.81, 185.81] (arr, dep), 4.00 min, 0.00 min, customers waited 19.81 min
# 	--> stop 5253010112, npass 7 -> 3, request_180_4, [196.66, 200.66] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5206020211, npass 3 -> 0, request_188_3, [213.02, 216.02] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250720127, npass 0 -> 1, request_266_1, [217.39, 218.39] (arr, dep), 1.00 min, 0.00 min, customers waited 10.39 min
# 	--> stop 5250710206, npass 1 -> 2, request_257_1, [220.72, 221.72] (arr, dep), 1.00 min, 0.00 min, customers waited 16.72 min
# 	--> stop 5250710204, npass 2 -> 6, request_259_4, [222.66, 226.66] (arr, dep), 4.00 min, 0.00 min, customers waited 18.66 min
# 	--> stop 5250710204, npass 6 -> 8, request_284_2, [226.66, 228.66] (arr, dep), 2.00 min, 0.00 min, customers waited 8.66 min
# 	--> stop 5253010112, npass 8 -> 7, request_266_1, [241.97, 242.97] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400116, npass 7 -> 5, request_284_2, [257.90, 259.90] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 925114100118, npass 5 -> 4, request_257_1, [264.82, 265.82] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100204, npass 4 -> 0, request_259_4, [268.11, 272.11] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 925114100204, npass 0 -> 1, request_410_1, [272.11, 273.11] (arr, dep), 1.00 min, 0.00 min, customers waited 0.11 min
# 	--> stop 925114100116, npass 1 -> 2, request_379_1, [273.22, 274.22] (arr, dep), 1.00 min, 0.00 min, customers waited 12.22 min
# 	--> stop 925114700207, npass 2 -> 5, request_387_3, [280.64, 283.64] (arr, dep), 3.00 min, 0.00 min, customers waited 15.64 min
# 	--> stop 5251300108, npass 5 -> 6, request_406_1, [290.16, 291.16] (arr, dep), 1.00 min, 0.00 min, customers waited 19.16 min
# 	--> stop 5206020130, npass 6 -> 3, request_387_3, [301.71, 304.71] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010218, npass 3 -> 2, request_410_1, [308.75, 309.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010118, npass 2 -> 1, request_379_1, [316.61, 317.61] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010112, npass 1 -> 2, request_499_1, [320.89, 321.89] (arr, dep), 1.00 min, 0.00 min, customers waited 10.89 min
# 	--> stop 5250060208, npass 2 -> 1, request_406_1, [339.75, 340.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060203, npass 1 -> 2, request_540_1, [347.70, 348.70] (arr, dep), 1.00 min, 0.00 min, customers waited 16.70 min
# 	--> stop 5250500119, npass 2 -> 1, request_499_1, [354.42, 355.42] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070121, npass 1 -> 2, request_562_1, [362.60, 363.60] (arr, dep), 1.00 min, 0.00 min, customers waited 19.60 min
# 	--> stop 5251310223, npass 2 -> 1, request_540_1, [368.91, 369.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254020107, npass 1 -> 2, request_595_1, [374.25, 375.25] (arr, dep), 1.00 min, 0.00 min, customers waited 13.25 min
# 	--> stop 92501650201, npass 2 -> 1, request_562_1, [383.96, 384.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070106, npass 1 -> 0, request_595_1, [400.94, 401.94] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925113110225 at time 413.75
# 	Vehicle currently at stop 925113110225
# 	Busy time: 350.53 (83.46%), Waiting time: 63.23 (15.05%), Busy+Wait: 98.51%
# Itinerary km: 209.23, cost: 209.23
# Total customers: 19, total waiting: 249.07 min, avg: 13.11 min, stdev: 6.01 min
#
#
# {'request_008_3': {'wait': 0, 'on-board': 59.281666666666666, 'trip_kms': 36.230599999999995, 'min_kms': 14.0661}, 'request_007_4': {'wait': 17.926666666666662, 'on-board': 12.760000000000005, 'trip_kms': 7.5165, 'min_kms': 7.5165}, 'request_057_3': {'wait': 15.644999999999996, 'on-board': 25.378333333333345, 'trip_kms': 13.331299999999999, 'min_kms': 11.226600000000001}, 'request_079_1': {'wait': 6.376666666666665, 'on-board': 39.370000000000005, 'trip_kms': 23.6873, 'min_kms': 7.8613}, 'request_148_1': {'wait': 18.663333333333327, 'on-board': 5.240000000000009, 'trip_kms': 2.623, 'min_kms': 2.623}, 'request_188_3': {'wait': 8.686666666666667, 'on-board': 40.33500000000001, 'trip_kms': 24.010800000000003, 'min_kms': 11.2928}, 'request_180_4': {'wait': 19.808333333333337, 'on-board': 14.84833333333333, 'trip_kms': 8.722, 'min_kms': 8.722}, 'request_266_1': {'wait': 10.38500000000002, 'on-board': 24.583333333333343, 'trip_kms': 12.7565, 'min_kms': 11.0202}, 'request_257_1': {'wait': 16.716666666666697, 'on-board': 44.10333333333335, 'trip_kms': 27.3523, 'min_kms': 18.0349}, 'request_259_4': {'wait': 18.65500000000003, 'on-board': 45.45166666666671, 'trip_kms': 28.0989, 'min_kms': 17.802}, 'request_284_2': {'wait': 8.65500000000003, 'on-board': 31.245000000000005, 'trip_kms': 23.899, 'min_kms': 16.7183}, 'request_410_1': {'wait': 0.10666666666674018, 'on-board': 36.64500000000004, 'trip_kms': 18.2417, 'min_kms': 9.1181}, 'request_379_1': {'wait': 12.223333333333414, 'on-board': 43.38166666666672, 'trip_kms': 24.3723, 'min_kms': 15.369200000000001}, 'request_387_3': {'wait': 15.63666666666677, 'on-board': 21.07166666666666, 'trip_kms': 12.419, 'min_kms': 8.7808}, 'request_406_1': {'wait': 19.155000000000086, 'on-board': 49.59666666666675, 'trip_kms': 32.7997, 'min_kms': 14.443100000000001}, 'request_499_1': {'wait': 10.886666666666827, 'on-board': 33.528333333333364, 'trip_kms': 20.4542, 'min_kms': 13.0579}, 'request_540_1': {'wait': 16.695000000000164, 'on-board': 21.216666666666697, 'trip_kms': 13.162700000000001, 'min_kms': 6.9693000000000005}, 'request_562_1': {'wait': 19.600000000000193, 'on-board': 21.363333333333287, 'trip_kms': 14.1359, 'min_kms': 7.337}, 'request_595_1': {'wait': 13.248333333333505, 'on-board': 26.694999999999993, 'trip_kms': 20.5976, 'min_kms': 7.269699999999999}}
# {'num_stops': 40, 'begin_time': 63.225, 'end_time': 413.75000000000017, 'total_time': 420, 'busy_time': 350.52500000000003, 'wait_time': 63.225, 'busy_percent': 83.45833333333334, 'wait_percent': 15.05357142857143, 'usage_percent': 98.51190476190477, 'itinerary_kms': 209.232, 'cost': 209.232, 'total_requests': 19, 'total_wait': 249.07000000000113, 'avg_wait': 13.108947368421113, 'std_wait': 6.008199373412999}
# Vehicle with ID veh_04_925113110225 has 36 stops scheduled
# 	Departure from stop 925113110225 at time 59.98
# 	--> stop 5252010217, npass 0 -> 1, request_009_1, [69.00, 70.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250500117, npass 1 -> 5, request_010_4, [84.44, 88.44] (arr, dep), 4.00 min, 0.00 min, customers waited 14.44 min
# 	--> stop 5250060203, npass 5 -> 7, request_047_2, [93.41, 95.41] (arr, dep), 2.00 min, 0.00 min, customers waited 2.41 min
# 	--> stop 5250060123, npass 7 -> 8, request_039_1, [96.85, 97.85] (arr, dep), 1.00 min, 0.00 min, customers waited 9.85 min
# 	--> stop 5250600210, npass 8 -> 7, request_009_1, [101.15, 102.15] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040139, npass 7 -> 3, request_010_4, [111.50, 115.50] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5102010203, npass 3 -> 2, request_039_1, [120.27, 121.27] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720216, npass 2 -> 0, request_047_2, [140.12, 142.12] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720215, npass 0 -> 1, request_113_1, [144.43, 145.43] (arr, dep), 1.00 min, 0.00 min, customers waited 16.43 min
# 	--> stop 5250720132, npass 1 -> 6, request_120_5, [150.90, 155.90] (arr, dep), 5.00 min, 0.00 min, customers waited 18.90 min
# 	--> stop 5206020119, npass 6 -> 7, request_149_1, [159.38, 160.38] (arr, dep), 1.00 min, 0.00 min, customers waited 13.38 min
# 	--> stop 5256120203, npass 7 -> 8, request_170_1, [176.82, 177.82] (arr, dep), 1.00 min, 0.00 min, customers waited 19.82 min
# 	--> stop 925113110225, npass 8 -> 7, request_113_1, [182.69, 183.69] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120113, npass 7 -> 2, request_120_5, [189.91, 194.91] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 925114700202, npass 2 -> 1, request_170_1, [209.90, 210.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700205, npass 1 -> 0, request_149_1, [213.90, 214.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400206, npass 0 -> 5, request_254_5, [218.37, 223.37] (arr, dep), 5.00 min, 0.00 min, customers waited 16.37 min
# 	--> stop 5251400119, npass 5 -> 6, request_267_1, [226.45, 227.45] (arr, dep), 1.00 min, 0.00 min, customers waited 18.45 min
# 	--> stop 5251400211, npass 6 -> 7, request_301_1, [228.03, 229.03] (arr, dep), 1.00 min, 0.00 min, customers waited 1.03 min
# 	--> stop 5250720133, npass 7 -> 6, request_267_1, [246.08, 247.08] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010228, npass 6 -> 1, request_254_5, [259.24, 264.24] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 5252010106, npass 1 -> 3, request_380_2, [266.52, 268.52] (arr, dep), 2.00 min, 0.00 min, customers waited 5.52 min
# 	--> stop 5252010107, npass 3 -> 6, request_364_3, [269.10, 272.10] (arr, dep), 3.00 min, 0.00 min, customers waited 16.10 min
# 	--> stop 5250710130, npass 6 -> 5, request_301_1, [286.80, 287.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120115, npass 5 -> 2, request_364_3, [309.32, 312.32] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5256120113, npass 2 -> 0, request_380_2, [315.38, 317.38] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5102010206, npass 0 -> 1, request_494_1, [319.82, 320.82] (arr, dep), 1.00 min, 0.00 min, customers waited 11.82 min
# 	--> stop 5102020204, npass 1 -> 2, request_513_1, [326.44, 327.44] (arr, dep), 1.00 min, 0.00 min, customers waited 10.44 min
# 	--> stop 5256120119, npass 2 -> 3, request_537_1, [331.64, 332.64] (arr, dep), 1.00 min, 0.00 min, customers waited 2.64 min
# 	--> stop 5201110121, npass 3 -> 2, request_494_1, [334.80, 335.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500104, npass 2 -> 4, request_523_2, [340.53, 342.53] (arr, dep), 2.00 min, 0.00 min, customers waited 18.53 min
# 	--> stop 5250600115, npass 4 -> 3, request_537_1, [349.89, 350.89] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710202, npass 3 -> 1, request_523_2, [363.57, 365.57] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250060215, npass 1 -> 0, request_513_1, [377.88, 378.88] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925113110225 at time 390.60
# 	Vehicle currently at stop 925113110225
# 	Busy time: 330.62 (78.72%), Waiting time: 59.98 (14.28%), Busy+Wait: 93.00%
# Itinerary km: 192.96, cost: 192.96
# Total customers: 17, total waiting: 196.13 min, avg: 11.54 min, stdev: 6.62 min
#
#
# {'request_009_1': {'wait': 0, 'on-board': 32.14666666666666, 'trip_kms': 17.0841, 'min_kms': 10.1326}, 'request_010_4': {'wait': 14.443333333333328, 'on-board': 27.056666666666672, 'trip_kms': 12.6356, 'min_kms': 7.7593000000000005}, 'request_047_2': {'wait': 2.4116666666666617, 'on-board': 46.70500000000001, 'trip_kms': 30.1652, 'min_kms': 9.489700000000001}, 'request_039_1': {'wait': 9.849999999999994, 'on-board': 23.415000000000006, 'trip_kms': 13.129599999999998, 'min_kms': 8.5014}, 'request_113_1': {'wait': 16.431666666666672, 'on-board': 38.25999999999999, 'trip_kms': 23.6195, 'min_kms': 14.3571}, 'request_120_5': {'wait': 18.89833333333334, 'on-board': 39.01666666666665, 'trip_kms': 23.5745, 'min_kms': 17.8228}, 'request_149_1': {'wait': 13.37833333333333, 'on-board': 54.51833333333332, 'trip_kms': 33.908500000000004, 'min_kms': 18.460900000000002}, 'request_170_1': {'wait': 19.819999999999993, 'on-board': 33.076666666666654, 'trip_kms': 18.6959, 'min_kms': 9.4586}, 'request_254_5': {'wait': 16.366666666666646, 'on-board': 40.8716666666667, 'trip_kms': 25.4084, 'min_kms': 17.117}, 'request_267_1': {'wait': 18.44999999999999, 'on-board': 19.630000000000024, 'trip_kms': 14.094199999999999, 'min_kms': 14.0942}, 'request_301_1': {'wait': 1.028333333333336, 'on-board': 58.77000000000001, 'trip_kms': 36.9937, 'min_kms': 17.8566}, 'request_380_2': {'wait': 5.523333333333369, 'on-board': 48.85499999999996, 'trip_kms': 30.2153, 'min_kms': 12.6251}, 'request_364_3': {'wait': 16.095000000000027, 'on-board': 40.224999999999966, 'trip_kms': 28.335500000000003, 'min_kms': 13.726899999999999}, 'request_494_1': {'wait': 11.824999999999989, 'on-board': 14.975000000000023, 'trip_kms': 6.7548, 'min_kms': 5.7322}, 'request_513_1': {'wait': 10.441666666666663, 'on-board': 51.433333333333394, 'trip_kms': 27.9275, 'min_kms': 13.956}, 'request_537_1': {'wait': 2.638333333333321, 'on-board': 18.253333333333387, 'trip_kms': 9.4627, 'min_kms': 7.5333000000000006}, 'request_523_2': {'wait': 18.525000000000034, 'on-board': 23.048333333333346, 'trip_kms': 13.832199999999998, 'min_kms': 11.622}}
# {'num_stops': 36, 'begin_time': 59.98, 'end_time': 390.59666666666675, 'total_time': 420, 'busy_time': 330.61666666666673, 'wait_time': 59.98000000000001, 'busy_percent': 78.71825396825398, 'wait_percent': 14.280952380952384, 'usage_percent': 92.99920634920636, 'itinerary_kms': 192.9624, 'cost': 192.9624, 'total_requests': 17, 'total_wait': 196.1266666666667, 'avg_wait': 11.536862745098041, 'std_wait': 6.622601202969978}
# Vehicle with ID veh_05_925611130111 has 44 stops scheduled
# 	Departure from stop 925611130111 at time 61.64
# 	--> stop 5251310103, npass 0 -> 1, request_011_1, [71.00, 72.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250720129, npass 1 -> 2, request_013_1, [84.40, 85.40] (arr, dep), 1.00 min, 0.00 min, customers waited 12.40 min
# 	--> stop 5250720218, npass 2 -> 3, request_012_1, [89.06, 90.06] (arr, dep), 1.00 min, 0.00 min, customers waited 18.06 min
# 	--> stop 5250720130, npass 3 -> 4, request_043_1, [91.85, 92.85] (arr, dep), 1.00 min, 0.00 min, customers waited 1.85 min
# 	--> stop 5250600208, npass 4 -> 5, request_037_1, [101.58, 102.58] (arr, dep), 1.00 min, 0.00 min, customers waited 17.58 min
# 	--> stop 5250060123, npass 5 -> 4, request_011_1, [105.04, 106.04] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500124, npass 4 -> 3, request_037_1, [114.08, 115.08] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92501650201, npass 3 -> 2, request_013_1, [126.59, 127.59] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120116, npass 2 -> 1, request_012_1, [137.23, 138.23] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500102, npass 1 -> 0, request_043_1, [144.65, 145.65] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500223, npass 0 -> 1, request_143_1, [146.75, 147.75] (arr, dep), 1.00 min, 0.00 min, customers waited 3.75 min
# 	--> stop 5252040204, npass 1 -> 5, request_117_4, [149.28, 153.28] (arr, dep), 4.00 min, 0.00 min, customers waited 19.28 min
# 	--> stop 92571910123, npass 5 -> 6, request_145_1, [158.12, 159.12] (arr, dep), 1.00 min, 0.00 min, customers waited 14.12 min
# 	--> stop 5259030211, npass 6 -> 7, request_181_1, [162.42, 163.42] (arr, dep), 1.00 min, 0.00 min, customers waited 0.42 min
# 	--> stop 5206020202, npass 7 -> 6, request_143_1, [165.71, 166.71] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500203, npass 6 -> 2, request_117_4, [177.04, 181.04] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254020226, npass 2 -> 1, request_181_1, [186.12, 187.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 1 -> 0, request_145_1, [195.31, 196.31] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 0 -> 2, request_237_2, [196.31, 198.31] (arr, dep), 2.00 min, 0.00 min, customers waited 10.31 min
# 	--> stop 92501650202, npass 2 -> 3, request_231_1, [200.93, 201.93] (arr, dep), 1.00 min, 0.00 min, customers waited 16.93 min
# 	--> stop 5250500118, npass 3 -> 6, request_247_3, [209.19, 212.19] (arr, dep), 3.00 min, 0.00 min, customers waited 13.19 min
# 	--> stop 5250060117, npass 6 -> 5, request_231_1, [219.65, 220.65] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040208, npass 5 -> 3, request_237_2, [231.44, 233.44] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5252060138, npass 3 -> 4, request_293_1, [239.85, 240.85] (arr, dep), 1.00 min, 0.00 min, customers waited 15.85 min
# 	--> stop 5253010119, npass 4 -> 1, request_247_3, [244.03, 247.03] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5252010218, npass 1 -> 2, request_350_1, [249.90, 250.90] (arr, dep), 1.00 min, 0.00 min, customers waited 2.90 min
# 	--> stop 5252010112, npass 2 -> 6, request_309_4, [250.99, 254.99] (arr, dep), 4.00 min, 0.00 min, customers waited 19.99 min
# 	--> stop 5250720229, npass 6 -> 5, request_293_1, [266.87, 267.87] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070116, npass 5 -> 1, request_309_4, [273.89, 277.89] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5206020131, npass 1 -> 0, request_350_1, [286.58, 287.58] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010216, npass 0 -> 1, request_408_1, [291.47, 292.47] (arr, dep), 1.00 min, 0.00 min, customers waited 19.47 min
# 	--> stop 5252040211, npass 1 -> 2, request_428_1, [298.20, 299.20] (arr, dep), 1.00 min, 0.00 min, customers waited 19.20 min
# 	--> stop 5252010226, npass 2 -> 1, request_408_1, [307.81, 308.81] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500120, npass 1 -> 0, request_428_1, [325.90, 326.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070120, npass 0 -> 1, request_508_1, [334.82, 335.82] (arr, dep), 1.00 min, 0.00 min, customers waited 19.82 min
# 	--> stop 5251400213, npass 1 -> 2, request_534_1, [344.50, 345.50] (arr, dep), 1.00 min, 0.00 min, customers waited 17.50 min
# 	--> stop 5251400208, npass 2 -> 3, request_545_1, [350.38, 351.38] (arr, dep), 1.00 min, 0.00 min, customers waited 17.38 min
# 	--> stop 925114700109, npass 3 -> 2, request_508_1, [354.75, 355.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300104, npass 2 -> 3, request_567_1, [363.18, 364.18] (arr, dep), 1.00 min, 0.00 min, customers waited 17.18 min
# 	--> stop 5206020134, npass 3 -> 2, request_534_1, [373.47, 374.47] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010102, npass 2 -> 1, request_545_1, [379.68, 380.68] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010106, npass 1 -> 0, request_567_1, [386.11, 387.11] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 396.05
# 	Vehicle currently at stop 925611130111
# 	Busy time: 334.41 (79.62%), Waiting time: 61.64 (14.68%), Busy+Wait: 94.30%
# Itinerary km: 200.53, cost: 200.53
# Total customers: 21, total waiting: 277.17 min, avg: 13.20 min, stdev: 6.86 min
#
#
# {'request_011_1': {'wait': 0, 'on-board': 34.03833333333331, 'trip_kms': 21.901999999999997, 'min_kms': 8.9426}, 'request_013_1': {'wait': 12.396666666666661, 'on-board': 42.19499999999999, 'trip_kms': 25.8966, 'min_kms': 15.194799999999999}, 'request_012_1': {'wait': 18.058333333333323, 'on-board': 48.16833333333334, 'trip_kms': 30.8811, 'min_kms': 15.0562}, 'request_043_1': {'wait': 1.8533333333333246, 'on-board': 52.80000000000001, 'trip_kms': 33.918099999999995, 'min_kms': 10.6662}, 'request_037_1': {'wait': 17.579999999999984, 'on-board': 12.49666666666667, 'trip_kms': 7.6388, 'min_kms': 6.0459}, 'request_143_1': {'wait': 3.7533333333333303, 'on-board': 18.958333333333343, 'trip_kms': 9.695, 'min_kms': 1.2722}, 'request_117_4': {'wait': 19.28, 'on-board': 27.76333333333335, 'trip_kms': 17.169200000000004, 'min_kms': 9.7674}, 'request_145_1': {'wait': 14.120000000000005, 'on-board': 37.19333333333333, 'trip_kms': 21.9202, 'min_kms': 9.9427}, 'request_181_1': {'wait': 0.4233333333333462, 'on-board': 23.69666666666666, 'trip_kms': 13.362500000000002, 'min_kms': 7.1538}, 'request_237_2': {'wait': 10.313333333333333, 'on-board': 35.12833333333333, 'trip_kms': 22.75, 'min_kms': 9.1463}, 'request_231_1': {'wait': 16.92833333333334, 'on-board': 18.72333333333333, 'trip_kms': 11.522, 'min_kms': 13.83}, 'request_247_3': {'wait': 13.189999999999998, 'on-board': 34.845, 'trip_kms': 20.1034, 'min_kms': 13.7512}, 'request_293_1': {'wait': 15.84833333333333, 'on-board': 27.02000000000001, 'trip_kms': 13.065500000000002, 'min_kms': 8.439}, 'request_350_1': {'wait': 2.8983333333333405, 'on-board': 36.67999999999998, 'trip_kms': 19.8822, 'min_kms': 7.0679}, 'request_309_4': {'wait': 19.985000000000014, 'on-board': 22.906666666666638, 'trip_kms': 13.709200000000001, 'min_kms': 10.594700000000001}, 'request_408_1': {'wait': 19.468333333333305, 'on-board': 16.345000000000027, 'trip_kms': 11.798, 'min_kms': 10.747}, 'request_428_1': {'wait': 19.20333333333332, 'on-board': 27.693333333333328, 'trip_kms': 22.8369, 'min_kms': 10.9329}, 'request_508_1': {'wait': 19.816666666666663, 'on-board': 19.930000000000007, 'trip_kms': 9.904599999999999, 'min_kms': 8.5594}, 'request_534_1': {'wait': 17.50333333333333, 'on-board': 28.9616666666667, 'trip_kms': 13.0928, 'min_kms': 7.2898000000000005}, 'request_545_1': {'wait': 17.37833333333333, 'on-board': 29.29666666666668, 'trip_kms': 14.388900000000001, 'min_kms': 10.885200000000001}, 'request_567_1': {'wait': 17.176666666666677, 'on-board': 22.92833333333334, 'trip_kms': 11.5462, 'min_kms': 6.7883000000000004}}
# {'num_stops': 44, 'begin_time': 61.638333333333335, 'end_time': 396.05, 'total_time': 420, 'busy_time': 334.4116666666667, 'wait_time': 61.63833333333335, 'busy_percent': 79.62182539682541, 'wait_percent': 14.675793650793656, 'usage_percent': 94.29761904761907, 'itinerary_kms': 200.52830000000003, 'cost': 200.52830000000003, 'total_requests': 21, 'total_wait': 277.17499999999995, 'avg_wait': 13.19880952380952, 'std_wait': 6.86268878736973}
# Vehicle with ID veh_06_925611130111 has 48 stops scheduled
# 	Departure from stop 925611130111 at time 62.64
# 	--> stop 5251310103, npass 0 -> 1, request_014_1, [72.00, 73.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250060121, npass 1 -> 4, request_015_3, [88.74, 91.74] (arr, dep), 3.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501650202, npass 4 -> 3, request_014_1, [107.89, 108.89] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 4, request_059_1, [110.38, 111.38] (arr, dep), 1.00 min, 0.00 min, customers waited 15.38 min
# 	--> stop 5252010204, npass 4 -> 1, request_015_3, [122.03, 125.03] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5206020127, npass 1 -> 2, request_087_1, [128.44, 129.44] (arr, dep), 1.00 min, 0.00 min, customers waited 17.44 min
# 	--> stop 5252060139, npass 2 -> 3, request_123_1, [138.22, 139.22] (arr, dep), 1.00 min, 0.00 min, customers waited 4.22 min
# 	--> stop 5252060209, npass 3 -> 2, request_059_1, [140.91, 141.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700110, npass 2 -> 1, request_087_1, [157.32, 158.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060125, npass 1 -> 3, request_161_2, [167.20, 169.20] (arr, dep), 2.00 min, 0.00 min, customers waited 17.20 min
# 	--> stop 5256120208, npass 3 -> 2, request_123_1, [183.90, 184.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010115, npass 2 -> 3, request_222_1, [195.93, 196.93] (arr, dep), 1.00 min, 0.00 min, customers waited 16.93 min
# 	--> stop 5252010110, npass 3 -> 1, request_161_2, [201.33, 203.33] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010117, npass 1 -> 4, request_253_3, [208.62, 211.62] (arr, dep), 3.00 min, 0.00 min, customers waited 8.62 min
# 	--> stop 5252060137, npass 4 -> 5, request_274_1, [214.42, 215.42] (arr, dep), 1.00 min, 0.00 min, customers waited 1.42 min
# 	--> stop 925217900103, npass 5 -> 6, request_248_1, [216.04, 217.04] (arr, dep), 1.00 min, 0.00 min, customers waited 19.04 min
# 	--> stop 5250060111, npass 6 -> 5, request_248_1, [225.91, 226.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060112, npass 5 -> 4, request_222_1, [228.23, 229.23] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600209, npass 4 -> 5, request_285_1, [232.20, 233.20] (arr, dep), 1.00 min, 0.00 min, customers waited 14.20 min
# 	--> stop 5250070106, npass 5 -> 2, request_253_3, [236.36, 239.36] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250060218, npass 2 -> 1, request_285_1, [243.71, 244.71] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600218, npass 1 -> 2, request_333_1, [252.87, 253.87] (arr, dep), 1.00 min, 0.00 min, customers waited 12.87 min
# 	--> stop 5206020128, npass 2 -> 1, request_274_1, [255.01, 256.01] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600108, npass 1 -> 2, request_338_1, [257.89, 258.89] (arr, dep), 1.00 min, 0.00 min, customers waited 16.89 min
# 	--> stop 5250600217, npass 2 -> 1, request_333_1, [260.78, 261.78] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020134, npass 1 -> 2, request_352_1, [265.37, 266.37] (arr, dep), 1.00 min, 0.00 min, customers waited 17.37 min
# 	--> stop 5252040139, npass 2 -> 1, request_352_1, [271.02, 272.02] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010124, npass 1 -> 2, request_395_1, [273.41, 274.41] (arr, dep), 1.00 min, 0.00 min, customers waited 6.41 min
# 	--> stop 5252060142, npass 2 -> 1, request_338_1, [280.32, 281.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010108, npass 1 -> 2, request_390_1, [284.26, 285.26] (arr, dep), 1.00 min, 0.00 min, customers waited 19.26 min
# 	--> stop 92571910204, npass 2 -> 3, request_439_1, [291.36, 292.36] (arr, dep), 1.00 min, 0.00 min, customers waited 6.36 min
# 	--> stop 5256120202, npass 3 -> 2, request_395_1, [298.25, 299.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120202, npass 2 -> 1, request_390_1, [299.25, 300.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020133, npass 1 -> 2, request_445_1, [305.52, 306.52] (arr, dep), 1.00 min, 0.00 min, customers waited 17.52 min
# 	--> stop 925114220110, npass 2 -> 1, request_445_1, [313.26, 314.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300104, npass 1 -> 2, request_473_1, [316.54, 317.54] (arr, dep), 1.00 min, 0.00 min, customers waited 19.54 min
# 	--> stop 5251300104, npass 2 -> 4, request_511_2, [317.54, 319.54] (arr, dep), 2.00 min, 0.00 min, customers waited 2.54 min
# 	--> stop 5251400123, npass 4 -> 3, request_439_1, [328.62, 329.62] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400119, npass 3 -> 4, request_519_1, [335.21, 336.21] (arr, dep), 1.00 min, 0.00 min, customers waited 15.21 min
# 	--> stop 92501650104, npass 4 -> 3, request_473_1, [341.54, 342.54] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114800112, npass 3 -> 2, request_519_1, [352.75, 353.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252060138, npass 2 -> 0, request_511_2, [369.90, 371.90] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 925218000218, npass 0 -> 1, request_589_1, [374.66, 375.66] (arr, dep), 1.00 min, 0.00 min, customers waited 16.66 min
# 	--> stop 5252010123, npass 1 -> 2, request_592_1, [377.83, 378.83] (arr, dep), 1.00 min, 0.00 min, customers waited 17.83 min
# 	--> stop 5253010218, npass 2 -> 1, request_589_1, [383.45, 384.45] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92571910203, npass 1 -> 0, request_592_1, [386.12, 387.12] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 398.82
# 	Vehicle currently at stop 925611130111
# 	Busy time: 336.18 (80.04%), Waiting time: 62.64 (14.91%), Busy+Wait: 94.96%
# Itinerary km: 202.38, cost: 202.38
# Total customers: 23, total waiting: 299.64 min, avg: 13.03 min, stdev: 6.20 min
#
#
# ...
# 	--> stop 5251310216, npass 1 -> 2, request_506_1, [323.87, 324.87] (arr, dep), 1.00 min, 0.00 min, customers waited 9.87 min
# 	--> stop 5107510108, npass 2 -> 1, request_423_1, [335.26, 336.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92571910124, npass 1 -> 3, request_530_2, [338.82, 340.82] (arr, dep), 2.00 min, 0.00 min, customers waited 13.82 min
# 	--> stop 92571910124, npass 3 -> 4, request_529_1, [340.82, 341.82] (arr, dep), 1.00 min, 0.00 min, customers waited 17.82 min
# 	--> stop 5252040138, npass 4 -> 2, request_530_2, [346.43, 348.43] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5206020205, npass 2 -> 4, request_549_2, [351.21, 353.21] (arr, dep), 2.00 min, 0.00 min, customers waited 17.21 min
# 	--> stop 5254010109, npass 4 -> 2, request_549_2, [362.24, 364.24] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720219, npass 2 -> 1, request_506_1, [373.68, 374.68] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020117, npass 1 -> 0, request_529_1, [379.97, 380.97] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 5254010218 at time 392.03
# 	Vehicle currently at stop 5254010218
# 	Busy time: 319.74 (76.13%), Waiting time: 72.29 (17.21%), Busy+Wait: 93.34%
# Itinerary km: 214.54, cost: 214.54
# Total customers: 18, total waiting: 273.41 min, avg: 15.19 min, stdev: 4.92 min
#
#
# {'request_049_1': {'wait': 0, 'on-board': 37.21333333333334, 'trip_kms': 27.386699999999998, 'min_kms': 5.3437}, 'request_054_1': {'wait': 13.928333333333342, 'on-board': 37.261666666666656, 'trip_kms': 22.364600000000003, 'min_kms': 12.337299999999999}, 'request_052_1': {'wait': 15.515000000000015, 'on-board': 37.958333333333314, 'trip_kms': 22.6934, 'min_kms': 12.44}, 'request_071_1': {'wait': 15.308333333333351, 'on-board': 18.564999999999984, 'trip_kms': 10.9662, 'min_kms': 9.0144}, 'request_130_1': {'wait': 18.546666666666653, 'on-board': 24.636666666666684, 'trip_kms': 18.373600000000003, 'min_kms': 16.2375}, 'request_154_1': {'wait': 12.824999999999989, 'on-board': 48.81666666666666, 'trip_kms': 36.602000000000004, 'min_kms': 11.617899999999999}, 'request_178_1': {'wait': 18.944999999999993, 'on-board': 16.064999999999998, 'trip_kms': 11.930000000000001, 'min_kms': 11.9299}, 'request_272_1': {'wait': 19.783333333333303, 'on-board': 25.181666666666672, 'trip_kms': 16.7277, 'min_kms': 9.2921}, 'request_289_1': {'wait': 19.896666666666647, 'on-board': 28.846666666666692, 'trip_kms': 18.7969, 'min_kms': 10.2553}, 'request_353_1': {'wait': 9.218333333333305, 'on-board': 21.058333333333394, 'trip_kms': 11.932599999999999, 'min_kms': 3.418}, 'request_334_3': {'wait': 18.625, 'on-board': 32.06666666666672, 'trip_kms': 21.5038, 'min_kms': 11.595600000000001}, 'request_423_1': {'wait': 19.388333333333378, 'on-board': 38.87333333333328, 'trip_kms': 21.3478, 'min_kms': 13.5341}, 'request_431_1': {'wait': 19.505000000000052, 'on-board': 18.67666666666662, 'trip_kms': 9.8111, 'min_kms': 4.8423}, 'request_448_1': {'wait': 13.211666666666702, 'on-board': 9.319999999999993, 'trip_kms': 5.3968, 'min_kms': 5.3968}, 'request_506_1': {'wait': 9.870000000000005, 'on-board': 49.81, 'trip_kms': 30.580299999999998, 'min_kms': 16.2731}, 'request_530_2': {'wait': 13.816666666666663, 'on-board': 7.611666666666679, 'trip_kms': 3.2986, 'min_kms': 3.2986}, 'request_529_1': {'wait': 17.816666666666663, 'on-board': 39.150000000000034, 'trip_kms': 24.946399999999997, 'min_kms': 16.1528}, 'request_549_2': {'wait': 17.2116666666667, 'on-board': 11.028333333333308, 'trip_kms': 8.135, 'min_kms': 8.135}}
# {'num_stops': 38, 'begin_time': 72.29333333333334, 'end_time': 392.03000000000003, 'total_time': 420, 'busy_time': 319.73666666666674, 'wait_time': 72.29333333333332, 'busy_percent': 76.1277777777778, 'wait_percent': 17.21269841269841, 'usage_percent': 93.34047619047621, 'itinerary_kms': 214.53799999999998, 'cost': 214.53799999999998, 'total_requests': 18, 'total_wait': 273.41166666666675, 'avg_wait': 15.189537037037042, 'std_wait': 4.9185218347336574}
# Vehicle with ID veh_20_5254010218 has 42 stops scheduled
# 	Departure from stop 5254010218 at time 82.02
# 	--> stop 5250070217, npass 0 -> 1, request_050_1, [92.00, 93.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250610128, npass 1 -> 0, request_050_1, [95.63, 96.63] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600111, npass 0 -> 1, request_062_1, [102.32, 103.32] (arr, dep), 1.00 min, 0.00 min, customers waited 5.32 min
# 	--> stop 5253010112, npass 1 -> 0, request_062_1, [111.79, 112.79] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010113, npass 0 -> 1, request_056_1, [113.10, 114.10] (arr, dep), 1.00 min, 0.00 min, customers waited 19.10 min
# 	--> stop 5252060140, npass 1 -> 2, request_075_1, [115.22, 116.22] (arr, dep), 1.00 min, 0.00 min, customers waited 10.22 min
# 	--> stop 5253010202, npass 2 -> 3, request_074_1, [117.34, 118.34] (arr, dep), 1.00 min, 0.00 min, customers waited 13.34 min
# 	--> stop 5252010226, npass 3 -> 5, request_091_2, [124.51, 126.51] (arr, dep), 2.00 min, -0.00 min, customers waited 11.51 min
# 	--> stop 925217900218, npass 5 -> 4, request_075_1, [133.83, 134.83] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060102, npass 4 -> 3, request_056_1, [146.05, 147.05] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720220, npass 3 -> 1, request_091_2, [151.50, 153.50] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720121, npass 1 -> 0, request_074_1, [156.44, 157.44] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720218, npass 0 -> 1, request_147_1, [162.59, 163.59] (arr, dep), 1.00 min, 0.00 min, customers waited 18.59 min
# 	--> stop 5250070116, npass 1 -> 4, request_168_3, [171.55, 174.55] (arr, dep), 3.00 min, 0.00 min, customers waited 17.55 min
# 	--> stop 5250500122, npass 4 -> 3, request_147_1, [183.62, 184.62] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010119, npass 3 -> 0, request_168_3, [199.62, 202.62] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5252010214, npass 0 -> 1, request_241_1, [206.73, 207.73] (arr, dep), 1.00 min, 0.00 min, customers waited 16.73 min
# 	--> stop 92501500101, npass 1 -> 2, request_249_1, [216.11, 217.11] (arr, dep), 1.00 min, 0.00 min, customers waited 18.11 min
# 	--> stop 5403110202, npass 2 -> 3, request_277_1, [220.25, 221.25] (arr, dep), 1.00 min, 0.00 min, customers waited 4.25 min
# 	--> stop 925918510213, npass 3 -> 2, request_277_1, [222.92, 223.92] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060124, npass 2 -> 1, request_249_1, [233.77, 234.77] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060205, npass 1 -> 2, request_315_1, [236.33, 237.33] (arr, dep), 1.00 min, 0.00 min, customers waited 2.33 min
# 	--> stop 5250060119, npass 2 -> 1, request_241_1, [239.85, 240.85] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060122, npass 1 -> 2, request_319_1, [246.94, 247.94] (arr, dep), 1.00 min, 0.00 min, customers waited 10.94 min
# 	--> stop 5250600217, npass 2 -> 5, request_317_3, [254.01, 257.01] (arr, dep), 3.00 min, 0.00 min, customers waited 19.01 min
# 	--> stop 5206020133, npass 5 -> 2, request_317_3, [261.18, 264.18] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5402010115, npass 2 -> 6, request_349_4, [265.75, 269.75] (arr, dep), 4.00 min, 0.00 min, customers waited 18.75 min
# 	--> stop 5256120116, npass 6 -> 5, request_315_1, [274.36, 275.36] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120206, npass 5 -> 4, request_319_1, [276.27, 277.27] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060126, npass 4 -> 0, request_349_4, [292.00, 296.00] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 92501620108, npass 0 -> 4, request_425_4, [297.30, 301.30] (arr, dep), 4.00 min, 0.00 min, customers waited 19.30 min
# 	--> stop 5250600108, npass 4 -> 5, request_492_1, [309.89, 310.89] (arr, dep), 1.00 min, 0.00 min, customers waited 1.89 min
# 	--> stop 5250500107, npass 5 -> 6, request_461_1, [311.49, 312.49] (arr, dep), 1.00 min, 0.00 min, customers waited 18.49 min
# 	--> stop 5253010113, npass 6 -> 2, request_425_4, [321.13, 325.13] (arr, dep), 4.00 min, -0.00 min
# 	--> stop 5250060217, npass 2 -> 1, request_492_1, [336.22, 337.22] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710130, npass 1 -> 0, request_461_1, [345.88, 346.88] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020118, npass 0 -> 1, request_551_1, [350.37, 351.37] (arr, dep), 1.00 min, 0.00 min, customers waited 15.37 min
# 	--> stop 5252060208, npass 1 -> 6, request_568_5, [365.47, 370.47] (arr, dep), 5.00 min, 0.00 min, customers waited 19.47 min
# 	--> stop 5252020202, npass 6 -> 5, request_551_1, [378.11, 379.11] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114800114, npass 5 -> 0, request_568_5, [392.89, 397.89] (arr, dep), 5.00 min, 0.00 min
# 	End in stop 5254010218 at time 413.36
# 	Vehicle currently at stop 5254010218
# 	Busy time: 331.34 (78.89%), Waiting time: 82.02 (19.53%), Busy+Wait: 98.42%
# Itinerary km: 197.36, cost: 197.36
# Total customers: 20, total waiting: 260.28 min, avg: 13.01 min, stdev: 6.60 min
#
#
# {'request_050_1': {'wait': 0, 'on-board': 3.6316666666666606, 'trip_kms': 1.4062000000000001, 'min_kms': 1.4062000000000001}, 'request_062_1': {'wait': 5.319999999999993, 'on-board': 9.469999999999999, 'trip_kms': 7.168399999999999, 'min_kms': 7.168399999999999}, 'request_056_1': {'wait': 19.103333333333325, 'on-board': 32.94333333333333, 'trip_kms': 19.2888, 'min_kms': 10.8542}, 'request_075_1': {'wait': 10.216666666666654, 'on-board': 18.618333333333325, 'trip_kms': 10.504, 'min_kms': 4.0353}, 'request_074_1': {'wait': 13.338333333333324, 'on-board': 39.101666666666674, 'trip_kms': 22.3048, 'min_kms': 9.3505}, 'request_091_2': {'wait': 11.509999999999991, 'on-board': 26.995000000000005, 'trip_kms': 16.3837, 'min_kms': 9.884799999999998}, 'request_147_1': {'wait': 18.593333333333334, 'on-board': 21.025000000000006, 'trip_kms': 13.079699999999999, 'min_kms': 11.979299999999999}, 'request_168_3': {'wait': 17.548333333333346, 'on-board': 28.073333333333323, 'trip_kms': 22.1201, 'min_kms': 11.2395}, 'request_241_1': {'wait': 16.72999999999999, 'on-board': 33.12166666666664, 'trip_kms': 17.7831, 'min_kms': 11.2079}, 'request_249_1': {'wait': 18.11499999999998, 'on-board': 17.654999999999973, 'trip_kms': 10.1613, 'min_kms': 8.193200000000001}, 'request_277_1': {'wait': 4.251666666666637, 'on-board': 2.666666666666657, 'trip_kms': 0.9666, 'min_kms': 0.9666}, 'request_315_1': {'wait': 2.331666666666621, 'on-board': 38.03000000000006, 'trip_kms': 17.3489, 'min_kms': 10.0155}, 'request_319_1': {'wait': 10.941666666666634, 'on-board': 29.328333333333404, 'trip_kms': 12.850499999999998, 'min_kms': 10.6199}, 'request_317_3': {'wait': 19.011666666666628, 'on-board': 7.166666666666686, 'trip_kms': 3.1766, 'min_kms': 3.1766}, 'request_349_4': {'wait': 18.75, 'on-board': 26.253333333333387, 'trip_kms': 15.678, 'min_kms': 7.477}, 'request_425_4': {'wait': 19.3033333333334, 'on-board': 23.823333333333323, 'trip_kms': 14.0171, 'min_kms': 11.8043}, 'request_492_1': {'wait': 1.888333333333378, 'on-board': 26.33166666666665, 'trip_kms': 17.095100000000002, 'min_kms': 8.7676}, 'request_461_1': {'wait': 18.49166666666673, 'on-board': 34.38333333333327, 'trip_kms': 23.2335, 'min_kms': 11.6761}, 'request_551_1': {'wait': 15.365000000000009, 'on-board': 27.748333333333335, 'trip_kms': 16.069, 'min_kms': 12.911299999999999}, 'request_568_5': {'wait': 19.470000000000027, 'on-board': 27.41666666666663, 'trip_kms': 16.2025, 'min_kms': 13.9588}}
# {'num_stops': 42, 'begin_time': 82.02333333333334, 'end_time': 413.35833333333335, 'total_time': 420, 'busy_time': 331.33500000000004, 'wait_time': 82.0233333333333, 'busy_percent': 78.88928571428573, 'wait_percent': 19.52936507936507, 'usage_percent': 98.4186507936508, 'itinerary_kms': 197.35599999999994, 'cost': 197.35599999999994, 'total_requests': 20, 'total_wait': 260.28, 'avg_wait': 13.014, 'std_wait': 6.602875244921722}
# Scheduled requests: 411, Accepted rate: 68.50%
# Rejected requests: 189, 31.50%
# Customer waiting time: Sum of waitings: 5605.95 min, avg: 13.64 min, std: 6.23 min
#
# 68.50	13.64	6.23
# {'total_requests': 600, 'scheduled_requests': 411, 'scheduled_percent': 68.5, 'rejected_requests': 189, 'rejected_percent': 31.5, 'total_cost': 4006.9077999999995, 'total_kms': 4006.9077999999995, 'num_vehicles': 20, 'vehicle_stats': {'veh_01_925113110225': {'num_stops': 52, 'begin_time': 63.96333333333333, 'end_time': 424.06166666666667, 'total_time': 420, 'busy_time': 360.0033333333333, 'wait_time': 64.05833333333334, 'busy_percent': 85.71507936507935, 'wait_percent': 15.251984126984128, 'usage_percent': 100.96706349206347, 'itinerary_kms': 208.55880000000002, 'cost': 208.55880000000002, 'total_requests': 25, 'total_wait': 348.8733333333335, 'avg_wait': 13.95493333333334, 'std_wait': 6.381488932494951, 'customer_stats': {'request_002_1': {'wait': 0, 'on-board': 2.7633333333333354, 'trip_kms': 1.441, 'min_kms': 1.441}, 'request_001_1': {'wait': 10.663333333333341, 'on-board': 38.599999999999994, 'trip_kms': 22.2201, 'min_kms': 11.1319}, 'request_003_2': {'wait': 18.79166666666667, 'on-board': 11.381666666666675, 'trip_kms': 5.3177, 'min_kms': 4.1061000000000005}, 'request_021_1': {'wait': 11.631666666666675, 'on-board': 20.625, 'trip_kms': 13.4997, 'min_kms': 8.312299999999999}, 'request_068_2': {'wait': 18.980000000000004, 'on-board': 20.83333333333333, 'trip_kms': 15.234300000000001, 'min_kms': 14.3408}, 'request_097_1': {'wait': 14.525000000000006, 'on-board': 29.043333333333322, 'trip_kms': 18.512900000000002, 'min_kms': 7.2163}, 'request_155_1': {'wait': 0, 'on-board': 39.16833333333332, 'trip_kms': 21.179199999999998, 'min_kms': 7.0262}, 'request_175_1': {'wait': 7.661666666666662, 'on-board': 39.383333333333326, 'trip_kms': 21.6827, 'min_kms': 7.421}, 'request_179_1': {'wait': 13.47666666666666, 'on-board': 17.931666666666672, 'trip_kms': 9.831199999999999, 'min_kms': 7.4684}, 'request_185_1': {'wait': 19.095, 'on-board': 30.758333333333326, 'trip_kms': 17.7209, 'min_kms': 10.4904}, 'request_244_1': {'wait': 5.50333333333333, 'on-board': 28.359999999999985, 'trip_kms': 14.8304, 'min_kms': 5.0297}, 'request_255_5': {'wait': 18.863333333333316, 'on-board': 26.468333333333334, 'trip_kms': 14.4844, 'min_kms': 11.5311}, 'request_296_1': {'wait': 17.676666666666648, 'on-board': 37.393333333333345, 'trip_kms': 19.1912, 'min_kms': 16.6616}, 'request_318_2': {'wait': 19.59499999999997, 'on-board': 40.62666666666672, 'trip_kms': 27.049299999999995, 'min_kms': 16.6756}, 'request_337_1': {'wait': 19.569999999999993, 'on-board': 25.23333333333335, 'trip_kms': 17.248299999999997, 'min_kms': 16.8191}, 'request_374_1': {'wait': 19.33499999999998, 'on-board': 30.091666666666697, 'trip_kms': 17.5449, 'min_kms': 10.3446}, 'request_459_1': {'wait': 16.906666666666695, 'on-board': 21.07833333333332, 'trip_kms': 9.5793, 'min_kms': 5.206600000000001}, 'request_483_1': {'wait': 10.098333333333358, 'on-board': 10.2233333333333, 'trip_kms': 2.6517, 'min_kms': 2.5542}, 'request_464_3': {'wait': 18.73666666666668, 'on-board': 24.426666666666677, 'trip_kms': 12.3263, 'min_kms': 8.62}, 'request_496_2': {'wait': 11.321666666666658, 'on-board': 32.71833333333336, 'trip_kms': 17.2833, 'min_kms': 11.6253}, 'request_542_1': {'wait': 1.7100000000000364, 'on-board': 30.76666666666665, 'trip_kms': 15.7257, 'min_kms': 5.505}, 'request_535_1': {'wait': 18.89166666666671, 'on-board': 8.781666666666638, 'trip_kms': 3.9259999999999997, 'min_kms': 2.7105}, 'request_581_1': {'wait': 19.885000000000048, 'on-board': 25.55166666666662, 'trip_kms': 14.9101, 'min_kms': 9.7023}, 'request_590_1': {'wait': 18.343333333333362, 'on-board': 13.449999999999989, 'trip_kms': 7.4441999999999995, 'min_kms': 4.140899999999999}, 'request_597_3': {'wait': 17.61166666666668, 'on-board': 28.71333333333331, 'trip_kms': 18.881, 'min_kms': 12.243}}}, 'veh_02_925113110225': {'num_stops': 52, 'begin_time': 53.11833333333333, 'end_time': 390.95333333333343, 'total_time': 420, 'busy_time': 337.4216666666667, 'wait_time': 53.53166666666666, 'busy_percent': 80.33849206349205, 'wait_percent':  ...

# %%
for i in sche.itineraries:
    print(i.to_string())
# Out:
# Vehicle with ID veh_01_925113110225 has 52 stops scheduled
# 	Departure from stop 925113110225 at time 63.96
# 	--> stop 5250500102, npass 0 -> 1, request_002_1, [65.00, 66.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040204, npass 1 -> 0, request_002_1, [67.76, 68.76] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010214, npass 0 -> 1, request_001_1, [75.66, 76.66] (arr, dep), 1.00 min, 0.00 min, customers waited 10.66 min
# 	--> stop 5252020202, npass 1 -> 3, request_003_2, [83.79, 85.79] (arr, dep), 2.00 min, 0.00 min, customers waited 18.79 min
# 	--> stop 5403110202, npass 3 -> 4, request_021_1, [88.63, 89.63] (arr, dep), 1.00 min, 0.00 min, customers waited 11.63 min
# 	--> stop 5904210202, npass 4 -> 2, request_003_2, [95.17, 97.17] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 92501650201, npass 2 -> 1, request_021_1, [109.26, 110.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400112, npass 1 -> 0, request_001_1, [114.26, 115.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300111, npass 0 -> 2, request_068_2, [120.98, 122.98] (arr, dep), 2.00 min, 0.00 min, customers waited 18.98 min
# 	--> stop 5254020107, npass 2 -> 3, request_097_1, [132.53, 133.53] (arr, dep), 1.00 min, 0.00 min, customers waited 14.53 min
# 	--> stop 5250060205, npass 3 -> 1, request_068_2, [141.81, 143.91] (arr, dep), 2.09 min, 0.09 min
# 	--> stop 5250600110, npass 1 -> 2, request_155_1, [150.00, 151.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5251300107, npass 2 -> 1, request_097_1, [161.57, 162.57] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300103, npass 1 -> 2, request_175_1, [166.66, 167.66] (arr, dep), 1.00 min, 0.00 min, customers waited 7.66 min
# 	--> stop 5201110204, npass 2 -> 3, request_179_1, [174.48, 175.48] (arr, dep), 1.00 min, 0.00 min, customers waited 13.48 min
# 	--> stop 5251400214, npass 3 -> 4, request_185_1, [182.09, 183.09] (arr, dep), 1.00 min, 0.00 min, customers waited 19.09 min
# 	--> stop 5250500121, npass 4 -> 3, request_155_1, [189.17, 190.17] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500118, npass 3 -> 2, request_179_1, [192.41, 193.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500112, npass 2 -> 3, request_244_1, [198.50, 199.50] (arr, dep), 1.00 min, 0.00 min, customers waited 5.50 min
# 	--> stop 5252010127, npass 3 -> 2, request_175_1, [206.04, 207.04] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010105, npass 2 -> 1, request_185_1, [212.85, 213.85] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040137, npass 1 -> 6, request_255_5, [221.86, 226.86] (arr, dep), 5.00 min, 0.00 min, customers waited 18.86 min
# 	--> stop 5252040137, npass 6 -> 5, request_244_1, [226.86, 227.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700112, npass 5 -> 6, request_296_1, [243.68, 244.68] (arr, dep), 1.00 min, 0.00 min, customers waited 17.68 min
# 	--> stop 925114700202, npass 6 -> 1, request_255_5, [248.33, 253.33] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 925114700206, npass 1 -> 3, request_318_2, [255.59, 257.59] (arr, dep), 2.00 min, 0.00 min, customers waited 19.59 min
# 	--> stop 5251400120, npass 3 -> 4, request_337_1, [260.57, 261.57] (arr, dep), 1.00 min, 0.00 min, customers waited 19.57 min
# 	--> stop 5250720229, npass 4 -> 5, request_374_1, [276.33, 277.33] (arr, dep), 1.00 min, 0.00 min, customers waited 19.33 min
# 	--> stop 5206020118, npass 5 -> 4, request_296_1, [281.07, 282.07] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060103, npass 4 -> 3, request_337_1, [285.80, 286.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010107, npass 3 -> 1, request_318_2, [296.22, 298.22] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010209, npass 1 -> 0, request_374_1, [306.43, 307.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010117, npass 0 -> 1, request_459_1, [309.91, 310.91] (arr, dep), 1.00 min, 0.00 min, customers waited 16.91 min
# 	--> stop 5253010204, npass 1 -> 2, request_483_1, [312.10, 313.10] (arr, dep), 1.00 min, 0.00 min, customers waited 10.10 min
# 	--> stop 5252060140, npass 2 -> 5, request_464_3, [313.74, 316.74] (arr, dep), 3.00 min, 0.00 min, customers waited 18.74 min
# 	--> stop 5252010111, npass 5 -> 7, request_496_2, [320.32, 322.32] (arr, dep), 2.00 min, 0.00 min, customers waited 11.32 min
# 	--> stop 5252010111, npass 7 -> 6, request_483_1, [322.32, 323.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010205, npass 6 -> 5, request_459_1, [330.99, 331.99] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040140, npass 5 -> 6, request_542_1, [332.71, 333.71] (arr, dep), 1.00 min, 0.00 min, customers waited 1.71 min
# 	--> stop 5254020107, npass 6 -> 3, request_464_3, [338.16, 341.16] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5256120203, npass 3 -> 4, request_535_1, [346.89, 347.89] (arr, dep), 1.00 min, 0.00 min, customers waited 18.89 min
# 	--> stop 5904210201, npass 4 -> 2, request_496_2, [353.04, 355.04] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5256120209, npass 2 -> 1, request_535_1, [355.67, 356.67] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130106, npass 1 -> 0, request_542_1, [363.48, 364.48] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040207, npass 0 -> 1, request_581_1, [372.89, 373.89] (arr, dep), 1.00 min, 0.00 min, customers waited 19.89 min
# 	--> stop 5206020205, npass 1 -> 2, request_590_1, [376.34, 377.34] (arr, dep), 1.00 min, 0.00 min, customers waited 18.34 min
# 	--> stop 5252010122, npass 2 -> 5, request_597_3, [380.61, 383.61] (arr, dep), 3.00 min, 0.00 min, customers waited 17.61 min
# 	--> stop 5201110120, npass 5 -> 4, request_590_1, [389.79, 390.79] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 4 -> 3, request_581_1, [398.44, 399.44] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500124, npass 3 -> 0, request_597_3, [409.32, 412.32] (arr, dep), 3.00 min, 0.00 min
# 	End in stop 925113110225 at time 424.06
# 	Vehicle currently at stop 925113110225
# 	Busy time: 360.00 (85.72%), Waiting time: 64.06 (15.25%), Busy+Wait: 100.97%
# Itinerary km: 208.56, cost: 208.56
# Total customers: 25, total waiting: 348.87 min, avg: 13.95 min, stdev: 6.38 min
#
# Vehicle with ID veh_02_925113110225 has 52 stops scheduled
# 	Departure from stop 925113110225 at time 53.12
# 	--> stop 5251400206, npass 0 -> 2, request_005_2, [67.00, 69.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5251400210, npass 2 -> 3, request_006_1, [72.16, 73.16] (arr, dep), 1.00 min, 0.00 min, customers waited 5.16 min
# 	--> stop 5250740213, npass 3 -> 5, request_004_2, [83.62, 85.62] (arr, dep), 2.00 min, 0.00 min, customers waited 17.62 min
# 	--> stop 5250500208, npass 5 -> 4, request_006_1, [93.56, 94.56] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 4 -> 5, request_064_1, [102.94, 103.94] (arr, dep), 1.00 min, 0.00 min, customers waited 3.94 min
# 	--> stop 5259030211, npass 5 -> 3, request_004_2, [107.63, 109.63] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010106, npass 3 -> 5, request_053_2, [112.91, 114.91] (arr, dep), 2.00 min, 0.00 min, customers waited 19.91 min
# 	--> stop 5250060218, npass 5 -> 4, request_064_1, [126.13, 127.13] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710202, npass 4 -> 2, request_005_2, [137.81, 139.81] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250710130, npass 2 -> 0, request_053_2, [141.89, 143.89] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250710128, npass 0 -> 1, request_111_1, [146.79, 147.79] (arr, dep), 1.00 min, 0.00 min, customers waited 19.79 min
# 	--> stop 5250720121, npass 1 -> 2, request_126_1, [153.04, 154.04] (arr, dep), 1.00 min, 0.00 min, customers waited 17.04 min
# 	--> stop 5250720229, npass 2 -> 3, request_157_1, [154.81, 155.81] (arr, dep), 1.00 min, 0.00 min, customers waited 4.81 min
# 	--> stop 5250720128, npass 3 -> 2, request_126_1, [157.18, 158.18] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600115, npass 2 -> 3, request_174_1, [165.19, 166.19] (arr, dep), 1.00 min, 0.00 min, customers waited 7.19 min
# 	--> stop 5250600111, npass 3 -> 4, request_156_1, [168.41, 169.41] (arr, dep), 1.00 min, 0.00 min, customers waited 18.41 min
# 	--> stop 5250070121, npass 4 -> 3, request_157_1, [170.06, 171.06] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040137, npass 3 -> 4, request_193_1, [177.03, 178.03] (arr, dep), 1.00 min, 0.00 min, customers waited 12.03 min
# 	--> stop 5252040136, npass 4 -> 3, request_111_1, [179.41, 180.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010122, npass 3 -> 2, request_174_1, [182.52, 183.52] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010207, npass 2 -> 3, request_229_1, [184.20, 185.20] (arr, dep), 1.00 min, 0.00 min, customers waited 1.20 min
# 	--> stop 5259030211, npass 3 -> 2, request_156_1, [186.46, 187.46] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925218000218, npass 2 -> 1, request_193_1, [191.80, 192.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020132, npass 1 -> 2, request_224_1, [198.52, 199.52] (arr, dep), 1.00 min, 0.00 min, customers waited 18.52 min
# 	--> stop 5252020202, npass 2 -> 5, request_250_3, [202.95, 205.95] (arr, dep), 3.00 min, 0.00 min, customers waited 3.95 min
# 	--> stop 5253010219, npass 5 -> 4, request_229_1, [209.34, 210.34] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010209, npass 4 -> 3, request_224_1, [216.96, 217.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010119, npass 3 -> 4, request_264_1, [221.74, 223.15] (arr, dep), 1.41 min, 0.41 min, customers waited 15.74 min
# 	--> stop 5252040210, npass 4 -> 5, request_299_1, [227.00, 228.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925218210235, npass 5 -> 4, request_264_1, [228.47, 229.47] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500118, npass 4 -> 5, request_297_1, [240.80, 241.80] (arr, dep), 1.00 min, 0.00 min, customers waited 13.80 min
# 	--> stop 5250060127, npass 5 -> 2, request_250_3, [242.98, 245.98] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5254020227, npass 2 -> 3, request_306_1, [247.37, 248.37] (arr, dep), 1.00 min, 0.00 min, customers waited 18.37 min
# 	--> stop 5251400115, npass 3 -> 2, request_306_1, [256.02, 257.02] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92501650109, npass 2 -> 1, request_299_1, [261.28, 262.28] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 2, request_344_1, [263.52, 264.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5256120113, npass 2 -> 1, request_297_1, [277.22, 278.22] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010106, npass 1 -> 2, request_400_1, [280.22, 281.22] (arr, dep), 1.00 min, 0.00 min, customers waited 11.22 min
# 	--> stop 5250750108, npass 2 -> 1, request_344_1, [296.35, 297.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020127, npass 1 -> 2, request_442_1, [304.88, 305.88] (arr, dep), 1.00 min, 0.00 min, customers waited 17.88 min
# 	--> stop 925114100204, npass 2 -> 1, request_400_1, [314.42, 315.42] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100116, npass 1 -> 4, request_486_3, [315.54, 318.54] (arr, dep), 3.00 min, 0.00 min, customers waited 11.54 min
# 	--> stop 925114800115, npass 4 -> 7, request_501_3, [325.01, 328.01] (arr, dep), 3.00 min, 0.00 min, customers waited 13.01 min
# 	--> stop 5251400118, npass 7 -> 6, request_442_1, [330.19, 331.19] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254010109, npass 6 -> 3, request_486_3, [340.26, 343.26] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500117, npass 3 -> 0, request_501_3, [349.30, 352.30] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500122, npass 0 -> 1, request_552_1, [355.48, 356.48] (arr, dep), 1.00 min, 0.00 min, customers waited 19.48 min
# 	--> stop 5254010108, npass 1 -> 4, request_593_3, [361.08, 364.08] (arr, dep), 3.00 min, 0.00 min, customers waited 1.08 min
# 	--> stop 5250060119, npass 4 -> 3, request_552_1, [369.57, 370.57] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060117, npass 3 -> 0, request_593_3, [377.05, 380.05] (arr, dep), 3.00 min, 0.00 min
# 	End in stop 925113110225 at time 390.95
# 	Vehicle currently at stop 925113110225
# 	Busy time: 337.42 (80.34%), Waiting time: 53.53 (12.75%), Busy+Wait: 93.08%
# Itinerary km: 190.52, cost: 190.52
# Total customers: 25, total waiting: 291.20 min, avg: 11.65 min, stdev: 7.05 min
#
# Vehicle with ID veh_03_925113110225 has 40 stops scheduled
# 	Departure from stop 925113110225 at time 63.23
# 	--> stop 5104010119, npass 0 -> 3, request_008_3, [69.00, 72.00] (arr, dep), 3.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250500119, npass 3 -> 7, request_007_4, [85.93, 89.93] (arr, dep), 4.00 min, 0.00 min, customers waited 17.93 min
# 	--> stop 5251310106, npass 7 -> 3, request_007_4, [98.69, 102.69] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5403010125, npass 3 -> 6, request_057_3, [109.64, 112.64] (arr, dep), 3.00 min, 0.00 min, customers waited 15.64 min
# 	--> stop 5259010102, npass 6 -> 7, request_079_1, [114.38, 115.38] (arr, dep), 1.00 min, 0.00 min, customers waited 6.38 min
# 	--> stop 5250720222, npass 7 -> 4, request_008_3, [128.28, 131.28] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250710204, npass 4 -> 1, request_057_3, [135.02, 138.02] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5254020226, npass 1 -> 0, request_079_1, [153.75, 154.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600101, npass 0 -> 1, request_148_1, [163.66, 164.66] (arr, dep), 1.00 min, 0.00 min, customers waited 18.66 min
# 	--> stop 5259010102, npass 1 -> 0, request_148_1, [168.90, 169.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010205, npass 0 -> 3, request_188_3, [172.69, 175.69] (arr, dep), 3.00 min, 0.00 min, customers waited 8.69 min
# 	--> stop 5256120113, npass 3 -> 7, request_180_4, [181.81, 185.81] (arr, dep), 4.00 min, 0.00 min, customers waited 19.81 min
# 	--> stop 5253010112, npass 7 -> 3, request_180_4, [196.66, 200.66] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5206020211, npass 3 -> 0, request_188_3, [213.02, 216.02] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250720127, npass 0 -> 1, request_266_1, [217.39, 218.39] (arr, dep), 1.00 min, 0.00 min, customers waited 10.39 min
# 	--> stop 5250710206, npass 1 -> 2, request_257_1, [220.72, 221.72] (arr, dep), 1.00 min, 0.00 min, customers waited 16.72 min
# 	--> stop 5250710204, npass 2 -> 6, request_259_4, [222.66, 226.66] (arr, dep), 4.00 min, 0.00 min, customers waited 18.66 min
# 	--> stop 5250710204, npass 6 -> 8, request_284_2, [226.66, 228.66] (arr, dep), 2.00 min, 0.00 min, customers waited 8.66 min
# 	--> stop 5253010112, npass 8 -> 7, request_266_1, [241.97, 242.97] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400116, npass 7 -> 5, request_284_2, [257.90, 259.90] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 925114100118, npass 5 -> 4, request_257_1, [264.82, 265.82] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100204, npass 4 -> 0, request_259_4, [268.11, 272.11] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 925114100204, npass 0 -> 1, request_410_1, [272.11, 273.11] (arr, dep), 1.00 min, 0.00 min, customers waited 0.11 min
# 	--> stop 925114100116, npass 1 -> 2, request_379_1, [273.22, 274.22] (arr, dep), 1.00 min, 0.00 min, customers waited 12.22 min
# 	--> stop 925114700207, npass 2 -> 5, request_387_3, [280.64, 283.64] (arr, dep), 3.00 min, 0.00 min, customers waited 15.64 min
# 	--> stop 5251300108, npass 5 -> 6, request_406_1, [290.16, 291.16] (arr, dep), 1.00 min, 0.00 min, customers waited 19.16 min
# 	--> stop 5206020130, npass 6 -> 3, request_387_3, [301.71, 304.71] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010218, npass 3 -> 2, request_410_1, [308.75, 309.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010118, npass 2 -> 1, request_379_1, [316.61, 317.61] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010112, npass 1 -> 2, request_499_1, [320.89, 321.89] (arr, dep), 1.00 min, 0.00 min, customers waited 10.89 min
# 	--> stop 5250060208, npass 2 -> 1, request_406_1, [339.75, 340.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060203, npass 1 -> 2, request_540_1, [347.70, 348.70] (arr, dep), 1.00 min, 0.00 min, customers waited 16.70 min
# 	--> stop 5250500119, npass 2 -> 1, request_499_1, [354.42, 355.42] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070121, npass 1 -> 2, request_562_1, [362.60, 363.60] (arr, dep), 1.00 min, 0.00 min, customers waited 19.60 min
# 	--> stop 5251310223, npass 2 -> 1, request_540_1, [368.91, 369.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254020107, npass 1 -> 2, request_595_1, [374.25, 375.25] (arr, dep), 1.00 min, 0.00 min, customers waited 13.25 min
# 	--> stop 92501650201, npass 2 -> 1, request_562_1, [383.96, 384.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070106, npass 1 -> 0, request_595_1, [400.94, 401.94] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925113110225 at time 413.75
# 	Vehicle currently at stop 925113110225
# 	Busy time: 350.53 (83.46%), Waiting time: 63.23 (15.05%), Busy+Wait: 98.51%
# Itinerary km: 209.23, cost: 209.23
# Total customers: 19, total waiting: 249.07 min, avg: 13.11 min, stdev: 6.01 min
#
# Vehicle with ID veh_04_925113110225 has 36 stops scheduled
# 	Departure from stop 925113110225 at time 59.98
# 	--> stop 5252010217, npass 0 -> 1, request_009_1, [69.00, 70.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250500117, npass 1 -> 5, request_010_4, [84.44, 88.44] (arr, dep), 4.00 min, 0.00 min, customers waited 14.44 min
# 	--> stop 5250060203, npass 5 -> 7, request_047_2, [93.41, 95.41] (arr, dep), 2.00 min, 0.00 min, customers waited 2.41 min
# 	--> stop 5250060123, npass 7 -> 8, request_039_1, [96.85, 97.85] (arr, dep), 1.00 min, 0.00 min, customers waited 9.85 min
# 	--> stop 5250600210, npass 8 -> 7, request_009_1, [101.15, 102.15] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040139, npass 7 -> 3, request_010_4, [111.50, 115.50] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5102010203, npass 3 -> 2, request_039_1, [120.27, 121.27] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720216, npass 2 -> 0, request_047_2, [140.12, 142.12] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720215, npass 0 -> 1, request_113_1, [144.43, 145.43] (arr, dep), 1.00 min, 0.00 min, customers waited 16.43 min
# 	--> stop 5250720132, npass 1 -> 6, request_120_5, [150.90, 155.90] (arr, dep), 5.00 min, 0.00 min, customers waited 18.90 min
# 	--> stop 5206020119, npass 6 -> 7, request_149_1, [159.38, 160.38] (arr, dep), 1.00 min, 0.00 min, customers waited 13.38 min
# 	--> stop 5256120203, npass 7 -> 8, request_170_1, [176.82, 177.82] (arr, dep), 1.00 min, 0.00 min, customers waited 19.82 min
# 	--> stop 925113110225, npass 8 -> 7, request_113_1, [182.69, 183.69] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120113, npass 7 -> 2, request_120_5, [189.91, 194.91] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 925114700202, npass 2 -> 1, request_170_1, [209.90, 210.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700205, npass 1 -> 0, request_149_1, [213.90, 214.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400206, npass 0 -> 5, request_254_5, [218.37, 223.37] (arr, dep), 5.00 min, 0.00 min, customers waited 16.37 min
# 	--> stop 5251400119, npass 5 -> 6, request_267_1, [226.45, 227.45] (arr, dep), 1.00 min, 0.00 min, customers waited 18.45 min
# 	--> stop 5251400211, npass 6 -> 7, request_301_1, [228.03, 229.03] (arr, dep), 1.00 min, 0.00 min, customers waited 1.03 min
# 	--> stop 5250720133, npass 7 -> 6, request_267_1, [246.08, 247.08] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010228, npass 6 -> 1, request_254_5, [259.24, 264.24] (arr, dep), 5.00 min, 0.00 min
# 	--> stop 5252010106, npass 1 -> 3, request_380_2, [266.52, 268.52] (arr, dep), 2.00 min, 0.00 min, customers waited 5.52 min
# 	--> stop 5252010107, npass 3 -> 6, request_364_3, [269.10, 272.10] (arr, dep), 3.00 min, 0.00 min, customers waited 16.10 min
# 	--> stop 5250710130, npass 6 -> 5, request_301_1, [286.80, 287.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120115, npass 5 -> 2, request_364_3, [309.32, 312.32] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5256120113, npass 2 -> 0, request_380_2, [315.38, 317.38] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5102010206, npass 0 -> 1, request_494_1, [319.82, 320.82] (arr, dep), 1.00 min, 0.00 min, customers waited 11.82 min
# 	--> stop 5102020204, npass 1 -> 2, request_513_1, [326.44, 327.44] (arr, dep), 1.00 min, 0.00 min, customers waited 10.44 min
# 	--> stop 5256120119, npass 2 -> 3, request_537_1, [331.64, 332.64] (arr, dep), 1.00 min, 0.00 min, customers waited 2.64 min
# 	--> stop 5201110121, npass 3 -> 2, request_494_1, [334.80, 335.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500104, npass 2 -> 4, request_523_2, [340.53, 342.53] (arr, dep), 2.00 min, 0.00 min, customers waited 18.53 min
# 	--> stop 5250600115, npass 4 -> 3, request_537_1, [349.89, 350.89] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710202, npass 3 -> 1, request_523_2, [363.57, 365.57] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250060215, npass 1 -> 0, request_513_1, [377.88, 378.88] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925113110225 at time 390.60
# 	Vehicle currently at stop 925113110225
# 	Busy time: 330.62 (78.72%), Waiting time: 59.98 (14.28%), Busy+Wait: 93.00%
# Itinerary km: 192.96, cost: 192.96
# Total customers: 17, total waiting: 196.13 min, avg: 11.54 min, stdev: 6.62 min
#
# Vehicle with ID veh_05_925611130111 has 44 stops scheduled
# 	Departure from stop 925611130111 at time 61.64
# 	--> stop 5251310103, npass 0 -> 1, request_011_1, [71.00, 72.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250720129, npass 1 -> 2, request_013_1, [84.40, 85.40] (arr, dep), 1.00 min, 0.00 min, customers waited 12.40 min
# 	--> stop 5250720218, npass 2 -> 3, request_012_1, [89.06, 90.06] (arr, dep), 1.00 min, 0.00 min, customers waited 18.06 min
# 	--> stop 5250720130, npass 3 -> 4, request_043_1, [91.85, 92.85] (arr, dep), 1.00 min, 0.00 min, customers waited 1.85 min
# 	--> stop 5250600208, npass 4 -> 5, request_037_1, [101.58, 102.58] (arr, dep), 1.00 min, 0.00 min, customers waited 17.58 min
# 	--> stop 5250060123, npass 5 -> 4, request_011_1, [105.04, 106.04] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500124, npass 4 -> 3, request_037_1, [114.08, 115.08] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92501650201, npass 3 -> 2, request_013_1, [126.59, 127.59] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120116, npass 2 -> 1, request_012_1, [137.23, 138.23] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500102, npass 1 -> 0, request_043_1, [144.65, 145.65] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500223, npass 0 -> 1, request_143_1, [146.75, 147.75] (arr, dep), 1.00 min, 0.00 min, customers waited 3.75 min
# 	--> stop 5252040204, npass 1 -> 5, request_117_4, [149.28, 153.28] (arr, dep), 4.00 min, 0.00 min, customers waited 19.28 min
# 	--> stop 92571910123, npass 5 -> 6, request_145_1, [158.12, 159.12] (arr, dep), 1.00 min, 0.00 min, customers waited 14.12 min
# 	--> stop 5259030211, npass 6 -> 7, request_181_1, [162.42, 163.42] (arr, dep), 1.00 min, 0.00 min, customers waited 0.42 min
# 	--> stop 5206020202, npass 7 -> 6, request_143_1, [165.71, 166.71] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500203, npass 6 -> 2, request_117_4, [177.04, 181.04] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254020226, npass 2 -> 1, request_181_1, [186.12, 187.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 1 -> 0, request_145_1, [195.31, 196.31] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114010111, npass 0 -> 2, request_237_2, [196.31, 198.31] (arr, dep), 2.00 min, 0.00 min, customers waited 10.31 min
# 	--> stop 92501650202, npass 2 -> 3, request_231_1, [200.93, 201.93] (arr, dep), 1.00 min, 0.00 min, customers waited 16.93 min
# 	--> stop 5250500118, npass 3 -> 6, request_247_3, [209.19, 212.19] (arr, dep), 3.00 min, 0.00 min, customers waited 13.19 min
# 	--> stop 5250060117, npass 6 -> 5, request_231_1, [219.65, 220.65] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040208, npass 5 -> 3, request_237_2, [231.44, 233.44] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5252060138, npass 3 -> 4, request_293_1, [239.85, 240.85] (arr, dep), 1.00 min, 0.00 min, customers waited 15.85 min
# 	--> stop 5253010119, npass 4 -> 1, request_247_3, [244.03, 247.03] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5252010218, npass 1 -> 2, request_350_1, [249.90, 250.90] (arr, dep), 1.00 min, 0.00 min, customers waited 2.90 min
# 	--> stop 5252010112, npass 2 -> 6, request_309_4, [250.99, 254.99] (arr, dep), 4.00 min, 0.00 min, customers waited 19.99 min
# 	--> stop 5250720229, npass 6 -> 5, request_293_1, [266.87, 267.87] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070116, npass 5 -> 1, request_309_4, [273.89, 277.89] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5206020131, npass 1 -> 0, request_350_1, [286.58, 287.58] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010216, npass 0 -> 1, request_408_1, [291.47, 292.47] (arr, dep), 1.00 min, 0.00 min, customers waited 19.47 min
# 	--> stop 5252040211, npass 1 -> 2, request_428_1, [298.20, 299.20] (arr, dep), 1.00 min, 0.00 min, customers waited 19.20 min
# 	--> stop 5252010226, npass 2 -> 1, request_408_1, [307.81, 308.81] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500120, npass 1 -> 0, request_428_1, [325.90, 326.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070120, npass 0 -> 1, request_508_1, [334.82, 335.82] (arr, dep), 1.00 min, 0.00 min, customers waited 19.82 min
# 	--> stop 5251400213, npass 1 -> 2, request_534_1, [344.50, 345.50] (arr, dep), 1.00 min, 0.00 min, customers waited 17.50 min
# 	--> stop 5251400208, npass 2 -> 3, request_545_1, [350.38, 351.38] (arr, dep), 1.00 min, 0.00 min, customers waited 17.38 min
# 	--> stop 925114700109, npass 3 -> 2, request_508_1, [354.75, 355.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300104, npass 2 -> 3, request_567_1, [363.18, 364.18] (arr, dep), 1.00 min, 0.00 min, customers waited 17.18 min
# 	--> stop 5206020134, npass 3 -> 2, request_534_1, [373.47, 374.47] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010102, npass 2 -> 1, request_545_1, [379.68, 380.68] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5102010106, npass 1 -> 0, request_567_1, [386.11, 387.11] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 396.05
# 	Vehicle currently at stop 925611130111
# 	Busy time: 334.41 (79.62%), Waiting time: 61.64 (14.68%), Busy+Wait: 94.30%
# Itinerary km: 200.53, cost: 200.53
# Total customers: 21, total waiting: 277.17 min, avg: 13.20 min, stdev: 6.86 min
#
# Vehicle with ID veh_06_925611130111 has 48 stops scheduled
# 	Departure from stop 925611130111 at time 62.64
# 	--> stop 5251310103, npass 0 -> 1, request_014_1, [72.00, 73.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250060121, npass 1 -> 4, request_015_3, [88.74, 91.74] (arr, dep), 3.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501650202, npass 4 -> 3, request_014_1, [107.89, 108.89] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 4, request_059_1, [110.38, 111.38] (arr, dep), 1.00 min, 0.00 min, customers waited 15.38 min
# 	--> stop 5252010204, npass 4 -> 1, request_015_3, [122.03, 125.03] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5206020127, npass 1 -> 2, request_087_1, [128.44, 129.44] (arr, dep), 1.00 min, 0.00 min, customers waited 17.44 min
# 	--> stop 5252060139, npass 2 -> 3, request_123_1, [138.22, 139.22] (arr, dep), 1.00 min, 0.00 min, customers waited 4.22 min
# 	--> stop 5252060209, npass 3 -> 2, request_059_1, [140.91, 141.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700110, npass 2 -> 1, request_087_1, [157.32, 158.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060125, npass 1 -> 3, request_161_2, [167.20, 169.20] (arr, dep), 2.00 min, 0.00 min, customers waited 17.20 min
# 	--> stop 5256120208, npass 3 -> 2, request_123_1, [183.90, 184.90] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010115, npass 2 -> 3, request_222_1, [195.93, 196.93] (arr, dep), 1.00 min, 0.00 min, customers waited 16.93 min
# 	--> stop 5252010110, npass 3 -> 1, request_161_2, [201.33, 203.33] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5253010117, npass 1 -> 4, request_253_3, [208.62, 211.62] (arr, dep), 3.00 min, 0.00 min, customers waited 8.62 min
# 	--> stop 5252060137, npass 4 -> 5, request_274_1, [214.42, 215.42] (arr, dep), 1.00 min, 0.00 min, customers waited 1.42 min
# 	--> stop 925217900103, npass 5 -> 6, request_248_1, [216.04, 217.04] (arr, dep), 1.00 min, 0.00 min, customers waited 19.04 min
# 	--> stop 5250060111, npass 6 -> 5, request_248_1, [225.91, 226.91] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060112, npass 5 -> 4, request_222_1, [228.23, 229.23] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600209, npass 4 -> 5, request_285_1, [232.20, 233.20] (arr, dep), 1.00 min, 0.00 min, customers waited 14.20 min
# 	--> stop 5250070106, npass 5 -> 2, request_253_3, [236.36, 239.36] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250060218, npass 2 -> 1, request_285_1, [243.71, 244.71] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600218, npass 1 -> 2, request_333_1, [252.87, 253.87] (arr, dep), 1.00 min, 0.00 min, customers waited 12.87 min
# 	--> stop 5206020128, npass 2 -> 1, request_274_1, [255.01, 256.01] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600108, npass 1 -> 2, request_338_1, [257.89, 258.89] (arr, dep), 1.00 min, 0.00 min, customers waited 16.89 min
# 	--> stop 5250600217, npass 2 -> 1, request_333_1, [260.78, 261.78] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020134, npass 1 -> 2, request_352_1, [265.37, 266.37] (arr, dep), 1.00 min, 0.00 min, customers waited 17.37 min
# 	--> stop 5252040139, npass 2 -> 1, request_352_1, [271.02, 272.02] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010124, npass 1 -> 2, request_395_1, [273.41, 274.41] (arr, dep), 1.00 min, 0.00 min, customers waited 6.41 min
# 	--> stop 5252060142, npass 2 -> 1, request_338_1, [280.32, 281.32] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010108, npass 1 -> 2, request_390_1, [284.26, 285.26] (arr, dep), 1.00 min, 0.00 min, customers waited 19.26 min
# 	--> stop 92571910204, npass 2 -> 3, request_439_1, [291.36, 292.36] (arr, dep), 1.00 min, 0.00 min, customers waited 6.36 min
# 	--> stop 5256120202, npass 3 -> 2, request_395_1, [298.25, 299.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120202, npass 2 -> 1, request_390_1, [299.25, 300.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020133, npass 1 -> 2, request_445_1, [305.52, 306.52] (arr, dep), 1.00 min, 0.00 min, customers waited 17.52 min
# 	--> stop 925114220110, npass 2 -> 1, request_445_1, [313.26, 314.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300104, npass 1 -> 2, request_473_1, [316.54, 317.54] (arr, dep), 1.00 min, 0.00 min, customers waited 19.54 min
# 	--> stop 5251300104, npass 2 -> 4, request_511_2, [317.54, 319.54] (arr, dep), 2.00 min, 0.00 min, customers waited 2.54 min
# 	--> stop 5251400123, npass 4 -> 3, request_439_1, [328.62, 329.62] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400119, npass 3 -> 4, request_519_1, [335.21, 336.21] (arr, dep), 1.00 min, 0.00 min, customers waited 15.21 min
# 	--> stop 92501650104, npass 4 -> 3, request_473_1, [341.54, 342.54] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114800112, npass 3 -> 2, request_519_1, [352.75, 353.75] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252060138, npass 2 -> 0, request_511_2, [369.90, 371.90] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 925218000218, npass 0 -> 1, request_589_1, [374.66, 375.66] (arr, dep), 1.00 min, 0.00 min, customers waited 16.66 min
# 	--> stop 5252010123, npass 1 -> 2, request_592_1, [377.83, 378.83] (arr, dep), 1.00 min, 0.00 min, customers waited 17.83 min
# 	--> stop 5253010218, npass 2 -> 1, request_589_1, [383.45, 384.45] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92571910203, npass 1 -> 0, request_592_1, [386.12, 387.12] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 398.82
# 	Vehicle currently at stop 925611130111
# 	Busy time: 336.18 (80.04%), Waiting time: 62.64 (14.91%), Busy+Wait: 94.96%
# Itinerary km: 202.38, cost: 202.38
# Total customers: 23, total waiting: 299.64 min, avg: 13.03 min, stdev: 6.20 min
#
# Vehicle with ID veh_07_925611130111 has 44 stops scheduled
# 	Departure from stop 925611130111 at time 60.82
# 	--> stop 5252050117, npass 0 -> 1, request_019_1, [76.00, 77.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040136, npass 1 -> 0, request_019_1, [80.25, 81.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_018_1, [94.52, 95.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5251400122, npass 1 -> 2, request_026_1, [98.31, 99.31] (arr, dep), 1.00 min, 0.00 min, customers waited 19.31 min
# 	--> stop 92501650202, npass 2 -> 1, request_018_1, [106.70, 107.70] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 3, request_055_2, [109.18, 111.18] (arr, dep), 2.00 min, 0.00 min, customers waited 15.18 min
# 	--> stop 5201110118, npass 3 -> 4, request_080_1, [116.49, 117.49] (arr, dep), 1.00 min, 0.00 min, customers waited 7.49 min
# 	--> stop 5251300103, npass 4 -> 3, request_026_1, [121.72, 122.72] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 2, request_080_1, [126.96, 127.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130108, npass 2 -> 0, request_055_2, [139.22, 141.33] (arr, dep), 2.11 min, 0.11 min
# 	--> stop 925611130107, npass 0 -> 2, request_140_2, [142.00, 144.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925114700111, npass 2 -> 6, request_133_4, [157.31, 161.31] (arr, dep), 4.00 min, 0.00 min, customers waited 17.31 min
# 	--> stop 5251400116, npass 6 -> 2, request_133_4, [166.85, 170.85] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254010221, npass 2 -> 3, request_182_1, [182.97, 183.97] (arr, dep), 1.00 min, 0.00 min, customers waited 19.97 min
# 	--> stop 5250060117, npass 3 -> 4, request_205_1, [187.74, 188.74] (arr, dep), 1.00 min, 0.00 min, customers waited 14.74 min
# 	--> stop 5250060117, npass 4 -> 5, request_204_1, [188.74, 189.74] (arr, dep), 1.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501620103, npass 5 -> 6, request_208_1, [190.77, 191.77] (arr, dep), 1.00 min, 0.00 min, customers waited 16.77 min
# 	--> stop 5250740213, npass 6 -> 4, request_140_2, [193.97, 195.97] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250600109, npass 4 -> 3, request_204_1, [202.41, 203.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 3 -> 2, request_205_1, [207.20, 208.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010213, npass 2 -> 1, request_182_1, [213.86, 214.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114220110, npass 1 -> 0, request_208_1, [226.35, 227.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300103, npass 0 -> 1, request_286_1, [229.43, 230.43] (arr, dep), 1.00 min, 0.00 min, customers waited 9.43 min
# 	--> stop 5251300108, npass 1 -> 2, request_279_1, [234.16, 235.16] (arr, dep), 1.00 min, 0.00 min, customers waited 18.16 min
# 	--> stop 925114100112, npass 2 -> 1, request_286_1, [239.97, 240.97] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254020225, npass 1 -> 4, request_316_3, [254.00, 257.00] (arr, dep), 3.00 min, 0.00 min, customers waited 20.00 min
# 	--> stop 5254020114, npass 4 -> 3, request_279_1, [257.80, 258.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060205, npass 3 -> 0, request_316_3, [264.30, 267.30] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250060123, npass 0 -> 1, request_375_1, [267.38, 268.38] (arr, dep), 1.00 min, 0.00 min, customers waited 9.38 min
# 	--> stop 92501620208, npass 1 -> 5, request_370_4, [272.97, 276.97] (arr, dep), 4.00 min, 0.00 min, customers waited 18.97 min
# 	--> stop 5250610202, npass 5 -> 7, request_398_2, [282.11, 284.11] (arr, dep), 2.00 min, 0.00 min, customers waited 14.11 min
# 	--> stop 925114010111, npass 7 -> 6, request_375_1, [294.12, 295.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130107, npass 6 -> 2, request_370_4, [304.68, 308.68] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5256120119, npass 2 -> 0, request_398_2, [312.24, 314.24] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5256120203, npass 0 -> 1, request_481_1, [316.85, 317.85] (arr, dep), 1.00 min, 0.00 min, customers waited 14.85 min
# 	--> stop 5252040210, npass 1 -> 2, request_493_1, [326.30, 327.30] (arr, dep), 1.00 min, 0.00 min, customers waited 18.30 min
# 	--> stop 5201110203, npass 2 -> 1, request_493_1, [335.43, 336.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400112, npass 1 -> 0, request_481_1, [343.35, 344.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_544_1, [351.71, 352.71] (arr, dep), 1.00 min, 0.00 min, customers waited 19.71 min
# 	--> stop 5251300105, npass 1 -> 4, request_572_3, [361.17, 364.17] (arr, dep), 3.00 min, 0.00 min, customers waited 13.17 min
# 	--> stop 5251400212, npass 4 -> 1, request_572_3, [370.19, 373.19] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 925611130106, npass 1 -> 0, request_544_1, [384.03, 385.03] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 389.96
# 	Vehicle currently at stop 925611130111
# 	Busy time: 329.04 (78.34%), Waiting time: 60.93 (14.51%), Busy+Wait: 92.85%
# Itinerary km: 181.16, cost: 181.16
# Total customers: 21, total waiting: 303.10 min, avg: 14.43 min, stdev: 5.88 min
#
# Vehicle with ID veh_08_925611130111 has 40 stops scheduled
# 	Departure from stop 925611130111 at time 65.83
# 	--> stop 5251300106, npass 0 -> 1, request_027_1, [80.00, 81.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5102010206, npass 1 -> 2, request_028_1, [96.38, 97.38] (arr, dep), 1.00 min, 0.00 min, customers waited 16.38 min
# 	--> stop 5253010213, npass 2 -> 3, request_073_1, [104.14, 105.14] (arr, dep), 1.00 min, 0.00 min, customers waited 0.14 min
# 	--> stop 5253010213, npass 3 -> 4, request_044_1, [105.14, 106.14] (arr, dep), 1.00 min, -0.00 min, customers waited 15.14 min
# 	--> stop 5256120117, npass 4 -> 3, request_027_1, [114.16, 115.16] (arr, dep), 1.00 min, -0.00 min
# 	--> stop 5254010218, npass 3 -> 2, request_044_1, [133.51, 134.51] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060206, npass 2 -> 1, request_028_1, [143.39, 144.39] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600208, npass 1 -> 4, request_124_3, [145.92, 148.92] (arr, dep), 3.00 min, 0.00 min, customers waited 9.92 min
# 	--> stop 92501620103, npass 4 -> 3, request_073_1, [149.19, 150.19] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254010111, npass 3 -> 4, request_137_1, [156.79, 159.05] (arr, dep), 2.26 min, 1.26 min, customers waited 15.79 min
# 	--> stop 5254010110, npass 4 -> 5, request_183_1, [163.00, 164.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5254010110, npass 5 -> 4, request_137_1, [164.00, 165.00] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060115, npass 4 -> 5, request_169_1, [170.89, 171.89] (arr, dep), 1.00 min, 0.00 min, customers waited 16.89 min
# 	--> stop 5250710128, npass 5 -> 2, request_124_3, [180.99, 183.99] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250070116, npass 2 -> 1, request_183_1, [194.23, 195.23] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010123, npass 1 -> 0, request_169_1, [204.60, 205.60] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300105, npass 0 -> 1, request_252_1, [218.21, 219.21] (arr, dep), 1.00 min, 0.00 min, customers waited 18.21 min
# 	--> stop 92501650108, npass 1 -> 3, request_256_2, [221.42, 223.42] (arr, dep), 2.00 min, 0.00 min, customers waited 18.42 min
# 	--> stop 92501620103, npass 3 -> 2, request_252_1, [236.92, 237.92] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250750109, npass 2 -> 3, request_294_1, [241.06, 242.06] (arr, dep), 1.00 min, 0.00 min, customers waited 17.06 min
# 	--> stop 5252010220, npass 3 -> 1, request_256_2, [255.13, 257.13] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5252010111, npass 1 -> 2, request_362_1, [257.68, 258.68] (arr, dep), 1.00 min, 0.00 min, customers waited 5.68 min
# 	--> stop 5252010115, npass 2 -> 3, request_357_1, [260.91, 261.91] (arr, dep), 1.00 min, 0.00 min, customers waited 10.91 min
# 	--> stop 925114700115, npass 3 -> 2, request_294_1, [277.26, 278.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114220110, npass 2 -> 3, request_393_1, [284.96, 285.96] (arr, dep), 1.00 min, 0.00 min, customers waited 17.96 min
# 	--> stop 5256120115, npass 3 -> 2, request_357_1, [295.18, 296.18] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720246, npass 2 -> 1, request_393_1, [303.35, 304.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130108, npass 1 -> 0, request_362_1, [312.43, 313.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600106, npass 0 -> 1, request_512_1, [321.74, 322.74] (arr, dep), 1.00 min, 0.00 min, customers waited 5.74 min
# 	--> stop 5250600111, npass 1 -> 2, request_502_1, [327.51, 328.51] (arr, dep), 1.00 min, 0.00 min, customers waited 14.51 min
# 	--> stop 5250600212, npass 2 -> 3, request_505_1, [329.99, 330.99] (arr, dep), 1.00 min, 0.00 min, customers waited 16.99 min
# 	--> stop 5254020112, npass 3 -> 2, request_512_1, [337.06, 338.06] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010211, npass 2 -> 1, request_505_1, [346.57, 347.57] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010210, npass 1 -> 2, request_548_1, [347.96, 348.96] (arr, dep), 1.00 min, 0.00 min, customers waited 13.96 min
# 	--> stop 5250710131, npass 2 -> 1, request_502_1, [366.92, 367.92] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710204, npass 1 -> 3, request_582_2, [371.72, 373.72] (arr, dep), 2.00 min, 0.00 min, customers waited 18.72 min
# 	--> stop 5250720219, npass 3 -> 2, request_548_1, [377.80, 378.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5904210110, npass 2 -> 0, request_582_2, [393.99, 395.99] (arr, dep), 2.00 min, 0.00 min
# 	End in stop 925611130111 at time 408.27
# 	Vehicle currently at stop 925611130111
# 	Busy time: 341.18 (81.23%), Waiting time: 67.09 (15.97%), Busy+Wait: 97.21%
# Itinerary km: 221.38, cost: 221.38
# Total customers: 19, total waiting: 232.41 min, avg: 12.23 min, stdev: 6.49 min
#
# Vehicle with ID veh_09_5403010204 has 42 stops scheduled
# 	Departure from stop 5403010204 at time 63.78
# 	--> stop 925426810110, npass 0 -> 1, request_016_1, [74.00, 75.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 92571910204, npass 1 -> 2, request_017_1, [82.69, 83.69] (arr, dep), 1.00 min, 0.00 min, customers waited 7.69 min
# 	--> stop 5250720119, npass 2 -> 1, request_016_1, [96.62, 97.62] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925113110226, npass 1 -> 0, request_017_1, [107.98, 108.98] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120208, npass 0 -> 1, request_063_1, [114.41, 115.41] (arr, dep), 1.00 min, 0.00 min, customers waited 17.41 min
# 	--> stop 5256120115, npass 1 -> 0, request_063_1, [117.39, 118.39] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120206, npass 0 -> 1, request_094_1, [119.82, 120.82] (arr, dep), 1.00 min, 0.00 min, customers waited 5.82 min
# 	--> stop 5250500110, npass 1 -> 5, request_090_4, [129.16, 133.16] (arr, dep), 4.00 min, 0.00 min, customers waited 18.16 min
# 	--> stop 5254020227, npass 5 -> 6, request_109_1, [137.25, 138.25] (arr, dep), 1.00 min, 0.00 min, customers waited 11.25 min
# 	--> stop 5250610123, npass 6 -> 2, request_090_4, [144.78, 148.78] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5252060142, npass 2 -> 1, request_094_1, [161.35, 162.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010115, npass 1 -> 2, request_150_1, [165.09, 166.09] (arr, dep), 1.00 min, 0.00 min, customers waited 19.09 min
# 	--> stop 5252060138, npass 2 -> 3, request_198_1, [167.17, 168.17] (arr, dep), 1.00 min, 0.00 min, customers waited 0.17 min
# 	--> stop 5253010208, npass 3 -> 2, request_109_1, [170.80, 171.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252060205, npass 2 -> 3, request_173_1, [174.13, 175.13] (arr, dep), 1.00 min, 0.00 min, customers waited 16.13 min
# 	--> stop 5253010202, npass 3 -> 4, request_189_1, [176.25, 177.25] (arr, dep), 1.00 min, 0.00 min, customers waited 12.25 min
# 	--> stop 5253010217, npass 4 -> 3, request_150_1, [185.05, 186.05] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5904210201, npass 3 -> 4, request_207_1, [191.18, 192.18] (arr, dep), 1.00 min, 0.00 min, customers waited 17.18 min
# 	--> stop 5250500102, npass 4 -> 3, request_173_1, [199.54, 200.54] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020130, npass 3 -> 4, request_234_1, [201.32, 202.32] (arr, dep), 1.00 min, 0.00 min, customers waited 17.32 min
# 	--> stop 5252040206, npass 4 -> 3, request_189_1, [204.12, 205.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040207, npass 3 -> 4, request_243_1, [205.39, 206.39] (arr, dep), 1.00 min, 0.00 min, customers waited 13.39 min
# 	--> stop 5250060203, npass 4 -> 3, request_198_1, [217.20, 218.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600117, npass 3 -> 2, request_234_1, [220.94, 221.94] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060111, npass 2 -> 5, request_269_3, [225.66, 228.66] (arr, dep), 3.00 min, 0.00 min, customers waited 17.66 min
# 	--> stop 5250060215, npass 5 -> 4, request_243_1, [231.07, 232.07] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720215, npass 4 -> 3, request_207_1, [240.26, 241.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010211, npass 3 -> 0, request_269_3, [254.99, 257.99] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010112, npass 0 -> 4, request_340_4, [260.58, 264.58] (arr, dep), 4.00 min, 0.00 min, customers waited 18.58 min
# 	--> stop 5252060140, npass 4 -> 5, request_359_1, [266.01, 267.01] (arr, dep), 1.00 min, 0.00 min, customers waited 15.01 min
# 	--> stop 5253010119, npass 5 -> 4, request_359_1, [269.11, 270.11] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250070120, npass 4 -> 5, request_388_1, [282.21, 283.21] (arr, dep), 1.00 min, 0.00 min, customers waited 17.21 min
# 	--> stop 5403010127, npass 5 -> 1, request_340_4, [292.01, 296.01] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5904210111, npass 1 -> 0, request_388_1, [310.00, 311.00] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060115, npass 0 -> 2, request_490_2, [326.98, 328.98] (arr, dep), 2.00 min, 0.00 min, customers waited 19.98 min
# 	--> stop 5250500110, npass 2 -> 5, request_517_3, [339.72, 342.72] (arr, dep), 3.00 min, 0.00 min, customers waited 19.72 min
# 	--> stop 5250500110, npass 5 -> 3, request_490_2, [342.72, 344.72] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250500120, npass 3 -> 0, request_517_3, [351.72, 354.72] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010208, npass 0 -> 3, request_569_3, [366.85, 369.85] (arr, dep), 3.00 min, 0.00 min, customers waited 19.85 min
# 	--> stop 92571910122, npass 3 -> 0, request_569_3, [377.29, 380.29] (arr, dep), 3.00 min, 0.00 min
# 	End in stop 5403010204 at time 389.27
# 	Vehicle currently at stop 5403010204
# 	Busy time: 325.49 (77.50%), Waiting time: 63.78 (15.19%), Busy+Wait: 92.68%
# Itinerary km: 209.14, cost: 209.14
# Total customers: 20, total waiting: 283.87 min, avg: 14.19 min, stdev: 6.05 min
#
# Vehicle with ID veh_10_5403010204 has 48 stops scheduled
# 	Departure from stop 5403010204 at time 69.79
# 	--> stop 5256120209, npass 0 -> 1, request_031_1, [81.00, 82.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5251300108, npass 1 -> 4, request_038_3, [96.79, 99.79] (arr, dep), 3.00 min, 0.00 min, customers waited 9.79 min
# 	--> stop 5250600101, npass 4 -> 1, request_038_3, [108.94, 111.94] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 925611130109, npass 1 -> 0, request_031_1, [119.67, 120.67] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251310103, npass 0 -> 1, request_089_1, [127.51, 128.51] (arr, dep), 1.00 min, 0.00 min, customers waited 16.51 min
# 	--> stop 5250600109, npass 1 -> 2, request_101_1, [133.12, 134.12] (arr, dep), 1.00 min, 0.00 min, customers waited 13.12 min
# 	--> stop 5254020227, npass 2 -> 3, request_107_1, [138.95, 139.95] (arr, dep), 1.00 min, 0.00 min, customers waited 15.95 min
# 	--> stop 5250060203, npass 3 -> 2, request_089_1, [144.24, 145.24] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060211, npass 2 -> 3, request_115_1, [148.34, 149.34] (arr, dep), 1.00 min, 0.00 min, customers waited 18.34 min
# 	--> stop 5250600116, npass 3 -> 2, request_101_1, [152.37, 153.37] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500108, npass 2 -> 5, request_135_3, [159.52, 162.52] (arr, dep), 3.00 min, 0.00 min, customers waited 18.52 min
# ...
# 	--> stop 5251400113, npass 3 -> 2, request_298_1, [253.69, 254.69] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400215, npass 2 -> 6, request_332_4, [255.99, 259.99] (arr, dep), 4.00 min, 0.00 min, customers waited 15.99 min
# 	--> stop 5250060125, npass 6 -> 2, request_332_4, [268.90, 272.90] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5250600209, npass 2 -> 3, request_383_1, [279.20, 280.20] (arr, dep), 1.00 min, 0.00 min, customers waited 16.20 min
# 	--> stop 5250710118, npass 3 -> 1, request_326_2, [283.75, 285.75] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720129, npass 1 -> 2, request_415_1, [291.42, 292.42] (arr, dep), 1.00 min, 0.00 min, customers waited 16.42 min
# 	--> stop 5252040140, npass 2 -> 5, request_444_3, [303.70, 306.70] (arr, dep), 3.00 min, 0.00 min, customers waited 15.70 min
# 	--> stop 5252010207, npass 5 -> 4, request_383_1, [309.01, 310.01] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252060142, npass 4 -> 3, request_415_1, [315.70, 316.70] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925217900102, npass 3 -> 0, request_444_3, [320.77, 323.77] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250600214, npass 0 -> 3, request_510_3, [334.22, 337.22] (arr, dep), 3.00 min, 0.00 min, customers waited 19.22 min
# 	--> stop 5102010203, npass 3 -> 4, request_536_1, [345.13, 346.13] (arr, dep), 1.00 min, 0.00 min, customers waited 17.13 min
# 	--> stop 5256120202, npass 4 -> 5, request_558_1, [348.45, 349.45] (arr, dep), 1.00 min, 0.00 min, customers waited 9.45 min
# 	--> stop 5104010119, npass 5 -> 7, request_554_2, [354.16, 356.16] (arr, dep), 2.00 min, 0.00 min, customers waited 17.16 min
# 	--> stop 5256120113, npass 7 -> 4, request_510_3, [357.83, 360.83] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010204, npass 4 -> 3, request_536_1, [372.46, 373.46] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010121, npass 3 -> 2, request_558_1, [378.43, 379.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700115, npass 2 -> 0, request_554_2, [392.30, 394.30] (arr, dep), 2.00 min, 0.00 min
# 	End in stop 5254010218 at time 410.06
# 	Vehicle currently at stop 5254010218
# 	Busy time: 345.27 (82.21%), Waiting time: 64.79 (15.43%), Busy+Wait: 97.63%
# Itinerary km: 185.85, cost: 185.85
# Total customers: 19, total waiting: 277.60 min, avg: 14.61 min, stdev: 5.52 min
#
# Vehicle with ID veh_18_5254010218 has 36 stops scheduled
# 	Departure from stop 5254010218 at time 80.77
# 	--> stop 92501620103, npass 0 -> 1, request_045_1, [91.00, 92.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 92501650104, npass 1 -> 0, request_045_1, [98.14, 99.14] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700204, npass 0 -> 1, request_046_1, [109.64, 110.64] (arr, dep), 1.00 min, 0.00 min, customers waited 18.64 min
# 	--> stop 5251300108, npass 1 -> 4, request_067_3, [119.91, 122.91] (arr, dep), 3.00 min, 0.00 min, customers waited 18.91 min
# 	--> stop 5253010218, npass 4 -> 5, request_104_1, [137.13, 138.13] (arr, dep), 1.00 min, 0.00 min, customers waited 16.13 min
# 	--> stop 5252060142, npass 5 -> 4, request_046_1, [145.76, 146.76] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710204, npass 4 -> 1, request_067_3, [160.71, 163.71] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 925114800111, npass 1 -> 0, request_104_1, [183.72, 184.72] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 0 -> 1, request_212_1, [194.32, 195.32] (arr, dep), 1.00 min, 0.00 min, customers waited 19.32 min
# 	--> stop 925114100202, npass 1 -> 2, request_236_1, [200.15, 201.15] (arr, dep), 1.00 min, 0.00 min, customers waited 15.15 min
# 	--> stop 925114100202, npass 2 -> 3, request_226_1, [201.15, 202.15] (arr, dep), 1.00 min, 0.00 min, customers waited 19.15 min
# 	--> stop 5251310216, npass 3 -> 2, request_226_1, [205.95, 206.95] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120118, npass 2 -> 1, request_212_1, [214.86, 215.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252040138, npass 1 -> 2, request_258_1, [221.80, 222.80] (arr, dep), 1.00 min, 0.00 min, customers waited 17.80 min
# 	--> stop 5250500110, npass 2 -> 1, request_236_1, [228.82, 229.82] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500118, npass 1 -> 2, request_280_1, [236.65, 237.65] (arr, dep), 1.00 min, 0.00 min, customers waited 19.65 min
# 	--> stop 92501650104, npass 2 -> 5, request_287_3, [238.88, 241.88] (arr, dep), 3.00 min, 0.00 min, customers waited 18.88 min
# 	--> stop 5250500118, npass 5 -> 4, request_258_1, [243.20, 244.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400205, npass 4 -> 3, request_280_1, [254.17, 255.17] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010115, npass 3 -> 0, request_287_3, [271.89, 274.89] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5253010118, npass 0 -> 1, request_412_1, [276.21, 277.21] (arr, dep), 1.00 min, 0.00 min, customers waited 3.21 min
# 	--> stop 5250500110, npass 1 -> 4, request_402_3, [288.74, 291.74] (arr, dep), 3.00 min, 0.00 min, customers waited 19.74 min
# 	--> stop 925114700109, npass 4 -> 3, request_412_1, [301.03, 302.03] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400122, npass 3 -> 0, request_402_3, [305.62, 308.62] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500205, npass 0 -> 1, request_480_1, [316.78, 317.78] (arr, dep), 1.00 min, 0.00 min, customers waited 14.78 min
# 	--> stop 5250500122, npass 1 -> 2, request_504_1, [318.95, 319.95] (arr, dep), 1.00 min, 0.00 min, customers waited 5.95 min
# 	--> stop 5250500125, npass 2 -> 3, request_489_1, [321.88, 322.88] (arr, dep), 1.00 min, 0.00 min, customers waited 15.88 min
# 	--> stop 5251400121, npass 3 -> 2, request_480_1, [334.01, 335.01] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700113, npass 2 -> 6, request_522_4, [338.73, 342.73] (arr, dep), 4.00 min, 0.00 min, customers waited 17.73 min
# 	--> stop 5252040140, npass 6 -> 5, request_504_1, [356.36, 357.36] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925217900114, npass 5 -> 4, request_489_1, [368.68, 369.68] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010226, npass 4 -> 5, request_583_1, [370.00, 371.00] (arr, dep), 1.00 min, 0.00 min, customers waited 17.00 min
# 	--> stop 5250710204, npass 5 -> 1, request_522_4, [383.26, 387.26] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5250600217, npass 1 -> 0, request_583_1, [400.15, 401.15] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 5254010218 at time 414.06
# 	Vehicle currently at stop 5254010218
# 	Busy time: 333.28 (79.35%), Waiting time: 80.77 (19.23%), Busy+Wait: 98.58%
# Itinerary km: 214.77, cost: 214.77
# Total customers: 17, total waiting: 257.93 min, avg: 15.17 min, stdev: 5.89 min
#
# Vehicle with ID veh_19_5254010218 has 38 stops scheduled
# 	Departure from stop 5254010218 at time 72.29
# 	--> stop 5251400205, npass 0 -> 1, request_049_1, [91.00, 92.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252060209, npass 1 -> 2, request_054_1, [106.93, 107.93] (arr, dep), 1.00 min, 0.00 min, customers waited 13.93 min
# 	--> stop 5252060208, npass 2 -> 3, request_052_1, [108.52, 109.52] (arr, dep), 1.00 min, 0.00 min, customers waited 15.52 min
# 	--> stop 5250600108, npass 3 -> 4, request_071_1, [118.31, 119.31] (arr, dep), 1.00 min, -0.00 min, customers waited 15.31 min
# 	--> stop 5201110205, npass 4 -> 3, request_049_1, [128.21, 129.21] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700114, npass 3 -> 2, request_071_1, [136.87, 137.87] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500120, npass 2 -> 1, request_054_1, [144.19, 145.19] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925010610127, npass 1 -> 0, request_052_1, [146.47, 147.47] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700114, npass 0 -> 1, request_130_1, [157.55, 158.55] (arr, dep), 1.00 min, 0.00 min, customers waited 18.55 min
# 	--> stop 925114700113, npass 1 -> 2, request_154_1, [161.82, 162.82] (arr, dep), 1.00 min, 0.00 min, customers waited 12.82 min
# 	--> stop 5252010109, npass 2 -> 3, request_178_1, [179.94, 180.94] (arr, dep), 1.00 min, 0.00 min, customers waited 18.94 min
# 	--> stop 5252010106, npass 3 -> 2, request_130_1, [182.18, 183.18] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206030212, npass 2 -> 1, request_178_1, [196.01, 197.01] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060208, npass 1 -> 0, request_154_1, [210.64, 211.64] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100113, npass 0 -> 1, request_272_1, [230.78, 231.78] (arr, dep), 1.00 min, 0.00 min, customers waited 19.78 min
# 	--> stop 5251400206, npass 1 -> 2, request_289_1, [241.90, 242.90] (arr, dep), 1.00 min, 0.00 min, customers waited 19.90 min
# 	--> stop 5252010205, npass 2 -> 1, request_272_1, [255.96, 256.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5252010208, npass 1 -> 2, request_353_1, [258.22, 259.22] (arr, dep), 1.00 min, 0.00 min, customers waited 9.22 min
# 	--> stop 5252010207, npass 2 -> 5, request_334_3, [259.62, 262.62] (arr, dep), 3.00 min, 0.00 min, customers waited 18.62 min
# 	--> stop 5256120206, npass 5 -> 4, request_289_1, [270.74, 271.74] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500222, npass 4 -> 3, request_353_1, [279.28, 280.28] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250500123, npass 3 -> 0, request_334_3, [291.69, 294.69] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250500122, npass 0 -> 1, request_423_1, [296.39, 297.39] (arr, dep), 1.00 min, 0.00 min, customers waited 19.39 min
# 	--> stop 5250500119, npass 1 -> 2, request_431_1, [300.51, 301.51] (arr, dep), 1.00 min, 0.00 min, customers waited 19.51 min
# 	--> stop 5250500120, npass 2 -> 3, request_448_1, [302.21, 303.21] (arr, dep), 1.00 min, 0.00 min, customers waited 13.21 min
# 	--> stop 925114800115, npass 3 -> 2, request_448_1, [311.53, 312.53] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114100113, npass 2 -> 1, request_431_1, [319.18, 320.18] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251310216, npass 1 -> 2, request_506_1, [323.87, 324.87] (arr, dep), 1.00 min, 0.00 min, customers waited 9.87 min
# 	--> stop 5107510108, npass 2 -> 1, request_423_1, [335.26, 336.26] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 92571910124, npass 1 -> 3, request_530_2, [338.82, 340.82] (arr, dep), 2.00 min, 0.00 min, customers waited 13.82 min
# 	--> stop 92571910124, npass 3 -> 4, request_529_1, [340.82, 341.82] (arr, dep), 1.00 min, 0.00 min, customers waited 17.82 min
# 	--> stop 5252040138, npass 4 -> 2, request_530_2, [346.43, 348.43] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5206020205, npass 2 -> 4, request_549_2, [351.21, 353.21] (arr, dep), 2.00 min, 0.00 min, customers waited 17.21 min
# 	--> stop 5254010109, npass 4 -> 2, request_549_2, [362.24, 364.24] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720219, npass 2 -> 1, request_506_1, [373.68, 374.68] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020117, npass 1 -> 0, request_529_1, [379.97, 380.97] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 5254010218 at time 392.03
# 	Vehicle currently at stop 5254010218
# 	Busy time: 319.74 (76.13%), Waiting time: 72.29 (17.21%), Busy+Wait: 93.34%
# Itinerary km: 214.54, cost: 214.54
# Total customers: 18, total waiting: 273.41 min, avg: 15.19 min, stdev: 4.92 min
#
# Vehicle with ID veh_20_5254010218 has 42 stops scheduled
# 	Departure from stop 5254010218 at time 82.02
# 	--> stop 5250070217, npass 0 -> 1, request_050_1, [92.00, 93.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5250610128, npass 1 -> 0, request_050_1, [95.63, 96.63] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250600111, npass 0 -> 1, request_062_1, [102.32, 103.32] (arr, dep), 1.00 min, 0.00 min, customers waited 5.32 min
# 	--> stop 5253010112, npass 1 -> 0, request_062_1, [111.79, 112.79] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010113, npass 0 -> 1, request_056_1, [113.10, 114.10] (arr, dep), 1.00 min, 0.00 min, customers waited 19.10 min
# 	--> stop 5252060140, npass 1 -> 2, request_075_1, [115.22, 116.22] (arr, dep), 1.00 min, 0.00 min, customers waited 10.22 min
# 	--> stop 5253010202, npass 2 -> 3, request_074_1, [117.34, 118.34] (arr, dep), 1.00 min, 0.00 min, customers waited 13.34 min
# 	--> stop 5252010226, npass 3 -> 5, request_091_2, [124.51, 126.51] (arr, dep), 2.00 min, -0.00 min, customers waited 11.51 min
# 	--> stop 925217900218, npass 5 -> 4, request_075_1, [133.83, 134.83] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060102, npass 4 -> 3, request_056_1, [146.05, 147.05] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720220, npass 3 -> 1, request_091_2, [151.50, 153.50] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250720121, npass 1 -> 0, request_074_1, [156.44, 157.44] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250720218, npass 0 -> 1, request_147_1, [162.59, 163.59] (arr, dep), 1.00 min, 0.00 min, customers waited 18.59 min
# 	--> stop 5250070116, npass 1 -> 4, request_168_3, [171.55, 174.55] (arr, dep), 3.00 min, 0.00 min, customers waited 17.55 min
# 	--> stop 5250500122, npass 4 -> 3, request_147_1, [183.62, 184.62] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010119, npass 3 -> 0, request_168_3, [199.62, 202.62] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5252010214, npass 0 -> 1, request_241_1, [206.73, 207.73] (arr, dep), 1.00 min, 0.00 min, customers waited 16.73 min
# 	--> stop 92501500101, npass 1 -> 2, request_249_1, [216.11, 217.11] (arr, dep), 1.00 min, 0.00 min, customers waited 18.11 min
# 	--> stop 5403110202, npass 2 -> 3, request_277_1, [220.25, 221.25] (arr, dep), 1.00 min, 0.00 min, customers waited 4.25 min
# 	--> stop 925918510213, npass 3 -> 2, request_277_1, [222.92, 223.92] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060124, npass 2 -> 1, request_249_1, [233.77, 234.77] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060205, npass 1 -> 2, request_315_1, [236.33, 237.33] (arr, dep), 1.00 min, 0.00 min, customers waited 2.33 min
# 	--> stop 5250060119, npass 2 -> 1, request_241_1, [239.85, 240.85] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060122, npass 1 -> 2, request_319_1, [246.94, 247.94] (arr, dep), 1.00 min, 0.00 min, customers waited 10.94 min
# 	--> stop 5250600217, npass 2 -> 5, request_317_3, [254.01, 257.01] (arr, dep), 3.00 min, 0.00 min, customers waited 19.01 min
# 	--> stop 5206020133, npass 5 -> 2, request_317_3, [261.18, 264.18] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5402010115, npass 2 -> 6, request_349_4, [265.75, 269.75] (arr, dep), 4.00 min, 0.00 min, customers waited 18.75 min
# 	--> stop 5256120116, npass 6 -> 5, request_315_1, [274.36, 275.36] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5256120206, npass 5 -> 4, request_319_1, [276.27, 277.27] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060126, npass 4 -> 0, request_349_4, [292.00, 296.00] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 92501620108, npass 0 -> 4, request_425_4, [297.30, 301.30] (arr, dep), 4.00 min, 0.00 min, customers waited 19.30 min
# 	--> stop 5250600108, npass 4 -> 5, request_492_1, [309.89, 310.89] (arr, dep), 1.00 min, 0.00 min, customers waited 1.89 min
# 	--> stop 5250500107, npass 5 -> 6, request_461_1, [311.49, 312.49] (arr, dep), 1.00 min, 0.00 min, customers waited 18.49 min
# 	--> stop 5253010113, npass 6 -> 2, request_425_4, [321.13, 325.13] (arr, dep), 4.00 min, -0.00 min
# 	--> stop 5250060217, npass 2 -> 1, request_492_1, [336.22, 337.22] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250710130, npass 1 -> 0, request_461_1, [345.88, 346.88] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020118, npass 0 -> 1, request_551_1, [350.37, 351.37] (arr, dep), 1.00 min, 0.00 min, customers waited 15.37 min
# 	--> stop 5252060208, npass 1 -> 6, request_568_5, [365.47, 370.47] (arr, dep), 5.00 min, 0.00 min, customers waited 19.47 min
# 	--> stop 5252020202, npass 6 -> 5, request_551_1, [378.11, 379.11] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114800114, npass 5 -> 0, request_568_5, [392.89, 397.89] (arr, dep), 5.00 min, 0.00 min
# 	End in stop 5254010218 at time 413.36
# 	Vehicle currently at stop 5254010218
# 	Busy time: 331.34 (78.89%), Waiting time: 82.02 (19.53%), Busy+Wait: 98.42%
# Itinerary km: 197.36, cost: 197.36
# Total customers: 20, total waiting: 260.28 min, avg: 13.01 min, stdev: 6.60 min

# %%
# Creation of stop-id to appearance-order num file
db = database
order = 1
id_order_dict = {}
for stop in db.stops_dic['features']:
    id = int(stop['properties']['id'])
    id_order_dict[id] = order
    order += 1

# %%
id_order_dict
# Out:
# {5206020116: 1,
#  5206020117: 2,
#  5206020120: 3,
#  5206020126: 4,
#  5206020127: 5,
#  5403110202: 6,
#  5102010203: 7,
#  5102010108: 8,
#  5102010206: 9,
#  5252040135: 10,
#  5252040211: 11,
#  5252010214: 12,
#  925217900217: 13,
#  925217900218: 14,
#  5252060137: 15,
#  5252060208: 16,
#  5252060142: 17,
#  5252060140: 18,
#  5252060207: 19,
#  5252060205: 20,
#  5403010125: 21,
#  5403010204: 22,
#  5206020134: 23,
#  5102010105: 24,
#  5256100110: 25,
#  5102010106: 26,
#  5106010209: 27,
#  5201110121: 28,
#  5102020204: 29,
#  5256150204: 30,
#  5252010107: 31,
#  92633201207: 32,
#  5104010118: 33,
#  5402010115: 34,
#  5107510108: 35,
#  5107510203: 36,
#  5250500117: 37,
#  5250500102: 38,
#  5201110203: 39,
#  5206020204: 40,
#  5206020205: 41,
#  5206020210: 42,
#  5206020211: 43,
#  5206020202: 44,
#  5206020207: 45,
#  5250710126: 46,
#  5250500126: 47,
#  5250500202: 48,
#  5250600117: 49,
#  5250600209: 50,
#  5250600217: 51,
#  5250750108: 52,
#  5250750109: 53,
#  5250720215: 54,
#  5250720216: 55,
#  5250720131: 56,
#  5250720130: 57,
#  5250720220: 58,
#  5250070106: 59,
#  5250070216: 60,
#  5250070217: 61,
#  5250070218: 62,
#  5250600118: 63,
#  5250600207: 64,
#  5250600208: 65,
#  5250610123: 66,
#  5250610128: 67,
#  5250610202: 68,
#  5250710131: 69,
#  5250710202: 70,
#  5250720121: 71,
#  5250720132: 72,
#  5250060108: 73,
#  5250060112: 74,
#  5250720134: 75,
#  5250720223: 76,
#  5250060114: 77,
#  5250060115: 78,
#  5250060116: 79,
#  5250060117: 80,
#  5250060119: 81,
#  5250060121: 82,
#  5250060122: 83,
#  5250060208: 84,
#  5904210202: 85,
#  5904210109: 86,
#  5904210110: 87,
#  5251400111: 88,
#  5251400112: 89,
#  5252060209: 90,
#  5252010114: 91,
#  5251400115: 92,
#  5252010101: 93,
#  5206020119: 94,
#  5250500208: 95,
#  5252010216: 96,
#  92531830221: 97,
#  92571910123: 98,
#  92571910124: 99,
#  92571910203: 100,
#  92571910204: 101,
#  92501500101: 102,
#  92501620103: 103,
#  92501620104: 104,
#  92501620108: 105,
#  92501620205: 106,
#  92501620206: 107,
#  92501620208: 108,
#  92501650104: 109,
#  92501650201: 110,
#  925611130108: 111,
#  925114220110: 112,
#  925611130106: 113,
#  925611130107: 114,
#  925611130109: 115,
#  925611130110: 116,
#  925611210107: 117,
#  5256120203: 118,
#  5256120205: 119,
#  5904210201: 120,
#  925611130111: 121,
#  5256120209: 122,
#  5106010102: 123,
#  925113110225: 124,
#  5206020130: 125,
#  5206020132: 126,
#  5250500104: 127,
#  5250500108: 128,
#  5250500217: 129,
#  5250600109: 130,
#  5254020107: 131,
#  5256120202: 132,
#  5259030211: 133,
#  5401030116: 134,
#  925016010225: 135,
#  925113110226: 136,
#  925918510213: 137,
#  5250720135: 138,
#  5250720128: 139,
#  5250720219: 140,
#  5250720127: 141,
#  5250500209: 142,
#  5250060217: 143,
#  5250070116: 144,
#  5250500120: 145,
#  5250500121: 146,
#  5250500123: 147,
#  5250500214: 148,
#  5250500215: 149,
#  5250500216: 150,
#  5250600113: 151,
#  5250600115: 152,
#  5250600116: 153,
#  5250600210: 154,
#  5250710203: 155,
#  5250720133: 156,
#  5250720222: 157,
#  5403010127: 158,
#  925010610128: 159,
#  5250070112: 160,
#  5250710120: 161,
#  5251310223: 162,
#  5253010106: 163,
#  5904210204: 164,
#  5250500118: 165,
#  5250060124: 166,
#  5250500204: 167,
#  5250500205: 168,
#  5250500206: 169,
#  5250500220: 170,
#  5250720227: 171,
#  5254020114: 172,
#  5254020227: 173,
#  5206020128: 174,
#  5250060123: 175,
#  5250060125: 176,
#  5250060203: 177,
#  5250600101: 178,
#  5250600119: 179,
#  5250610118: 180,
#  5250610129: 181,
#  5206030121: 182,
#  5250060111: 183,
#  5250060126: 184,
#  5250060127: 185,
#  5250060205: 186,
#  5250500119: 187,
#  5250600108: 188,
#  5250600110: 189,
#  5250600111: 190,
#  5250600112: 191,
#  5250600114: 192,
#  5250710130: 193,
#  5250710204: 194,
#  5250710205: 195,
#  5250720119: 196,
#  5250720217: 197,
#  5250720218: 198,
#  5251400116: 199,
#  5254020225: 200,
#  925426710102: 201,
#  5201110119: 202,
#  5201110120: 203,
#  5206030119: 204,
#  5250070120: 205,
#  5250070121: 206,
#  5250500222: 207,
#  5250500223: 208,
#  5250600212: 209,
#  5250600213: 210,
#  5250600214: 211,
#  5250600218: 212,
#  5250720229: 213,
#  5250720246: 214,
#  5251300101: 215,
#  5251300111: 216,
#  5251310103: 217,
#  5251400205: 218,
#  5206020118: 219,
#  925114100112: 220,
#  925114100113: 221,
#  925114100115: 222,
#  925114100117: 223,
#  925114100118: 224,
#  925114100203: 225,
#  5218010299: 226,
#  5252010223: 227,
#  5254010111: 228,
#  5254010112: 229,
#  5254010113: 230,
#  5254010218: 231,
#  5254010219: 232,
#  5254010220: 233,
#  925114700115: 234,
#  925114700201: 235,
#  925114700204: 236,
#  925114800111: 237,
#  5104010119: 238,
#  5250720221: 239,
#  5250720129: 240,
#  5206040209: 241,
#  5206040125: 242,
#  5206030212: 243,
#  5252010106: 244,
#  5252010224: 245,
#  5252010109: 246,
#  5252010221: 247,
#  5252010111: 248,
#  5252010219: 249,
#  5252010112: 250,
#  5252010218: 251,
#  5252010115: 252,
#  5252010215: 253,
#  5253010114: 254,
#  5253010204: 255,
#  5253010113: 256,
#  5252060138: 257,
#  925217900103: 258,
#  5201110118: 259,
#  5201110204: 260,
#  5201110205: 261,
#  5206020131: 262,
#  5206020133: 263,
#  5206020208: 264,
#  5250060101: 265,
#  5250060102: 266,
#  5250060103: 267,
#  5250060204: 268,
#  5250060206: 269,
#  5250060210: 270,
#  5250060211: 271,
#  5250060214: 272,
#  5250060215: 273,
#  5250060216: 274,
#  5250060218: 275,
#  5250500103: 276,
#  5250500106: 277,
#  5250500107: 278,
#  5250500110: 279,
#  5250500111: 280,
#  5250500112: 281,
#  5250500122: 282,
#  5250500124: 283,
#  5250500125: 284,
#  5250500203: 285,
#  5250500207: 286,
#  5250500218: 287,
#  5250500225: 288,
#  5250600106: 289,
#  5250710118: 290,
#  5250710128: 291,
#  5250710129: 292,
#  5250710206: 293,
#  5250720124: 294,
#  5250740208: 295,
#  5250740211: 296,
#  5250740212: 297,
#  5250740213: 298,
#  5250750107: 299,
#  5251300102: 300,
#  5251300103: 301,
#  5251300104: 302,
#  5251300105: 303,
#  5251300106: 304,
#  5251300107: 305,
#  5251300108: 306,
#  5251300109: 307,
#  5251310104: 308,
#  5251310105: 309,
#  5251310106: 310,
#  5251310216: 311,
#  5251310221: 312,
#  5251310222: 313,
#  5251400113: 314,
#  5251400114: 315,
#  5251400117: 316,
#  5251400118: 317,
#  5251400119: 318,
#  5251400120: 319,
#  5251400121: 320,
#  5251400122: 321,
#  5251400123: 322,
#  5251400206: 323,
#  5251400207: 324,
#  5251400208: 325,
#  5251400209: 326,
#  5251400210: 327,
#  5251400211: 328,
#  5251400212: 329,
#  5251400213: 330,
#  5251400214: 331,
#  5251400215: 332,
#  5251400216: 333,
#  5251400221: 334,
#  5252010105: 335,
#  5252010108: 336,
#  5252010110: 337,
#  5252010113: 338,
#  5252010119: 339,
#  5252010120: 340,
#  5252010121: 341,
#  5252010122: 342,
#  5252010123: 343,
#  5252010124: 344,
#  5252010125: 345,
#  5252010127: 346,
#  5252010128: 347,
#  5252010203: 348,
#  5252010204: 349,
#  5252010205: 350,
#  5252010206: 351,
#  5252010207: 352,
#  5252010208: 353,
#  5252010209: 354,
#  5252010210: 355,
#  5252010211: 356,
#  5252010212: 357,
#  5252010213: 358,
#  5252010217: 359,
#  5252010220: 360,
#  5252010222: 361,
#  5252010226: 362,
#  5252010227: 363,
#  5252010228: 364,
#  5252010229: 365,
#  5252020202: 366,
#  5252020225: 367,
#  5252040136: 368,
#  5252040137: 369,
#  5252040138: 370,
#  5252040139: 371,
#  5252040140: 372,
#  5252040204: 373,
#  5252040205: 374,
#  5252040206: 375,
#  5252040207: 376,
#  5252040208: 377,
#  5252040209: 378,
#  5252040210: 379,
#  5252050117: 380,
#  5252060139: 381,
#  5252060206: 382,
#  5253010102: 383,
#  5253010103: 384,
#  5253010104: 385,
#  5253010107: 386,
#  5253010108: 387,
#  5253010109: 388,
#  5253010110: 389,
#  5253010111: 390,
#  5253010112: 391,
#  5253010115: 392,
#  5253010116: 393,
#  5253010117: 394,
#  5253010118: 395,
#  5253010119: 396,
#  5253010120: 397,
#  5253010202: 398,
#  5253010203: 399,
#  5253010206: 400,
#  5253010207: 401,
#  5253010208: 402,
#  5253010209: 403,
#  5253010210: 404,
#  5253010211: 405,
#  5253010213: 406,
#  5253010214: 407,
#  5253010215: 408,
#  5253010216: 409,
#  5253010217: 410,
#  5253010218: 411,
#  5253010219: 412,
#  5253010220: 413,
#  5254010108: 414,
#  5254010109: 415,
#  5254010110: 416,
#  5254010221: 417,
#  5254010223: 418,
#  5254010228: 419,
#  5254020112: 420,
#  5254020113: 421,
#  5254020115: 422,
#  5254020224: 423,
#  5254020226: 424,
#  5254020233: 425,
#  5256120113: 426,
#  5256120114: 427,
#  5256120115: 428,
#  5256120116: 429,
#  5256120117: 430,
#  5256120118: 431,
#  5256120119: 432,
#  5256120204: 433,
#  5256120206: 434,
#  5256120208: 435,
#  5256120210: 436,
#  5259010102: 437,
#  5259010103: 438,
#  5259010208: 439,
#  5259020214: 440,
#  5259020216: 441,
#  5904210111: 442,
#  5904210112: 443,
#  92501650108: 444,
#  92501650109: 445,
#  92501650202: 446,
#  92571910122: 447,
#  92592810104: 448,
#  925010610127: 449,
#  925113110101: 450,
#  925113110107: 451,
#  925114010111: 452,
#  925114010112: 453,
#  925114010123: 454,
#  925114100114: 455,
#  925114100116: 456,
#  925114100202: 457,
#  925114100204: 458,
#  925114700109: 459,
#  925114700110: 460,
#  925114700111: 461,
#  925114700112: 462,
#  925114700113: 463,
#  925114700114: 464,
#  925114700202: 465,
#  925114700203: 466,
#  925114700205: 467,
#  925114700206: 468,
#  925114700207: 469,
#  925114800109: 470,
#  925114800110: 471,
#  925114800112: 472,
#  925114800113: 473,
#  925114800114: 474,
#  925114800115: 475,
#  925217900101: 476,
#  925217900102: 477,
#  925217900114: 478,
#  925218000218: 479,
#  925218000223: 480,
#  925218210235: 481,
#  925426810110: 482}

# %% [markdown]
# # Neighbouring stops

# %%
db = database
for stop in db.stops_dic['features']:
    id = stop['id']
    print(f"{id}: {len(db.get_neighbouring_stops_dict(stop_id=id, max_distance_km=1, geodesic=True))}")

# Version for NUMERIC DISTANCE MATRIX
# for i in range(0, len(db.stops_dic['features'])):
#    print(f"{i}: {[x[0] for x in db.neighbouring_stops(stop_id=i, max_distance_km=0.5)]}")
# Out:
# 5206020116: 0
# 5206020117: 0
# 5206020120: 23
# 5206020126: 1
# 5206020127: 15
# 5403110202: 29
# 5102010203: 9
# 5102010108: 13
# 5102010206: 4
# 5252040135: 20
# 5252040211: 19
# 5252010214: 20
# 925217900217: 3
# 925217900218: 3
# 5252060137: 25
# 5252060208: 25
# 5252060142: 26
# 5252060140: 25
# 5252060207: 26
# 5252060205: 25
# 5403010125: 31
# 5403010204: 0
# 5206020134: 13
# 5102010105: 15
# 5256100110: 16
# 5102010106: 13
# 5106010209: 7
# 5201110121: 14
# 5102020204: 12
# 5256150204: 15
# 5252010107: 13
# 92633201207: 16
# 5104010118: 13
# 5402010115: 13
# 5107510108: 13
# 5107510203: 14
# 5250500117: 19
# 5250500102: 21
# 5201110203: 9
# 5206020204: 16
# 5206020205: 1
# 5206020210: 21
# 5206020211: 20
# 5206020202: 20
# 5206020207: 14
# 5250710126: 22
# 5250500126: 10
# 5250500202: 11
# 5250600117: 22
# 5250600209: 23
# 5250600217: 11
# 5250750108: 12
# 5250750109: 15
# 5250720215: 1
# 5250720216: 3
# 5250720131: 7
# 5250720130: 11
# 5250720220: 11
# 5250070106: 16
# 5250070216: 21
# 5250070217: 21
# 5250070218: 21
# 5250600118: 21
# 5250600207: 23
# 5250600208: 25
# 5250610123: 24
# 5250610128: 12
# 5250610202: 20
# 5250710131: 3
# 5250710202: 5
# 5250720121: 12
# 5250720132: 4
# 5250060108: 12
# 5250060112: 18
# 5250720134: 3
# 5250720223: 18
# 5250060114: 21
# 5250060115: 15
# 5250060116: 16
# 5250060117: 18
# 5250060119: 2
# 5250060121: 3
# 5250060122: 22
# 5250060208: 4
# 5904210202: 15
# 5904210109: 20
# 5904210110: 25
# 5251400111: 5
# 5251400112: 7
# 5252060209: 18
# 5252010114: 18
# 5251400115: 11
# 5252010101: 9
# 5206020119: 18
# 5250500208: 19
# 5252010216: 16
# 92531830221: 19
# 92571910123: 5
# 92571910124: 7
# 92571910203: 5
# 92571910204: 1
# 92501500101: 14
# 92501620103: 24
# 92501620104: 14
# 92501620108: 18
# 92501620205: 21
# 92501620206: 27
# 92501620208: 28
# 92501650104: 16
# 92501650201: 11
# 925611130108: 2
# 925114220110: 6
# 925611130106: 4
# 925611130107: 2
# 925611130109: 2
# 925611130110: 2
# 925611210107: 15
# 5256120203: 11
# 5256120205: 7
# 5904210201: 6
# 925611130111: 1
# 5256120209: 10
# 5106010102: 8
# 925113110225: 22
# 5206020130: 18
# 5206020132: 22
# 5250500104: 9
# 5250500108: 15
# 5250500217: 9
# 5250600109: 14
# 5254020107: 16
# 5256120202: 8
# 5259030211: 32
# 5401030116: 27
# 925016010225: 17
# 925113110226: 28
# 925918510213: 27
# 5250720135: 1
# 5250720128: 20
# 5250720219: 5
# 5250720127: 19
# 5250500209: 19
# 5250060217: 15
# 5250070116: 9
# 5250500120: 14
# 5250500121: 12
# 5250500123: 9
# 5250500214: 7
# 5250500215: 6
# 5250500216: 5
# 5250600113: 11
# 5250600115: 9
# 5250600116: 9
# 5250600210: 9
# 5250710203: 6
# 5250720133: 5
# 5250720222: 20
# 5403010127: 10
# 925010610128: 20
# 5250070112: 16
# 5250710120: 9
# 5251310223: 17
# 5253010106: 7
# 5904210204: 18
# 5250500118: 18
# 5250060124: 13
# 5250500204: 13
# 5250500205: 14
# 5250500206: 16
# 5250500220: 16
# 5250720227: 18
# 5254020114: 12
# 5254020227: 9
# 5206020128: 15
# 5250060123: 15
# 5250060125: 20
# 5250060203: 13
# 5250600101: 15
# 5250600119: 21
# 5250610118: 21
# 5250610129: 12
# 5206030121: 12
# 5250060111: 13
# 5250060126: 19
# 5250060127: 16
# 5250060205: 14
# 5250500119: 17
# 5250600108: 15
# 5250600110: 7
# 5250600111: 8
# 5250600112: 9
# 5250600114: 9
# 5250710130: 4
# 5250710204: 10
# 5250710205: 13
# 5250720119: 13
# 5250720217: 5
# 5250720218: 4
# 5251400116: 13
# 5254020225: 13
# 925426710102: 19
# 5201110119: 9
# 5201110120: 14
# 5206030119: 17
# 5250070120: 7
# 5250070121: 7
# 5250500222: 14
# 5250500223: 9
# 5250600212: 10
# 5250600213: 11
# 5250600214: 9
# 5250600218: 14
# 5250720229: 13
# 5250720246: 16
# 5251300101: 6
# 5251300111: 3
# 5251310103: 14
# 5251400205: 18
# 5206020118: 5
# 925114100112: 11
# 925114100113: 9
# 925114100115: 11
# 925114100117: 10
# 925114100118: 9
# 925114100203: 8
# 5218010299: 14
# 5252010223: 13
# 5254010111: 3
# 5254010112: 1
# 5254010113: 1
# 5254010218: 1
# 5254010219: 1
# 5254010220: 3
# 925114700115: 22
# 925114700201: 22
# 925114700204: 12
# 925114800111: 12
# 5104010119: 15
# 5250720221: 19
# 5250720129: 19
# 5206040209: 19
# 5206040125: 19
# 5206030212: 4
# 5252010106: 13
# 5252010224: 13
# 5252010109: 11
# 5252010221: 11
# 5252010111: 11
# 5252010219: 11
# 5252010112: 11
# 5252010218: 9
# 5252010115: 19
# 5252010215: 18
# 5253010114: 27
# 5253010204: 27
# 5253010113: 26
# 5252060138: 26
# 925217900103: 20
# 5201110118: 6
# 5201110204: 6
# 5201110205: 8
# 5206020131: 27
# 5206020133: 16
# 5206020208: 17
# 5250060101: 19
# 5250060102: 18
# 5250060103: 18
# 5250060204: 12
# 5250060206: 22
# 5250060210: 21
# 5250060211: 21
# 5250060214: 15
# 5250060215: 25
# 5250060216: 16
# 5250060218: 14
# 5250500103: 16
# 5250500106: 14
# 5250500107: 14
# 5250500110: 9
# 5250500111: 9
# 5250500112: 5
# 5250500122: 11
# 5250500124: 6
# 5250500125: 6
# 5250500203: 10
# 5250500207: 17
# 5250500218: 9
# 5250500225: 28
# 5250600106: 15
# 5250710118: 17
# 5250710128: 11
# 5250710129: 13
# 5250710206: 13
# 5250720124: 18
# 5250740208: 9
# 5250740211: 15
# 5250740212: 12
# 5250740213: 9
# 5250750107: 9
# 5251300102: 4
# 5251300103: 3
# 5251300104: 9
# 5251300105: 10
# 5251300106: 9
# 5251300107: 8
# 5251300108: 8
# 5251300109: 8
# 5251310104: 15
# 5251310105: 11
# 5251310106: 8
# 5251310216: 7
# 5251310221: 15
# 5251310222: 14
# 5251400113: 11
# 5251400114: 12
# 5251400117: 14
# 5251400118: 17
# 5251400119: 16
# 5251400120: 17
# 5251400121: 22
# 5251400122: 22
# 5251400123: 18
# 5251400206: 22
# 5251400207: 19
# 5251400208: 16
# 5251400209: 17
# 5251400210: 16
# 5251400211: 16
# 5251400212: 15
# 5251400213: 13
# 5251400214: 11
# 5251400215: 7
# 5251400216: 5
# 5251400221: 10
# 5252010105: 11
# 5252010108: 13
# 5252010110: 11
# 5252010113: 14
# 5252010119: 14
# 5252010120: 13
# 5252010121: 15
# 5252010122: 19
# 5252010123: 21
# 5252010124: 26
# 5252010125: 28
# 5252010127: 28
# 5252010128: 29
# 5252010203: 30
# 5252010204: 29
# 5252010205: 28
# 5252010206: 24
# 5252010207: 25
# 5252010208: 22
# 5252010209: 19
# 5252010210: 15
# 5252010211: 13
# 5252010212: 9
# 5252010213: 13
# 5252010217: 14
# 5252010220: 11
# 5252010222: 13
# 5252010226: 13
# 5252010227: 9
# 5252010228: 4
# 5252010229: 4
# 5252020202: 32
# 5252020225: 11
# 5252040136: 18
# 5252040137: 19
# 5252040138: 23
# 5252040139: 30
# 5252040140: 33
# 5252040204: 30
# 5252040205: 25
# 5252040206: 23
# 5252040207: 22
# 5252040208: 19
# 5252040209: 15
# 5252040210: 22
# 5252050117: 5
# 5252060139: 23
# 5252060206: 23
# 5253010102: 19
# 5253010103: 18
# 5253010104: 10
# 5253010107: 11
# 5253010108: 11
# 5253010109: 18
# 5253010110: 19
# 5253010111: 20
# 5253010112: 25
# 5253010115: 25
# 5253010116: 25
# 5253010117: 19
# 5253010118: 15
# 5253010119: 9
# 5253010120: 11
# 5253010202: 17
# 5253010203: 24
# 5253010206: 25
# 5253010207: 22
# 5253010208: 18
# 5253010209: 18
# 5253010210: 13
# 5253010211: 11
# 5253010213: 10
# 5253010214: 14
# 5253010215: 14
# 5253010216: 6
# 5253010217: 12
# 5253010218: 15
# 5253010219: 16
# 5253010220: 14
# 5254010108: 22
# 5254010109: 3
# 5254010110: 3
# 5254010221: 3
# 5254010223: 20
# 5254010228: 29
# 5254020112: 7
# 5254020113: 9
# 5254020115: 15
# 5254020224: 19
# 5254020226: 12
# 5254020233: 16
# 5256120113: 16
# 5256120114: 15
# 5256120115: 7
# 5256120116: 8
# 5256120117: 8
# 5256120118: 10
# 5256120119: 10
# 5256120204: 12
# 5256120206: 8
# 5256120208: 16
# 5256120210: 0
# 5259010102: 29
# 5259010103: 10
# 5259010208: 7
# 5259020214: 31
# 5259020216: 7
# 5904210111: 15
# 5904210112: 6
# 92501650108: 12
# 92501650109: 11
# 92501650202: 13
# 92571910122: 1
# 92592810104: 31
# 925010610127: 12
# 925113110101: 30
# 925113110107: 15
# 925114010111: 9
# 925114010112: 9
# 925114010123: 17
# 925114100114: 11
# 925114100116: 11
# 925114100202: 8
# 925114100204: 11
# 925114700109: 16
# 925114700110: 18
# 925114700111: 17
# 925114700112: 12
# 925114700113: 22
# 925114700114: 20
# 925114700202: 22
# 925114700203: 22
# 925114700205: 17
# 925114700206: 18
# 925114700207: 16
# 925114800109: 14
# 925114800110: 13
# 925114800112: 11
# 925114800113: 17
# 925114800114: 16
# 925114800115: 19
# 925217900101: 3
# 925217900102: 3
# 925217900114: 11
# 925218000218: 9
# 925218000223: 25
# 925218210235: 22
# 925426810110: 0

# %% [markdown]
# # Stop modification creation

# %% [markdown]
# ## Itinerary Leg evaluation

# %%
from main.scheduler import new_itinerary_from_itinerary
I = new_itinerary_from_itinerary(sche.itineraries[0])
itinerary_id = I.vehicle_id
# Cost of an itinerary (sum of all leg times)
print(f"{I.vehicle_id}, {I.cost}")
for S in I.stop_list:
    # Cost of an itinerary leg (going from S to S.snext)
    try:
        print(f"\t{int(S.id):2d} --> {int(S.snext.id):2d}, {S.leg_time:3.2f}min, {db.get_route_distance_km(S.id, S.snext.id):3.2f}km, {S.passenger_id}")
    except AttributeError:
        print(f"\t{int(S.id):2d} --> None, {S.leg_time:3.2f}, 0km, {S.passenger_id}")
# Out:
# veh_01_925113110225, 208.55880000000002
# 	925113110225 --> 5250500102, 1.04min, 0.61km, None
# 	5250500102 --> 5252040204, 1.76min, 1.44km, None
# 	5252040204 --> 5252010214, 6.90min, 4.57km, None
# 	5252010214 --> 5252020202, 7.13min, 4.59km, None
# 	5252020202 --> 5403110202, 2.84min, 1.33km, None
# 	5403110202 --> 5904210202, 5.54min, 3.99km, None
# 	5904210202 --> 92501650201, 12.08min, 9.51km, None
# 	92501650201 --> 5251400112, 4.01min, 2.80km, None
# 	5251400112 --> 5251300111, 5.72min, 3.84km, None
# 	5251300111 --> 5254020107, 9.54min, 8.75km, None
# 	5254020107 --> 5250060205, 8.29min, 6.48km, None
# 	5250060205 --> 5250600110, 6.09min, 4.06km, None
# 	5250600110 --> 5251300107, 10.57min, 7.97km, None
# 	5251300107 --> 5251300103, 4.09min, 1.66km, None
# 	5251300103 --> 5201110204, 6.81min, 3.13km, None
# 	5201110204 --> 5251400214, 6.62min, 5.19km, None
# 	5251400214 --> 5250500121, 6.07min, 3.22km, None
# 	5250500121 --> 5250500118, 2.24min, 1.42km, None
# 	5250500118 --> 5250500112, 5.09min, 4.03km, None
# 	5250500112 --> 5252010127, 6.54min, 4.70km, None
# 	5252010127 --> 5102010105, 5.81min, 4.36km, None
# 	5102010105 --> 5252040137, 8.01min, 5.77km, None
# 	5252040137 --> 5252040137, 0.00min, 0.00km, None
# 	5252040137 --> 925114700112, 15.81min, 13.05km, None
# 	925114700112 --> 925114700202, 3.66min, 1.43km, None
# 	925114700202 --> 925114700206, 2.26min, 0.96km, None
# 	925114700206 --> 5251400120, 2.98min, 1.54km, None
# 	5251400120 --> 5250720229, 14.76min, 12.80km, None
# 	5250720229 --> 5206020118, 3.73min, 2.46km, None
# 	5206020118 --> 5250060103, 3.73min, 1.99km, None
# 	5250060103 --> 5252010107, 9.42min, 8.26km, None
# 	5252010107 --> 5253010209, 8.21min, 4.83km, None
# 	5253010209 --> 5253010117, 2.48min, 1.47km, None
# 	5253010117 --> 5253010204, 1.19min, 0.71km, None
# 	5253010204 --> 5252060140, 0.64min, 0.35km, None
# 	5252060140 --> 5252010111, 3.58min, 2.30km, None
# 	5252010111 --> 5252010111, 0.00min, 0.00km, None
# 	5252010111 --> 5252010205, 7.66min, 6.21km, None
# 	5252010205 --> 5252040140, 0.72min, 0.59km, None
# 	5252040140 --> 5254020107, 4.45min, 3.22km, None
# 	5254020107 --> 5256120203, 5.73min, 3.94km, None
# 	5256120203 --> 5904210201, 5.15min, 3.32km, None
# 	5904210201 --> 5256120209, 0.63min, 0.61km, None
# 	5256120209 --> 925611130106, 6.80min, 4.64km, None
# 	925611130106 --> 5252040207, 8.41min, 6.48km, None
# 	5252040207 --> 5206020205, 2.46min, 1.88km, None
# 	5206020205 --> 5252010122, 3.27min, 2.46km, None
# 	5252010122 --> 5201110120, 6.18min, 4.99km, None
# 	5201110120 --> 925114010111, 7.64min, 5.58km, None
# 	925114010111 --> 5250500124, 9.89min, 8.31km, None
# 	5250500124 --> 925113110225, 11.74min, 10.74km, None
# 	925113110225 --> None, 0.00, 0km, None

# %%
from main.leg import Leg
def create_legs_from_itinerary(I, database):
    legs = []
    prev = None

    for S in I.stop_list:
        # Get previous leg
        if len(legs) > 0:
            prev = legs[-1]

        # Get S and T
        T = S.snext
        # if S is not the last stop, T is not None
        if T is not None:
            # Leg creation with temporal and distance costs
            l = Leg(itinerary=I.vehicle_id,
                    origin_stop=S,
                    dest_stop=S.snext,
                    passenger_id=S.snext.passenger_id,
                    time_cost=S.leg_time,
                    dist_cost=database.get_route_distance_km(S.id,S.snext.id),
                    prev=prev, next=None)
            # update result
            legs.append(l)
        # S is the last stop
        else:
            l = Leg(itinerary=I.vehicle_id,
                    origin_stop=S,
                    dest_stop=None,
                    passenger_id="DEPOT",
                    time_cost=S.leg_time,
                    dist_cost=0,
                    prev=prev, # prev -> l connection
                    next=None)
            # update result
            legs.append(l)

        # if S is not the first stop, update prev leg
        if prev is not None:
            prev.set_next(l) # prev -> l connection
    count = 0
    for leg in legs:
        print(f"{count:3d}: {leg.__str__()}")
        count += 1
    return legs

legs = create_legs_from_itinerary(I, db)
# Out:
#   0: veh_01_925113110225 :: leg (925113110225, 63.96) --> (5250500102, 65.00), 1.04min, 0.61km, request_002_1
#   1: veh_01_925113110225 :: leg (5250500102, 66.00) --> (5252040204, 67.76), 1.76min, 1.44km, request_002_1
#   2: veh_01_925113110225 :: leg (5252040204, 68.76) --> (5252010214, 75.66), 6.90min, 4.57km, request_001_1
#   3: veh_01_925113110225 :: leg (5252010214, 76.66) --> (5252020202, 83.79), 7.13min, 4.59km, request_003_2
#   4: veh_01_925113110225 :: leg (5252020202, 85.79) --> (5403110202, 88.63), 2.84min, 1.33km, request_021_1
#   5: veh_01_925113110225 :: leg (5403110202, 89.63) --> (5904210202, 95.17), 5.54min, 3.99km, request_003_2
#   6: veh_01_925113110225 :: leg (5904210202, 97.17) --> (92501650201, 109.26), 12.08min, 9.51km, request_021_1
#   7: veh_01_925113110225 :: leg (92501650201, 110.26) --> (5251400112, 114.26), 4.01min, 2.80km, request_001_1
#   8: veh_01_925113110225 :: leg (5251400112, 115.26) --> (5251300111, 120.98), 5.72min, 3.84km, request_068_2
#   9: veh_01_925113110225 :: leg (5251300111, 122.98) --> (5254020107, 132.53), 9.54min, 8.75km, request_097_1
#  10: veh_01_925113110225 :: leg (5254020107, 133.53) --> (5250060205, 141.81), 8.29min, 6.48km, request_068_2
#  11: veh_01_925113110225 :: leg (5250060205, 143.91) --> (5250600110, 150.00), 6.09min, 4.06km, request_155_1
#  12: veh_01_925113110225 :: leg (5250600110, 151.00) --> (5251300107, 161.57), 10.57min, 7.97km, request_097_1
#  13: veh_01_925113110225 :: leg (5251300107, 162.57) --> (5251300103, 166.66), 4.09min, 1.66km, request_175_1
#  14: veh_01_925113110225 :: leg (5251300103, 167.66) --> (5201110204, 174.48), 6.81min, 3.13km, request_179_1
#  15: veh_01_925113110225 :: leg (5201110204, 175.48) --> (5251400214, 182.09), 6.62min, 5.19km, request_185_1
#  16: veh_01_925113110225 :: leg (5251400214, 183.09) --> (5250500121, 189.17), 6.07min, 3.22km, request_155_1
#  17: veh_01_925113110225 :: leg (5250500121, 190.17) --> (5250500118, 192.41), 2.24min, 1.42km, request_179_1
#  18: veh_01_925113110225 :: leg (5250500118, 193.41) --> (5250500112, 198.50), 5.09min, 4.03km, request_244_1
#  19: veh_01_925113110225 :: leg (5250500112, 199.50) --> (5252010127, 206.04), 6.54min, 4.70km, request_175_1
#  20: veh_01_925113110225 :: leg (5252010127, 207.04) --> (5102010105, 212.85), 5.81min, 4.36km, request_185_1
#  21: veh_01_925113110225 :: leg (5102010105, 213.85) --> (5252040137, 221.86), 8.01min, 5.77km, request_255_5
#  22: veh_01_925113110225 :: leg (5252040137, 226.86) --> (5252040137, 226.86), 0.00min, 0.00km, request_244_1
#  23: veh_01_925113110225 :: leg (5252040137, 227.86) --> (925114700112, 243.68), 15.81min, 13.05km, request_296_1
#  24: veh_01_925113110225 :: leg (925114700112, 244.68) --> (925114700202, 248.33), 3.66min, 1.43km, request_255_5
#  25: veh_01_925113110225 :: leg (925114700202, 253.33) --> (925114700206, 255.59), 2.26min, 0.96km, request_318_2
#  26: veh_01_925113110225 :: leg (925114700206, 257.59) --> (5251400120, 260.57), 2.98min, 1.54km, request_337_1
#  27: veh_01_925113110225 :: leg (5251400120, 261.57) --> (5250720229, 276.33), 14.76min, 12.80km, request_374_1
#  28: veh_01_925113110225 :: leg (5250720229, 277.33) --> (5206020118, 281.07), 3.73min, 2.46km, request_296_1
#  29: veh_01_925113110225 :: leg (5206020118, 282.07) --> (5250060103, 285.80), 3.73min, 1.99km, request_337_1
#  30: veh_01_925113110225 :: leg (5250060103, 286.80) --> (5252010107, 296.22), 9.42min, 8.26km, request_318_2
#  31: veh_01_925113110225 :: leg (5252010107, 298.22) --> (5253010209, 306.43), 8.21min, 4.83km, request_374_1
#  32: veh_01_925113110225 :: leg (5253010209, 307.43) --> (5253010117, 309.91), 2.48min, 1.47km, request_459_1
#  33: veh_01_925113110225 :: leg (5253010117, 310.91) --> (5253010204, 312.10), 1.19min, 0.71km, request_483_1
#  34: veh_01_925113110225 :: leg (5253010204, 313.10) --> (5252060140, 313.74), 0.64min, 0.35km, request_464_3
#  35: veh_01_925113110225 :: leg (5252060140, 316.74) --> (5252010111, 320.32), 3.58min, 2.30km, request_496_2
#  36: veh_01_925113110225 :: leg (5252010111, 322.32) --> (5252010111, 322.32), 0.00min, 0.00km, request_483_1
#  37: veh_01_925113110225 :: leg (5252010111, 323.32) --> (5252010205, 330.99), 7.66min, 6.21km, request_459_1
#  38: veh_01_925113110225 :: leg (5252010205, 331.99) --> (5252040140, 332.71), 0.72min, 0.59km, request_542_1
#  39: veh_01_925113110225 :: leg (5252040140, 333.71) --> (5254020107, 338.16), 4.45min, 3.22km, request_464_3
#  40: veh_01_925113110225 :: leg (5254020107, 341.16) --> (5256120203, 346.89), 5.73min, 3.94km, request_535_1
#  41: veh_01_925113110225 :: leg (5256120203, 347.89) --> (5904210201, 353.04), 5.15min, 3.32km, request_496_2
#  42: veh_01_925113110225 :: leg (5904210201, 355.04) --> (5256120209, 355.67), 0.63min, 0.61km, request_535_1
#  43: veh_01_925113110225 :: leg (5256120209, 356.67) --> (925611130106, 363.48), 6.80min, 4.64km, request_542_1
#  44: veh_01_925113110225 :: leg (925611130106, 364.48) --> (5252040207, 372.89), 8.41min, 6.48km, request_581_1
#  45: veh_01_925113110225 :: leg (5252040207, 373.89) --> (5206020205, 376.34), 2.46min, 1.88km, request_590_1
#  46: veh_01_925113110225 :: leg (5206020205, 377.34) --> (5252010122, 380.61), 3.27min, 2.46km, request_597_3
#  47: veh_01_925113110225 :: leg (5252010122, 383.61) --> (5201110120, 389.79), 6.18min, 4.99km, request_590_1
#  48: veh_01_925113110225 :: leg (5201110120, 390.79) --> (925114010111, 398.44), 7.64min, 5.58km, request_581_1
#  49: veh_01_925113110225 :: leg (925114010111, 399.44) --> (5250500124, 409.32), 9.89min, 8.31km, request_597_3
#  50: veh_01_925113110225 :: leg (5250500124, 412.32) --> (925113110225, 424.06), 11.74min, 10.74km, None
#  51: veh_01_925113110225 :: leg (925113110225, inf) --> (None, inf), 0.00, 0.00min, 0.00km, DEPOT

# %% [markdown]
# ## Itinerary stop-visit cost computation

# %%
def compute_stop_cost_dict(legs):
    # Cost of a stop visit: cost of prev -> S + cost of S -> next
    stop_cost_dict = {}
    for i in range(len(I.stop_list)):
        stop = I.stop_list[i]
        leg = legs[i]

        prev_dist_cost = 0
        next_dist_cost = 0
        prev_time_cost = 0
        next_time_cost = 0

        # not first stop
        if leg.prev is not None:
            prev_dist_cost = leg.prev.dist_cost
            prev_time_cost = leg.prev.time_cost

        # not last stop
        if leg.next is not None:
            next_dist_cost = leg.dist_cost
            next_time_cost = leg.time_cost

        stop_cost_dict[i] = { "stop_id": stop.id,
                             "leg": leg,
                             "dist_cost": prev_dist_cost+next_dist_cost,
                             "time_cost": prev_time_cost+next_time_cost}
    return stop_cost_dict

stop_cost_dict = compute_stop_cost_dict(legs)

# %%
for key, value in stop_cost_dict.items():
    print(f"{key}: {value}")
# Out:
# 0: {'stop_id': 925113110225, 'leg': <main.leg.Leg object at 0x3575c8f10>, 'dist_cost': 0.6092000000000001, 'time_cost': 1.0366666666666666}
# 1: {'stop_id': 5250500102, 'leg': <main.leg.Leg object at 0x3575c8340>, 'dist_cost': 2.0502000000000002, 'time_cost': 2.8}
# 2: {'stop_id': 5252040204, 'leg': <main.leg.Leg object at 0x119a71fd0>, 'dist_cost': 6.0138, 'time_cost': 8.663333333333334}
# 3: {'stop_id': 5252010214, 'leg': <main.leg.Leg object at 0x1079f85b0>, 'dist_cost': 9.1653, 'time_cost': 14.028333333333332}
# 4: {'stop_id': 5252020202, 'leg': <main.leg.Leg object at 0x119a88910>, 'dist_cost': 5.919700000000001, 'time_cost': 9.968333333333334}
# 5: {'stop_id': 5403110202, 'leg': <main.leg.Leg object at 0x357573a90>, 'dist_cost': 5.3177, 'time_cost': 8.381666666666668}
# 6: {'stop_id': 5904210202, 'leg': <main.leg.Leg object at 0x357573970>, 'dist_cost': 13.4997, 'time_cost': 17.625}
# 7: {'stop_id': 92501650201, 'leg': <main.leg.Leg object at 0x357573d60>, 'dist_cost': 12.309899999999999, 'time_cost': 16.09}
# 8: {'stop_id': 5251400112, 'leg': <main.leg.Leg object at 0x3575a2640>, 'dist_cost': 6.6378, 'time_cost': 9.723333333333333}
# 9: {'stop_id': 5251300111, 'leg': <main.leg.Leg object at 0x3575a29d0>, 'dist_cost': 12.5915, 'time_cost': 15.261666666666667}
# 10: {'stop_id': 5254020107, 'leg': <main.leg.Leg object at 0x3575a2c40>, 'dist_cost': 15.234300000000001, 'time_cost': 17.833333333333336}
# 11: {'stop_id': 5250060205, 'leg': <main.leg.Leg object at 0x3575a2940>, 'dist_cost': 10.538, 'time_cost': 14.38}
# 12: {'stop_id': 5250600110, 'leg': <main.leg.Leg object at 0x3575a2490>, 'dist_cost': 12.033, 'time_cost': 16.66}
# 13: {'stop_id': 5251300107, 'leg': <main.leg.Leg object at 0x3575a7370>, 'dist_cost': 9.6381, 'time_cost': 14.661666666666665}
# 14: {'stop_id': 5251300103, 'leg': <main.leg.Leg object at 0x3575a7b20>, 'dist_cost': 4.7888, 'time_cost': 10.908333333333331}
# 15: {'stop_id': 5201110204, 'leg': <main.leg.Leg object at 0x3575a7c40>, 'dist_cost': 8.3186, 'time_cost': 13.433333333333334}
# 16: {'stop_id': 5251400214, 'leg': <main.leg.Leg object at 0x3575a7220>, 'dist_cost': 8.4155, 'time_cost': 12.691666666666666}
# 17: {'stop_id': 5250500121, 'leg': <main.leg.Leg object at 0x3575a72e0>, 'dist_cost': 4.6382, 'time_cost': 8.313333333333333}
# 18: {'stop_id': 5250500118, 'leg': <main.leg.Leg object at 0x3575a7340>, 'dist_cost': 5.4416, 'time_cost': 7.335}
# 19: {'stop_id': 5250500112, 'leg': <main.leg.Leg object at 0x3575a7520>, 'dist_cost': 8.7259, 'time_cost': 11.636666666666667}
# 20: {'stop_id': 5252010127, 'leg': <main.leg.Leg object at 0x3575a7910>, 'dist_cost': 9.056799999999999, 'time_cost': 12.350000000000001}
# 21: {'stop_id': 5102010105, 'leg': <main.leg.Leg object at 0x3575a78e0>, 'dist_cost': 10.1304, 'time_cost': 13.818333333333333}
# 22: {'stop_id': 5252040137, 'leg': <main.leg.Leg object at 0x3575a7760>, 'dist_cost': 5.7736, 'time_cost': 8.01}
# 23: {'stop_id': 5252040137, 'leg': <main.leg.Leg object at 0x3575a7700>, 'dist_cost': 13.0524, 'time_cost': 15.813333333333333}
# 24: {'stop_id': 925114700112, 'leg': <main.leg.Leg object at 0x3575a75b0>, 'dist_cost': 14.4844, 'time_cost': 19.468333333333334}
# 25: {'stop_id': 925114700202, 'leg': <main.leg.Leg object at 0x3575a7550>, 'dist_cost': 2.3901, 'time_cost': 5.918333333333334}
# 26: {'stop_id': 925114700206, 'leg': <main.leg.Leg object at 0x3575a7fd0>, 'dist_cost': 2.4994, 'time_cost': 5.238333333333333}
# 27: {'stop_id': 5251400120, 'leg': <main.leg.Leg object at 0x3575a7250>, 'dist_cost': 14.339099999999998, 'time_cost': 17.74}
# 28: {'stop_id': 5250720229, 'leg': <main.leg.Leg object at 0x3575a7df0>, 'dist_cost': 15.259799999999998, 'time_cost': 18.5}
# 29: {'stop_id': 5206020118, 'leg': <main.leg.Leg object at 0x3575a76d0>, 'dist_cost': 4.4505, 'time_cost': 7.468333333333334}
# 30: {'stop_id': 5250060103, 'leg': <main.leg.Leg object at 0x3575a7af0>, 'dist_cost': 10.2482, 'time_cost': 13.151666666666667}
# 31: {'stop_id': 5252010107, 'leg': <main.leg.Leg object at 0x3575a7f40>, 'dist_cost': 13.0944, 'time_cost': 17.623333333333335}
# 32: {'stop_id': 5253010209, 'leg': <main.leg.Leg object at 0x3575a7e20>, 'dist_cost': 6.3019, 'time_cost': 10.685}
# 33: {'stop_id': 5253010117, 'leg': <main.leg.Leg object at 0x3575a7580>, 'dist_cost': 2.1812, 'time_cost': 3.671666666666667}
# 34: {'stop_id': 5253010204, 'leg': <main.leg.Leg object at 0x3575a7460>, 'dist_cost': 1.0646, 'time_cost': 1.83}
# 35: {'stop_id': 5252060140, 'leg': <main.leg.Leg object at 0x3575a7eb0>, 'dist_cost': 2.6517, 'time_cost': 4.223333333333334}
# 36: {'stop_id': 5252010111, 'leg': <main.leg.Leg object at 0x3575a73a0>, 'dist_cost': 2.3011, 'time_cost': 3.585}
# 37: {'stop_id': 5252010111, 'leg': <main.leg.Leg object at 0x3575a7730>, 'dist_cost': 6.2136000000000005, 'time_cost': 7.663333333333333}
# 38: {'stop_id': 5252010205, 'leg': <main.leg.Leg object at 0x3575a7880>, 'dist_cost': 6.808400000000001, 'time_cost': 8.388333333333334}
# 39: {'stop_id': 5252040140, 'leg': <main.leg.Leg object at 0x3575a70d0>, 'dist_cost': 3.8116000000000003, 'time_cost': 5.178333333333333}
# 40: {'stop_id': 5254020107, 'leg': <main.leg.Leg object at 0x3575a7160>, 'dist_cost': 7.1583000000000006, 'time_cost': 10.181666666666667}
# 41: {'stop_id': 5256120203, 'leg': <main.leg.Leg object at 0x3575a7070>, 'dist_cost': 7.2581, 'time_cost': 10.876666666666665}
# 42: {'stop_id': 5904210201, 'leg': <main.leg.Leg object at 0x3575a7970>, 'dist_cost': 3.9259999999999997, 'time_cost': 5.781666666666666}
# 43: {'stop_id': 5256120209, 'leg': <main.leg.Leg object at 0x3575a79a0>, 'dist_cost': 5.2508, 'time_cost': 7.436666666666666}
# 44: {'stop_id': 925611130106, 'leg': <main.leg.Leg object at 0x3575a7a90>, 'dist_cost': 11.1255, 'time_cost': 15.211666666666666}
# 45: {'stop_id': 5252040207, 'leg': <main.leg.Leg object at 0x3575a7b80>, 'dist_cost': 8.367600000000001, 'time_cost': 10.866666666666667}
# 46: {'stop_id': 5206020205, 'leg': <main.leg.Leg object at 0x3575a7d60>, 'dist_cost': 4.3388, 'time_cost': 5.726666666666667}
# 47: {'stop_id': 5252010122, 'leg': <main.leg.Leg object at 0x3575a71f0>, 'dist_cost': 7.4441999999999995, 'time_cost': 9.45}
# 48: {'stop_id': 5201110120, 'leg': <main.leg.Leg object at 0x3575a7d90>, 'dist_cost': 10.571299999999999, 'time_cost': 13.825}
# 49: {'stop_id': 925114010111, 'leg': <main.leg.Leg object at 0x3575a7c70>, 'dist_cost': 13.892100000000001, 'time_cost': 17.531666666666666}
# 50: {'stop_id': 5250500124, 'leg': <main.leg.Leg object at 0x3575a7b50>, 'dist_cost': 19.0473, 'time_cost': 21.625}
# 51: {'stop_id': 925113110225, 'leg': <main.leg.Leg object at 0x3575a7670>, 'dist_cost': 10.7376, 'time_cost': 11.736666666666668}

# %% [markdown]
# ## Modification generation according to max_distance_km and MINUMUM_COST_SAVE_MINUTES

# %%
# Sort stops according to cost
    # Extract from stop_cost_dict a list of (id, cost)
id_cost_list = []
for key, value in stop_cost_dict.items():
    id_cost_list.append((key, value.get('dist_cost')))
id_cost_list.sort(key=lambda x: x[1], reverse=True)
print(id_cost_list)
# Out:
# [(50, 19.0473), (28, 15.259799999999998), (10, 15.234300000000001), (24, 14.4844), (27, 14.339099999999998), (49, 13.892100000000001), (6, 13.4997), (31, 13.0944), (23, 13.0524), (9, 12.5915), (7, 12.309899999999999), (12, 12.033), (44, 11.1255), (51, 10.7376), (48, 10.571299999999999), (11, 10.538), (30, 10.2482), (21, 10.1304), (13, 9.6381), (3, 9.1653), (20, 9.056799999999999), (19, 8.7259), (16, 8.4155), (45, 8.367600000000001), (15, 8.3186), (47, 7.4441999999999995), (41, 7.2581), (40, 7.1583000000000006), (38, 6.808400000000001), (8, 6.6378), (32, 6.3019), (37, 6.2136000000000005), (2, 6.0138), (4, 5.919700000000001), (22, 5.7736), (18, 5.4416), (5, 5.3177), (43, 5.2508), (14, 4.7888), (17, 4.6382), (29, 4.4505), (46, 4.3388), (42, 3.9259999999999997), (39, 3.8116000000000003), (35, 2.6517), (26, 2.4994), (25, 2.3901), (36, 2.3011), (33, 2.1812), (1, 2.0502000000000002), (34, 1.0646), (0, 0.6092000000000001)]

# %% [markdown]
# #### Modification generation with leg dist_cost (Distance)

# %%
MINIMUM_COST_SAVE_KM = 0.1 # 100 meters

# Select a costly stop
for i in range(len(id_cost_list)):
    print()
    # Gets dict entry number that corresponds to the next stop with higher cost
    dic_entry = id_cost_list[i][0]
    print(f"Entry nº{dic_entry}")

    # Gets associated stop information from stop_cost_dict (id, leg, dist_cost, time_cost)
    stop_info = stop_cost_dict[dic_entry]
    print(f"Stop costs: ", stop_info)

    # Get leg corresponding to that stop and previous leg
    stop_id = stop_info['stop_id']
    leg = stop_info['leg']
    prev = leg.prev
    print("\tLeg 1:", prev.__str__())
    print("\tLeg 2:", leg.__str__())
    current_cost = stop_info['dist_cost']
    # Modification type: origin/destination (stop) to be modified
    mod_type = None

    # If the first/last leg has not been chosen
    if prev is not None and leg.next is not None:
        # Get customer/request info associated with the stop to be modified
        # Such a customer is leg.prev.passenger_id
        customer_id = leg.prev.passenger_id
        # customer origin stop id
        origin_coords = db.get_customer_origin(leg.prev.passenger_id)
        origin_id = db.get_stop_id([origin_coords[1], origin_coords[0]])
        # customer destination stop id
        destination_coords = db.get_customer_destination(leg.prev.passenger_id)
        destination_id = db.get_stop_id([destination_coords[1], destination_coords[0]])
        print(f"\t\tTrip to modify: Customer {customer_id} trip: {int(origin_id):3d} --> {int(destination_id):3d}")
        # the stop to be modified is the customer's origin
        if origin_id == stop_id:
            mod_type = "origin"
        # the stop to be modified is the customer's destination
        elif destination_id == stop_id:
            mod_type = "destination"
        else:
            print(f"ERROR :: Stop to be modified {stop_id}, origin_id {origin_id}, destination_id {destination_id}")
            exit()

        # Search for alternative stop among neighbours
        alter = False
        neighbours = db.get_neighbouring_stops_dict(stop_id, max_distance_km=1, geodesic=True)
        if len(neighbours) > 0:
            alter = True
            # Sort neighbours according to distance to the stop
            neighbours.sort(key=lambda x: x[1], reverse=False)

        # If there are neighbouring stops
        if alter:
            modifications = []
            for j in range(len(neighbours)):
                # Calculate costs if visiting each neighbour instead
                # Select next neighbour
                neigh_id = neighbours[j][0]
                neigh_distance = neighbours[j][1]

                # # TIME Cost of a stop visit: cost of prev -> S + cost of S -> next
                # new_prev_time_cost = db.get_route_time_min(prev.origin_stop.id, neigh_id)
                # new_next_time_cost = db.get_route_time_min(neigh_id, leg.dest_stop.id)
                # new_time_cost = new_prev_time_cost + new_next_time_cost
                # # Cost saving
                # time_cost_save = current_cost - new_time_cost

                # DISTANCE cost of a stop visit: cost of prev -> S + cost of S -> next
                new_prev_dist_cost = db.get_route_distance_km(prev.origin_stop.id, neigh_id)
                new_next_dist_cost = db.get_route_distance_km(neigh_id, leg.dest_stop.id)
                new_dist_cost = new_prev_dist_cost + new_next_dist_cost
                dist_cost_save = current_cost - new_dist_cost

                # If the cost is improved
                if dist_cost_save > MINIMUM_COST_SAVE_KM: # Distance cost
                    # Store stop modification proposal
                    mod = {
                        "vehicle_id": itinerary_id,
                        "customer_id": customer_id,
                        "mod_type": mod_type,
                        "stop_id": stop_id,
                        "neigh_id": neigh_id,
                        "neigh_distance": neigh_distance,
                        "cost_save": dist_cost_save,
                        # Ratio between saved distance and walking effort of the customers.
                        # if >1 the vehicle saves more distance than the customers have to walk.
                        "walk_to_save_ratio": dist_cost_save/neigh_distance
                    }
                    modifications.append(mod)
            if len(modifications) > 0:
                modifications.sort(key=lambda x: x["cost_save"], reverse=True)
                print(f"\t\t\tRESULT :: {len(modifications)} modifications found")
                print(f"\t\t\t\tMODIFICATIONS :: ")
                for mod_dict in modifications:
                    print(f"\t\t\t\t{mod_dict}")
            else:
                print(f"\t\t\tRESULT :: No modifications for stop {stop_id} with current parameters.")
        else:
            print(f"\t\t\tWARNING :: No neighbours for stop {stop_id}. Skipping.")
    # If first/last leg have been chosen, skip
    else:
        print(f"\t\t\tWARNING :: Candidate stop corresponds to DEPOT which cannot be modified. Skipping.")

# %%
# Comprovar la feasibility de la modificació --> Segurament siga evident. Si la restricció forta són els temps i es disminuex, entrarà sense problemes
    # Representar la nova request
    # Extraure viatge actual
    # Fer els checks de clavar el nou viatge

# Substituir viatge per viatge alternatiu
    # Extraure viatge previ
    # Clavar viatge modificat
    # Actualitzar costos per veure si la millora es nota

# %% [markdown]
# #### Modification generation with leg time_cost (Time)

# %%
MINIMUM_COST_SAVE_MINUTES = 1 # 1 second

# Select a costly stop
for i in range(len(id_cost_list)):
    print()
    # Gets dict entry number that corresponds to the next stop with higher cost
    dic_entry = id_cost_list[i][0]
    print(f"Entry nº{dic_entry}")

    # Gets associated stop information from stop_cost_dict (id, leg, dist_cost, time_cost)
    stop_info = stop_cost_dict[dic_entry]
    print(f"Stop costs: ", stop_info)

    # Get leg corresponding to that stop and previous leg
    stop_id = stop_info['stop_id']
    leg = stop_info['leg']
    prev = leg.prev
    print("\tLeg 1:", prev.__str__())
    print("\tLeg 2:", leg.__str__())
    current_cost = stop_info['time_cost']
    # Modification type: origin/destination (stop) to be modified
    mod_type = None

    # If the first/last leg has not been chosen
    if prev is not None and leg.next is not None:
        # Get customer/request info associated with the stop to be modified
        # Such a customer is leg.prev.passenger_id
        customer_id = leg.prev.passenger_id
        # customer origin stop id
        origin_coords = db.get_customer_origin(leg.prev.passenger_id)
        origin_id = db.get_stop_id([origin_coords[1], origin_coords[0]])
        # customer destination stop id
        destination_coords = db.get_customer_destination(leg.prev.passenger_id)
        destination_id = db.get_stop_id([destination_coords[1], destination_coords[0]])
        print(f"\t\tTrip to modify: Customer {customer_id} trip: {int(origin_id):3d} --> {int(destination_id):3d}")
        # the stop to be modified is the customer's origin
        if origin_id == stop_id:
            mod_type = "origin"
        # the stop to be modified is the customer's destination
        elif destination_id == stop_id:
            mod_type = "destination"
        else:
            print(f"ERROR :: Stop to be modified {stop_id}, origin_id {origin_id}, destination_id {destination_id}")
            exit()

        # Search for alternative stop among neighbours
        alter = False
        neighbours = db.get_neighbouring_stops_dict(stop_id, max_distance_km=1, geodesic=True)
        if len(neighbours) > 0:
            alter = True
            # Sort neighbours according to distance to the stop
            neighbours.sort(key=lambda x: x[1], reverse=False)

        # If there are neighbouring stops
        if alter:
            modifications = []
            for j in range(len(neighbours)):
                # Calculate costs if visiting each neighbour instead
                # Select next neighbour
                neigh_id = neighbours[j][0]
                neigh_distance = neighbours[j][1]

                # TIME Cost of a stop visit: cost of prev -> S + cost of S -> next
                new_prev_time_cost = db.get_route_time_min(prev.origin_stop.id, neigh_id)
                new_next_time_cost = db.get_route_time_min(neigh_id, leg.dest_stop.id)
                new_time_cost = new_prev_time_cost + new_next_time_cost
                # Cost saving
                time_cost_save = current_cost - new_time_cost

                # # DISTANCE cost of a stop visit: cost of prev -> S + cost of S -> next
                # new_prev_dist_cost = db.get_route_distance_km(prev.origin_stop.id, neigh_id)
                # new_next_dist_cost = db.get_route_distance_km(neigh_id, leg.dest_stop.id)
                # new_dist_cost = new_prev_dist_cost + new_next_dist_cost
                # dist_cost_save = current_cost - new_dist_cost

                # If the cost is improved
                if time_cost_save > MINIMUM_COST_SAVE_MINUTES: # Time cost
                    # Store stop modification proposal
                    mod = {
                        "vehicle_id": itinerary_id,
                        "customer_id": customer_id,
                        "mod_type": mod_type,
                        "stop_id": stop_id,
                        "neigh_id": neigh_id,
                        "neigh_distance": neigh_distance,
                        "cost_save": time_cost_save,
                        # Ratio between saved minutes and walking effort of the customers.
                        # if >1 the vehicle saves more minutes than km the customers have to walk.
                        "walk_to_save_ratio": time_cost_save/neigh_distance
                    }
                    modifications.append(mod)
            if len(modifications) > 0:
                modifications.sort(key=lambda x: x["cost_save"], reverse=True)
                print(f"\t\t\tRESULT :: {len(modifications)} modifications found")
                print(f"\t\t\t\tMODIFICATIONS :: ")
                for mod_dict in modifications:
                    print(f"\t\t\t\t{mod_dict}")
            else:
                print(f"\t\t\tRESULT :: No modifications for stop {stop_id} with current parameters.")
        else:
            print(f"\t\t\tWARNING :: No neighbours for stop {stop_id}. Skipping.")
    # If first/last leg have been chosen, skip
    else:
        print(f"\t\t\tWARNING :: Candidate stop corresponds to DEPOT which cannot be modified. Skipping.")

# %% [markdown]
# # Modification creation script - Distance cost

# %%
MINIMUM_COST_SAVE_KM = 0.1 # 100 meters

db = database
itinerary_modification_dict = {}

for itinerary in sche.itineraries:
	itinerary_modification_dict[itinerary.vehicle_id] = None

for I in sche.itineraries:
    # Initialise mod_per_request_dict
    mod_per_request_dict = {}
    for request_id in I.customer_dict.keys():
        mod_per_request_dict[request_id] = []

    # 1. Create leg from itinerary
    itinerary_id = I.vehicle_id
    legs = create_legs_from_itinerary(I, db)
    # 2. Evaluate legs, creating stop_cost_dict
    stop_cost_dict = compute_stop_cost_dict(legs)
    # 3. Obtain id_cost_list to process entries in descending cost order
    id_cost_list = []
    for key, value in stop_cost_dict.items():
        id_cost_list.append((key, value.get('dist_cost')))
    id_cost_list.sort(key=lambda x: x[1], reverse=True)
    # 4. Process all entries, obtaining the modifications for each of them
    for i in range(len(id_cost_list)):
        modification_list = []
        print()
        # Gets dict entry number that corresponds to the next stop with higher cost
        dic_entry = id_cost_list[i][0]
        print(f"Entry nº{dic_entry}")

        # Gets associated stop information from stop_cost_dict (id, leg, dist_cost, time_cost)
        stop_info = stop_cost_dict[dic_entry]
        print(f"Stop costs: ", stop_info)

        # Get leg corresponding to that stop and previous leg
        stop_id = stop_info['stop_id']
        leg = stop_info['leg']
        prev = leg.prev
        print("\tLeg 1:", prev.__str__())
        print("\tLeg 2:", leg.__str__())
        current_cost = stop_info['dist_cost']
        # Modification type: origin/destination (stop) to be modified
        mod_type = None

        # If the first/last leg has not been chosen
        if prev is not None and leg.next is not None:
            # Get customer/request info associated with the stop to be modified
            # Such a customer is leg.prev.passenger_id
            customer_id = leg.prev.passenger_id
            # customer origin stop id
            origin_coords = db.get_customer_origin(leg.prev.passenger_id)
            origin_id = db.get_stop_id([origin_coords[1], origin_coords[0]])
            # customer destination stop id
            destination_coords = db.get_customer_destination(leg.prev.passenger_id)
            destination_id = db.get_stop_id([destination_coords[1], destination_coords[0]])
            print(f"\t\tTrip to modify: Customer {customer_id} trip: {int(origin_id):3d} --> {int(destination_id):3d}")
            # the stop to be modified is the customer's origin
            if origin_id == stop_id:
                mod_type = "origin"
            # the stop to be modified is the customer's destination
            elif destination_id == stop_id:
                mod_type = "destination"
            else:
                print(f"ERROR :: Stop to be modified {stop_id}, origin_id {origin_id}, destination_id {destination_id}")
                exit()

            # Search for alternative stop among neighbours
            alter = False
            neighbours = db.get_neighbouring_stops_dict(stop_id, max_distance_km=1, geodesic=True)
            if len(neighbours) > 0:
                alter = True
                # Sort neighbours according to distance to the stop
                neighbours.sort(key=lambda x: x[1], reverse=False)

            # If there are neighbouring stops
            if alter:
                modifications = []
                for j in range(len(neighbours)):
                    # Calculate costs if visiting each neighbour instead
                    # Select next neighbour
                    neigh_id = neighbours[j][0]
                    neigh_distance = neighbours[j][1]
                    # Avoid modifications that propose changing a customer origin with their destination and vice versa
                    if (mod_type == "origin" and neigh_id == destination_id) or (mod_type == "destination" and neigh_id == origin_id):
                        continue
                    # # TIME Cost of a stop visit: cost of prev -> S + cost of S -> next
                    # new_prev_time_cost = db.get_route_time_min(prev.origin_stop.id, neigh_id)
                    # new_next_time_cost = db.get_route_time_min(neigh_id, leg.dest_stop.id)
                    # new_time_cost = new_prev_time_cost + new_next_time_cost
                    # # Cost saving
                    # time_cost_save = current_cost - new_time_cost

                    # DISTANCE cost of a stop visit: cost of prev -> S + cost of S -> next
                    new_prev_dist_cost = db.get_route_distance_km(prev.origin_stop.id, neigh_id)
                    new_next_dist_cost = db.get_route_distance_km(neigh_id, leg.dest_stop.id)
                    new_dist_cost = new_prev_dist_cost + new_next_dist_cost
                    dist_cost_save = current_cost - new_dist_cost

                    # If the cost is improved
                    if dist_cost_save > MINIMUM_COST_SAVE_KM: # Distance cost
                        # Store stop modification proposal
                        mod = {
                            "vehicle_id": itinerary_id,
                            "customer_id": customer_id,
                            "mod_type": mod_type,
                            "stop_id": stop_id,
                            "neigh_id": neigh_id,
                            "neigh_distance": neigh_distance,
                            "cost_save": dist_cost_save,
                            # Ratio between saved distance and walking effort of the customers.
                            # if >1 the vehicle saves more distance than the customers have to walk.
                            "walk_to_save_ratio": dist_cost_save/neigh_distance
                        }
                        modifications.append(mod)
                if len(modifications) > 0:
                    modifications.sort(key=lambda x: x["cost_save"], reverse=True)
                    # 5. Store modifications in list, sort by cost_save or ratio
                    mod_per_request_dict[customer_id] += modifications
                    print(f"\t\t\tRESULT :: {len(modifications)} modifications found")
                    print(f"\t\t\t\tMODIFICATIONS :: ")
                    for mod_dict in modifications:
                        print(f"\t\t\t\t{mod_dict}")
                else:
                    print(f"\t\t\tRESULT :: No modifications for stop {stop_id} with current parameters.")
            else:
                print(f"\t\t\tWARNING :: No neighbours for stop {stop_id}. Skipping.")
        # If first/last leg have been chosen, skip
        else:
            print(f"\t\t\tWARNING :: Candidate stop corresponds to DEPOT which cannot be modified. Skipping.")
    # end of THIS itinerary for
    # Sort modifications by cost_save or ratio
    for key in mod_per_request_dict.keys():
        mod_per_request_dict[key].sort(key=lambda x: x["cost_save"], reverse=True)
        # modification_list.sort(key=lambda x: x["cost_save"], reverse=True)
    # 6. Store list in dict
    itinerary_modification_dict[itinerary_id] = mod_per_request_dict
# Out:
#   0: veh_01_925113110225 :: leg (925113110225, 63.96) --> (5250500102, 65.00), 1.04min, 0.61km, request_002_1
#   1: veh_01_925113110225 :: leg (5250500102, 66.00) --> (5252040204, 67.76), 1.76min, 1.44km, request_002_1
#   2: veh_01_925113110225 :: leg (5252040204, 68.76) --> (5252010214, 75.66), 6.90min, 4.57km, request_001_1
#   3: veh_01_925113110225 :: leg (5252010214, 76.66) --> (5252020202, 83.79), 7.13min, 4.59km, request_003_2
#   4: veh_01_925113110225 :: leg (5252020202, 85.79) --> (5403110202, 88.63), 2.84min, 1.33km, request_021_1
#   5: veh_01_925113110225 :: leg (5403110202, 89.63) --> (5904210202, 95.17), 5.54min, 3.99km, request_003_2
#   6: veh_01_925113110225 :: leg (5904210202, 97.17) --> (92501650201, 109.26), 12.08min, 9.51km, request_021_1
#   7: veh_01_925113110225 :: leg (92501650201, 110.26) --> (5251400112, 114.26), 4.01min, 2.80km, request_001_1
#   8: veh_01_925113110225 :: leg (5251400112, 115.26) --> (5251300111, 120.98), 5.72min, 3.84km, request_068_2
#   9: veh_01_925113110225 :: leg (5251300111, 122.98) --> (5254020107, 132.53), 9.54min, 8.75km, request_097_1
#  10: veh_01_925113110225 :: leg (5254020107, 133.53) --> (5250060205, 141.81), 8.29min, 6.48km, request_068_2
#  11: veh_01_925113110225 :: leg (5250060205, 143.91) --> (5250600110, 150.00), 6.09min, 4.06km, request_155_1
#  12: veh_01_925113110225 :: leg (5250600110, 151.00) --> (5251300107, 161.57), 10.57min, 7.97km, request_097_1
#  13: veh_01_925113110225 :: leg (5251300107, 162.57) --> (5251300103, 166.66), 4.09min, 1.66km, request_175_1
#  14: veh_01_925113110225 :: leg (5251300103, 167.66) --> (5201110204, 174.48), 6.81min, 3.13km, request_179_1
#  15: veh_01_925113110225 :: leg (5201110204, 175.48) --> (5251400214, 182.09), 6.62min, 5.19km, request_185_1
#  16: veh_01_925113110225 :: leg (5251400214, 183.09) --> (5250500121, 189.17), 6.07min, 3.22km, request_155_1
#  17: veh_01_925113110225 :: leg (5250500121, 190.17) --> (5250500118, 192.41), 2.24min, 1.42km, request_179_1
#  18: veh_01_925113110225 :: leg (5250500118, 193.41) --> (5250500112, 198.50), 5.09min, 4.03km, request_244_1
#  19: veh_01_925113110225 :: leg (5250500112, 199.50) --> (5252010127, 206.04), 6.54min, 4.70km, request_175_1
#  20: veh_01_925113110225 :: leg (5252010127, 207.04) --> (5102010105, 212.85), 5.81min, 4.36km, request_185_1
#  21: veh_01_925113110225 :: leg (5102010105, 213.85) --> (5252040137, 221.86), 8.01min, 5.77km, request_255_5
#  22: veh_01_925113110225 :: leg (5252040137, 226.86) --> (5252040137, 226.86), 0.00min, 0.00km, request_244_1
#  23: veh_01_925113110225 :: leg (5252040137, 227.86) --> (925114700112, 243.68), 15.81min, 13.05km, request_296_1
#  24: veh_01_925113110225 :: leg (925114700112, 244.68) --> (925114700202, 248.33), 3.66min, 1.43km, request_255_5
#  25: veh_01_925113110225 :: leg (925114700202, 253.33) --> (925114700206, 255.59), 2.26min, 0.96km, request_318_2
#  26: veh_01_925113110225 :: leg (925114700206, 257.59) --> (5251400120, 260.57), 2.98min, 1.54km, request_337_1
#  27: veh_01_925113110225 :: leg (5251400120, 261.57) --> (5250720229, 276.33), 14.76min, 12.80km, request_374_1
#  28: veh_01_925113110225 :: leg (5250720229, 277.33) --> (5206020118, 281.07), 3.73min, 2.46km, request_296_1
#  29: veh_01_925113110225 :: leg (5206020118, 282.07) --> (5250060103, 285.80), 3.73min, 1.99km, request_337_1
#  30: veh_01_925113110225 :: leg (5250060103, 286.80) --> (5252010107, 296.22), 9.42min, 8.26km, request_318_2
#  31: veh_01_925113110225 :: leg (5252010107, 298.22) --> (5253010209, 306.43), 8.21min, 4.83km, request_374_1
#  32: veh_01_925113110225 :: leg (5253010209, 307.43) --> (5253010117, 309.91), 2.48min, 1.47km, request_459_1
#  33: veh_01_925113110225 :: leg (5253010117, 310.91) --> (5253010204, 312.10), 1.19min, 0.71km, request_483_1
#  34: veh_01_925113110225 :: leg (5253010204, 313.10) --> (5252060140, 313.74), 0.64min, 0.35km, request_464_3
#  35: veh_01_925113110225 :: leg (5252060140, 316.74) --> (5252010111, 320.32), 3.58min, 2.30km, request_496_2
#  36: veh_01_925113110225 :: leg (5252010111, 322.32) --> (5252010111, 322.32), 0.00min, 0.00km, request_483_1
#  37: veh_01_925113110225 :: leg (5252010111, 323.32) --> (5252010205, 330.99), 7.66min, 6.21km, request_459_1
#  38: veh_01_925113110225 :: leg (5252010205, 331.99) --> (5252040140, 332.71), 0.72min, 0.59km, request_542_1
#  39: veh_01_925113110225 :: leg (5252040140, 333.71) --> (5254020107, 338.16), 4.45min, 3.22km, request_464_3
#  40: veh_01_925113110225 :: leg (5254020107, 341.16) --> (5256120203, 346.89), 5.73min, 3.94km, request_535_1
#  41: veh_01_925113110225 :: leg (5256120203, 347.89) --> (5904210201, 353.04), 5.15min, 3.32km, request_496_2
#  42: veh_01_925113110225 :: leg (5904210201, 355.04) --> (5256120209, 355.67), 0.63min, 0.61km, request_535_1
#  43: veh_01_925113110225 :: leg (5256120209, 356.67) --> (925611130106, 363.48), 6.80min, 4.64km, request_542_1
#  44: veh_01_925113110225 :: leg (925611130106, 364.48) --> (5252040207, 372.89), 8.41min, 6.48km, request_581_1
#  45: veh_01_925113110225 :: leg (5252040207, 373.89) --> (5206020205, 376.34), 2.46min, 1.88km, request_590_1
#  46: veh_01_925113110225 :: leg (5206020205, 377.34) --> (5252010122, 380.61), 3.27min, 2.46km, request_597_3
#  47: veh_01_925113110225 :: leg (5252010122, 383.61) --> (5201110120, 389.79), 6.18min, 4.99km, request_590_1
#  48: veh_01_925113110225 :: leg (5201110120, 390.79) --> (925114010111, 398.44), 7.64min, 5.58km, request_581_1
#  49: veh_01_925113110225 :: leg (925114010111, 399.44) --> (5250500124, 409.32), 9.89min, 8.31km, request_597_3
#  50: veh_01_925113110225 :: leg (5250500124, 412.32) --> (925113110225, 424.06), 11.74min, 10.74km, None
#  51: veh_01_925113110225 :: leg (925113110225, inf) --> (None, inf), 0.00, 0.00min, 0.00km, DEPOT
#
# Entry nº50
# Stop costs:  {'stop_id': 5250500124, 'leg': <main.leg.Leg object at 0x358fbbe80>, 'dist_cost': 19.0473, 'time_cost': 21.625}
# 	Leg 1: veh_01_925113110225 :: leg (925114010111, 399.44) --> (5250500124, 409.32), 9.89min, 8.31km, request_597_3
# 	Leg 2: veh_01_925113110225 :: leg (5250500124, 412.32) --> (925113110225, 424.06), 11.74min, 10.74km, None
# 		Trip to modify: Customer request_597_3 trip: 5252010122 --> 5250500124
# 			RESULT :: 5 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5250500126, 'neigh_distance': 0.5176981009161767, 'cost_save': 0.6469999999999985, 'walk_to_save_ratio': 1.2497631319392413}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5250500202, 'neigh_distance': 0.8103847508803643, 'cost_save': 0.3222999999999985, 'walk_to_save_ratio': 0.3977123207832659}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5250500123, 'neigh_distance': 0.3854570913475967, 'cost_save': 0.20560000000000045, 'walk_to_save_ratio': 0.5333927034036453}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5250500122, 'neigh_distance': 0.7633075969952192, 'cost_save': 0.20560000000000045, 'walk_to_save_ratio': 0.26935405963382303}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5403010127, 'neigh_distance': 0.6890565478883703, 'cost_save': 0.14250000000000185, 'walk_to_save_ratio': 0.20680450746269863}
#
# Entry nº28
# Stop costs:  {'stop_id': 5250720229, 'leg': <main.leg.Leg object at 0x358fbba00>, 'dist_cost': 15.259799999999998, 'time_cost': 18.5}
# 	Leg 1: veh_01_925113110225 :: leg (5251400120, 261.57) --> (5250720229, 276.33), 14.76min, 12.80km, request_374_1
# 	Leg 2: veh_01_925113110225 :: leg (5250720229, 277.33) --> (5206020118, 281.07), 3.73min, 2.46km, request_296_1
# 		Trip to modify: Customer request_374_1 trip: 5250720229 --> 5253010209
# 			RESULT :: 1 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_374_1', 'mod_type': 'origin', 'stop_id': 5250720229, 'neigh_id': 5250720222, 'neigh_distance': 0.9994252773546092, 'cost_save': 0.17999999999999972, 'walk_to_save_ratio': 0.18010350956546134}
#
# Entry nº10
# Stop costs:  {'stop_id': 5254020107, 'leg': <main.leg.Leg object at 0x358fbb610>, 'dist_cost': 15.234300000000001, 'time_cost': 17.833333333333336}
# 	Leg 1: veh_01_925113110225 :: leg (5251300111, 122.98) --> (5254020107, 132.53), 9.54min, 8.75km, request_097_1
# 	Leg 2: veh_01_925113110225 :: leg (5254020107, 133.53) --> (5250060205, 141.81), 8.29min, 6.48km, request_068_2
# 		Trip to modify: Customer request_097_1 trip: 5254020107 --> 5251300107
# 			RESULT :: No modifications for stop 5254020107 with current parameters.
#
# Entry nº24
# Stop costs:  {'stop_id': 925114700112, 'leg': <main.leg.Leg object at 0x358fbb940>, 'dist_cost': 14.4844, 'time_cost': 19.468333333333334}
# 	Leg 1: veh_01_925113110225 :: leg (5252040137, 227.86) --> (925114700112, 243.68), 15.81min, 13.05km, request_296_1
# 	Leg 2: veh_01_925113110225 :: leg (925114700112, 244.68) --> (925114700202, 248.33), 3.66min, 1.43km, request_255_5
# 		Trip to modify: Customer request_296_1 trip: 925114700112 --> 5206020118
# 			RESULT :: 10 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114700203, 'neigh_distance': 0.7649222422507015, 'cost_save': 1.4100000000000001, 'walk_to_save_ratio': 1.8433246180046048}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 5251400122, 'neigh_distance': 0.8479165657918916, 'cost_save': 1.0649999999999995, 'walk_to_save_ratio': 1.2560198054455605}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 5251400206, 'neigh_distance': 0.8875365140864366, 'cost_save': 1.0477000000000007, 'walk_to_save_ratio': 1.1804584750841765}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114800111, 'neigh_distance': 0.5967589178683034, 'cost_save': 0.9030000000000005, 'walk_to_save_ratio': 1.51317386797608}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114800113, 'neigh_distance': 0.6371229714844996, 'cost_save': 0.9030000000000005, 'walk_to_save_ratio': 1.4173088091550146}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114700113, 'neigh_distance': 0.6605683408139222, 'cost_save': 0.8483, 'walk_to_save_ratio': 1.2841971792877076}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114700205, 'neigh_distance': 0.9910123491668104, 'cost_save': 0.7396999999999991, 'walk_to_save_ratio': 0.746408458604879}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114700111, 'neigh_distance': 0.9741888103865955, 'cost_save': 0.6935000000000002, 'walk_to_save_ratio': 0.711874323135361}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 5251400205, 'neigh_distance': 0.49620223173774747, 'cost_save': 0.5675000000000008, 'walk_to_save_ratio': 1.1436869157411118}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 5251400123, 'neigh_distance': 0.5511101529302275, 'cost_save': 0.20760000000000112, 'walk_to_save_ratio': 0.3766942033206999}
#
# Entry nº27
# Stop costs:  {'stop_id': 5251400120, 'leg': <main.leg.Leg object at 0x358fbb9d0>, 'dist_cost': 14.339099999999998, 'time_cost': 17.74}
# 	Leg 1: veh_01_925113110225 :: leg (925114700206, 257.59) --> (5251400120, 260.57), 2.98min, 1.54km, request_337_1
# 	Leg 2: veh_01_925113110225 :: leg (5251400120, 261.57) --> (5250720229, 276.33), 14.76min, 12.80km, request_374_1
# 		Trip to modify: Customer request_337_1 trip: 5251400120 --> 5250060103
# 			RESULT :: 12 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400211, 'neigh_distance': 0.5603688217449216, 'cost_save': 0.9852999999999987, 'walk_to_save_ratio': 1.7583062471817974}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400212, 'neigh_distance': 0.7841228063818264, 'cost_save': 0.9852999999999987, 'walk_to_save_ratio': 1.2565633749979332}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400119, 'neigh_distance': 0.29664321680883565, 'cost_save': 0.985199999999999, 'walk_to_save_ratio': 3.3211613958288706}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400210, 'neigh_distance': 0.329072264151749, 'cost_save': 0.985199999999999, 'walk_to_save_ratio': 2.9938712779077665}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400118, 'neigh_distance': 0.5243032700854694, 'cost_save': 0.985199999999999, 'walk_to_save_ratio': 1.8790651445668007}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400116, 'neigh_distance': 0.9090323346681729, 'cost_save': 0.9297999999999984, 'walk_to_save_ratio': 1.0228459038692022}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400117, 'neigh_distance': 0.8287878548434848, 'cost_save': 0.8828999999999976, 'walk_to_save_ratio': 1.06529070719398}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400207, 'neigh_distance': 0.42914421278686976, 'cost_save': 0.6123999999999992, 'walk_to_save_ratio': 1.4270261179174786}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 925114700201, 'neigh_distance': 0.7921577596703592, 'cost_save': 0.532099999999998, 'walk_to_save_ratio': 0.6717096354915729}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 925114700115, 'neigh_distance': 0.7619546424120638, 'cost_save': 0.5211999999999986, 'walk_to_save_ratio': 0.6840302177962642}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 925114010123, 'neigh_distance': 0.13095914844783532, 'cost_save': 0.16939999999999955, 'walk_to_save_ratio': 1.2935331514275712}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400208, 'neigh_distance': 0.18401724784904167, 'cost_save': 0.16939999999999777, 'walk_to_save_ratio': 0.9205658816230361}
#
# Entry nº49
# Stop costs:  {'stop_id': 925114010111, 'leg': <main.leg.Leg object at 0x358fbbe50>, 'dist_cost': 13.892100000000001, 'time_cost': 17.531666666666666}
# 	Leg 1: veh_01_925113110225 :: leg (5201110120, 390.79) --> (925114010111, 398.44), 7.64min, 5.58km, request_581_1
# 	Leg 2: veh_01_925113110225 :: leg (925114010111, 399.44) --> (5250500124, 409.32), 9.89min, 8.31km, request_597_3
# 		Trip to modify: Customer request_581_1 trip: 5252040207 --> 925114010111
# 			RESULT :: 2 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'destination', 'stop_id': 925114010111, 'neigh_id': 92501650202, 'neigh_distance': 0.8783982339683147, 'cost_save': 0.4001000000000001, 'walk_to_save_ratio': 0.4554881653079831}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'destination', 'stop_id': 925114010111, 'neigh_id': 92501650108, 'neigh_distance': 0.9502486414906663, 'cost_save': 0.4001000000000001, 'walk_to_save_ratio': 0.42104769481423143}
#
# Entry nº6
# Stop costs:  {'stop_id': 5904210202, 'leg': <main.leg.Leg object at 0x358fbb520>, 'dist_cost': 13.4997, 'time_cost': 17.625}
# 	Leg 1: veh_01_925113110225 :: leg (5403110202, 89.63) --> (5904210202, 95.17), 5.54min, 3.99km, request_003_2
# 	Leg 2: veh_01_925113110225 :: leg (5904210202, 97.17) --> (92501650201, 109.26), 12.08min, 9.51km, request_021_1
# 		Trip to modify: Customer request_003_2 trip: 5252020202 --> 5904210202
# 			RESULT :: 12 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5102010106, 'neigh_distance': 0.8384049223097626, 'cost_save': 1.302500000000002, 'walk_to_save_ratio': 1.553545268331299}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5107510108, 'neigh_distance': 0.741370227415163, 'cost_save': 1.3025000000000002, 'walk_to_save_ratio': 1.756881989368866}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5102020204, 'neigh_distance': 0.6025631078798788, 'cost_save': 0.9931999999999999, 'walk_to_save_ratio': 1.6482920826244722}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5256120114, 'neigh_distance': 0.8965935580778238, 'cost_save': 0.9377999999999993, 'walk_to_save_ratio': 1.0459588868901941}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 92633201207, 'neigh_distance': 0.2140188139633506, 'cost_save': 0.7974000000000014, 'walk_to_save_ratio': 3.72584066434716}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5904210111, 'neigh_distance': 0.07948988447379332, 'cost_save': 0.7973000000000017, 'walk_to_save_ratio': 10.030207054368788}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5256100110, 'neigh_distance': 0.15470946545609632, 'cost_save': 0.7972999999999999, 'walk_to_save_ratio': 5.153530830511847}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5104010119, 'neigh_distance': 0.48798500075285584, 'cost_save': 0.7972999999999999, 'walk_to_save_ratio': 1.633861694047845}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5256150204, 'neigh_distance': 0.14103456416824983, 'cost_save': 0.7558000000000007, 'walk_to_save_ratio': 5.358970011765023}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5256120208, 'neigh_distance': 0.39867345684169037, 'cost_save': 0.4543999999999997, 'walk_to_save_ratio': 1.1397799181309376}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 5256120113, 'neigh_distance': 0.4018957712435003, 'cost_save': 0.4542999999999999, 'walk_to_save_ratio': 1.130392585605856}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'destination', 'stop_id': 5904210202, 'neigh_id': 925611210107, 'neigh_distance': 0.8467626511632144, 'cost_save': 0.43130000000000024, 'walk_to_save_ratio': 0.509351704881545}
#
# Entry nº31
# Stop costs:  {'stop_id': 5252010107, 'leg': <main.leg.Leg object at 0x358fbba60>, 'dist_cost': 13.0944, 'time_cost': 17.623333333333335}
# 	Leg 1: veh_01_925113110225 :: leg (5250060103, 286.80) --> (5252010107, 296.22), 9.42min, 8.26km, request_318_2
# 	Leg 2: veh_01_925113110225 :: leg (5252010107, 298.22) --> (5253010209, 306.43), 8.21min, 4.83km, request_374_1
# 		Trip to modify: Customer request_318_2 trip: 925114700206 --> 5252010107
# 			RESULT :: No modifications for stop 5252010107 with current parameters.
#
# Entry nº23
# Stop costs:  {'stop_id': 5252040137, 'leg': <main.leg.Leg object at 0x358fbb8b0>, 'dist_cost': 13.0524, 'time_cost': 15.813333333333333}
# 	Leg 1: veh_01_925113110225 :: leg (5252040137, 226.86) --> (5252040137, 226.86), 0.00min, 0.00km, request_244_1
# 	Leg 2: veh_01_925113110225 :: leg (5252040137, 227.86) --> (925114700112, 243.68), 15.81min, 13.05km, request_296_1
# 		Trip to modify: Customer request_244_1 trip: 5250500112 --> 5252040137
# 			RESULT :: No modifications for stop 5252040137 with current parameters.
#
# Entry nº9
# Stop costs:  {'stop_id': 5251300111, 'leg': <main.leg.Leg object at 0x358fbb5e0>, 'dist_cost': 12.5915, 'time_cost': 15.261666666666667}
# 	Leg 1: veh_01_925113110225 :: leg (5251400112, 115.26) --> (5251300111, 120.98), 5.72min, 3.84km, request_068_2
# 	Leg 2: veh_01_925113110225 :: leg (5251300111, 122.98) --> (5254020107, 132.53), 9.54min, 8.75km, request_097_1
# 		Trip to modify: Customer request_068_2 trip: 5251300111 --> 5250060205
# 			RESULT :: 3 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'origin', 'stop_id': 5251300111, 'neigh_id': 925114100202, 'neigh_distance': 0.9937978445196669, 'cost_save': 1.3032000000000004, 'walk_to_save_ratio': 1.3113330917213621}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'origin', 'stop_id': 5251300111, 'neigh_id': 925114100118, 'neigh_distance': 0.7824967650777384, 'cost_save': 0.738900000000001, 'walk_to_save_ratio': 0.9442850539153268}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'origin', 'stop_id': 5251300111, 'neigh_id': 925114100117, 'neigh_distance': 0.902331737070016, 'cost_save': 0.738900000000001, 'walk_to_save_ratio': 0.8188784342212119}
#
# Entry nº7
# Stop costs:  {'stop_id': 92501650201, 'leg': <main.leg.Leg object at 0x358fbb550>, 'dist_cost': 12.309899999999999, 'time_cost': 16.09}
# 	Leg 1: veh_01_925113110225 :: leg (5904210202, 97.17) --> (92501650201, 109.26), 12.08min, 9.51km, request_021_1
# 	Leg 2: veh_01_925113110225 :: leg (92501650201, 110.26) --> (5251400112, 114.26), 4.01min, 2.80km, request_001_1
# 		Trip to modify: Customer request_021_1 trip: 5403110202 --> 92501650201
# 			RESULT :: 6 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 92501650108, 'neigh_distance': 0.4090673800381317, 'cost_save': 0.6180999999999983, 'walk_to_save_ratio': 1.5109980168606487}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 92501650202, 'neigh_distance': 0.4728982991339966, 'cost_save': 0.6180999999999983, 'walk_to_save_ratio': 1.3070463588723091}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5201110205, 'neigh_distance': 0.7795009646516444, 'cost_save': 0.5100999999999978, 'walk_to_save_ratio': 0.654393032378041}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5251300105, 'neigh_distance': 0.38196888514173366, 'cost_save': 0.4764999999999997, 'walk_to_save_ratio': 1.24748380963855}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5251300104, 'neigh_distance': 0.9524093117817346, 'cost_save': 0.4764999999999997, 'walk_to_save_ratio': 0.5003101020805644}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5251310216, 'neigh_distance': 0.9202383123539347, 'cost_save': 0.3241999999999994, 'walk_to_save_ratio': 0.352300046246399}
#
# Entry nº12
# Stop costs:  {'stop_id': 5250600110, 'leg': <main.leg.Leg object at 0x358fbb640>, 'dist_cost': 12.033, 'time_cost': 16.66}
# 	Leg 1: veh_01_925113110225 :: leg (5250060205, 143.91) --> (5250600110, 150.00), 6.09min, 4.06km, request_155_1
# 	Leg 2: veh_01_925113110225 :: leg (5250600110, 151.00) --> (5251300107, 161.57), 10.57min, 7.97km, request_097_1
# 		Trip to modify: Customer request_155_1 trip: 5250600110 --> 5250500121
# 			RESULT :: No modifications for stop 5250600110 with current parameters.
#
# Entry nº44
# Stop costs:  {'stop_id': 925611130106, 'leg': <main.leg.Leg object at 0x358fbbd60>, 'dist_cost': 11.1255, 'time_cost': 15.211666666666666}
# 	Leg 1: veh_01_925113110225 :: leg (5256120209, 356.67) --> (925611130106, 363.48), 6.80min, 4.64km, request_542_1
# 	Leg 2: veh_01_925113110225 :: leg (925611130106, 364.48) --> (5252040207, 372.89), 8.41min, 6.48km, request_581_1
# 		Trip to modify: Customer request_542_1 trip: 5252040140 --> 925611130106
# 			RESULT :: 3 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_542_1', 'mod_type': 'destination', 'stop_id': 925611130106, 'neigh_id': 5256120205, 'neigh_distance': 0.6683402336572117, 'cost_save': 0.9749000000000017, 'walk_to_save_ratio': 1.4586881814151307}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_542_1', 'mod_type': 'destination', 'stop_id': 925611130106, 'neigh_id': 5256120117, 'neigh_distance': 0.7247895095344402, 'cost_save': 0.9550999999999998, 'walk_to_save_ratio': 1.3177618983661847}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_542_1', 'mod_type': 'destination', 'stop_id': 925611130106, 'neigh_id': 5256120116, 'neigh_distance': 0.906969758706097, 'cost_save': 0.8170000000000002, 'walk_to_save_ratio': 0.9008018097158502}
#
# Entry nº51
# Stop costs:  {'stop_id': 925113110225, 'leg': <main.leg.Leg object at 0x358fbbeb0>, 'dist_cost': 10.7376, 'time_cost': 11.736666666666668}
# 	Leg 1: veh_01_925113110225 :: leg (5250500124, 412.32) --> (925113110225, 424.06), 11.74min, 10.74km, None
# 	Leg 2: veh_01_925113110225 :: leg (925113110225, inf) --> (None, inf), 0.00, 0.00min, 0.00km, DEPOT
# 			WARNING :: Candidate stop corresponds to DEPOT which cannot be modified. Skipping.
#
# Entry nº48
# Stop costs:  {'stop_id': 5201110120, 'leg': <main.leg.Leg object at 0x358fbbe20>, 'dist_cost': 10.571299999999999, 'time_cost': 13.825}
# 	Leg 1: veh_01_925113110225 :: leg (5252010122, 383.61) --> (5201110120, 389.79), 6.18min, 4.99km, request_590_1
# 	Leg 2: veh_01_925113110225 :: leg (5201110120, 390.79) --> (925114010111, 398.44), 7.64min, 5.58km, request_581_1
# 		Trip to modify: Customer request_590_1 trip: 5206020205 --> 5201110120
# 			RESULT :: 7 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5201110203, 'neigh_distance': 0.7899297751377098, 'cost_save': 0.7584, 'walk_to_save_ratio': 0.9600853441279471}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5251310106, 'neigh_distance': 0.6118175052254986, 'cost_save': 0.7446999999999981, 'walk_to_save_ratio': 1.217193025108889}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 925113110107, 'neigh_distance': 0.1439925964798672, 'cost_save': 0.7310999999999996, 'walk_to_save_ratio': 5.077344376536892}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5251310105, 'neigh_distance': 0.21270551295222476, 'cost_save': 0.7309999999999999, 'walk_to_save_ratio': 3.4366763223677608}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5251310104, 'neigh_distance': 0.41478717990979497, 'cost_save': 0.7284999999999986, 'walk_to_save_ratio': 1.7563223630933524}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5251310103, 'neigh_distance': 0.7513951335139641, 'cost_save': 0.48639999999999795, 'walk_to_save_ratio': 0.6473291858110743}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5251310221, 'neigh_distance': 0.453198056824018, 'cost_save': 0.2875999999999994, 'walk_to_save_ratio': 0.6346011322631901}
#
# Entry nº11
# Stop costs:  {'stop_id': 5250060205, 'leg': <main.leg.Leg object at 0x358fbb310>, 'dist_cost': 10.538, 'time_cost': 14.38}
# 	Leg 1: veh_01_925113110225 :: leg (5254020107, 133.53) --> (5250060205, 141.81), 8.29min, 6.48km, request_068_2
# 	Leg 2: veh_01_925113110225 :: leg (5250060205, 143.91) --> (5250600110, 150.00), 6.09min, 4.06km, request_155_1
# 		Trip to modify: Customer request_068_2 trip: 5251300111 --> 5250060205
# 			RESULT :: 9 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250060203, 'neigh_distance': 0.4867024808293407, 'cost_save': 1.7750000000000004, 'walk_to_save_ratio': 3.6469918891216695}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250060124, 'neigh_distance': 0.3034226369846323, 'cost_save': 1.4017, 'walk_to_save_ratio': 4.619628956922528}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250600119, 'neigh_distance': 0.7559618778642996, 'cost_save': 0.9311000000000007, 'walk_to_save_ratio': 1.2316758652307858}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5254010223, 'neigh_distance': 0.9192801364799242, 'cost_save': 0.7914000000000012, 'walk_to_save_ratio': 0.8608910043791469}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250600118, 'neigh_distance': 0.974395903207904, 'cost_save': 0.7863000000000007, 'walk_to_save_ratio': 0.8069615208883223}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250060204, 'neigh_distance': 0.16089230252946835, 'cost_save': 0.657700000000002, 'walk_to_save_ratio': 4.087827631651554}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250610128, 'neigh_distance': 0.3143797799915454, 'cost_save': 0.6577000000000002, 'walk_to_save_ratio': 2.09205566597727}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250610129, 'neigh_distance': 0.4676044218221935, 'cost_save': 0.6577000000000002, 'walk_to_save_ratio': 1.406530754001489}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250600207, 'neigh_distance': 0.8616344491206748, 'cost_save': 0.6292000000000009, 'walk_to_save_ratio': 0.7302400694890036}
#
# Entry nº30
# Stop costs:  {'stop_id': 5250060103, 'leg': <main.leg.Leg object at 0x358fbb730>, 'dist_cost': 10.2482, 'time_cost': 13.151666666666667}
# 	Leg 1: veh_01_925113110225 :: leg (5206020118, 282.07) --> (5250060103, 285.80), 3.73min, 1.99km, request_337_1
# 	Leg 2: veh_01_925113110225 :: leg (5250060103, 286.80) --> (5252010107, 296.22), 9.42min, 8.26km, request_318_2
# 		Trip to modify: Customer request_337_1 trip: 5251400120 --> 5250060103
# 			RESULT :: 4 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'destination', 'stop_id': 5250060103, 'neigh_id': 5206020120, 'neigh_distance': 0.5370533669758485, 'cost_save': 0.5223000000000013, 'walk_to_save_ratio': 0.9725290485395828}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'destination', 'stop_id': 5250060103, 'neigh_id': 5206020119, 'neigh_distance': 0.7301415121722368, 'cost_save': 0.5223000000000013, 'walk_to_save_ratio': 0.7153407816056256}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'destination', 'stop_id': 5250060103, 'neigh_id': 5250060102, 'neigh_distance': 0.6567780799107462, 'cost_save': 0.4773999999999994, 'walk_to_save_ratio': 0.7268817498672859}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'destination', 'stop_id': 5250060103, 'neigh_id': 5250710126, 'neigh_distance': 0.17316412472771187, 'cost_save': 0.10529999999999973, 'walk_to_save_ratio': 0.6080936231195486}
#
# Entry nº21
# Stop costs:  {'stop_id': 5102010105, 'leg': <main.leg.Leg object at 0x358fbb880>, 'dist_cost': 10.1304, 'time_cost': 13.818333333333333}
# 	Leg 1: veh_01_925113110225 :: leg (5252010127, 207.04) --> (5102010105, 212.85), 5.81min, 4.36km, request_185_1
# 	Leg 2: veh_01_925113110225 :: leg (5102010105, 213.85) --> (5252040137, 221.86), 8.01min, 5.77km, request_255_5
# 		Trip to modify: Customer request_185_1 trip: 5251400214 --> 5102010105
# 			RESULT :: 9 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5904210111, 'neigh_distance': 0.8104999017746941, 'cost_save': 1.878499999999999, 'walk_to_save_ratio': 2.3177054011811484}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5904210202, 'neigh_distance': 0.7925388768601442, 'cost_save': 1.5495, 'walk_to_save_ratio': 1.9551091375337457}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5256150204, 'neigh_distance': 0.7746177709682528, 'cost_save': 1.5008999999999997, 'walk_to_save_ratio': 1.937600783576024}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5256100110, 'neigh_distance': 0.654394115911037, 'cost_save': 1.1550999999999991, 'walk_to_save_ratio': 1.765144233291107}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 92633201207, 'neigh_distance': 0.7165563533812032, 'cost_save': 1.1550999999999991, 'walk_to_save_ratio': 1.6120155721869565}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5256120208, 'neigh_distance': 0.5190028231208867, 'cost_save': 0.6969999999999992, 'walk_to_save_ratio': 1.342959939618003}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5256120113, 'neigh_distance': 0.4926279793506853, 'cost_save': 0.5097000000000005, 'walk_to_save_ratio': 1.0346549959907214}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5104010119, 'neigh_distance': 0.9212153804340288, 'cost_save': 0.26399999999999935, 'walk_to_save_ratio': 0.2865779334639596}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5104010118, 'neigh_distance': 0.39107191978984285, 'cost_save': 0.17580000000000062, 'walk_to_save_ratio': 0.44953368192345117}
#
# Entry nº13
# Stop costs:  {'stop_id': 5251300107, 'leg': <main.leg.Leg object at 0x358fbb670>, 'dist_cost': 9.6381, 'time_cost': 14.661666666666665}
# 	Leg 1: veh_01_925113110225 :: leg (5250600110, 151.00) --> (5251300107, 161.57), 10.57min, 7.97km, request_097_1
# 	Leg 2: veh_01_925113110225 :: leg (5251300107, 162.57) --> (5251300103, 166.66), 4.09min, 1.66km, request_175_1
# 		Trip to modify: Customer request_097_1 trip: 5254020107 --> 5251300107
# 			RESULT :: 5 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 92501650108, 'neigh_distance': 0.9321834188971548, 'cost_save': 1.0793999999999997, 'walk_to_save_ratio': 1.1579266248663953}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 92501650109, 'neigh_distance': 0.5705959995522752, 'cost_save': 1.0793, 'walk_to_save_ratio': 1.8915309620938197}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 5251300105, 'neigh_distance': 0.4690545762096774, 'cost_save': 0.7852999999999994, 'walk_to_save_ratio': 1.6742188219243672}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 92501650202, 'neigh_distance': 0.9816053337856425, 'cost_save': 0.3635999999999999, 'walk_to_save_ratio': 0.37041363518039}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 92501650201, 'neigh_distance': 0.5535248131419596, 'cost_save': 0.3102999999999998, 'walk_to_save_ratio': 0.560589141864574}
#
# Entry nº3
# Stop costs:  {'stop_id': 5252010214, 'leg': <main.leg.Leg object at 0x358fbb430>, 'dist_cost': 9.1653, 'time_cost': 14.028333333333332}
# 	Leg 1: veh_01_925113110225 :: leg (5252040204, 68.76) --> (5252010214, 75.66), 6.90min, 4.57km, request_001_1
# 	Leg 2: veh_01_925113110225 :: leg (5252010214, 76.66) --> (5252020202, 83.79), 7.13min, 4.59km, request_003_2
# 		Trip to modify: Customer request_001_1 trip: 5252010214 --> 5251400112
# 			RESULT :: 4 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_001_1', 'mod_type': 'origin', 'stop_id': 5252010214, 'neigh_id': 5252010212, 'neigh_distance': 0.9464267109242167, 'cost_save': 1.8685, 'walk_to_save_ratio': 1.9742680319909278}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_001_1', 'mod_type': 'origin', 'stop_id': 5252010214, 'neigh_id': 925218000218, 'neigh_distance': 0.9435367881879307, 'cost_save': 1.8595000000000006, 'walk_to_save_ratio': 1.970776363231352}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_001_1', 'mod_type': 'origin', 'stop_id': 5252010214, 'neigh_id': 5252010213, 'neigh_distance': 0.7591064160297198, 'cost_save': 1.5045000000000002, 'walk_to_save_ratio': 1.9819355603247824}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_001_1', 'mod_type': 'origin', 'stop_id': 5252010214, 'neigh_id': 5252010119, 'neigh_distance': 0.6914288592538596, 'cost_save': 1.3708, 'walk_to_save_ratio': 1.9825611581779636}
#
# Entry nº20
# Stop costs:  {'stop_id': 5252010127, 'leg': <main.leg.Leg object at 0x358fbb850>, 'dist_cost': 9.056799999999999, 'time_cost': 12.350000000000001}
# 	Leg 1: veh_01_925113110225 :: leg (5250500112, 199.50) --> (5252010127, 206.04), 6.54min, 4.70km, request_175_1
# 	Leg 2: veh_01_925113110225 :: leg (5252010127, 207.04) --> (5102010105, 212.85), 5.81min, 4.36km, request_185_1
# 		Trip to modify: Customer request_175_1 trip: 5251300103 --> 5252010127
# 			RESULT :: 4 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_175_1', 'mod_type': 'destination', 'stop_id': 5252010127, 'neigh_id': 5254010228, 'neigh_distance': 0.45828566340351184, 'cost_save': 0.3338000000000001, 'walk_to_save_ratio': 0.7283666644096949}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_175_1', 'mod_type': 'destination', 'stop_id': 5252010127, 'neigh_id': 5250500225, 'neigh_distance': 0.5987049706802988, 'cost_save': 0.3338000000000001, 'walk_to_save_ratio': 0.5575367106451589}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_175_1', 'mod_type': 'destination', 'stop_id': 5252010127, 'neigh_id': 925113110226, 'neigh_distance': 0.4856292266626031, 'cost_save': 0.1706000000000003, 'walk_to_save_ratio': 0.35129681376966787}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_175_1', 'mod_type': 'destination', 'stop_id': 5252010127, 'neigh_id': 925113110225, 'neigh_distance': 0.8558287737704529, 'cost_save': 0.1706000000000003, 'walk_to_save_ratio': 0.19933893931656707}
#
# Entry nº19
# Stop costs:  {'stop_id': 5250500112, 'leg': <main.leg.Leg object at 0x358fbb820>, 'dist_cost': 8.7259, 'time_cost': 11.636666666666667}
# 	Leg 1: veh_01_925113110225 :: leg (5250500118, 193.41) --> (5250500112, 198.50), 5.09min, 4.03km, request_244_1
# 	Leg 2: veh_01_925113110225 :: leg (5250500112, 199.50) --> (5252010127, 206.04), 6.54min, 4.70km, request_175_1
# 		Trip to modify: Customer request_244_1 trip: 5250500112 --> 5252040137
# 			RESULT :: No modifications for stop 5250500112 with current parameters.
#
# Entry nº16
# Stop costs:  {'stop_id': 5251400214, 'leg': <main.leg.Leg object at 0x358fbb790>, 'dist_cost': 8.4155, 'time_cost': 12.691666666666666}
# 	Leg 1: veh_01_925113110225 :: leg (5201110204, 175.48) --> (5251400214, 182.09), 6.62min, 5.19km, request_185_1
# 	Leg 2: veh_01_925113110225 :: leg (5251400214, 183.09) --> (5250500121, 189.17), 6.07min, 3.22km, request_155_1
# 		Trip to modify: Customer request_185_1 trip: 5251400214 --> 5102010105
# 			RESULT :: 8 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400114, 'neigh_distance': 0.6498875278031649, 'cost_save': 0.46799999999999997, 'walk_to_save_ratio': 0.7201246061483823}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400111, 'neigh_distance': 0.8435389603843587, 'cost_save': 0.3366000000000007, 'walk_to_save_ratio': 0.399033139911675}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400112, 'neigh_distance': 0.47306819853414206, 'cost_save': 0.3365999999999989, 'walk_to_save_ratio': 0.7115253171593312}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400113, 'neigh_distance': 0.09825365014921153, 'cost_save': 0.21289999999999942, 'walk_to_save_ratio': 2.1668406178974706}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400115, 'neigh_distance': 0.8155016280021606, 'cost_save': 0.19539999999999935, 'walk_to_save_ratio': 0.23960712436429574}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400116, 'neigh_distance': 0.8517134704533503, 'cost_save': 0.1875, 'walk_to_save_ratio': 0.22014445761929471}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400212, 'neigh_distance': 0.9302185791579413, 'cost_save': 0.16779999999999973, 'walk_to_save_ratio': 0.18038771075922475}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'origin', 'stop_id': 5251400214, 'neigh_id': 5251400117, 'neigh_distance': 0.885217831052666, 'cost_save': 0.10400000000000098, 'walk_to_save_ratio': 0.11748520686295744}
#
# Entry nº45
# Stop costs:  {'stop_id': 5252040207, 'leg': <main.leg.Leg object at 0x358fbbd90>, 'dist_cost': 8.367600000000001, 'time_cost': 10.866666666666667}
# 	Leg 1: veh_01_925113110225 :: leg (925611130106, 364.48) --> (5252040207, 372.89), 8.41min, 6.48km, request_581_1
# 	Leg 2: veh_01_925113110225 :: leg (5252040207, 373.89) --> (5206020205, 376.34), 2.46min, 1.88km, request_590_1
# 		Trip to modify: Customer request_581_1 trip: 5252040207 --> 925114010111
# 			RESULT :: 4 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'origin', 'stop_id': 5252040207, 'neigh_id': 5252010204, 'neigh_distance': 0.9926448557678526, 'cost_save': 0.4684000000000008, 'walk_to_save_ratio': 0.4718706768874289}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'origin', 'stop_id': 5252040207, 'neigh_id': 5252040205, 'neigh_distance': 0.6851340391607448, 'cost_save': 0.42850000000000144, 'walk_to_save_ratio': 0.625425063575724}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'origin', 'stop_id': 5252040207, 'neigh_id': 5252040204, 'neigh_distance': 0.9070236142548038, 'cost_save': 0.42850000000000144, 'walk_to_save_ratio': 0.47242430435733496}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'origin', 'stop_id': 5252040207, 'neigh_id': 92592810104, 'neigh_distance': 0.9769582820979309, 'cost_save': 0.19980000000000153, 'walk_to_save_ratio': 0.20451231507137524}
#
# Entry nº15
# Stop costs:  {'stop_id': 5201110204, 'leg': <main.leg.Leg object at 0x358fbb760>, 'dist_cost': 8.3186, 'time_cost': 13.433333333333334}
# 	Leg 1: veh_01_925113110225 :: leg (5251300103, 167.66) --> (5201110204, 174.48), 6.81min, 3.13km, request_179_1
# 	Leg 2: veh_01_925113110225 :: leg (5201110204, 175.48) --> (5251400214, 182.09), 6.62min, 5.19km, request_185_1
# 		Trip to modify: Customer request_179_1 trip: 5201110204 --> 5250500118
# 			RESULT :: 1 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_179_1', 'mod_type': 'origin', 'stop_id': 5201110204, 'neigh_id': 5251300101, 'neigh_distance': 0.5742622369431045, 'cost_save': 1.0606999999999998, 'walk_to_save_ratio': 1.847065559536504}
#
# Entry nº47
# Stop costs:  {'stop_id': 5252010122, 'leg': <main.leg.Leg object at 0x358fbbdf0>, 'dist_cost': 7.4441999999999995, 'time_cost': 9.45}
# 	Leg 1: veh_01_925113110225 :: leg (5206020205, 377.34) --> (5252010122, 380.61), 3.27min, 2.46km, request_597_3
# 	Leg 2: veh_01_925113110225 :: leg (5252010122, 383.61) --> (5201110120, 389.79), 6.18min, 4.99km, request_590_1
# 		Trip to modify: Customer request_597_3 trip: 5252010122 --> 5250500124
# 			RESULT :: 9 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'origin', 'stop_id': 5252010122, 'neigh_id': 5252040137, 'neigh_distance': 0.9648443462307459, 'cost_save': 0.9919000000000002, 'walk_to_save_ratio': 1.0280414699790177}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'origin', 'stop_id': 5252010122, 'neigh_id': 5252040208, 'neigh_distance': 0.9751559809752393, 'cost_save': 0.9918999999999993, 'walk_to_save_ratio': 1.017170605884009}
# 				{'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'origin', 'stop_id': 5252010122, 'neigh_id': 5252040136, 'neigh_distance': 0.851609979700362, 'cost_save': 0.3855999999999993, 'walk_to_save_ratio': 0.45278943318122244}
# ...
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'destination', 'stop_id': 5250720121, 'neigh_id': 5206020207, 'neigh_distance': 0.34015693348546766, 'cost_save': 0.45619999999999994, 'walk_to_save_ratio': 1.3411456745140546}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'destination', 'stop_id': 5250720121, 'neigh_id': 5206030119, 'neigh_distance': 0.7168110797524284, 'cost_save': 0.4101999999999997, 'walk_to_save_ratio': 0.5722567794873848}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'destination', 'stop_id': 5250720121, 'neigh_id': 5250060108, 'neigh_distance': 0.19285309754889862, 'cost_save': 0.1856, 'walk_to_save_ratio': 0.9623905571593965}
#
# Entry nº23
# Stop costs:  {'stop_id': 5250060119, 'leg': <main.leg.Leg object at 0x359830ac0>, 'dist_cost': 4.9444, 'time_cost': 8.61}
# 	Leg 1: veh_20_5254010218 :: leg (5250060205, 237.33) --> (5250060119, 239.85), 2.52min, 1.75km, request_241_1
# 	Leg 2: veh_20_5254010218 :: leg (5250060119, 240.85) --> (5250060122, 246.94), 6.09min, 3.19km, request_319_1
# 		Trip to modify: Customer request_241_1 trip: 5252010214 --> 5250060119
# 			RESULT :: No modifications for stop 5250060119 with current parameters.
#
# Entry nº7
# Stop costs:  {'stop_id': 5253010202, 'leg': <main.leg.Leg object at 0x359830070>, 'dist_cost': 4.803699999999999, 'time_cost': 7.293333333333333}
# 	Leg 1: veh_20_5254010218 :: leg (5252060140, 116.22) --> (5253010202, 117.34), 1.12min, 0.73km, request_074_1
# 	Leg 2: veh_20_5254010218 :: leg (5253010202, 118.34) --> (5252010226, 124.51), 6.17min, 4.07km, request_091_2
# 		Trip to modify: Customer request_074_1 trip: 5253010202 --> 5250720121
# 			RESULT :: 6 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060140, 'neigh_distance': 0.6141941037857985, 'cost_save': 0.3262999999999998, 'walk_to_save_ratio': 0.5312652758936247}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060205, 'neigh_distance': 0.6200118975855158, 'cost_save': 0.32489999999999863, 'walk_to_save_ratio': 0.524022202259734}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060138, 'neigh_distance': 0.9627728994109194, 'cost_save': 0.14829999999999988, 'walk_to_save_ratio': 0.15403424846164498}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060207, 'neigh_distance': 0.9700954424845138, 'cost_save': 0.148299999999999, 'walk_to_save_ratio': 0.15287155624624674}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060206, 'neigh_distance': 0.7484070201942121, 'cost_save': 0.13289999999999935, 'walk_to_save_ratio': 0.17757716912584773}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'origin', 'stop_id': 5253010202, 'neigh_id': 5252060139, 'neigh_distance': 0.7545244130182774, 'cost_save': 0.1261000000000001, 'walk_to_save_ratio': 0.16712514243981855}
#
# Entry nº11
# Stop costs:  {'stop_id': 5250720220, 'leg': <main.leg.Leg object at 0x3598308b0>, 'dist_cost': 4.3015, 'time_cost': 7.393333333333333}
# 	Leg 1: veh_20_5254010218 :: leg (5250060102, 147.05) --> (5250720220, 151.50), 4.46min, 2.45km, request_091_2
# 	Leg 2: veh_20_5254010218 :: leg (5250720220, 153.50) --> (5250720121, 156.44), 2.94min, 1.85km, request_074_1
# 		Trip to modify: Customer request_091_2 trip: 5252010226 --> 5250720220
# 			RESULT :: 8 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5250720222, 'neigh_distance': 0.9119455476096547, 'cost_save': 1.7748999999999997, 'walk_to_save_ratio': 1.9462784863112466}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5206020210, 'neigh_distance': 0.8563272383818843, 'cost_save': 1.7748, 'walk_to_save_ratio': 2.0725721668665607}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5250720128, 'neigh_distance': 0.8782807495999896, 'cost_save': 1.7748, 'walk_to_save_ratio': 2.020766139766046}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5206020211, 'neigh_distance': 0.6533092596038397, 'cost_save': 1.5673, 'walk_to_save_ratio': 2.3990169693146477}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5250720127, 'neigh_distance': 0.7125545257428104, 'cost_save': 1.0808, 'walk_to_save_ratio': 1.516796204295114}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5206020119, 'neigh_distance': 0.6144693810544082, 'cost_save': 0.8184, 'walk_to_save_ratio': 1.3318808474974846}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5250720223, 'neigh_distance': 0.7214887460842879, 'cost_save': 0.6110999999999995, 'walk_to_save_ratio': 0.8469986584220508}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'destination', 'stop_id': 5250720220, 'neigh_id': 5206020120, 'neigh_distance': 0.840109832630512, 'cost_save': 0.5195999999999996, 'walk_to_save_ratio': 0.6184905589939982}
#
# Entry nº26
# Stop costs:  {'stop_id': 5206020133, 'leg': <main.leg.Leg object at 0x359830b50>, 'dist_cost': 3.9413, 'time_cost': 5.738333333333333}
# 	Leg 1: veh_20_5254010218 :: leg (5250600217, 257.01) --> (5206020133, 261.18), 4.17min, 3.18km, request_317_3
# 	Leg 2: veh_20_5254010218 :: leg (5206020133, 264.18) --> (5402010115, 265.75), 1.57min, 0.76km, request_349_4
# 		Trip to modify: Customer request_317_3 trip: 5250600217 --> 5206020133
# 			RESULT :: 2 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_317_3', 'mod_type': 'destination', 'stop_id': 5206020133, 'neigh_id': 5206020134, 'neigh_distance': 0.38422135743063035, 'cost_save': 0.7589000000000001, 'walk_to_save_ratio': 1.9751634970916903}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_317_3', 'mod_type': 'destination', 'stop_id': 5206020133, 'neigh_id': 5402010115, 'neigh_distance': 0.41171543004687483, 'cost_save': 0.7587999999999999, 'walk_to_save_ratio': 1.8430205540598967}
#
# Entry nº27
# Stop costs:  {'stop_id': 5402010115, 'leg': <main.leg.Leg object at 0x359830b80>, 'dist_cost': 3.7215000000000003, 'time_cost': 6.183333333333333}
# 	Leg 1: veh_20_5254010218 :: leg (5206020133, 264.18) --> (5402010115, 265.75), 1.57min, 0.76km, request_349_4
# 	Leg 2: veh_20_5254010218 :: leg (5402010115, 269.75) --> (5256120116, 274.36), 4.61min, 2.96km, request_315_1
# 		Trip to modify: Customer request_349_4 trip: 5402010115 --> 5250060126
# 			RESULT :: 4 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_349_4', 'mod_type': 'origin', 'stop_id': 5402010115, 'neigh_id': 5251310103, 'neigh_distance': 0.16755370711112463, 'cost_save': 0.4780000000000002, 'walk_to_save_ratio': 2.852816617676994}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_349_4', 'mod_type': 'origin', 'stop_id': 5402010115, 'neigh_id': 925016010225, 'neigh_distance': 0.2336888739462085, 'cost_save': 0.4599000000000002, 'walk_to_save_ratio': 1.9680012669574587}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_349_4', 'mod_type': 'origin', 'stop_id': 5402010115, 'neigh_id': 5206020133, 'neigh_distance': 0.41171543004687483, 'cost_save': 0.4599000000000002, 'walk_to_save_ratio': 1.117033675292761}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_349_4', 'mod_type': 'origin', 'stop_id': 5402010115, 'neigh_id': 5206020134, 'neigh_distance': 0.029010657435941386, 'cost_save': 0.43030000000000035, 'walk_to_save_ratio': 14.83248013079843}
#
# Entry nº28
# Stop costs:  {'stop_id': 5256120116, 'leg': <main.leg.Leg object at 0x359830bb0>, 'dist_cost': 3.4028000000000005, 'time_cost': 5.52}
# 	Leg 1: veh_20_5254010218 :: leg (5402010115, 269.75) --> (5256120116, 274.36), 4.61min, 2.96km, request_315_1
# 	Leg 2: veh_20_5254010218 :: leg (5256120116, 275.36) --> (5256120206, 276.27), 0.91min, 0.45km, request_319_1
# 		Trip to modify: Customer request_315_1 trip: 5250060205 --> 5256120116
# 			RESULT :: 3 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_315_1', 'mod_type': 'destination', 'stop_id': 5256120116, 'neigh_id': 5256120206, 'neigh_distance': 0.2674376948273721, 'cost_save': 0.4686000000000008, 'walk_to_save_ratio': 1.7521838135139347}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_315_1', 'mod_type': 'destination', 'stop_id': 5256120116, 'neigh_id': 5256120203, 'neigh_distance': 0.7789619013086565, 'cost_save': 0.2977000000000003, 'walk_to_save_ratio': 0.38217530215516843}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_315_1', 'mod_type': 'destination', 'stop_id': 5256120116, 'neigh_id': 5256120204, 'neigh_distance': 0.6674984039646261, 'cost_save': 0.2142000000000004, 'walk_to_save_ratio': 0.3208996436961546}
#
# Entry nº19
# Stop costs:  {'stop_id': 5403110202, 'leg': <main.leg.Leg object at 0x359830a00>, 'dist_cost': 2.4314, 'time_cost': 4.803333333333333}
# 	Leg 1: veh_20_5254010218 :: leg (92501500101, 217.11) --> (5403110202, 220.25), 3.14min, 1.46km, request_277_1
# 	Leg 2: veh_20_5254010218 :: leg (5403110202, 221.25) --> (925918510213, 222.92), 1.67min, 0.97km, request_277_1
# 		Trip to modify: Customer request_277_1 trip: 5403110202 --> 925918510213
# 			RESULT :: 10 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5401030116, 'neigh_distance': 0.5967044032588859, 'cost_save': 1.3739, 'walk_to_save_ratio': 2.302480076393739}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5206020131, 'neigh_distance': 0.6777268872757288, 'cost_save': 1.3739, 'walk_to_save_ratio': 2.027217786094766}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 925113110226, 'neigh_distance': 0.693682627267853, 'cost_save': 1.1433, 'walk_to_save_ratio': 1.648160059165696}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5254010228, 'neigh_distance': 0.6826644143614502, 'cost_save': 0.6692, 'walk_to_save_ratio': 0.9802766717025312}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5252020202, 'neigh_distance': 0.28632857573855613, 'cost_save': 0.6011000000000002, 'walk_to_save_ratio': 2.099336395082197}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5259010102, 'neigh_distance': 0.3116446098998037, 'cost_save': 0.5458000000000001, 'walk_to_save_ratio': 1.751353890495585}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5259020214, 'neigh_distance': 0.3725432855600518, 'cost_save': 0.5458000000000001, 'walk_to_save_ratio': 1.4650646546467425}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5252010128, 'neigh_distance': 0.37692884240311664, 'cost_save': 0.5457999999999998, 'walk_to_save_ratio': 1.4480186671846127}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5252010127, 'neigh_distance': 0.22439588574982505, 'cost_save': 0.3483999999999998, 'walk_to_save_ratio': 1.552613136536847}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5252010203, 'neigh_distance': 0.5930394006557499, 'cost_save': 0.3483999999999998, 'walk_to_save_ratio': 0.5874820452313262}
#
# Entry nº22
# Stop costs:  {'stop_id': 5250060205, 'leg': <main.leg.Leg object at 0x359830a90>, 'dist_cost': 2.3562, 'time_cost': 4.081666666666667}
# 	Leg 1: veh_20_5254010218 :: leg (5250060124, 234.77) --> (5250060205, 236.33), 1.56min, 0.61km, request_315_1
# 	Leg 2: veh_20_5254010218 :: leg (5250060205, 237.33) --> (5250060119, 239.85), 2.52min, 1.75km, request_241_1
# 		Trip to modify: Customer request_315_1 trip: 5250060205 --> 5256120116
# 			RESULT :: No modifications for stop 5250060205 with current parameters.
#
# Entry nº6
# Stop costs:  {'stop_id': 5252060140, 'leg': <main.leg.Leg object at 0x3598300d0>, 'dist_cost': 1.2854999999999999, 'time_cost': 2.235}
# 	Leg 1: veh_20_5254010218 :: leg (5253010113, 114.10) --> (5252060140, 115.22), 1.11min, 0.55km, request_075_1
# 	Leg 2: veh_20_5254010218 :: leg (5252060140, 116.22) --> (5253010202, 117.34), 1.12min, 0.73km, request_074_1
# 		Trip to modify: Customer request_075_1 trip: 5252060140 --> 925217900218
# 			RESULT :: 7 modifications found
# 				MODIFICATIONS ::
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010203, 'neigh_distance': 0.2506481383960942, 'cost_save': 0.3677999999999999, 'walk_to_save_ratio': 1.4673956980233902}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5252060142, 'neigh_distance': 0.4529224838683773, 'cost_save': 0.3677999999999999, 'walk_to_save_ratio': 0.8120594872187563}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010113, 'neigh_distance': 0.45147854337769056, 'cost_save': 0.3677999999999998, 'walk_to_save_ratio': 0.8146566551055598}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010202, 'neigh_distance': 0.6141941037857985, 'cost_save': 0.3677999999999998, 'walk_to_save_ratio': 0.5988334921044289}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010114, 'neigh_distance': 0.33941969859999405, 'cost_save': 0.36119999999999985, 'walk_to_save_ratio': 1.0641692320447018}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010204, 'neigh_distance': 0.3510346521745039, 'cost_save': 0.36119999999999985, 'walk_to_save_ratio': 1.0289582460378943}
# 				{'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010115, 'neigh_distance': 0.3859595380535076, 'cost_save': 0.27549999999999986, 'walk_to_save_ratio': 0.7138053936674726}
#
# Entry nº5
# Stop costs:  {'stop_id': 5253010113, 'leg': <main.leg.Leg object at 0x3598300a0>, 'dist_cost': 0.7633, 'time_cost': 1.4266666666666667}
# 	Leg 1: veh_20_5254010218 :: leg (5253010112, 112.79) --> (5253010113, 113.10), 0.31min, 0.21km, request_056_1
# 	Leg 2: veh_20_5254010218 :: leg (5253010113, 114.10) --> (5252060140, 115.22), 1.11min, 0.55km, request_075_1
# 		Trip to modify: Customer request_056_1 trip: 5253010113 --> 5250060102
# 			RESULT :: No modifications for stop 5253010113 with current parameters.

# %%
# Analise results
for key, value in itinerary_modification_dict.items():
    print(f"Itinerary {key} has modifications for {len(value)} requests")
    mod_per_request_dict = value
    for key, value in mod_per_request_dict.items():
        print(f"\tRequest {key} has {len(value)} modifications")
        if len(value) > 0:
            print(f"\t\tBest modification: {value[0]}")
    print()
# Out:
# Itinerary veh_01_925113110225 has modifications for 25 requests
# 	Request request_002_1 has 21 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_002_1', 'mod_type': 'origin', 'stop_id': 5250500102, 'neigh_id': 925113110225, 'neigh_distance': 0.38639018274583853, 'cost_save': 0.8944000000000003, 'walk_to_save_ratio': 2.3147586039687833}
# 	Request request_001_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_001_1', 'mod_type': 'origin', 'stop_id': 5252010214, 'neigh_id': 5252010212, 'neigh_distance': 0.9464267109242167, 'cost_save': 1.8685, 'walk_to_save_ratio': 1.9742680319909278}
# 	Request request_003_2 has 32 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_003_2', 'mod_type': 'origin', 'stop_id': 5252020202, 'neigh_id': 5403110202, 'neigh_distance': 0.28632857573855613, 'cost_save': 1.735500000000001, 'walk_to_save_ratio': 6.061218289244973}
# 	Request request_021_1 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_021_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5401030116, 'neigh_distance': 0.5967044032588859, 'cost_save': 1.2117000000000004, 'walk_to_save_ratio': 2.0306536928206524}
# 	Request request_068_2 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_068_2', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250060203, 'neigh_distance': 0.4867024808293407, 'cost_save': 1.7750000000000004, 'walk_to_save_ratio': 3.6469918891216695}
# 	Request request_097_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_097_1', 'mod_type': 'destination', 'stop_id': 5251300107, 'neigh_id': 92501650108, 'neigh_distance': 0.9321834188971548, 'cost_save': 1.0793999999999997, 'walk_to_save_ratio': 1.1579266248663953}
# 	Request request_155_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_155_1', 'mod_type': 'destination', 'stop_id': 5250500121, 'neigh_id': 92501650104, 'neigh_distance': 0.7442658778489133, 'cost_save': 1.0940000000000003, 'walk_to_save_ratio': 1.4699048183720218}
# 	Request request_175_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_175_1', 'mod_type': 'origin', 'stop_id': 5251300103, 'neigh_id': 5251300104, 'neigh_distance': 0.358410748742544, 'cost_save': 0.4438000000000004, 'walk_to_save_ratio': 1.2382441139308402}
# 	Request request_179_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_179_1', 'mod_type': 'origin', 'stop_id': 5201110204, 'neigh_id': 5251300101, 'neigh_distance': 0.5742622369431045, 'cost_save': 1.0606999999999998, 'walk_to_save_ratio': 1.847065559536504}
# 	Request request_185_1 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_185_1', 'mod_type': 'destination', 'stop_id': 5102010105, 'neigh_id': 5904210111, 'neigh_distance': 0.8104999017746941, 'cost_save': 1.878499999999999, 'walk_to_save_ratio': 2.3177054011811484}
# 	Request request_244_1 has 0 modifications
# 	Request request_255_5 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_255_5', 'mod_type': 'destination', 'stop_id': 925114700202, 'neigh_id': 5251400206, 'neigh_distance': 0.547815339703595, 'cost_save': 0.7481, 'walk_to_save_ratio': 1.3656061555428012}
# 	Request request_296_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_296_1', 'mod_type': 'origin', 'stop_id': 925114700112, 'neigh_id': 925114700203, 'neigh_distance': 0.7649222422507015, 'cost_save': 1.4100000000000001, 'walk_to_save_ratio': 1.8433246180046048}
# 	Request request_318_2 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_318_2', 'mod_type': 'origin', 'stop_id': 925114700206, 'neigh_id': 925114700115, 'neigh_distance': 0.5811101391862409, 'cost_save': 1.2627000000000002, 'walk_to_save_ratio': 2.172909944005151}
# 	Request request_337_1 has 16 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_337_1', 'mod_type': 'origin', 'stop_id': 5251400120, 'neigh_id': 5251400211, 'neigh_distance': 0.5603688217449216, 'cost_save': 0.9852999999999987, 'walk_to_save_ratio': 1.7583062471817974}
# 	Request request_374_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_374_1', 'mod_type': 'destination', 'stop_id': 5253010209, 'neigh_id': 5253010116, 'neigh_distance': 0.8368457860243542, 'cost_save': 1.8143999999999991, 'walk_to_save_ratio': 2.1681414070563245}
# 	Request request_459_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_459_1', 'mod_type': 'origin', 'stop_id': 5253010117, 'neigh_id': 5253010116, 'neigh_distance': 0.5792674439338636, 'cost_save': 0.9933000000000001, 'walk_to_save_ratio': 1.7147519861540976}
# 	Request request_483_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_483_1', 'mod_type': 'destination', 'stop_id': 5252010111, 'neigh_id': 5252010217, 'neigh_distance': 0.7406109704869358, 'cost_save': 1.1393000000000004, 'walk_to_save_ratio': 1.5383244988268743}
# 	Request request_464_3 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_464_3', 'mod_type': 'destination', 'stop_id': 5254020107, 'neigh_id': 5250500107, 'neigh_distance': 0.9095932078497003, 'cost_save': 1.3158000000000003, 'walk_to_save_ratio': 1.4465807227283307}
# 	Request request_496_2 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_496_2', 'mod_type': 'destination', 'stop_id': 5904210201, 'neigh_id': 5256120209, 'neigh_distance': 0.6274562870150919, 'cost_save': 1.2154999999999996, 'walk_to_save_ratio': 1.9371867413781507}
# 	Request request_542_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_542_1', 'mod_type': 'destination', 'stop_id': 925611130106, 'neigh_id': 5256120205, 'neigh_distance': 0.6683402336572117, 'cost_save': 0.9749000000000017, 'walk_to_save_ratio': 1.4586881814151307}
# 	Request request_535_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_535_1', 'mod_type': 'destination', 'stop_id': 5256120209, 'neigh_id': 5102010105, 'neigh_distance': 0.2697829284600778, 'cost_save': 1.2856999999999998, 'walk_to_save_ratio': 4.765683311908509}
# 	Request request_581_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_581_1', 'mod_type': 'origin', 'stop_id': 5252040207, 'neigh_id': 5252010204, 'neigh_distance': 0.9926448557678526, 'cost_save': 0.4684000000000008, 'walk_to_save_ratio': 0.4718706768874289}
# 	Request request_590_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_590_1', 'mod_type': 'destination', 'stop_id': 5201110120, 'neigh_id': 5201110203, 'neigh_distance': 0.7899297751377098, 'cost_save': 0.7584, 'walk_to_save_ratio': 0.9600853441279471}
# 	Request request_597_3 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_01_925113110225', 'customer_id': 'request_597_3', 'mod_type': 'origin', 'stop_id': 5252010122, 'neigh_id': 5252040137, 'neigh_distance': 0.9648443462307459, 'cost_save': 0.9919000000000002, 'walk_to_save_ratio': 1.0280414699790177}
#
# Itinerary veh_02_925113110225 has modifications for 25 requests
# 	Request request_005_2 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_005_2', 'mod_type': 'destination', 'stop_id': 5250710202, 'neigh_id': 5250710129, 'neigh_distance': 0.7858624691381617, 'cost_save': 1.8082000000000011, 'walk_to_save_ratio': 2.300911509342105}
# 	Request request_006_1 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_006_1', 'mod_type': 'destination', 'stop_id': 5250500208, 'neigh_id': 5254010223, 'neigh_distance': 0.9920794358552504, 'cost_save': 3.3028000000000013, 'walk_to_save_ratio': 3.329168895787794}
# 	Request request_004_2 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_004_2', 'mod_type': 'origin', 'stop_id': 5250740213, 'neigh_id': 5250600210, 'neigh_distance': 0.5674910405902373, 'cost_save': 1.2988, 'walk_to_save_ratio': 2.288670493633065}
# 	Request request_064_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_064_1', 'mod_type': 'destination', 'stop_id': 5250060218, 'neigh_id': 5250720119, 'neigh_distance': 0.2000982731909962, 'cost_save': 0.5580999999999996, 'walk_to_save_ratio': 2.789129516711453}
# 	Request request_053_2 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_053_2', 'mod_type': 'origin', 'stop_id': 5253010106, 'neigh_id': 5253010104, 'neigh_distance': 0.9421457592951668, 'cost_save': 0.9071999999999996, 'walk_to_save_ratio': 0.9629083303189618}
# 	Request request_111_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_111_1', 'mod_type': 'origin', 'stop_id': 5250710128, 'neigh_id': 5250060102, 'neigh_distance': 0.5329657894769861, 'cost_save': 1.093, 'walk_to_save_ratio': 2.0507882899436956}
# 	Request request_126_1 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_126_1', 'mod_type': 'destination', 'stop_id': 5250720128, 'neigh_id': 5206030119, 'neigh_distance': 0.8086802601801794, 'cost_save': 1.0669000000000013, 'walk_to_save_ratio': 1.3193100568106966}
# 	Request request_157_1 has 0 modifications
# 	Request request_174_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_174_1', 'mod_type': 'destination', 'stop_id': 5252010122, 'neigh_id': 5252010123, 'neigh_distance': 0.21361438870263982, 'cost_save': 0.41979999999999995, 'walk_to_save_ratio': 1.965223422212345}
# 	Request request_156_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_156_1', 'mod_type': 'destination', 'stop_id': 5259030211, 'neigh_id': 925218000223, 'neigh_distance': 0.9515204260845038, 'cost_save': 1.9743, 'walk_to_save_ratio': 2.074889772071655}
# 	Request request_193_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_193_1', 'mod_type': 'destination', 'stop_id': 925218000218, 'neigh_id': 5252010211, 'neigh_distance': 0.6735481109087275, 'cost_save': 1.3133999999999997, 'walk_to_save_ratio': 1.9499720639525016}
# 	Request request_229_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_229_1', 'mod_type': 'destination', 'stop_id': 5253010219, 'neigh_id': 5252020202, 'neigh_distance': 0.8962788359416293, 'cost_save': 0.5926999999999998, 'walk_to_save_ratio': 0.6612897417992806}
# 	Request request_224_1 has 27 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_224_1', 'mod_type': 'origin', 'stop_id': 5206020132, 'neigh_id': 5252010127, 'neigh_distance': 0.8652396145150186, 'cost_save': 2.4023999999999996, 'walk_to_save_ratio': 2.776571899503914}
# 	Request request_250_3 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_250_3', 'mod_type': 'origin', 'stop_id': 5252020202, 'neigh_id': 925113110226, 'neigh_distance': 0.554490924180501, 'cost_save': 1.157, 'walk_to_save_ratio': 2.086598625054081}
# 	Request request_264_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_264_1', 'mod_type': 'destination', 'stop_id': 925218210235, 'neigh_id': 5252010206, 'neigh_distance': 0.8628957383149224, 'cost_save': 0.22719999999999985, 'walk_to_save_ratio': 0.2632994809357616}
# 	Request request_299_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_299_1', 'mod_type': 'origin', 'stop_id': 5252040210, 'neigh_id': 925218210235, 'neigh_distance': 0.06982687273501903, 'cost_save': 0.49860000000000015, 'walk_to_save_ratio': 7.140517403551802}
# 	Request request_297_1 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_297_1', 'mod_type': 'origin', 'stop_id': 5250500118, 'neigh_id': 5250060127, 'neigh_distance': 0.7849142506355078, 'cost_save': 2.5676000000000005, 'walk_to_save_ratio': 3.2711853529492383}
# 	Request request_306_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_306_1', 'mod_type': 'origin', 'stop_id': 5254020227, 'neigh_id': 5254020115, 'neigh_distance': 0.7586429090877067, 'cost_save': 1.1628999999999996, 'walk_to_save_ratio': 1.5328687397848686}
# 	Request request_344_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_344_1', 'mod_type': 'destination', 'stop_id': 5250750108, 'neigh_id': 5250600210, 'neigh_distance': 0.9050631423599946, 'cost_save': 2.223300000000002, 'walk_to_save_ratio': 2.456513690528423}
# 	Request request_400_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_400_1', 'mod_type': 'origin', 'stop_id': 5102010106, 'neigh_id': 5256120114, 'neigh_distance': 0.4814169204291761, 'cost_save': 0.3816000000000006, 'walk_to_save_ratio': 0.7926601326347438}
# 	Request request_442_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_442_1', 'mod_type': 'origin', 'stop_id': 5206020127, 'neigh_id': 5250720246, 'neigh_distance': 0.09314582018311038, 'cost_save': 0.5097000000000005, 'walk_to_save_ratio': 5.472065187659613}
# 	Request request_486_3 has 0 modifications
# 	Request request_501_3 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_501_3', 'mod_type': 'origin', 'stop_id': 925114800115, 'neigh_id': 5251400118, 'neigh_distance': 0.9834443556280947, 'cost_save': 1.6066999999999996, 'walk_to_save_ratio': 1.6337477466875603}
# 	Request request_552_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_552_1', 'mod_type': 'origin', 'stop_id': 5250500122, 'neigh_id': 5250500205, 'neigh_distance': 0.9514593647670793, 'cost_save': 2.7688000000000006, 'walk_to_save_ratio': 2.9100559651097795}
# 	Request request_593_3 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_02_925113110225', 'customer_id': 'request_593_3', 'mod_type': 'origin', 'stop_id': 5254010108, 'neigh_id': 5250060125, 'neigh_distance': 0.39774382403835595, 'cost_save': 1.1352000000000002, 'walk_to_save_ratio': 2.8540983703383125}
#
# Itinerary veh_03_925113110225 has modifications for 19 requests
# 	Request request_008_3 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_008_3', 'mod_type': 'origin', 'stop_id': 5104010119, 'neigh_id': 5256120114, 'neigh_distance': 0.487538694867069, 'cost_save': 0.8963000000000001, 'walk_to_save_ratio': 1.838418179800852}
# 	Request request_007_4 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_007_4', 'mod_type': 'origin', 'stop_id': 5250500119, 'neigh_id': 5254020224, 'neigh_distance': 0.9716736828756135, 'cost_save': 2.7044999999999995, 'walk_to_save_ratio': 2.7833418231480596}
# 	Request request_057_3 has 31 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_057_3', 'mod_type': 'destination', 'stop_id': 5250710204, 'neigh_id': 5206020120, 'neigh_distance': 0.9998903687758269, 'cost_save': 2.9563999999999986, 'walk_to_save_ratio': 2.956724149288027}
# 	Request request_079_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_079_1', 'mod_type': 'origin', 'stop_id': 5259010102, 'neigh_id': 5403110202, 'neigh_distance': 0.3116446098998037, 'cost_save': 0.901600000000002, 'walk_to_save_ratio': 2.8930389660513423}
# 	Request request_148_1 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_148_1', 'mod_type': 'origin', 'stop_id': 5250600101, 'neigh_id': 5251310223, 'neigh_distance': 0.8580002430429514, 'cost_save': 1.6940999999999988, 'walk_to_save_ratio': 1.9744749651722329}
# 	Request request_188_3 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_188_3', 'mod_type': 'origin', 'stop_id': 5252010205, 'neigh_id': 5259010102, 'neigh_distance': 0.8873865154115651, 'cost_save': 2.1322, 'walk_to_save_ratio': 2.402786117401274}
# 	Request request_180_4 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_180_4', 'mod_type': 'origin', 'stop_id': 5256120113, 'neigh_id': 5904210111, 'neigh_distance': 0.45809786353530824, 'cost_save': 1.2307000000000006, 'walk_to_save_ratio': 2.6865438544118936}
# 	Request request_266_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_266_1', 'mod_type': 'destination', 'stop_id': 5253010112, 'neigh_id': 5252060207, 'neigh_distance': 0.7501671158084032, 'cost_save': 0.497799999999998, 'walk_to_save_ratio': 0.6635854725030881}
# 	Request request_257_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_257_1', 'mod_type': 'destination', 'stop_id': 925114100118, 'neigh_id': 925114100204, 'neigh_distance': 0.44638887103803376, 'cost_save': 1.7935999999999992, 'walk_to_save_ratio': 4.018021318114758}
# 	Request request_259_4 has 0 modifications
# 	Request request_284_2 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_284_2', 'mod_type': 'destination', 'stop_id': 5251400116, 'neigh_id': 5251400113, 'neigh_distance': 0.8236739148168997, 'cost_save': 0.8830000000000009, 'walk_to_save_ratio': 1.0720261794332642}
# 	Request request_410_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_410_1', 'mod_type': 'destination', 'stop_id': 5253010218, 'neigh_id': 5904210204, 'neigh_distance': 0.8578850372947157, 'cost_save': 1.6277999999999988, 'walk_to_save_ratio': 1.8974570358904495}
# 	Request request_379_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_379_1', 'mod_type': 'destination', 'stop_id': 5253010118, 'neigh_id': 5253010202, 'neigh_distance': 0.4920074222927724, 'cost_save': 0.3536999999999999, 'walk_to_save_ratio': 0.7188915938538998}
# 	Request request_387_3 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_387_3', 'mod_type': 'destination', 'stop_id': 5206020130, 'neigh_id': 5251310223, 'neigh_distance': 0.9517153659598716, 'cost_save': 0.997399999999999, 'walk_to_save_ratio': 1.0480024129841081}
# 	Request request_406_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_406_1', 'mod_type': 'origin', 'stop_id': 5251300108, 'neigh_id': 92501650202, 'neigh_distance': 0.8477326083678091, 'cost_save': 1.930200000000001, 'walk_to_save_ratio': 2.2768971972380916}
# 	Request request_499_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_499_1', 'mod_type': 'destination', 'stop_id': 5250500119, 'neigh_id': 5250610202, 'neigh_distance': 0.9506215902301353, 'cost_save': 3.4342000000000006, 'walk_to_save_ratio': 3.6125836350598957}
# 	Request request_540_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_540_1', 'mod_type': 'destination', 'stop_id': 5251310223, 'neigh_id': 5206020130, 'neigh_distance': 0.9517153659598716, 'cost_save': 1.6606000000000005, 'walk_to_save_ratio': 1.7448494154816647}
# 	Request request_562_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_562_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5251310216, 'neigh_distance': 0.9202383123539347, 'cost_save': 1.650500000000001, 'walk_to_save_ratio': 1.7935571447553456}
# 	Request request_595_1 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_03_925113110225', 'customer_id': 'request_595_1', 'mod_type': 'destination', 'stop_id': 5250070106, 'neigh_id': 92501620103, 'neigh_distance': 0.919962598047356, 'cost_save': 2.0141000000000027, 'walk_to_save_ratio': 2.1893281360296397}
#
# Itinerary veh_04_925113110225 has modifications for 17 requests
# 	Request request_009_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_009_1', 'mod_type': 'origin', 'stop_id': 5252010217, 'neigh_id': 925217900103, 'neigh_distance': 0.9183005146895761, 'cost_save': 1.7856000000000023, 'walk_to_save_ratio': 1.9444615040900959}
# 	Request request_010_4 has 27 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_010_4', 'mod_type': 'destination', 'stop_id': 5252040139, 'neigh_id': 5250500225, 'neigh_distance': 0.7213945265849875, 'cost_save': 2.3604999999999983, 'walk_to_save_ratio': 3.2721346129064477}
# 	Request request_047_2 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_047_2', 'mod_type': 'destination', 'stop_id': 5250720216, 'neigh_id': 5250720134, 'neigh_distance': 0.055707772696274076, 'cost_save': 0.12810000000000343, 'walk_to_save_ratio': 2.2994995814753008}
# 	Request request_039_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_039_1', 'mod_type': 'destination', 'stop_id': 5102010203, 'neigh_id': 92501500101, 'neigh_distance': 0.9087772893542315, 'cost_save': 4.322200000000002, 'walk_to_save_ratio': 4.756060753973414}
# 	Request request_113_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_113_1', 'mod_type': 'destination', 'stop_id': 925113110225, 'neigh_id': 92501500101, 'neigh_distance': 0.6331997810942065, 'cost_save': 0.805200000000001, 'walk_to_save_ratio': 1.271636573544874}
# 	Request request_120_5 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_120_5', 'mod_type': 'origin', 'stop_id': 5250720132, 'neigh_id': 5250720133, 'neigh_distance': 0.4676843019494519, 'cost_save': 2.5393, 'walk_to_save_ratio': 5.429517282096955}
# 	Request request_149_1 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_149_1', 'mod_type': 'destination', 'stop_id': 925114700205, 'neigh_id': 925114700203, 'neigh_distance': 0.5856663967434583, 'cost_save': 1.9138000000000002, 'walk_to_save_ratio': 3.2677305897034574}
# 	Request request_170_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_170_1', 'mod_type': 'origin', 'stop_id': 5256120203, 'neigh_id': 5256120119, 'neigh_distance': 0.7552569090032847, 'cost_save': 0.9393999999999991, 'walk_to_save_ratio': 1.2438151691187158}
# 	Request request_254_5 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_254_5', 'mod_type': 'origin', 'stop_id': 5251400206, 'neigh_id': 925114700205, 'neigh_distance': 0.42066911914539934, 'cost_save': 1.0065000000000004, 'walk_to_save_ratio': 2.3926167959386517}
# 	Request request_267_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_267_1', 'mod_type': 'destination', 'stop_id': 5250720133, 'neigh_id': 5250720132, 'neigh_distance': 0.4676843019494519, 'cost_save': 0.4514999999999958, 'walk_to_save_ratio': 0.9653948146602421}
# 	Request request_301_1 has 1 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_301_1', 'mod_type': 'destination', 'stop_id': 5250710130, 'neigh_id': 5250710129, 'neigh_distance': 0.6464057784959325, 'cost_save': 1.082100000000004, 'walk_to_save_ratio': 1.6740258766217282}
# 	Request request_380_2 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_380_2', 'mod_type': 'destination', 'stop_id': 5256120113, 'neigh_id': 5256120208, 'neigh_distance': 0.02917485050172687, 'cost_save': 0.1871999999999998, 'walk_to_save_ratio': 6.416485321455867}
# 	Request request_364_3 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_364_3', 'mod_type': 'origin', 'stop_id': 5252010107, 'neigh_id': 925217900114, 'neigh_distance': 0.62146892771913, 'cost_save': 1.7553999999999998, 'walk_to_save_ratio': 2.8245981765211354}
# 	Request request_494_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_494_1', 'mod_type': 'origin', 'stop_id': 5102010206, 'neigh_id': 5107510203, 'neigh_distance': 0.9929831859780971, 'cost_save': 1.6347000000000005, 'walk_to_save_ratio': 1.6462514401890973}
# 	Request request_513_1 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_513_1', 'mod_type': 'destination', 'stop_id': 5250060215, 'neigh_id': 5250710118, 'neigh_distance': 0.6864582558569259, 'cost_save': 1.3039999999999985, 'walk_to_save_ratio': 1.8996056772194796}
# 	Request request_537_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_537_1', 'mod_type': 'destination', 'stop_id': 5250600115, 'neigh_id': 5250600113, 'neigh_distance': 0.9524912503738273, 'cost_save': 0.7654999999999994, 'walk_to_save_ratio': 0.8036819232718003}
# 	Request request_523_2 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_04_925113110225', 'customer_id': 'request_523_2', 'mod_type': 'destination', 'stop_id': 5250710202, 'neigh_id': 5250710129, 'neigh_distance': 0.7858624691381617, 'cost_save': 2.3666999999999963, 'walk_to_save_ratio': 3.0115956582014975}
#
# Itinerary veh_05_925611130111 has modifications for 21 requests
# 	Request request_011_1 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_011_1', 'mod_type': 'destination', 'stop_id': 5250060123, 'neigh_id': 5250600119, 'neigh_distance': 0.7227297750495546, 'cost_save': 1.5929000000000002, 'walk_to_save_ratio': 2.2040049476179138}
# 	Request request_013_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_013_1', 'mod_type': 'destination', 'stop_id': 92501650201, 'neigh_id': 5251310216, 'neigh_distance': 0.9202383123539347, 'cost_save': 3.1942999999999984, 'walk_to_save_ratio': 3.4711660633092967}
# 	Request request_012_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_012_1', 'mod_type': 'destination', 'stop_id': 5256120116, 'neigh_id': 5256120204, 'neigh_distance': 0.6674984039646261, 'cost_save': 1.7334999999999994, 'walk_to_save_ratio': 2.597009954935961}
# 	Request request_043_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_043_1', 'mod_type': 'origin', 'stop_id': 5250720130, 'neigh_id': 5250720131, 'neigh_distance': 0.5755496088224985, 'cost_save': 0.8079999999999998, 'walk_to_save_ratio': 1.4038755089297434}
# 	Request request_037_1 has 23 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_037_1', 'mod_type': 'destination', 'stop_id': 5250500124, 'neigh_id': 5250500122, 'neigh_distance': 0.7633075969952192, 'cost_save': 1.638399999999999, 'walk_to_save_ratio': 2.1464479149029887}
# 	Request request_143_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_143_1', 'mod_type': 'origin', 'stop_id': 5250500223, 'neigh_id': 5206020130, 'neigh_distance': 0.4341243310870399, 'cost_save': 0.5932000000000004, 'walk_to_save_ratio': 1.366428825849585}
# 	Request request_117_4 has 20 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_117_4', 'mod_type': 'destination', 'stop_id': 5250500203, 'neigh_id': 5250500120, 'neigh_distance': 0.7673732740115715, 'cost_save': 1.6174000000000035, 'walk_to_save_ratio': 2.1077095786054363}
# 	Request request_145_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_145_1', 'mod_type': 'origin', 'stop_id': 92571910123, 'neigh_id': 5253010217, 'neigh_distance': 0.6154410976252395, 'cost_save': 1.552999999999999, 'walk_to_save_ratio': 2.5233933937666078}
# 	Request request_181_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_181_1', 'mod_type': 'origin', 'stop_id': 5259030211, 'neigh_id': 5206020131, 'neigh_distance': 0.8410772336806478, 'cost_save': 0.9013, 'walk_to_save_ratio': 1.0716019455856756}
# 	Request request_237_2 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_237_2', 'mod_type': 'destination', 'stop_id': 5252040208, 'neigh_id': 5252040209, 'neigh_distance': 0.3676749764471134, 'cost_save': 0.7329000000000008, 'walk_to_save_ratio': 1.9933366341166314}
# 	Request request_231_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_231_1', 'mod_type': 'origin', 'stop_id': 92501650202, 'neigh_id': 925114010111, 'neigh_distance': 0.8783982339683147, 'cost_save': 1.913800000000001, 'walk_to_save_ratio': 2.178738442305469}
# 	Request request_247_3 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_247_3', 'mod_type': 'destination', 'stop_id': 5253010119, 'neigh_id': 5253010203, 'neigh_distance': 0.8123934022544995, 'cost_save': 1.1140000000000003, 'walk_to_save_ratio': 1.3712568281678588}
# 	Request request_293_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_293_1', 'mod_type': 'destination', 'stop_id': 5250720229, 'neigh_id': 5206030121, 'neigh_distance': 0.4829903586179922, 'cost_save': 0.9207000000000019, 'walk_to_save_ratio': 1.9062492316294948}
# 	Request request_350_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_350_1', 'mod_type': 'destination', 'stop_id': 5206020131, 'neigh_id': 5252010204, 'neigh_distance': 0.8074370611819534, 'cost_save': 0.22690000000000055, 'walk_to_save_ratio': 0.28101261498680374}
# 	Request request_309_4 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_309_4', 'mod_type': 'origin', 'stop_id': 5252010112, 'neigh_id': 5252010115, 'neigh_distance': 0.9964833461895167, 'cost_save': 0.12910000000000288, 'walk_to_save_ratio': 0.12955560220215656}
# 	Request request_408_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_408_1', 'mod_type': 'destination', 'stop_id': 5252010226, 'neigh_id': 5252010222, 'neigh_distance': 0.9572193800136964, 'cost_save': 2.2851999999999997, 'walk_to_save_ratio': 2.387331522651894}
# 	Request request_428_1 has 21 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_428_1', 'mod_type': 'destination', 'stop_id': 5250500120, 'neigh_id': 5250060125, 'neigh_distance': 0.802268816441863, 'cost_save': 2.337500000000002, 'walk_to_save_ratio': 2.9136119366661073}
# 	Request request_508_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_508_1', 'mod_type': 'destination', 'stop_id': 925114700109, 'neigh_id': 5251400208, 'neigh_distance': 0.6394529681987368, 'cost_save': 1.2507000000000001, 'walk_to_save_ratio': 1.9558905223680074}
# 	Request request_534_1 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_534_1', 'mod_type': 'destination', 'stop_id': 5206020134, 'neigh_id': 5201110120, 'neigh_distance': 0.9189266682506365, 'cost_save': 1.0270000000000001, 'walk_to_save_ratio': 1.117608222161082}
# 	Request request_545_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_545_1', 'mod_type': 'origin', 'stop_id': 5251400208, 'neigh_id': 925114700109, 'neigh_distance': 0.6394529681987368, 'cost_save': 0.8354999999999997, 'walk_to_save_ratio': 1.3065855372499156}
# 	Request request_567_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_05_925611130111', 'customer_id': 'request_567_1', 'mod_type': 'origin', 'stop_id': 5251300104, 'neigh_id': 5251310216, 'neigh_distance': 0.8469402208555674, 'cost_save': 1.9018000000000006, 'walk_to_save_ratio': 2.2454949631260024}
#
# Itinerary veh_06_925611130111 has modifications for 23 requests
# 	Request request_014_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_014_1', 'mod_type': 'origin', 'stop_id': 5251310103, 'neigh_id': 5402010115, 'neigh_distance': 0.16755370711112463, 'cost_save': 0.5003999999999991, 'walk_to_save_ratio': 2.9865050951580843}
# 	Request request_015_3 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_015_3', 'mod_type': 'destination', 'stop_id': 5252010204, 'neigh_id': 5206020130, 'neigh_distance': 0.9922525924452777, 'cost_save': 1.4443000000000001, 'walk_to_save_ratio': 1.4555769478421923}
# 	Request request_059_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_059_1', 'mod_type': 'origin', 'stop_id': 5251300109, 'neigh_id': 92501650202, 'neigh_distance': 0.6630968276890802, 'cost_save': 1.9652000000000012, 'walk_to_save_ratio': 2.9636697356083035}
# 	Request request_087_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_087_1', 'mod_type': 'destination', 'stop_id': 925114700110, 'neigh_id': 925114800115, 'neigh_distance': 0.8958420992907338, 'cost_save': 1.5040000000000013, 'walk_to_save_ratio': 1.6788672927860449}
# 	Request request_123_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_123_1', 'mod_type': 'origin', 'stop_id': 5252060139, 'neigh_id': 5252010214, 'neigh_distance': 0.7698270843488577, 'cost_save': 1.6944000000000008, 'walk_to_save_ratio': 2.2010137528912406}
# 	Request request_161_2 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_161_2', 'mod_type': 'origin', 'stop_id': 5250060125, 'neigh_id': 5250500119, 'neigh_distance': 0.6961273251650509, 'cost_save': 1.7938000000000027, 'walk_to_save_ratio': 2.576827449740886}
# 	Request request_222_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_222_1', 'mod_type': 'origin', 'stop_id': 5253010115, 'neigh_id': 5253010202, 'neigh_distance': 0.5498335112521778, 'cost_save': 0.2181999999999995, 'walk_to_save_ratio': 0.3968474011398032}
# 	Request request_253_3 has 27 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_253_3', 'mod_type': 'origin', 'stop_id': 5253010117, 'neigh_id': 5253010202, 'neigh_distance': 0.9110265547849938, 'cost_save': 1.3688000000000002, 'walk_to_save_ratio': 1.5024809022422436}
# 	Request request_274_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_274_1', 'mod_type': 'destination', 'stop_id': 5206020128, 'neigh_id': 5250600108, 'neigh_distance': 0.6441080526185738, 'cost_save': 1.7866000000000002, 'walk_to_save_ratio': 2.7737582114316215}
# 	Request request_248_1 has 0 modifications
# 	Request request_285_1 has 27 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_285_1', 'mod_type': 'destination', 'stop_id': 5250060218, 'neigh_id': 5250060112, 'neigh_distance': 0.5818855399036286, 'cost_save': 1.855900000000001, 'walk_to_save_ratio': 3.189458875894001}
# 	Request request_333_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_333_1', 'mod_type': 'destination', 'stop_id': 5250600217, 'neigh_id': 5250720246, 'neigh_distance': 0.9968430253430797, 'cost_save': 1.7058000000000004, 'walk_to_save_ratio': 1.7112022220478713}
# 	Request request_338_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_338_1', 'mod_type': 'destination', 'stop_id': 5252060142, 'neigh_id': 5253010210, 'neigh_distance': 0.9625112935169943, 'cost_save': 1.6246000000000005, 'walk_to_save_ratio': 1.6878762991587861}
# 	Request request_352_1 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_352_1', 'mod_type': 'origin', 'stop_id': 5206020134, 'neigh_id': 5251310223, 'neigh_distance': 0.43854945281751007, 'cost_save': 1.1009000000000002, 'walk_to_save_ratio': 2.5103212258666496}
# 	Request request_395_1 has 0 modifications
# 	Request request_390_1 has 0 modifications
# 	Request request_439_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_439_1', 'mod_type': 'destination', 'stop_id': 5251400123, 'neigh_id': 925114700202, 'neigh_distance': 0.9170766422169132, 'cost_save': 1.3259999999999996, 'walk_to_save_ratio': 1.445898782019535}
# 	Request request_445_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_445_1', 'mod_type': 'origin', 'stop_id': 5206020133, 'neigh_id': 5251310104, 'neigh_distance': 0.8718773462925874, 'cost_save': 2.106700000000001, 'walk_to_save_ratio': 2.41628023592785}
# 	Request request_473_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_473_1', 'mod_type': 'destination', 'stop_id': 92501650104, 'neigh_id': 5250500119, 'neigh_distance': 0.2662464125313567, 'cost_save': 0.7754000000000012, 'walk_to_save_ratio': 2.9123397105254134}
# 	Request request_511_2 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_511_2', 'mod_type': 'destination', 'stop_id': 5252060138, 'neigh_id': 5252010213, 'neigh_distance': 0.9081841478117239, 'cost_save': 2.673200000000003, 'walk_to_save_ratio': 2.9434559130338243}
# 	Request request_519_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_519_1', 'mod_type': 'destination', 'stop_id': 925114800112, 'neigh_id': 925114800110, 'neigh_distance': 0.9536743210902918, 'cost_save': 1.472299999999997, 'walk_to_save_ratio': 1.5438184372174186}
# 	Request request_589_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_589_1', 'mod_type': 'destination', 'stop_id': 5253010218, 'neigh_id': 5904210109, 'neigh_distance': 0.790673521204337, 'cost_save': 0.5501, 'walk_to_save_ratio': 0.6957359583284128}
# 	Request request_592_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_06_925611130111', 'customer_id': 'request_592_1', 'mod_type': 'destination', 'stop_id': 92571910203, 'neigh_id': 5259020216, 'neigh_distance': 0.9400405052018724, 'cost_save': 1.2142000000000017, 'walk_to_save_ratio': 1.2916464697861652}
#
# Itinerary veh_07_925611130111 has modifications for 21 requests
# 	Request request_019_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_019_1', 'mod_type': 'origin', 'stop_id': 5252050117, 'neigh_id': 5253010104, 'neigh_distance': 0.9121009472763062, 'cost_save': 1.2957999999999998, 'walk_to_save_ratio': 1.4206760818191084}
# 	Request request_018_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_018_1', 'mod_type': 'origin', 'stop_id': 925114700201, 'neigh_id': 5251400121, 'neigh_distance': 0.10126813177503843, 'cost_save': 0.9288000000000007, 'walk_to_save_ratio': 9.171690873722039}
# 	Request request_026_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_026_1', 'mod_type': 'origin', 'stop_id': 5251400122, 'neigh_id': 925114700115, 'neigh_distance': 0.7185528699985851, 'cost_save': 1.7189000000000005, 'walk_to_save_ratio': 2.3921691385122226}
# 	Request request_055_2 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_055_2', 'mod_type': 'origin', 'stop_id': 5251300109, 'neigh_id': 92501650202, 'neigh_distance': 0.6630968276890802, 'cost_save': 1.9652000000000012, 'walk_to_save_ratio': 2.9636697356083035}
# 	Request request_080_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_080_1', 'mod_type': 'destination', 'stop_id': 5251300109, 'neigh_id': 5251300105, 'neigh_distance': 0.7021574608362099, 'cost_save': 2.976, 'walk_to_save_ratio': 4.2383655604197905}
# 	Request request_140_2 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_140_2', 'mod_type': 'destination', 'stop_id': 5250740213, 'neigh_id': 5250600210, 'neigh_distance': 0.5674910405902373, 'cost_save': 1.2204999999999995, 'walk_to_save_ratio': 2.1506947470581728}
# 	Request request_133_4 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_133_4', 'mod_type': 'origin', 'stop_id': 925114700111, 'neigh_id': 5251400121, 'neigh_distance': 0.8079536244741342, 'cost_save': 1.3619000000000003, 'walk_to_save_ratio': 1.6856165487052657}
# 	Request request_182_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_182_1', 'mod_type': 'destination', 'stop_id': 5253010213, 'neigh_id': 5904210109, 'neigh_distance': 0.6924832581899415, 'cost_save': 1.2422999999999984, 'walk_to_save_ratio': 1.7939783890908847}
# 	Request request_205_1 has 1 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_205_1', 'mod_type': 'destination', 'stop_id': 5206020126, 'neigh_id': 5206020205, 'neigh_distance': 0.125046286633619, 'cost_save': 0.21820000000000128, 'walk_to_save_ratio': 1.7449538556816104}
# 	Request request_204_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_204_1', 'mod_type': 'destination', 'stop_id': 5250600109, 'neigh_id': 5250600218, 'neigh_distance': 0.5076733358224648, 'cost_save': 1.001599999999998, 'walk_to_save_ratio': 1.9729222106521294}
# 	Request request_208_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_208_1', 'mod_type': 'destination', 'stop_id': 925114220110, 'neigh_id': 5251300102, 'neigh_distance': 0.5636644063052315, 'cost_save': 1.0531999999999986, 'walk_to_save_ratio': 1.8684876820653409}
# 	Request request_286_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_286_1', 'mod_type': 'destination', 'stop_id': 925114100112, 'neigh_id': 5251400114, 'neigh_distance': 0.9668366522597963, 'cost_save': 4.3766, 'walk_to_save_ratio': 4.526721230282832}
# 	Request request_279_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_279_1', 'mod_type': 'origin', 'stop_id': 5251300108, 'neigh_id': 92501650201, 'neigh_distance': 0.5104382864774274, 'cost_save': 1.1194000000000006, 'walk_to_save_ratio': 2.1930173140519362}
# 	Request request_316_3 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_316_3', 'mod_type': 'destination', 'stop_id': 5250060205, 'neigh_id': 5250060203, 'neigh_distance': 0.4867024808293407, 'cost_save': 0.8235000000000006, 'walk_to_save_ratio': 1.691998772220674}
# 	Request request_375_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_375_1', 'mod_type': 'destination', 'stop_id': 925114010111, 'neigh_id': 925114100115, 'neigh_distance': 0.7906466512517296, 'cost_save': 0.7424, 'walk_to_save_ratio': 0.9389782386666067}
# 	Request request_370_4 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_370_4', 'mod_type': 'origin', 'stop_id': 92501620208, 'neigh_id': 5250600207, 'neigh_distance': 0.8736851926285841, 'cost_save': 2.3946000000000005, 'walk_to_save_ratio': 2.740804147997022}
# 	Request request_398_2 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_398_2', 'mod_type': 'destination', 'stop_id': 5256120119, 'neigh_id': 5256120118, 'neigh_distance': 0.5735409050200657, 'cost_save': 1.0419999999999998, 'walk_to_save_ratio': 1.816784105335163}
# 	Request request_481_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_481_1', 'mod_type': 'origin', 'stop_id': 5256120203, 'neigh_id': 5256120119, 'neigh_distance': 0.7552569090032847, 'cost_save': 2.1084999999999994, 'walk_to_save_ratio': 2.791765258768165}
# 	Request request_493_1 has 17 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_493_1', 'mod_type': 'origin', 'stop_id': 5252040210, 'neigh_id': 5252040138, 'neigh_distance': 0.9509481341679684, 'cost_save': 2.6317000000000004, 'walk_to_save_ratio': 2.7674485131648163}
# 	Request request_544_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_544_1', 'mod_type': 'origin', 'stop_id': 925114700201, 'neigh_id': 925114700109, 'neigh_distance': 0.9222683987348541, 'cost_save': 2.2720000000000002, 'walk_to_save_ratio': 2.46349110857173}
# 	Request request_572_3 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_572_3', 'mod_type': 'origin', 'stop_id': 5251300105, 'neigh_id': 92501650202, 'neigh_distance': 0.8385071308653198, 'cost_save': 1.4397000000000002, 'walk_to_save_ratio': 1.7169800315404156}
#
# Itinerary veh_08_925611130111 has modifications for 19 requests
# 	Request request_027_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_08_925611130111', 'customer_id': 'request_027_1', 'mod_type': 'origin', 'stop_id': 5251300106, 'neigh_id': 5251300104, 'neigh_distance': 0.9925153666497154, 'cost_save': 2.379299999999999, 'walk_to_save_ratio': 2.3972424810221766}
# 	Request request_028_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_08_925611130111', 'customer_id': 'request_028_1', 'mod_type': 'destination', 'stop_id': 5250060206, 'neigh_id': 5250610123, 'neigh_distance': 0.8296959840675345, 'cost_save': 1.4723000000000006, 'walk_to_save_ratio': 1.7745053950751197}
# 	Request request_073_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_08_925611130111', 'customer_id': 'request_073_1', 'mod_type': 'destination', 'stop_id': 92501620103, 'neigh_id': 5250070216, 'neigh_distance': 0.7495727861207828, 'cost_save': 0.41749999999999954, 'walk_to_save_ratio': 0.55698393502339}
# 	Request request_044_1 has 1 modifications
# 		Best modification: {'vehicle_id': 'veh_08_925611130111', 'customer_id': 'request_044_1', 'mod_type': 'destination', 'stop_id': 5254010218, 'neigh_id': 5254010113, 'neigh_distance': 0.07552114252712945, 'cost_save': 2.8234999999999992, 'walk_to_save_ratio': 37.38688141517078}
# 	Request request_124_3 has 6 modifications
# ...
#
# Itinerary veh_18_5254010218 has modifications for 17 requests
# 	Request request_045_1 has 27 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_045_1', 'mod_type': 'origin', 'stop_id': 92501620103, 'neigh_id': 5250610123, 'neigh_distance': 0.5048456314116126, 'cost_save': 2.798399999999999, 'walk_to_save_ratio': 5.543080549544059}
# 	Request request_046_1 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_046_1', 'mod_type': 'origin', 'stop_id': 925114700204, 'neigh_id': 5251400122, 'neigh_distance': 0.778996473564426, 'cost_save': 1.3497999999999983, 'walk_to_save_ratio': 1.7327421186180307}
# 	Request request_067_3 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_067_3', 'mod_type': 'origin', 'stop_id': 5251300108, 'neigh_id': 92501650108, 'neigh_distance': 0.8130277770720589, 'cost_save': 1.5314000000000014, 'walk_to_save_ratio': 1.8835764818700322}
# 	Request request_104_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_104_1', 'mod_type': 'destination', 'stop_id': 925114800111, 'neigh_id': 925114800114, 'neigh_distance': 0.8801084493694156, 'cost_save': 1.2865000000000002, 'walk_to_save_ratio': 1.4617516749461479}
# 	Request request_212_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_212_1', 'mod_type': 'origin', 'stop_id': 5251300109, 'neigh_id': 92501650108, 'neigh_distance': 0.6443531255997996, 'cost_save': 1.3051999999999992, 'walk_to_save_ratio': 2.0255973753290117}
# 	Request request_236_1 has 0 modifications
# 	Request request_226_1 has 0 modifications
# 	Request request_258_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_258_1', 'mod_type': 'origin', 'stop_id': 5252040138, 'neigh_id': 5252010204, 'neigh_distance': 0.7593980783274689, 'cost_save': 1.008000000000001, 'walk_to_save_ratio': 1.3273670671119733}
# 	Request request_280_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_280_1', 'mod_type': 'destination', 'stop_id': 5251400205, 'neigh_id': 925114800114, 'neigh_distance': 0.8589788676290065, 'cost_save': 2.2027, 'walk_to_save_ratio': 2.564323853600724}
# 	Request request_287_3 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_287_3', 'mod_type': 'origin', 'stop_id': 92501650104, 'neigh_id': 5250500118, 'neigh_distance': 0.6773034607111835, 'cost_save': 1.5227, 'walk_to_save_ratio': 2.248179860768955}
# 	Request request_412_1 has 24 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_412_1', 'mod_type': 'origin', 'stop_id': 5253010118, 'neigh_id': 5253010115, 'neigh_distance': 0.6330467911776237, 'cost_save': 2.111700000000001, 'walk_to_save_ratio': 3.3357723780128734}
# 	Request request_402_3 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_402_3', 'mod_type': 'origin', 'stop_id': 5250500110, 'neigh_id': 5250500112, 'neigh_distance': 0.8299809106905223, 'cost_save': 1.3412000000000006, 'walk_to_save_ratio': 1.6159407797513772}
# 	Request request_480_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_480_1', 'mod_type': 'destination', 'stop_id': 5251400121, 'neigh_id': 5251400120, 'neigh_distance': 0.769853377874424, 'cost_save': 0.9225000000000003, 'walk_to_save_ratio': 1.1982801225696194}
# 	Request request_504_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_504_1', 'mod_type': 'destination', 'stop_id': 5252040140, 'neigh_id': 925113110226, 'neigh_distance': 0.6906751116599182, 'cost_save': 0.6218000000000004, 'walk_to_save_ratio': 0.9002785673072996}
# 	Request request_489_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_489_1', 'mod_type': 'origin', 'stop_id': 5250500125, 'neigh_id': 5250500122, 'neigh_distance': 0.7892625516181985, 'cost_save': 1.6826999999999996, 'walk_to_save_ratio': 2.13199016797391}
# 	Request request_522_4 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_522_4', 'mod_type': 'origin', 'stop_id': 925114700113, 'neigh_id': 5251400121, 'neigh_distance': 0.929638965462392, 'cost_save': 1.7174999999999994, 'walk_to_save_ratio': 1.8474914066728412}
# 	Request request_583_1 has 1 modifications
# 		Best modification: {'vehicle_id': 'veh_18_5254010218', 'customer_id': 'request_583_1', 'mod_type': 'destination', 'stop_id': 5250600217, 'neigh_id': 5250600109, 'neigh_distance': 0.06448268715748279, 'cost_save': 0.24239999999999995, 'walk_to_save_ratio': 3.7591485511141736}
#
# Itinerary veh_19_5254010218 has modifications for 18 requests
# 	Request request_049_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_049_1', 'mod_type': 'origin', 'stop_id': 5251400205, 'neigh_id': 925114800114, 'neigh_distance': 0.8589788676290065, 'cost_save': 1.074300000000001, 'walk_to_save_ratio': 1.250671047316139}
# 	Request request_054_1 has 6 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_054_1', 'mod_type': 'origin', 'stop_id': 5252060209, 'neigh_id': 5252010119, 'neigh_distance': 0.8554011072223304, 'cost_save': 0.35579999999999856, 'walk_to_save_ratio': 0.4159452179754092}
# 	Request request_052_1 has 15 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_052_1', 'mod_type': 'destination', 'stop_id': 925010610127, 'neigh_id': 5250500120, 'neigh_distance': 0.6931378893065697, 'cost_save': 1.3139000000000003, 'walk_to_save_ratio': 1.8955824234546672}
# 	Request request_071_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_071_1', 'mod_type': 'destination', 'stop_id': 925114700114, 'neigh_id': 925114800115, 'neigh_distance': 0.7245723612805239, 'cost_save': 0.7081, 'walk_to_save_ratio': 0.9772660921658498}
# 	Request request_130_1 has 9 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_130_1', 'mod_type': 'destination', 'stop_id': 5252010106, 'neigh_id': 5252010227, 'neigh_distance': 0.8289118447950765, 'cost_save': 0.9929000000000023, 'walk_to_save_ratio': 1.1978354589027098}
# 	Request request_154_1 has 14 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_154_1', 'mod_type': 'origin', 'stop_id': 925114700113, 'neigh_id': 925114700114, 'neigh_distance': 0.5186848490908249, 'cost_save': 2.136000000000001, 'walk_to_save_ratio': 4.118107563280636}
# 	Request request_178_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_178_1', 'mod_type': 'destination', 'stop_id': 5206030212, 'neigh_id': 5250720127, 'neigh_distance': 0.9851582649874928, 'cost_save': 1.2420000000000009, 'walk_to_save_ratio': 1.2607111406772482}
# 	Request request_272_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_272_1', 'mod_type': 'origin', 'stop_id': 925114100113, 'neigh_id': 925114010111, 'neigh_distance': 0.3654365410810865, 'cost_save': 3.3012999999999977, 'walk_to_save_ratio': 9.033853019278316}
# 	Request request_289_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_289_1', 'mod_type': 'destination', 'stop_id': 5256120206, 'neigh_id': 5256120203, 'neigh_distance': 0.8728889276116927, 'cost_save': 1.9464999999999986, 'walk_to_save_ratio': 2.2299515304035396}
# 	Request request_353_1 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_353_1', 'mod_type': 'destination', 'stop_id': 5250500222, 'neigh_id': 5218010299, 'neigh_distance': 0.4303545195062954, 'cost_save': 2.2647000000000013, 'walk_to_save_ratio': 5.26240552230769}
# 	Request request_334_3 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_334_3', 'mod_type': 'destination', 'stop_id': 5250500123, 'neigh_id': 5250500122, 'neigh_distance': 0.3891149648457432, 'cost_save': 2.1316000000000006, 'walk_to_save_ratio': 5.4780725301712065}
# 	Request request_423_1 has 18 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_423_1', 'mod_type': 'destination', 'stop_id': 5107510108, 'neigh_id': 925611210107, 'neigh_distance': 0.4241223841175623, 'cost_save': 0.6042000000000005, 'walk_to_save_ratio': 1.4245888041422556}
# 	Request request_431_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_431_1', 'mod_type': 'destination', 'stop_id': 925114100113, 'neigh_id': 925114100115, 'neigh_distance': 0.42570314684286387, 'cost_save': 1.431700000000001, 'walk_to_save_ratio': 3.3631416883288208}
# 	Request request_448_1 has 16 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_448_1', 'mod_type': 'destination', 'stop_id': 925114800115, 'neigh_id': 5251400118, 'neigh_distance': 0.9834443556280947, 'cost_save': 2.831900000000001, 'walk_to_save_ratio': 2.879573189671068}
# 	Request request_506_1 has 0 modifications
# 	Request request_530_2 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_19_5254010218', 'customer_id': 'request_530_2', 'mod_type': 'destination', 'stop_id': 5252040138, 'neigh_id': 5252010204, 'neigh_distance': 0.7593980783274689, 'cost_save': 0.46839999999999904, 'walk_to_save_ratio': 0.616804299836554}
# 	Request request_529_1 has 0 modifications
# 	Request request_549_2 has 0 modifications
#
# Itinerary veh_20_5254010218 has modifications for 20 requests
# 	Request request_050_1 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_050_1', 'mod_type': 'destination', 'stop_id': 5250610128, 'neigh_id': 5250060122, 'neigh_distance': 0.6350598540880478, 'cost_save': 0.6180000000000003, 'walk_to_save_ratio': 0.9731366201496935}
# 	Request request_062_1 has 2 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_062_1', 'mod_type': 'origin', 'stop_id': 5250600111, 'neigh_id': 5250070121, 'neigh_distance': 0.3282098999430523, 'cost_save': 0.3445999999999998, 'walk_to_save_ratio': 1.0499378600700082}
# 	Request request_056_1 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_056_1', 'mod_type': 'destination', 'stop_id': 5250060102, 'neigh_id': 5250720222, 'neigh_distance': 0.9469249867840116, 'cost_save': 2.4281999999999986, 'walk_to_save_ratio': 2.5643002707603677}
# 	Request request_075_1 has 8 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_075_1', 'mod_type': 'origin', 'stop_id': 5252060140, 'neigh_id': 5253010203, 'neigh_distance': 0.2506481383960942, 'cost_save': 0.3677999999999999, 'walk_to_save_ratio': 1.4673956980233902}
# 	Request request_074_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_074_1', 'mod_type': 'destination', 'stop_id': 5250720121, 'neigh_id': 5250720221, 'neigh_distance': 0.9615356551268374, 'cost_save': 1.9105999999999996, 'walk_to_save_ratio': 1.9870297994804675}
# 	Request request_091_2 has 16 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_091_2', 'mod_type': 'origin', 'stop_id': 5252010226, 'neigh_id': 5252010222, 'neigh_distance': 0.9572193800136964, 'cost_save': 2.2851999999999997, 'walk_to_save_ratio': 2.387331522651894}
# 	Request request_147_1 has 7 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_147_1', 'mod_type': 'destination', 'stop_id': 5250500122, 'neigh_id': 5250500205, 'neigh_distance': 0.9514593647670793, 'cost_save': 1.968700000000002, 'walk_to_save_ratio': 2.0691372358103246}
# 	Request request_168_3 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_168_3', 'mod_type': 'destination', 'stop_id': 5253010119, 'neigh_id': 5253010204, 'neigh_distance': 0.8878410682870025, 'cost_save': 2.869699999999998, 'walk_to_save_ratio': 3.2322226381539068}
# 	Request request_241_1 has 0 modifications
# 	Request request_249_1 has 13 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_249_1', 'mod_type': 'origin', 'stop_id': 92501500101, 'neigh_id': 5259010102, 'neigh_distance': 0.9124090501323163, 'cost_save': 1.7617000000000003, 'walk_to_save_ratio': 1.9308225841737552}
# 	Request request_277_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_277_1', 'mod_type': 'origin', 'stop_id': 5403110202, 'neigh_id': 5401030116, 'neigh_distance': 0.5967044032588859, 'cost_save': 1.3739, 'walk_to_save_ratio': 2.302480076393739}
# 	Request request_315_1 has 3 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_315_1', 'mod_type': 'destination', 'stop_id': 5256120116, 'neigh_id': 5256120206, 'neigh_distance': 0.2674376948273721, 'cost_save': 0.4686000000000008, 'walk_to_save_ratio': 1.7521838135139347}
# 	Request request_319_1 has 10 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_319_1', 'mod_type': 'destination', 'stop_id': 5256120206, 'neigh_id': 5256120116, 'neigh_distance': 0.2674376948273721, 'cost_save': 1.6565999999999992, 'walk_to_save_ratio': 6.194339960450657}
# 	Request request_317_3 has 4 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_317_3', 'mod_type': 'destination', 'stop_id': 5206020133, 'neigh_id': 5206020134, 'neigh_distance': 0.38422135743063035, 'cost_save': 0.7589000000000001, 'walk_to_save_ratio': 1.9751634970916903}
# 	Request request_349_4 has 19 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_349_4', 'mod_type': 'destination', 'stop_id': 5250060126, 'neigh_id': 5254010108, 'neigh_distance': 0.6154400468493061, 'cost_save': 2.294500000000001, 'walk_to_save_ratio': 3.7282266757688296}
# 	Request request_425_4 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_425_4', 'mod_type': 'origin', 'stop_id': 92501620108, 'neigh_id': 925426710102, 'neigh_distance': 0.6345394976178033, 'cost_save': 1.5052000000000012, 'walk_to_save_ratio': 2.3721139592583964}
# 	Request request_492_1 has 11 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_492_1', 'mod_type': 'destination', 'stop_id': 5250060217, 'neigh_id': 5250720119, 'neigh_distance': 0.53723072021212, 'cost_save': 0.8037000000000027, 'walk_to_save_ratio': 1.4960052911394754}
# 	Request request_461_1 has 5 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_461_1', 'mod_type': 'destination', 'stop_id': 5250710130, 'neigh_id': 5206020118, 'neigh_distance': 0.9942015788334724, 'cost_save': 2.689700000000001, 'walk_to_save_ratio': 2.705386973088405}
# 	Request request_551_1 has 22 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_551_1', 'mod_type': 'origin', 'stop_id': 5206020118, 'neigh_id': 5250710130, 'neigh_distance': 0.9942015788334724, 'cost_save': 1.6822, 'walk_to_save_ratio': 1.6920109923520514}
# 	Request request_568_5 has 12 modifications
# 		Best modification: {'vehicle_id': 'veh_20_5254010218', 'customer_id': 'request_568_5', 'mod_type': 'destination', 'stop_id': 925114800114, 'neigh_id': 925114800115, 'neigh_distance': 0.9282892378049625, 'cost_save': 1.3496999999999986, 'walk_to_save_ratio': 1.4539649335927949}

# %%
# Get best modifications for each request into a single itinerary-list
all_mods_per_itinerary = {}
for vehicle_id, value in itinerary_modification_dict.items():
    all_mods_per_itinerary[vehicle_id] = []
    mod_per_request_dict = value
    for request_id, value in mod_per_request_dict.items():
        if len(value) > 0:
            all_mods_per_itinerary[vehicle_id].append(value[0])

for key in all_mods_per_itinerary.keys():
    all_mods_per_itinerary[key].sort(key=lambda x: x["cost_save"], reverse=True)

# Get best modifications overall
all_mods = []
for vehicle_id in all_mods_per_itinerary.keys():
    all_mods += all_mods_per_itinerary[vehicle_id]

all_mods.sort(key=lambda x: x["cost_save"], reverse=True)
for entry in all_mods:
    print(f"\t{entry['vehicle_id']:20s}, {entry['customer_id']}, {entry['cost_save']:3.2f}km, (customer walks {entry['neigh_distance']*1000:3.2f} meters)")
# Out:
# 	veh_07_925611130111 , request_286_1, 4.38km, (customer walks 966.84 meters)
# 	veh_04_925113110225 , request_039_1, 4.32km, (customer walks 908.78 meters)
# 	veh_03_925113110225 , request_499_1, 3.43km, (customer walks 950.62 meters)
# 	veh_09_5403010204   , request_269_3, 3.43km, (customer walks 983.05 meters)
# 	veh_14_5252010101   , request_587_1, 3.41km, (customer walks 785.65 meters)
# 	veh_15_5252010101   , request_440_1, 3.40km, (customer walks 995.84 meters)
# 	veh_02_925113110225 , request_006_1, 3.30km, (customer walks 992.08 meters)
# 	veh_19_5254010218   , request_272_1, 3.30km, (customer walks 365.44 meters)
# 	veh_05_925611130111 , request_013_1, 3.19km, (customer walks 920.24 meters)
# 	veh_09_5403010204   , request_490_2, 3.11km, (customer walks 958.93 meters)
# 	veh_13_5252010101   , request_242_1, 3.00km, (customer walks 951.47 meters)
# 	veh_07_925611130111 , request_080_1, 2.98km, (customer walks 702.16 meters)
# 	veh_03_925113110225 , request_057_3, 2.96km, (customer walks 999.89 meters)
# 	veh_20_5254010218   , request_168_3, 2.87km, (customer walks 887.84 meters)
# 	veh_19_5254010218   , request_448_1, 2.83km, (customer walks 983.44 meters)
# 	veh_14_5252010101   , request_192_1, 2.83km, (customer walks 983.44 meters)
# 	veh_08_925611130111 , request_044_1, 2.82km, (customer walks 75.52 meters)
# 	veh_18_5254010218   , request_045_1, 2.80km, (customer walks 504.85 meters)
# 	veh_02_925113110225 , request_552_1, 2.77km, (customer walks 951.46 meters)
# 	veh_09_5403010204   , request_359_1, 2.73km, (customer walks 877.74 meters)
# 	veh_03_925113110225 , request_007_4, 2.70km, (customer walks 971.67 meters)
# 	veh_20_5254010218   , request_461_1, 2.69km, (customer walks 994.20 meters)
# 	veh_06_925611130111 , request_511_2, 2.67km, (customer walks 908.18 meters)
# 	veh_11_5403010204   , request_245_1, 2.67km, (customer walks 945.03 meters)
# 	veh_07_925611130111 , request_493_1, 2.63km, (customer walks 950.95 meters)
# 	veh_13_5252010101   , request_102_1, 2.59km, (customer walks 940.16 meters)
# 	veh_15_5252010101   , request_290_1, 2.58km, (customer walks 936.02 meters)
# 	veh_02_925113110225 , request_297_1, 2.57km, (customer walks 784.91 meters)
# 	veh_17_5254010218   , request_092_1, 2.55km, (customer walks 722.89 meters)
# 	veh_12_5403010204   , request_533_1, 2.55km, (customer walks 959.38 meters)
# 	veh_11_5403010204   , request_449_1, 2.54km, (customer walks 901.56 meters)
# 	veh_04_925113110225 , request_120_5, 2.54km, (customer walks 467.68 meters)
# 	veh_08_925611130111 , request_548_1, 2.53km, (customer walks 910.05 meters)
# 	veh_15_5252010101   , request_088_1, 2.47km, (customer walks 966.60 meters)
# 	veh_20_5254010218   , request_056_1, 2.43km, (customer walks 946.92 meters)
# 	veh_02_925113110225 , request_224_1, 2.40km, (customer walks 865.24 meters)
# 	veh_13_5252010101   , request_076_4, 2.40km, (customer walks 969.05 meters)
# 	veh_07_925611130111 , request_370_4, 2.39km, (customer walks 873.69 meters)
# 	veh_14_5252010101   , request_158_1, 2.39km, (customer walks 397.74 meters)
# 	veh_08_925611130111 , request_027_1, 2.38km, (customer walks 992.52 meters)
# 	veh_04_925113110225 , request_523_2, 2.37km, (customer walks 785.86 meters)
# 	veh_04_925113110225 , request_010_4, 2.36km, (customer walks 721.39 meters)
# 	veh_11_5403010204   , request_061_1, 2.36km, (customer walks 446.39 meters)
# 	veh_10_5403010204   , request_038_3, 2.34km, (customer walks 602.07 meters)
# 	veh_05_925611130111 , request_428_1, 2.34km, (customer walks 802.27 meters)
# 	veh_14_5252010101   , request_023_2, 2.31km, (customer walks 809.71 meters)
# 	veh_15_5252010101   , request_106_1, 2.30km, (customer walks 778.96 meters)
# 	veh_12_5403010204   , request_270_1, 2.30km, (customer walks 764.87 meters)
# 	veh_20_5254010218   , request_349_4, 2.29km, (customer walks 615.44 meters)
# 	veh_11_5403010204   , request_125_4, 2.29km, (customer walks 721.39 meters)
# 	veh_05_925611130111 , request_408_1, 2.29km, (customer walks 957.22 meters)
# 	veh_20_5254010218   , request_091_2, 2.29km, (customer walks 957.22 meters)
# 	veh_07_925611130111 , request_544_1, 2.27km, (customer walks 922.27 meters)
# 	veh_19_5254010218   , request_353_1, 2.26km, (customer walks 430.35 meters)
# 	veh_10_5403010204   , request_446_1, 2.26km, (customer walks 782.33 meters)
# 	veh_09_5403010204   , request_569_3, 2.26km, (customer walks 709.65 meters)
# 	veh_12_5403010204   , request_466_1, 2.23km, (customer walks 736.48 meters)
# 	veh_02_925113110225 , request_344_1, 2.22km, (customer walks 905.06 meters)
# 	veh_18_5254010218   , request_280_1, 2.20km, (customer walks 858.98 meters)
# 	veh_09_5403010204   , request_243_1, 2.20km, (customer walks 983.05 meters)
# 	veh_09_5403010204   , request_094_1, 2.19km, (customer walks 954.15 meters)
# 	veh_16_5252010101   , request_034_1, 2.19km, (customer walks 888.62 meters)
# 	veh_09_5403010204   , request_090_4, 2.19km, (customer walks 864.81 meters)
# 	veh_11_5403010204   , request_060_1, 2.19km, (customer walks 995.57 meters)
# 	veh_08_925611130111 , request_582_2, 2.18km, (customer walks 792.30 meters)
# 	veh_11_5403010204   , request_238_1, 2.17km, (customer walks 682.11 meters)
# 	veh_19_5254010218   , request_154_1, 2.14km, (customer walks 518.68 meters)
# 	veh_03_925113110225 , request_188_3, 2.13km, (customer walks 887.39 meters)
# 	veh_19_5254010218   , request_334_3, 2.13km, (customer walks 389.11 meters)
# 	veh_15_5252010101   , request_176_2, 2.13km, (customer walks 817.28 meters)
# 	veh_18_5254010218   , request_412_1, 2.11km, (customer walks 633.05 meters)
# 	veh_07_925611130111 , request_481_1, 2.11km, (customer walks 755.26 meters)
# 	veh_06_925611130111 , request_445_1, 2.11km, (customer walks 871.88 meters)
# 	veh_09_5403010204   , request_517_3, 2.10km, (customer walks 945.17 meters)
# 	veh_10_5403010204   , request_107_1, 2.05km, (customer walks 899.35 meters)
# 	veh_17_5254010218   , request_033_1, 2.03km, (customer walks 864.55 meters)
# 	veh_03_925113110225 , request_595_1, 2.01km, (customer walks 919.96 meters)
# 	veh_10_5403010204   , request_115_1, 2.01km, (customer walks 875.18 meters)
# 	veh_12_5403010204   , request_127_4, 1.99km, (customer walks 845.97 meters)
# 	veh_02_925113110225 , request_156_1, 1.97km, (customer walks 951.52 meters)
# 	veh_20_5254010218   , request_147_1, 1.97km, (customer walks 951.46 meters)
# 	veh_06_925611130111 , request_059_1, 1.97km, (customer walks 663.10 meters)
# 	veh_07_925611130111 , request_055_2, 1.97km, (customer walks 663.10 meters)
# 	veh_19_5254010218   , request_289_1, 1.95km, (customer walks 872.89 meters)
# 	veh_16_5252010101   , request_320_2, 1.94km, (customer walks 857.89 meters)
# 	veh_03_925113110225 , request_406_1, 1.93km, (customer walks 847.73 meters)
# 	veh_05_925611130111 , request_231_1, 1.91km, (customer walks 878.40 meters)
# 	veh_04_925113110225 , request_149_1, 1.91km, (customer walks 585.67 meters)
# 	veh_20_5254010218   , request_074_1, 1.91km, (customer walks 961.54 meters)
# 	veh_05_925611130111 , request_567_1, 1.90km, (customer walks 846.94 meters)
# 	veh_10_5403010204   , request_532_4, 1.90km, (customer walks 673.55 meters)
# 	veh_15_5252010101   , request_040_1, 1.89km, (customer walks 554.49 meters)
# 	veh_13_5252010101   , request_235_1, 1.89km, (customer walks 903.98 meters)
# 	veh_11_5403010204   , request_389_1, 1.88km, (customer walks 849.64 meters)
# 	veh_12_5403010204   , request_065_1, 1.88km, (customer walks 956.78 meters)
# 	veh_01_925113110225 , request_185_1, 1.88km, (customer walks 810.50 meters)
# 	veh_01_925113110225 , request_001_1, 1.87km, (customer walks 946.43 meters)
# 	veh_06_925611130111 , request_285_1, 1.86km, (customer walks 581.89 meters)
# 	veh_12_5403010204   , request_066_1, 1.85km, (customer walks 614.48 meters)
# 	veh_12_5403010204   , request_404_2, 1.84km, (customer walks 876.99 meters)
# 	veh_10_5403010204   , request_564_1, 1.82km, (customer walks 702.46 meters)
# 	veh_01_925113110225 , request_374_1, 1.81km, (customer walks 836.85 meters)
# 	veh_02_925113110225 , request_005_2, 1.81km, (customer walks 785.86 meters)
# 	veh_09_5403010204   , request_150_1, 1.81km, (customer walks 663.11 meters)
# 	veh_06_925611130111 , request_161_2, 1.79km, (customer walks 696.13 meters)
# 	veh_03_925113110225 , request_257_1, 1.79km, (customer walks 446.39 meters)
# 	veh_06_925611130111 , request_274_1, 1.79km, (customer walks 644.11 meters)
# 	veh_04_925113110225 , request_009_1, 1.79km, (customer walks 918.30 meters)
# 	veh_01_925113110225 , request_068_2, 1.78km, (customer walks 486.70 meters)
# 	veh_10_5403010204   , request_031_1, 1.77km, (customer walks 891.68 meters)
# 	veh_20_5254010218   , request_249_1, 1.76km, (customer walks 912.41 meters)
# 	veh_17_5254010218   , request_558_1, 1.76km, (customer walks 427.52 meters)
# 	veh_04_925113110225 , request_364_3, 1.76km, (customer walks 621.47 meters)
# 	veh_17_5254010218   , request_167_1, 1.74km, (customer walks 851.93 meters)
# 	veh_01_925113110225 , request_003_2, 1.74km, (customer walks 286.33 meters)
# 	veh_05_925611130111 , request_012_1, 1.73km, (customer walks 667.50 meters)
# 	veh_14_5252010101   , request_282_1, 1.73km, (customer walks 954.08 meters)
# 	veh_07_925611130111 , request_026_1, 1.72km, (customer walks 718.55 meters)
# 	veh_13_5252010101   , request_566_3, 1.72km, (customer walks 874.21 meters)
# 	veh_18_5254010218   , request_522_4, 1.72km, (customer walks 929.64 meters)
# 	veh_06_925611130111 , request_333_1, 1.71km, (customer walks 996.84 meters)
# 	veh_06_925611130111 , request_123_1, 1.69km, (customer walks 769.83 meters)
# 	veh_03_925113110225 , request_148_1, 1.69km, (customer walks 858.00 meters)
# 	veh_18_5254010218   , request_489_1, 1.68km, (customer walks 789.26 meters)
# 	veh_20_5254010218   , request_551_1, 1.68km, (customer walks 994.20 meters)
# 	veh_08_925611130111 , request_169_1, 1.68km, (customer walks 867.03 meters)
# 	veh_17_5254010218   , request_554_2, 1.68km, (customer walks 436.98 meters)
# 	veh_03_925113110225 , request_540_1, 1.66km, (customer walks 951.72 meters)
# 	veh_20_5254010218   , request_319_1, 1.66km, (customer walks 267.44 meters)
# 	veh_17_5254010218   , request_142_3, 1.66km, (customer walks 648.04 meters)
# 	veh_03_925113110225 , request_562_1, 1.65km, (customer walks 920.24 meters)
# 	veh_17_5254010218   , request_415_1, 1.65km, (customer walks 995.33 meters)
# 	veh_08_925611130111 , request_124_3, 1.65km, (customer walks 869.13 meters)
# 	veh_14_5252010101   , request_366_3, 1.64km, (customer walks 884.17 meters)
# 	veh_05_925611130111 , request_037_1, 1.64km, (customer walks 763.31 meters)
# 	veh_04_925113110225 , request_494_1, 1.63km, (customer walks 992.98 meters)
# 	veh_03_925113110225 , request_410_1, 1.63km, (customer walks 857.89 meters)
# 	veh_06_925611130111 , request_338_1, 1.62km, (customer walks 962.51 meters)
# 	veh_05_925611130111 , request_117_4, 1.62km, (customer walks 767.37 meters)
# 	veh_15_5252010101   , request_376_4, 1.62km, (customer walks 818.33 meters)
# 	veh_11_5403010204   , request_347_1, 1.61km, (customer walks 992.98 meters)
# 	veh_12_5403010204   , request_240_1, 1.61km, (customer walks 750.70 meters)
# 	veh_02_925113110225 , request_501_3, 1.61km, (customer walks 983.44 meters)
# 	veh_14_5252010101   , request_184_1, 1.60km, (customer walks 767.37 meters)
# 	veh_05_925611130111 , request_011_1, 1.59km, (customer walks 722.73 meters)
# 	veh_10_5403010204   , request_135_3, 1.58km, (customer walks 871.08 meters)
# 	veh_09_5403010204   , request_109_1, 1.57km, (customer walks 854.61 meters)
# 	veh_15_5252010101   , request_484_1, 1.57km, (customer walks 798.08 meters)
# 	veh_10_5403010204   , request_215_4, 1.57km, (customer walks 798.08 meters)
# 	veh_17_5254010218   , request_444_3, 1.57km, (customer walks 806.83 meters)
# 	veh_15_5252010101   , request_262_3, 1.56km, (customer walks 331.39 meters)
# 	veh_05_925611130111 , request_145_1, 1.55km, (customer walks 615.44 meters)
# 	veh_17_5254010218   , request_214_1, 1.54km, (customer walks 995.57 meters)
# 	veh_18_5254010218   , request_067_3, 1.53km, (customer walks 813.03 meters)
# 	veh_18_5254010218   , request_287_3, 1.52km, (customer walks 677.30 meters)
# 	veh_10_5403010204   , request_377_3, 1.52km, (customer walks 724.79 meters)
# 	veh_20_5254010218   , request_425_4, 1.51km, (customer walks 634.54 meters)
# 	veh_06_925611130111 , request_087_1, 1.50km, (customer walks 895.84 meters)
# 	veh_08_925611130111 , request_357_1, 1.49km, (customer walks 996.61 meters)
# 	veh_12_5403010204   , request_271_1, 1.49km, (customer walks 946.65 meters)
# 	veh_08_925611130111 , request_028_1, 1.47km, (customer walks 829.70 meters)
# 	veh_06_925611130111 , request_519_1, 1.47km, (customer walks 953.67 meters)
# 	veh_11_5403010204   , request_555_1, 1.46km, (customer walks 914.22 meters)
# 	veh_12_5403010204   , request_251_1, 1.46km, (customer walks 875.16 meters)
# 	veh_06_925611130111 , request_015_3, 1.44km, (customer walks 992.25 meters)
# 	veh_07_925611130111 , request_572_3, 1.44km, (customer walks 838.51 meters)
# 	veh_15_5252010101   , request_386_1, 1.44km, (customer walks 893.47 meters)
# 	veh_19_5254010218   , request_431_1, 1.43km, (customer walks 425.70 meters)
# 	veh_14_5252010101   , request_048_1, 1.43km, (customer walks 912.93 meters)
# 	veh_08_925611130111 , request_294_1, 1.42km, (customer walks 945.93 meters)
# 	veh_16_5252010101   , request_268_1, 1.42km, (customer walks 733.64 meters)
# 	veh_09_5403010204   , request_234_1, 1.41km, (customer walks 533.20 meters)
# 	veh_01_925113110225 , request_296_1, 1.41km, (customer walks 764.92 meters)
# 	veh_12_5403010204   , request_495_1, 1.39km, (customer walks 975.97 meters)
# 	veh_08_925611130111 , request_252_1, 1.38km, (customer walks 768.45 meters)
# 	veh_20_5254010218   , request_277_1, 1.37km, (customer walks 596.70 meters)
# 	veh_06_925611130111 , request_253_3, 1.37km, (customer walks 911.03 meters)
# 	veh_12_5403010204   , request_419_1, 1.37km, (customer walks 702.18 meters)
# 	veh_07_925611130111 , request_133_4, 1.36km, (customer walks 807.95 meters)
# 	veh_17_5254010218   , request_263_5, 1.35km, (customer walks 711.56 meters)
# 	veh_18_5254010218   , request_046_1, 1.35km, (customer walks 779.00 meters)
# 	veh_20_5254010218   , request_568_5, 1.35km, (customer walks 928.29 meters)
# 	veh_15_5252010101   , request_261_1, 1.34km, (customer walks 724.79 meters)
# 	veh_18_5254010218   , request_402_3, 1.34km, (customer walks 829.98 meters)
# 	veh_11_5403010204   , request_588_1, 1.34km, (customer walks 586.81 meters)
# 	veh_06_925611130111 , request_439_1, 1.33km, (customer walks 917.08 meters)
# 	veh_08_925611130111 , request_502_1, 1.32km, (customer walks 983.45 meters)
# 	veh_13_5252010101   , request_491_1, 1.32km, (customer walks 662.55 meters)
# 	veh_01_925113110225 , request_464_3, 1.32km, (customer walks 909.59 meters)
# 	veh_19_5254010218   , request_052_1, 1.31km, (customer walks 693.14 meters)
# 	veh_02_925113110225 , request_193_1, 1.31km, (customer walks 673.55 meters)
# 	veh_18_5254010218   , request_212_1, 1.31km, (customer walks 644.35 meters)
# 	veh_14_5252010101   , request_210_1, 1.30km, (customer walks 454.09 meters)
# 	veh_04_925113110225 , request_513_1, 1.30km, (customer walks 686.46 meters)
# 	veh_02_925113110225 , request_004_2, 1.30km, (customer walks 567.49 meters)
# 	veh_16_5252010101   , request_096_1, 1.30km, (customer walks 774.00 meters)
# 	veh_07_925611130111 , request_019_1, 1.30km, (customer walks 912.10 meters)
# 	veh_18_5254010218   , request_104_1, 1.29km, (customer walks 880.11 meters)
# 	veh_15_5252010101   , request_503_1, 1.29km, (customer walks 949.21 meters)
# 	veh_01_925113110225 , request_535_1, 1.29km, (customer walks 269.78 meters)
# 	veh_13_5252010101   , request_122_1, 1.27km, (customer walks 814.39 meters)
# 	veh_17_5254010218   , request_024_4, 1.27km, (customer walks 635.06 meters)
# 	veh_01_925113110225 , request_318_2, 1.26km, (customer walks 581.11 meters)
# 	veh_13_5252010101   , request_311_3, 1.26km, (customer walks 700.82 meters)
# 	veh_05_925611130111 , request_508_1, 1.25km, (customer walks 639.45 meters)
# 	veh_07_925611130111 , request_182_1, 1.24km, (customer walks 692.48 meters)
# 	veh_19_5254010218   , request_178_1, 1.24km, (customer walks 985.16 meters)
# 	veh_15_5252010101   , request_163_3, 1.24km, (customer walks 918.98 meters)
# 	veh_03_925113110225 , request_180_4, 1.23km, (customer walks 458.10 meters)
# 	veh_15_5252010101   , request_029_2, 1.23km, (customer walks 754.71 meters)
# 	veh_07_925611130111 , request_140_2, 1.22km, (customer walks 567.49 meters)
# 	veh_12_5403010204   , request_121_1, 1.22km, (customer walks 947.45 meters)
# 	veh_09_5403010204   , request_207_1, 1.22km, (customer walks 758.70 meters)
# 	veh_01_925113110225 , request_496_2, 1.22km, (customer walks 627.46 meters)
# 	veh_06_925611130111 , request_592_1, 1.21km, (customer walks 940.04 meters)
# 	veh_01_925113110225 , request_021_1, 1.21km, (customer walks 596.70 meters)
# 	veh_11_5403010204   , request_128_1, 1.21km, (customer walks 596.70 meters)
# 	veh_08_925611130111 , request_505_1, 1.20km, (customer walks 784.94 meters)
# 	veh_13_5252010101   , request_405_2, 1.17km, (customer walks 454.53 meters)
# 	veh_13_5252010101   , request_303_1, 1.17km, (customer walks 921.58 meters)
# 	veh_13_5252010101   , request_239_1, 1.17km, (customer walks 723.66 meters)
# 	veh_10_5403010204   , request_348_1, 1.17km, (customer walks 951.47 meters)
# 	veh_02_925113110225 , request_306_1, 1.16km, (customer walks 758.64 meters)
# 	veh_02_925113110225 , request_250_3, 1.16km, (customer walks 554.49 meters)
# 	veh_14_5252010101   , request_098_2, 1.15km, (customer walks 892.87 meters)
# 	veh_13_5252010101   , request_563_1, 1.14km, (customer walks 928.97 meters)
# 	veh_01_925113110225 , request_483_1, 1.14km, (customer walks 740.61 meters)
# 	veh_02_925113110225 , request_593_3, 1.14km, (customer walks 397.74 meters)
# 	veh_16_5252010101   , request_035_1, 1.13km, (customer walks 609.05 meters)
# 	veh_07_925611130111 , request_279_1, 1.12km, (customer walks 510.44 meters)
# 	veh_05_925611130111 , request_247_3, 1.11km, (customer walks 812.39 meters)
# 	veh_17_5254010218   , request_383_1, 1.11km, (customer walks 886.10 meters)
# 	veh_06_925611130111 , request_352_1, 1.10km, (customer walks 438.55 meters)
# 	veh_01_925113110225 , request_155_1, 1.09km, (customer walks 744.27 meters)
# 	veh_17_5254010218   , request_510_3, 1.09km, (customer walks 364.75 meters)
# 	veh_02_925113110225 , request_111_1, 1.09km, (customer walks 532.97 meters)
# 	veh_16_5252010101   , request_560_5, 1.09km, (customer walks 872.10 meters)
# 	veh_15_5252010101   , request_565_1, 1.08km, (customer walks 992.75 meters)
# 	veh_10_5403010204   , request_471_2, 1.08km, (customer walks 994.81 meters)
# 	veh_04_925113110225 , request_301_1, 1.08km, (customer walks 646.41 meters)
# 	veh_01_925113110225 , request_097_1, 1.08km, (customer walks 932.18 meters)
# 	veh_19_5254010218   , request_049_1, 1.07km, (customer walks 858.98 meters)
# 	veh_11_5403010204   , request_177_1, 1.07km, (customer walks 597.07 meters)
# 	veh_02_925113110225 , request_126_1, 1.07km, (customer walks 808.68 meters)
# 	veh_01_925113110225 , request_179_1, 1.06km, (customer walks 574.26 meters)
# 	veh_07_925611130111 , request_208_1, 1.05km, (customer walks 563.66 meters)
# 	veh_16_5252010101   , request_585_1, 1.04km, (customer walks 371.69 meters)
# 	veh_07_925611130111 , request_398_2, 1.04km, (customer walks 573.54 meters)
# 	veh_05_925611130111 , request_534_1, 1.03km, (customer walks 918.93 meters)
# 	veh_11_5403010204   , request_328_1, 1.03km, (customer walks 606.56 meters)
# 	veh_18_5254010218   , request_258_1, 1.01km, (customer walks 759.40 meters)
# 	veh_04_925113110225 , request_254_5, 1.01km, (customer walks 420.67 meters)
# 	veh_11_5403010204   , request_275_1, 1.01km, (customer walks 918.83 meters)
# 	veh_17_5254010218   , request_332_4, 1.00km, (customer walks 423.52 meters)
# 	veh_17_5254010218   , request_298_1, 1.00km, (customer walks 455.07 meters)
# 	veh_07_925611130111 , request_204_1, 1.00km, (customer walks 507.67 meters)
# 	veh_03_925113110225 , request_387_3, 1.00km, (customer walks 951.72 meters)
# 	veh_01_925113110225 , request_459_1, 0.99km, (customer walks 579.27 meters)
# 	veh_19_5254010218   , request_130_1, 0.99km, (customer walks 828.91 meters)
# 	veh_14_5252010101   , request_324_1, 0.99km, (customer walks 975.16 meters)
# 	veh_01_925113110225 , request_597_3, 0.99km, (customer walks 964.84 meters)
# 	veh_01_925113110225 , request_337_1, 0.99km, (customer walks 560.37 meters)
# 	veh_14_5252010101   , request_394_1, 0.98km, (customer walks 654.90 meters)
# 	veh_01_925113110225 , request_542_1, 0.97km, (customer walks 668.34 meters)
# 	veh_14_5252010101   , request_396_1, 0.97km, (customer walks 682.13 meters)
# 	veh_14_5252010101   , request_559_1, 0.96km, (customer walks 811.35 meters)
# 	veh_14_5252010101   , request_041_1, 0.96km, (customer walks 968.84 meters)
# 	veh_14_5252010101   , request_521_1, 0.95km, (customer walks 913.32 meters)
# 	veh_17_5254010218   , request_536_1, 0.94km, (customer walks 809.70 meters)
# 	veh_15_5252010101   , request_036_1, 0.94km, (customer walks 294.08 meters)
# 	veh_04_925113110225 , request_170_1, 0.94km, (customer walks 755.26 meters)
# 	veh_12_5403010204   , request_524_1, 0.94km, (customer walks 861.74 meters)
# 	veh_07_925611130111 , request_018_1, 0.93km, (customer walks 101.27 meters)
# 	veh_18_5254010218   , request_480_1, 0.92km, (customer walks 769.85 meters)
# 	veh_05_925611130111 , request_293_1, 0.92km, (customer walks 482.99 meters)
# 	veh_02_925113110225 , request_053_2, 0.91km, (customer walks 942.15 meters)
# 	veh_03_925113110225 , request_079_1, 0.90km, (customer walks 311.64 meters)
# 	veh_13_5252010101   , request_468_4, 0.90km, (customer walks 411.33 meters)
# 	veh_05_925611130111 , request_181_1, 0.90km, (customer walks 841.08 meters)
# 	veh_03_925113110225 , request_008_3, 0.90km, (customer walks 487.54 meters)
# 	veh_01_925113110225 , request_002_1, 0.89km, (customer walks 386.39 meters)
# 	veh_12_5403010204   , request_543_1, 0.89km, (customer walks 460.94 meters)
# 	veh_08_925611130111 , request_362_1, 0.89km, (customer walks 460.94 meters)
# 	veh_03_925113110225 , request_284_2, 0.88km, (customer walks 823.67 meters)
# 	veh_08_925611130111 , request_512_1, 0.87km, (customer walks 676.09 meters)
# 	veh_14_5252010101   , request_527_1, 0.87km, (customer walks 299.99 meters)
# 	veh_05_925611130111 , request_545_1, 0.84km, (customer walks 639.45 meters)
# 	veh_10_5403010204   , request_101_1, 0.83km, (customer walks 912.56 meters)
# 	veh_07_925611130111 , request_316_3, 0.82km, (customer walks 486.70 meters)
# 	veh_11_5403010204   , request_058_1, 0.82km, (customer walks 753.65 meters)
# 	veh_05_925611130111 , request_043_1, 0.81km, (customer walks 575.55 meters)
# 	veh_04_925113110225 , request_113_1, 0.81km, (customer walks 633.20 meters)
# 	veh_13_5252010101   , request_213_2, 0.80km, (customer walks 481.43 meters)
# 	veh_20_5254010218   , request_492_1, 0.80km, (customer walks 537.23 meters)
# 	veh_13_5252010101   , request_556_3, 0.80km, (customer walks 514.62 meters)
# 	veh_11_5403010204   , request_516_2, 0.80km, (customer walks 890.56 meters)
# 	veh_10_5403010204   , request_201_1, 0.79km, (customer walks 888.62 meters)
# 	veh_14_5252010101   , request_025_3, 0.78km, (customer walks 789.93 meters)
# 	veh_06_925611130111 , request_473_1, 0.78km, (customer walks 266.25 meters)
# 	veh_04_925113110225 , request_537_1, 0.77km, (customer walks 952.49 meters)
# 	veh_16_5252010101   , request_197_5, 0.76km, (customer walks 517.73 meters)
# 	veh_20_5254010218   , request_317_3, 0.76km, (customer walks 384.22 meters)
# 	veh_16_5252010101   , request_343_1, 0.76km, (customer walks 539.14 meters)
# 	veh_01_925113110225 , request_590_1, 0.76km, (customer walks 789.93 meters)
# 	veh_01_925113110225 , request_255_5, 0.75km, (customer walks 547.82 meters)
# 	veh_07_925611130111 , request_375_1, 0.74km, (customer walks 790.65 meters)
# 	veh_09_5403010204   , request_198_1, 0.73km, (customer walks 827.86 meters)
# 	veh_05_925611130111 , request_237_2, 0.73km, (customer walks 367.67 meters)
# 	veh_08_925611130111 , request_256_2, 0.72km, (customer walks 74.00 meters)
# 	veh_16_5252010101   , request_220_1, 0.71km, (customer walks 902.08 meters)
# 	veh_13_5252010101   , request_020_1, 0.71km, (customer walks 802.50 meters)
# 	veh_12_5403010204   , request_186_1, 0.71km, (customer walks 600.16 meters)
# 	veh_19_5254010218   , request_071_1, 0.71km, (customer walks 724.57 meters)
# 	veh_10_5403010204   , request_246_1, 0.69km, (customer walks 69.83 meters)
# 	veh_11_5403010204   , request_538_1, 0.68km, (customer walks 921.60 meters)
# 	veh_13_5252010101   , request_190_1, 0.67km, (customer walks 932.05 meters)
# 	veh_11_5403010204   , request_518_1, 0.64km, (customer walks 404.09 meters)
# 	veh_10_5403010204   , request_314_3, 0.64km, (customer walks 309.00 meters)
# 	veh_17_5254010218   , request_326_2, 0.63km, (customer walks 565.57 meters)
# 	veh_18_5254010218   , request_504_1, 0.62km, (customer walks 690.68 meters)
# 	veh_20_5254010218   , request_050_1, 0.62km, (customer walks 635.06 meters)
# 	veh_17_5254010218   , request_084_1, 0.61km, (customer walks 88.59 meters)
# 	veh_19_5254010218   , request_423_1, 0.60km, (customer walks 424.12 meters)
# 	veh_05_925611130111 , request_143_1, 0.59km, (customer walks 434.12 meters)
# 	veh_02_925113110225 , request_229_1, 0.59km, (customer walks 896.28 meters)
# 	veh_15_5252010101   , request_500_3, 0.59km, (customer walks 378.85 meters)
# 	veh_13_5252010101   , request_401_1, 0.58km, (customer walks 845.12 meters)
# 	veh_09_5403010204   , request_016_1, 0.58km, (customer walks 918.83 meters)
# 	veh_08_925611130111 , request_393_1, 0.56km, (customer walks 402.03 meters)
# 	veh_02_925113110225 , request_064_1, 0.56km, (customer walks 200.10 meters)
# 	veh_12_5403010204   , request_360_3, 0.55km, (customer walks 858.00 meters)
# 	veh_10_5403010204   , request_089_1, 0.55km, (customer walks 397.85 meters)
# 	veh_06_925611130111 , request_589_1, 0.55km, (customer walks 790.67 meters)
# 	veh_09_5403010204   , request_017_1, 0.52km, (customer walks 109.63 meters)
# 	veh_16_5252010101   , request_438_5, 0.52km, (customer walks 918.98 meters)
# 	veh_02_925113110225 , request_442_1, 0.51km, (customer walks 93.15 meters)
# 	veh_14_5252010101   , request_539_1, 0.51km, (customer walks 173.56 meters)
# 	veh_11_5403010204   , request_151_1, 0.50km, (customer walks 837.05 meters)
# 	veh_15_5252010101   , request_283_2, 0.50km, (customer walks 708.56 meters)
# 	veh_06_925611130111 , request_014_1, 0.50km, (customer walks 167.55 meters)
# 	veh_02_925113110225 , request_299_1, 0.50km, (customer walks 69.83 meters)
# 	veh_03_925113110225 , request_266_1, 0.50km, (customer walks 750.17 meters)
# 	veh_09_5403010204   , request_063_1, 0.48km, (customer walks 588.98 meters)
# 	veh_16_5252010101   , request_051_4, 0.48km, (customer walks 188.82 meters)
# 	veh_20_5254010218   , request_315_1, 0.47km, (customer walks 267.44 meters)
# 	veh_01_925113110225 , request_581_1, 0.47km, (customer walks 992.64 meters)
# 	veh_19_5254010218   , request_530_2, 0.47km, (customer walks 759.40 meters)
# 	veh_04_925113110225 , request_267_1, 0.45km, (customer walks 467.68 meters)
# 	veh_01_925113110225 , request_175_1, 0.44km, (customer walks 358.41 meters)
# 	veh_16_5252010101   , request_454_1, 0.43km, (customer walks 877.96 meters)
# 	veh_16_5252010101   , request_209_1, 0.43km, (customer walks 843.28 meters)
# 	veh_09_5403010204   , request_388_1, 0.43km, (customer walks 141.86 meters)
# 	veh_02_925113110225 , request_174_1, 0.42km, (customer walks 213.61 meters)
# 	veh_08_925611130111 , request_073_1, 0.42km, (customer walks 749.57 meters)
# 	veh_16_5252010101   , request_300_1, 0.41km, (customer walks 795.04 meters)
# 	veh_09_5403010204   , request_189_1, 0.39km, (customer walks 549.83 meters)
# 	veh_02_925113110225 , request_400_1, 0.38km, (customer walks 481.42 meters)
# 	veh_20_5254010218   , request_075_1, 0.37km, (customer walks 250.65 meters)
# 	veh_09_5403010204   , request_173_1, 0.36km, (customer walks 251.05 meters)
# 	veh_19_5254010218   , request_054_1, 0.36km, (customer walks 855.40 meters)
# 	veh_03_925113110225 , request_379_1, 0.35km, (customer walks 492.01 meters)
# 	veh_14_5252010101   , request_085_1, 0.35km, (customer walks 268.08 meters)
# 	veh_20_5254010218   , request_062_1, 0.34km, (customer walks 328.21 meters)
# 	veh_17_5254010218   , request_132_4, 0.33km, (customer walks 205.08 meters)
# 	veh_13_5252010101   , request_032_1, 0.32km, (customer walks 234.83 meters)
# 	veh_10_5403010204   , request_520_1, 0.31km, (customer walks 112.70 meters)
# 	veh_15_5252010101   , request_594_1, 0.30km, (customer walks 186.66 meters)
# 	veh_15_5252010101   , request_119_1, 0.29km, (customer walks 962.85 meters)
# 	veh_18_5254010218   , request_583_1, 0.24km, (customer walks 64.48 meters)
# 	veh_09_5403010204   , request_340_4, 0.24km, (customer walks 515.73 meters)
# 	veh_13_5252010101   , request_042_3, 0.23km, (customer walks 670.88 meters)
# 	veh_02_925113110225 , request_264_1, 0.23km, (customer walks 862.90 meters)
# 	veh_05_925611130111 , request_350_1, 0.23km, (customer walks 807.44 meters)
# 	veh_07_925611130111 , request_205_1, 0.22km, (customer walks 125.05 meters)
# 	veh_06_925611130111 , request_222_1, 0.22km, (customer walks 549.83 meters)
# 	veh_13_5252010101   , request_561_1, 0.21km, (customer walks 149.74 meters)
# 	veh_15_5252010101   , request_030_2, 0.20km, (customer walks 578.42 meters)
# 	veh_15_5252010101   , request_281_1, 0.19km, (customer walks 401.90 meters)
# 	veh_04_925113110225 , request_380_2, 0.19km, (customer walks 29.17 meters)
# 	veh_10_5403010204   , request_598_1, 0.16km, (customer walks 446.72 meters)
# 	veh_10_5403010204   , request_331_1, 0.15km, (customer walks 173.53 meters)
# 	veh_05_925611130111 , request_309_4, 0.13km, (customer walks 996.48 meters)
# 	veh_04_925113110225 , request_047_2, 0.13km, (customer walks 55.71 meters)
# 	veh_16_5252010101   , request_131_1, 0.11km, (customer walks 109.63 meters)

# %% [markdown]
# # Implementation of a modification

# %%
# Select the modification to implement
mod = all_mods[0]
vehicle_id = mod["vehicle_id"]
passenger_id = mod["customer_id"]
print(f"Modification to apply: {mod}")
itinerary_to_modify = None
for value in sche.itineraries:
    if value.vehicle_id == vehicle_id:
        itinerary_to_modify = value
I = itinerary_to_modify
print(f"Itinerary to modify:\n",I.to_string_simple())
# Out:
# Modification to apply: {'vehicle_id': 'veh_07_925611130111', 'customer_id': 'request_286_1', 'mod_type': 'destination', 'stop_id': 925114100112, 'neigh_id': 5251400114, 'neigh_distance': 0.9668366522597963, 'cost_save': 4.3766, 'walk_to_save_ratio': 4.526721230282832}
# Itinerary to modify:
#  Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300103, 5251300108, 925114100112, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 181.16

# %% [markdown]
# ### Customer trip extraction

# %%
def get_customer_insertion(vehicle_id, passenger_id):
    itinerary_insertions = sche.itinerary_insertion_dic.get(vehicle_id)
    for insertion in itinerary_insertions:
        if insertion.t.passenger_id == passenger_id:
            return insertion

# %%
insertion_to_delete = get_customer_insertion(vehicle_id, passenger_id)
print(insertion_to_delete.to_string())
# Out:
# Insert
# 	Pickup stop 5251300103 in position 23
# 	Setdown stop 925114100112 in position 25
# 	of itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300103, 5251300108, 925114100112, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment of 3.02

# %%
# Itinerary previous to insertion removal
print(I.to_string_simple())
print(I.to_string())
print()
for S in I.stop_list:
    print(S.to_string())

# %%
# Extract trip
sche.remove_trip(insertion_to_delete)

# Itinerary after trip removal
print(I.to_string_simple())
print(I.to_string())
for S in I.stop_list:
    print(S.to_string())
# Out:
# Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300108, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 178.14
# Vehicle with ID veh_07_925611130111 has 42 stops scheduled
# 	Departure from stop 925611130111 at time 60.82
# 	--> stop 5252050117, npass 0 -> 1, request_019_1, [76.00, 77.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040136, npass 1 -> 0, request_019_1, [80.25, 81.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_018_1, [94.52, 95.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5251400122, npass 1 -> 2, request_026_1, [98.31, 99.31] (arr, dep), 1.00 min, 0.00 min, customers waited 19.31 min
# 	--> stop 92501650202, npass 2 -> 1, request_018_1, [106.70, 107.70] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 3, request_055_2, [109.18, 111.18] (arr, dep), 2.00 min, 0.00 min, customers waited 15.18 min
# 	--> stop 5201110118, npass 3 -> 4, request_080_1, [116.49, 117.49] (arr, dep), 1.00 min, 0.00 min, customers waited 7.49 min
# 	--> stop 5251300103, npass 4 -> 3, request_026_1, [121.72, 122.72] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 2, request_080_1, [126.96, 127.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130108, npass 2 -> 0, request_055_2, [139.22, 141.33] (arr, dep), 2.11 min, 0.11 min
# 	--> stop 925611130107, npass 0 -> 2, request_140_2, [142.00, 144.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925114700111, npass 2 -> 6, request_133_4, [157.31, 161.31] (arr, dep), 4.00 min, 0.00 min, customers waited 17.31 min
# 	--> stop 5251400116, npass 6 -> 2, request_133_4, [166.85, 170.85] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254010221, npass 2 -> 3, request_182_1, [182.97, 183.97] (arr, dep), 1.00 min, 0.00 min, customers waited 19.97 min
# 	--> stop 5250060117, npass 3 -> 4, request_205_1, [187.74, 188.74] (arr, dep), 1.00 min, 0.00 min, customers waited 14.74 min
# 	--> stop 5250060117, npass 4 -> 5, request_204_1, [188.74, 189.74] (arr, dep), 1.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501620103, npass 5 -> 6, request_208_1, [190.77, 191.77] (arr, dep), 1.00 min, 0.00 min, customers waited 16.77 min
# 	--> stop 5250740213, npass 6 -> 4, request_140_2, [193.97, 195.97] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250600109, npass 4 -> 3, request_204_1, [202.41, 203.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 3 -> 2, request_205_1, [207.20, 208.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010213, npass 2 -> 1, request_182_1, [213.86, 214.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114220110, npass 1 -> 0, request_208_1, [226.35, 227.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300108, npass 0 -> 2, request_279_1, [234.16, 235.16] (arr, dep), 1.00 min, 0.00 min, customers waited 18.16 min
# 	--> stop 5254020225, npass 2 -> 4, request_316_3, [254.00, 257.00] (arr, dep), 3.00 min, 0.00 min, customers waited 20.00 min
# 	--> stop 5254020114, npass 4 -> 3, request_279_1, [257.80, 258.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060205, npass 3 -> 0, request_316_3, [264.30, 267.30] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250060123, npass 0 -> 1, request_375_1, [267.38, 268.38] (arr, dep), 1.00 min, 0.00 min, customers waited 9.38 min
# 	--> stop 92501620208, npass 1 -> 5, request_370_4, [272.97, 276.97] (arr, dep), 4.00 min, 0.00 min, customers waited 18.97 min
# 	--> stop 5250610202, npass 5 -> 7, request_398_2, [282.11, 284.11] (arr, dep), 2.00 min, 0.00 min, customers waited 14.11 min
# 	--> stop 925114010111, npass 7 -> 6, request_375_1, [294.12, 295.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130107, npass 6 -> 2, request_370_4, [304.68, 308.68] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5256120119, npass 2 -> 0, request_398_2, [312.24, 314.24] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5256120203, npass 0 -> 1, request_481_1, [316.85, 317.85] (arr, dep), 1.00 min, 0.00 min, customers waited 14.85 min
# 	--> stop 5252040210, npass 1 -> 2, request_493_1, [326.30, 327.30] (arr, dep), 1.00 min, 0.00 min, customers waited 18.30 min
# 	--> stop 5201110203, npass 2 -> 1, request_493_1, [335.43, 336.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400112, npass 1 -> 0, request_481_1, [343.35, 344.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_544_1, [351.71, 352.71] (arr, dep), 1.00 min, 0.00 min, customers waited 19.71 min
# 	--> stop 5251300105, npass 1 -> 4, request_572_3, [361.17, 364.17] (arr, dep), 3.00 min, 0.00 min, customers waited 13.17 min
# 	--> stop 5251400212, npass 4 -> 1, request_572_3, [370.19, 373.19] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 925611130106, npass 1 -> 0, request_544_1, [384.03, 385.03] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 389.96
# 	Vehicle currently at stop 925611130111
# 	Busy time: 319.80 (76.14%), Waiting time: 60.93 (14.51%), Busy+Wait: 90.65%
# Itinerary km: 178.14, cost: 178.14
# Total customers: 20, total waiting: 293.66 min, avg: 14.68 min, stdev: 5.91 min
#
# Stop with ID 925611130111 located at (39.52, -0.36)
# 	 prev stop None
# 	 next stop 5252050117, with leg time 15.18
# 	 Time window
# 		 start_time: 0.00
# 		 EAT: 0.00, EAT_F: 0.00
# 		 LDT: 60.96, LDT_F: 60.96
# 		 slack: 60.93
# 		 latest: inf, end_time: inf
# 	 Arrival at 0.00, departure at 60.82
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 5252050117 located at (39.44, -0.38)
# 	 prev stop 925611130111
# 	 next stop 5252040136, with leg time 3.25
# 	 Time window
# 		 start_time: 76.00
# 		 EAT: 15.18, EAT_F: 76.00
# 		 LDT: 77.14, LDT_F: 77.14
# 		 slack: 60.93
# 		 latest: 96.00, end_time: 97.00
# 	 Arrival at 76.00, departure at 77.00
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5252040136 located at (39.45, -0.39)
# 	 prev stop 5252050117
# 	 next stop 925114700201, with leg time 13.27
# 	 Time window
# 		 start_time: 79.25
# 		 EAT: 80.25, EAT_F: 80.25
# 		 LDT: 81.39, LDT_F: 81.39
# 		 slack: 0.11
# 		 latest: 103.12, end_time: 104.12
# 	 Arrival at 80.25, departure at 81.25
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 925114700201 located at (39.51, -0.46)
# 	 prev stop 5252040136
# 	 next stop 5251400122, with leg time 2.79
# 	 Time window
# 		 start_time: 75.00
# 		 EAT: 94.52, EAT_F: 94.52
# 		 LDT: 95.66, LDT_F: 95.66
# 		 slack: 0.11
# 		 latest: 95.00, end_time: 96.00
# 	 Arrival at 94.52, departure at 95.52
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5251400122 located at (39.52, -0.46)
# 	 prev stop 925114700201
# 	 next stop 92501650202, with leg time 7.39
# 	 Time window
# 		 start_time: 79.00
# 		 EAT: 98.31, EAT_F: 98.31
# 		 LDT: 99.45, LDT_F: 99.45
# 		 slack: 0.11
# 		 latest: 99.00, end_time: 100.00
# 	 Arrival at 98.31, departure at 99.31
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 92501650202 located at (39.51, -0.42)
# 	 prev stop 5251400122
# 	 next stop 5251300109, with leg time 1.48
# 	 Time window
# 		 start_time: 81.89
# 		 EAT: 106.70, EAT_F: 106.70
# 		 LDT: 107.84, LDT_F: 107.84
# 		 slack: 0.11
# 		 latest: 111.22, end_time: 112.22
# 	 Arrival at 106.70, departure at 107.70
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5251300109 located at (39.52, -0.42)
# 	 prev stop 92501650202
# 	 next stop 5201110118, with leg time 5.30
# 	 Time window
# 		 start_time: 94.00
# 		 EAT: 109.18, EAT_F: 109.18
# 		 LDT: 111.33, LDT_F: 111.33
# 		 slack: 0.11
# 		 latest: 114.00, end_time: 116.00
# 	 Arrival at 109.18, departure at 111.18
# 	 Capacity
# 		 Passengers on board on departure from here: 3	 Number of seats reserved on departure from here: 3
#
# Stop with ID 5201110118 located at (39.49, -0.40)
# 	 prev stop 5251300109
# 	 next stop 5251300103, with leg time 4.24
# 	 Time window
# 		 start_time: 109.00
# 		 EAT: 116.49, EAT_F: 116.49
# 		 LDT: 117.63, LDT_F: 117.63
# 		 slack: 0.11
# 		 latest: 129.00, end_time: 130.00
# 	 Arrival at 116.49, departure at 117.49
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# Stop with ID 5251300103 located at (39.51, -0.41)
# 	 prev stop 5201110118
# 	 next stop 5251300109, with leg time 4.23
# 	 Time window
# 		 start_time: 89.14
# 		 EAT: 121.72, EAT_F: 121.72
# 		 LDT: 122.87, LDT_F: 122.87
# 		 slack: 0.11
# 		 latest: 123.34, end_time: 124.34
# 	 Arrival at 121.72, departure at 122.72
# 	 Capacity
# 		 Passengers on board on departure from here: 3	 Number of seats reserved on departure from here: 3
#
# Stop with ID 5251300109 located at (39.52, -0.42)
# 	 prev stop 5251300103
# 	 next stop 925611130108, with leg time 11.26
# 	 Time window
# 		 start_time: 114.54
# 		 EAT: 126.96, EAT_F: 126.96
# 		 LDT: 128.10, LDT_F: 128.10
# 		 slack: 0.11
# 		 latest: 141.85, end_time: 142.85
# 	 Arrival at 126.96, departure at 127.96
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 925611130108 located at (39.51, -0.37)
# 	 prev stop 5251300109
# 	 next stop 925611130107, with leg time 0.67
# 	 Time window
# 		 start_time: 105.27
# 		 EAT: 139.22, EAT_F: 139.22
# 		 LDT: 141.36, LDT_F: 141.36
# 		 slack: 0.11
# 		 latest: 140.16, end_time: 142.16
# 	 Arrival at 139.22, departure at 141.33
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 925611130107 located at (39.50, -0.37)
# 	 prev stop 925611130108
# 	 next stop 925114700111, with leg time 13.31
# 	 Time window
# 		 start_time: 142.00
# 		 EAT: 141.89, EAT_F: 142.00
# 		 LDT: 144.03, LDT_F: 144.03
# 		 slack: 0.11
# 		 latest: 162.00, end_time: 164.00
# 	 Arrival at 142.00, departure at 144.00
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 925114700111 located at (39.52, -0.46)
# 	 prev stop 925611130107
# 	 next stop 5251400116, with leg time 5.54
# 	 Time window
# 		 start_time: 140.00
# 		 EAT: 157.31, EAT_F: 157.31
# 		 LDT: 161.34, LDT_F: 161.34
# 		 slack: 0.00
# 		 latest: 160.00, end_time: 164.00
# 	 Arrival at 157.31, departure at 161.31
# 	 Capacity
# 		 Passengers on board on departure from here: 6	 Number of seats reserved on departure from here: 6
#
# Stop with ID 5251400116 located at (39.51, -0.44)
# 	 prev stop 925114700111
# 	 next stop 5254010221, with leg time 12.12
# 	 Time window
# 		 start_time: 145.54
# 		 EAT: 166.85, EAT_F: 166.85
# 		 LDT: 170.88, LDT_F: 170.88
# 		 slack: 0.00
# 		 latest: 169.86, end_time: 173.86
# 	 Arrival at 166.85, departure at 170.85
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 5254010221 located at (39.48, -0.48)
# 	 prev stop 5251400116
# 	 next stop 5250060117, with leg time 3.77
# 	 Time window
# 		 start_time: 163.00
# 		 EAT: 182.97, EAT_F: 182.97
# 		 LDT: 184.28, LDT_F: 184.00
# 		 slack: 0.00
# 		 latest: 183.00, end_time: 184.00
# 	 Arrival at 182.97, departure at 183.97
# 	 Capacity
# 		 Passengers on board on departure from here: 3	 Number of seats reserved on departure from here: 3
#
# Stop with ID 5250060117 located at (39.47, -0.47)
# 	 prev stop 5254010221
# 	 next stop 5250060117, with leg time 0.00
# 	 Time window
# 		 start_time: 173.00
# 		 EAT: 187.74, EAT_F: 187.74
# 		 LDT: 189.05, LDT_F: 189.05
# 		 slack: 0.00
# 		 latest: 193.00, end_time: 194.00
# 	 Arrival at 187.74, departure at 188.74
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# Stop with ID 5250060117 located at (39.47, -0.47)
# 	 prev stop 5250060117
# 	 next stop 92501620103, with leg time 1.03
# 	 Time window
# 		 start_time: 172.00
# 		 EAT: 188.74, EAT_F: 188.74
# 		 LDT: 190.05, LDT_F: 190.05
# 		 slack: 0.00
# 		 latest: 192.00, end_time: 193.00
# 	 Arrival at 188.74, departure at 189.74
# 	 Capacity
# 		 Passengers on board on departure from here: 5	 Number of seats reserved on departure from here: 5
#
# Stop with ID 92501620103 located at (39.46, -0.46)
# 	 prev stop 5250060117
# 	 next stop 5250740213, with leg time 2.20
# 	 Time window
# 		 start_time: 174.00
# 		 EAT: 190.77, EAT_F: 190.77
# 		 LDT: 192.08, LDT_F: 192.08
# 		 slack: 0.00
# 		 latest: 194.00, end_time: 195.00
# 	 Arrival at 190.77, departure at 191.77
# 	 Capacity
# 		 Passengers on board on departure from here: 6	 Number of seats reserved on departure from here: 6
#
# Stop with ID 5250740213 located at (39.46, -0.45)
# 	 prev stop 92501620103
# 	 next stop 5250600109, with leg time 6.44
# 	 Time window
# 		 start_time: 157.20
# 		 EAT: 193.97, EAT_F: 193.97
# 		 LDT: 196.28, LDT_F: 196.28
# 		 slack: 0.00
# 		 latest: 198.00, end_time: 200.00
# 	 Arrival at 193.97, departure at 195.97
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# Stop with ID 5250600109 located at (39.47, -0.41)
# 	 prev stop 5250740213
# 	 next stop 5206020126, with leg time 3.79
# 	 Time window
# 		 start_time: 179.84
# 		 EAT: 202.41, EAT_F: 202.41
# 		 LDT: 203.72, LDT_F: 203.72
# 		 slack: 0.00
# 		 latest: 210.60, end_time: 211.60
# 	 Arrival at 202.41, departure at 203.41
# 	 Capacity
# 		 Passengers on board on departure from here: 3	 Number of seats reserved on departure from here: 3
#
# Stop with ID 5206020126 located at (39.46, -0.40)
# 	 prev stop 5250600109
# 	 next stop 5253010213, with leg time 5.66
# 	 Time window
# 		 start_time: 182.29
# 		 EAT: 207.20, EAT_F: 207.20
# 		 LDT: 208.51, LDT_F: 208.51
# 		 slack: 0.00
# 		 latest: 215.23, end_time: 216.23
# 	 Arrival at 207.20, departure at 208.20
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 5253010213 located at (39.45, -0.37)
# 	 prev stop 5206020126
# 	 next stop 925114220110, with leg time 11.48
# 	 Time window
# 		 start_time: 175.87
# 		 EAT: 213.86, EAT_F: 213.86
# 		 LDT: 215.40, LDT_F: 215.17
# 		 slack: 0.00
# 		 latest: 214.17, end_time: 215.17
# 	 Arrival at 213.86, departure at 214.86
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 925114220110 located at (39.50, -0.41)
# 	 prev stop 5253010213
# 	 next stop 5251300108, with leg time 5.03
# 	 Time window
# 		 start_time: 187.55
# 		 EAT: 226.35, EAT_F: 226.35
# 		 LDT: 230.97, LDT_F: 227.88
# 		 slack: 0.00
# 		 latest: 226.88, end_time: 227.88
# 	 Arrival at 226.35, departure at 227.35
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 5251300108 located at (39.52, -0.42)
# 	 prev stop 925114220110
# 	 next stop 5254020225, with leg time 11.38
# 	 Time window
# 		 start_time: 216.00
# 		 EAT: 232.38, EAT_F: 232.38
# 		 LDT: 242.62, LDT_F: 237.00
# 		 slack: 0.00
# 		 latest: 236.00, end_time: 237.00
# 	 Arrival at 234.16, departure at 235.16
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 5254020225 located at (39.48, -0.45)
# 	 prev stop 5251300108
# 	 next stop 5254020114, with leg time 0.80
# 	 Time window
# 		 start_time: 234.00
# 		 EAT: 244.76, EAT_F: 244.76
# 		 LDT: 257.28, LDT_F: 257.00
# 		 slack: 0.28
# 		 latest: 254.00, end_time: 257.00
# 	 Arrival at 254.00, departure at 257.00
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# Stop with ID 5254020114 located at (39.48, -0.44)
# 	 prev stop 5254020225
# 	 next stop 5250060205, with leg time 5.50
# 	 Time window
# 		 start_time: 228.12
# 		 EAT: 248.56, EAT_F: 248.56
# 		 LDT: 259.08, LDT_F: 259.08
# 		 slack: 0.28
# 		 latest: 265.31, end_time: 266.31
# 	 Arrival at 257.80, departure at 258.80
# 	 Capacity
# 		 Passengers on board on departure from here: 3	 Number of seats reserved on departure from here: 3
#
# Stop with ID 5250060205 located at (39.47, -0.46)
# 	 prev stop 5254020114
# 	 next stop 5250060123, with leg time 0.07
# 	 Time window
# 		 start_time: 239.43
# 		 EAT: 255.07, EAT_F: 255.07
# 		 LDT: 267.60, LDT_F: 267.58
# 		 slack: 0.29
# 		 latest: 264.58, end_time: 267.58
# 	 Arrival at 264.30, departure at 267.30
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 5250060123 located at (39.47, -0.46)
# 	 prev stop 5250060205
# 	 next stop 92501620208, with leg time 4.59
# 	 Time window
# 		 start_time: 258.00
# 		 EAT: 258.14, EAT_F: 258.14
# 		 LDT: 268.67, LDT_F: 268.67
# 		 slack: 0.29
# 		 latest: 278.00, end_time: 279.00
# 	 Arrival at 267.38, departure at 268.38
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 92501620208 located at (39.46, -0.46)
# 	 prev stop 5250060123
# 	 next stop 5250610202, with leg time 5.14
# 	 Time window
# 		 start_time: 254.00
# 		 EAT: 263.73, EAT_F: 263.73
# 		 LDT: 277.26, LDT_F: 277.26
# 		 slack: 0.29
# 		 latest: 274.00, end_time: 278.00
# 	 Arrival at 272.97, departure at 276.97
# 	 Capacity
# 		 Passengers on board on departure from here: 5	 Number of seats reserved on departure from here: 5
#
# Stop with ID 5250610202 located at (39.48, -0.45)
# 	 prev stop 92501620208
# 	 next stop 925114010111, with leg time 10.01
# 	 Time window
# 		 start_time: 268.00
# 		 EAT: 272.87, EAT_F: 272.87
# 		 LDT: 284.40, LDT_F: 284.40
# 		 slack: 0.29
# 		 latest: 288.00, end_time: 290.00
# 	 Arrival at 282.11, departure at 284.11
# 	 Capacity
# 		 Passengers on board on departure from here: 7	 Number of seats reserved on departure from here: 7
#
# Stop with ID 925114010111 located at (39.51, -0.43)
# 	 prev stop 5250610202
# 	 next stop 925611130107, with leg time 9.55
# 	 Time window
# 		 start_time: 270.12
# 		 EAT: 284.88, EAT_F: 284.88
# 		 LDT: 295.41, LDT_F: 295.41
# 		 slack: 0.29
# 		 latest: 307.29, end_time: 308.29
# 	 Arrival at 294.12, departure at 295.12
# 	 Capacity
# 		 Passengers on board on departure from here: 6	 Number of seats reserved on departure from here: 6
#
# Stop with ID 925611130107 located at (39.50, -0.37)
# 	 prev stop 925114010111
# 	 next stop 5256120119, with leg time 3.56
# 	 Time window
# 		 start_time: 269.51
# 		 EAT: 295.44, EAT_F: 295.44
# 		 LDT: 308.97, LDT_F: 308.97
# 		 slack: 0.29
# 		 latest: 308.77, end_time: 312.77
# 	 Arrival at 304.68, departure at 308.68
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 5256120119 located at (39.48, -0.38)
# 	 prev stop 925611130107
# 	 next stop 5256120203, with leg time 2.61
# 	 Time window
# 		 start_time: 279.52
# 		 EAT: 303.00, EAT_F: 303.00
# 		 LDT: 314.53, LDT_F: 314.53
# 		 slack: 0.29
# 		 latest: 314.80, end_time: 316.80
# 	 Arrival at 312.24, departure at 314.24
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 5256120203 located at (39.48, -0.37)
# 	 prev stop 5256120119
# 	 next stop 5252040210, with leg time 8.45
# 	 Time window
# 		 start_time: 302.00
# 		 EAT: 307.61, EAT_F: 307.61
# 		 LDT: 318.14, LDT_F: 318.14
# 		 slack: 0.29
# 		 latest: 322.00, end_time: 323.00
# 	 Arrival at 316.85, departure at 317.85
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5252040210 located at (39.45, -0.39)
# 	 prev stop 5256120203
# 	 next stop 5201110203, with leg time 8.13
# 	 Time window
# 		 start_time: 308.00
# 		 EAT: 317.06, EAT_F: 317.06
# 		 LDT: 327.59, LDT_F: 327.59
# 		 slack: 0.29
# 		 latest: 328.00, end_time: 329.00
# 	 Arrival at 326.30, departure at 327.30
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Stop with ID 5201110203 located at (39.49, -0.40)
# 	 prev stop 5252040210
# 	 next stop 5251400112, with leg time 6.92
# 	 Time window
# 		 start_time: 316.13
# 		 EAT: 326.19, EAT_F: 326.19
# 		 LDT: 336.72, LDT_F: 336.72
# 		 slack: 0.29
# 		 latest: 347.32, end_time: 348.32
# 	 Arrival at 335.43, departure at 336.43
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5251400112 located at (39.50, -0.44)
# 	 prev stop 5201110203
# 	 next stop 925114700201, with leg time 7.36
# 	 Time window
# 		 start_time: 311.66
# 		 EAT: 334.11, EAT_F: 334.11
# 		 LDT: 344.64, LDT_F: 344.64
# 		 slack: 0.29
# 		 latest: 345.15, end_time: 346.15
# 	 Arrival at 343.35, departure at 344.35
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 925114700201 located at (39.51, -0.46)
# 	 prev stop 5251400112
# 	 next stop 5251300105, with leg time 8.46
# 	 Time window
# 		 start_time: 332.00
# 		 EAT: 342.47, EAT_F: 342.47
# 		 LDT: 353.30, LDT_F: 353.00
# 		 slack: 0.59
# 		 latest: 352.00, end_time: 353.00
# 	 Arrival at 351.71, departure at 352.71
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 5251300105 located at (39.51, -0.42)
# 	 prev stop 925114700201
# 	 next stop 5251400212, with leg time 6.02
# 	 Time window
# 		 start_time: 348.00
# 		 EAT: 351.93, EAT_F: 351.93
# 		 LDT: 364.76, LDT_F: 364.76
# 		 slack: 0.59
# 		 latest: 368.00, end_time: 371.00
# 	 Arrival at 361.17, departure at 364.17
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# Stop with ID 5251400212 located at (39.51, -0.45)
# 	 prev stop 5251300105
# 	 next stop 925611130106, with leg time 10.84
# 	 Time window
# 		 start_time: 354.02
# 		 EAT: 360.95, EAT_F: 360.95
# 		 LDT: 373.78, LDT_F: 373.78
# 		 slack: 0.59
# 		 latest: 380.05, end_time: 383.05
# 	 Arrival at 370.19, departure at 373.19
# 	 Capacity
# 		 Passengers on board on departure from here: 1	 Number of seats reserved on departure from here: 1
#
# Stop with ID 925611130106 located at (39.50, -0.37)
# 	 prev stop 5251400212
# 	 next stop 925611130111, with leg time 4.94
# 	 Time window
# 		 start_time: 345.45
# 		 EAT: 374.79, EAT_F: 374.79
# 		 LDT: 415.06, LDT_F: 385.62
# 		 slack: 30.04
# 		 latest: 384.62, end_time: 385.62
# 	 Arrival at 384.03, departure at 385.03
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# Stop with ID 925611130111 located at (39.52, -0.36)
# 	 prev stop 925611130106
# 	 next stop None, with leg time 0.00
# 	 Time window
# 		 start_time: 0.00
# 		 EAT: 380.73, EAT_F: 380.73
# 		 LDT: 420.00, LDT_F: 420.00
# 		 slack: 30.04
# 		 latest: 420.00, end_time: 420.00
# 	 Arrival at 389.96, departure at inf
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0

# %% [markdown]
# ### Modified trip creation

# %%
# Get original customer request attributes
attributes = db.get_customer_dic(passenger_id)

# Current origin stop
coords = db.get_customer_origin(passenger_id)
origin_id = db.get_stop_id([coords[1], coords[0]])
# Current destination stop
coords = db.get_customer_destination(passenger_id)
destination_id = db.get_stop_id([coords[1], coords[0]])

# Get modified stop data
if mod.get('mod_type') == 'origin':
    origin_id = mod.get('neigh_id')
    # origin_coords = db.get_stop_coords(origin_id)

elif mod.get('mod_type') == 'destination':
    destination_id = mod.get('neigh_id')
    # destination_coords = db.get_stop_coords(destination_id)

else:
    print(f"ERROR :: Mod type {mod.get('mod_type')} not recognized.")
    exit()


# Update origin/destination stop id

# Initialise request stops
mod_Request = request.Request(db, passenger_id, origin_id, destination_id,
                      attributes.get("origin_time_ini"), attributes.get("origin_time_end"),
                      attributes.get("destination_time_ini"), attributes.get("destination_time_end"),
                      attributes.get("npass"))

# Create insertion with same indexes as original one
index_Spu = insertion_to_delete.index_Spu
index_Ssd = insertion_to_delete.index_Ssd

mod_insertion = Insertion(
    itinerary=I,
    trip=mod_Request,
    index_Spu=index_Spu,
    index_Ssd=index_Ssd,
    cost_increment=-1
)

# %%
print(f"Modified insertion: {mod_insertion.to_string()}")
# Out:
# Modified insertion: Insert
# 	Pickup stop 5251300103 in position 23
# 	Setdown stop 5251400114 in position 25
# 	of itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300108, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment of -1.00

# %% [markdown]
# ### Feasibility of a given modification

# %%
from main.scheduler import new_stop_from_stop, new_itinerary_from_itinerary

# Check feasibility of inserting the modified customer trip in the same indexes of the itinerary

# Extract Request's stops
Spu = new_stop_from_stop(mod_Request.Spu)
print(f"Spu is {Spu.to_string_trip()}")
Ssd = new_stop_from_stop(mod_Request.Ssd)
print(f"Ssd is {Ssd.to_string_trip()}")
print()
passenger_id = mod_Request.passenger_id
# Extract itinerary's stop list
filtered_stops_i = I.stop_list

# Feasibility of PICKUP stop
# Index to insert pickup stop
index_stop_i = index_Spu - 1
try:
    R = filtered_stops_i[index_stop_i]
except IndexError:
    print("ERROR Searching inside itinerary {}".format(I.vehicle_id))
    print(I.to_string())
    print()
    print("with the following list of filtered stops: {}".format([x.id for x in filtered_stops_i]))
    for x in filtered_stops_i:
        print(x.to_string())
    print()
    print("and an index_stop_i of: {}".format(index_stop_i))
    print(len(filtered_stops_i), index_stop_i)
    exit()

T = R.snext
print(f"R is {R.to_string()}")
print(f"T is {T.to_string()}")
# Check feasibility of inserting Spu in R's position, so that leg (R -> R.rnext)
# becomes (Spu -> R.snext) therefore creating also a new leg (R -> Spu)
test, code = I.pickup_insertion_feasibility_check(mod_Request, Spu, R, T)
print(f"Spu insertion in position {index_stop_i+1}: {test}\n")
# Feasibility of SETDOWN stop
if test:
    # Once we select a feasible leg to insert Spu, store the index
    index_Spu = index_stop_i + 1
    # Copy of the itinerary to avoid modifications over the original
    I_with_Spu = new_itinerary_from_itinerary(I)
    # I_with_Spu = copy_Itinerary(I)
    # Insert Spu in the itinerary and re-calculate EAT carried forward over its putative successors
    I_with_Spu.insert_stop(Spu, index_Spu)
    # Compute the insertion's net additional cost
    I_with_Spu.compute_cost()
    print("Itinerary after insertion of Spu: {}\n".format(I_with_Spu.to_string_simple()))
    # Filter list of stops to keep only those not yet visited
    filtered_stops_j = [new_stop_from_stop(x) for x in I_with_Spu.stop_list]

    # Index to insert setdown stop
    index_stop_j = index_Ssd - 1
    R = filtered_stops_j[index_stop_j]
    T = R.snext
    print(f"\tR is {R.to_string()}")
    print(f"\tT is {T.to_string()}")
    test, code = I_with_Spu.setdown_insertion_feasibility_check(mod_Request, index_Spu,
                                                                index_stop_j + 1,
                                                                I_with_Spu.stop_list, Ssd, R, T)
    print(f"\tSsd insertion in position {index_stop_j+1}: {test}")
    if test:
        I_with_Spu_Ssd = new_itinerary_from_itinerary(I_with_Spu)
        I_with_Spu_Ssd.insert_stop(Ssd, index_Ssd)
        # Compute the insertion's net additional cost
        I_with_Spu_Ssd.compute_cost()
        print("Itinerary after insertion of Ssd: {}\n".format(I_with_Spu_Ssd.to_string_simple()))

        mod_insertion = Insertion(
                            itinerary=I,
                            trip=mod_Request,
                            index_Spu=index_Spu,
                            index_Ssd=index_Ssd,
                            cost_increment=-1
                        )
# Out:
# Spu is Stop with ID 5251300103 located at (39.51, -0.41)
# 	 Time window
# 		 start_time: 220.00
# 		 latest: 240.00, end_time: 241.00
#
# Ssd is Stop with ID 5251400114 located at (39.51, -0.44)
# 	 Time window
# 		 start_time: 226.34
# 		 latest: 254.85, end_time: 255.85
#
#
# R is Stop with ID 925114220110 located at (39.50, -0.41)
# 	 prev stop 5253010213
# 	 next stop 5251300108, with leg time 5.03
# 	 Time window
# 		 start_time: 187.55
# 		 EAT: 226.35, EAT_F: 226.35
# 		 LDT: 230.97, LDT_F: 227.88
# 		 slack: 0.00
# 		 latest: 226.88, end_time: 227.88
# 	 Arrival at 226.35, departure at 227.35
# 	 Capacity
# 		 Passengers on board on departure from here: 0	 Number of seats reserved on departure from here: 0
#
# T is Stop with ID 5251300108 located at (39.52, -0.42)
# 	 prev stop 925114220110
# 	 next stop 5254020225, with leg time 11.38
# 	 Time window
# 		 start_time: 216.00
# 		 EAT: 232.38, EAT_F: 232.38
# 		 LDT: 242.62, LDT_F: 237.00
# 		 slack: 0.00
# 		 latest: 236.00, end_time: 237.00
# 	 Arrival at 234.16, departure at 235.16
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# Spu insertion in position 23: True
#
# Itinerary after insertion of Spu: Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300103, 5251300108, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 178.47
#
# 	R is Stop with ID 5251300108 located at (39.52, -0.42)
# 	 prev stop 5251300103
# 	 next stop 5254020225, with leg time 11.38
# 	 Time window
# 		 start_time: 216.00
# 		 EAT: 234.16, EAT_F: 234.16
# 		 LDT: 242.62, LDT_F: 237.00
# 		 slack: 7.46
# 		 latest: 236.00, end_time: 237.00
# 	 Arrival at 234.16, departure at 233.38
# 	 Capacity
# 		 Passengers on board on departure from here: 2	 Number of seats reserved on departure from here: 2
#
# 	T is Stop with ID 5254020225 located at (39.48, -0.45)
# 	 prev stop 5251300108
# 	 next stop 5254020114, with leg time 0.80
# 	 Time window
# 		 start_time: 234.00
# 		 EAT: 244.76, EAT_F: 244.76
# 		 LDT: 257.28, LDT_F: 257.00
# 		 slack: 0.28
# 		 latest: 254.00, end_time: 257.00
# 	 Arrival at 254.00, departure at 257.00
# 	 Capacity
# 		 Passengers on board on departure from here: 4	 Number of seats reserved on departure from here: 4
#
# 	Ssd insertion in position 25: True
# Itinerary after insertion of Ssd: Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300103, 5251300108, 5251400114, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 176.79

# %%
print(I.to_string_simple())

# %% [markdown]
# ### Modified trip insertion

# %%
# Apply insertion with Scheduler.insert_trip(modified_insertion)
# Check Itinerary integrity (times)

# Itinerary previous to insertion
print(I.to_string_simple())
print(I.to_string())
print()

# Insert trip
sche.insert_trip(mod_insertion)

# Itinerary after trip insertion
print(I.to_string_simple())
print(I.to_string())
# Out:
# Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300108, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 178.14
# Vehicle with ID veh_07_925611130111 has 42 stops scheduled
# 	Departure from stop 925611130111 at time 60.82
# 	--> stop 5252050117, npass 0 -> 1, request_019_1, [76.00, 77.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040136, npass 1 -> 0, request_019_1, [80.25, 81.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_018_1, [94.52, 95.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5251400122, npass 1 -> 2, request_026_1, [98.31, 99.31] (arr, dep), 1.00 min, 0.00 min, customers waited 19.31 min
# 	--> stop 92501650202, npass 2 -> 1, request_018_1, [106.70, 107.70] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 3, request_055_2, [109.18, 111.18] (arr, dep), 2.00 min, 0.00 min, customers waited 15.18 min
# 	--> stop 5201110118, npass 3 -> 4, request_080_1, [116.49, 117.49] (arr, dep), 1.00 min, 0.00 min, customers waited 7.49 min
# 	--> stop 5251300103, npass 4 -> 3, request_026_1, [121.72, 122.72] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 2, request_080_1, [126.96, 127.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130108, npass 2 -> 0, request_055_2, [139.22, 141.33] (arr, dep), 2.11 min, 0.11 min
# 	--> stop 925611130107, npass 0 -> 2, request_140_2, [142.00, 144.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925114700111, npass 2 -> 6, request_133_4, [157.31, 161.31] (arr, dep), 4.00 min, 0.00 min, customers waited 17.31 min
# 	--> stop 5251400116, npass 6 -> 2, request_133_4, [166.85, 170.85] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254010221, npass 2 -> 3, request_182_1, [182.97, 183.97] (arr, dep), 1.00 min, 0.00 min, customers waited 19.97 min
# 	--> stop 5250060117, npass 3 -> 4, request_205_1, [187.74, 188.74] (arr, dep), 1.00 min, 0.00 min, customers waited 14.74 min
# 	--> stop 5250060117, npass 4 -> 5, request_204_1, [188.74, 189.74] (arr, dep), 1.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501620103, npass 5 -> 6, request_208_1, [190.77, 191.77] (arr, dep), 1.00 min, 0.00 min, customers waited 16.77 min
# 	--> stop 5250740213, npass 6 -> 4, request_140_2, [193.97, 195.97] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250600109, npass 4 -> 3, request_204_1, [202.41, 203.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 3 -> 2, request_205_1, [207.20, 208.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010213, npass 2 -> 1, request_182_1, [213.86, 214.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114220110, npass 1 -> 0, request_208_1, [226.35, 227.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300108, npass 0 -> 2, request_279_1, [234.16, 235.16] (arr, dep), 1.00 min, 0.00 min, customers waited 18.16 min
# 	--> stop 5254020225, npass 2 -> 4, request_316_3, [254.00, 257.00] (arr, dep), 3.00 min, 0.00 min, customers waited 20.00 min
# 	--> stop 5254020114, npass 4 -> 3, request_279_1, [257.80, 258.80] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5250060205, npass 3 -> 0, request_316_3, [264.30, 267.30] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 5250060123, npass 0 -> 1, request_375_1, [267.38, 268.38] (arr, dep), 1.00 min, 0.00 min, customers waited 9.38 min
# 	--> stop 92501620208, npass 1 -> 5, request_370_4, [272.97, 276.97] (arr, dep), 4.00 min, 0.00 min, customers waited 18.97 min
# 	--> stop 5250610202, npass 5 -> 7, request_398_2, [282.11, 284.11] (arr, dep), 2.00 min, 0.00 min, customers waited 14.11 min
# 	--> stop 925114010111, npass 7 -> 6, request_375_1, [294.12, 295.12] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130107, npass 6 -> 2, request_370_4, [304.68, 308.68] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5256120119, npass 2 -> 0, request_398_2, [312.24, 314.24] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5256120203, npass 0 -> 1, request_481_1, [316.85, 317.85] (arr, dep), 1.00 min, 0.00 min, customers waited 14.85 min
# 	--> stop 5252040210, npass 1 -> 2, request_493_1, [326.30, 327.30] (arr, dep), 1.00 min, 0.00 min, customers waited 18.30 min
# 	--> stop 5201110203, npass 2 -> 1, request_493_1, [335.43, 336.43] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251400112, npass 1 -> 0, request_481_1, [343.35, 344.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_544_1, [351.71, 352.71] (arr, dep), 1.00 min, 0.00 min, customers waited 19.71 min
# 	--> stop 5251300105, npass 1 -> 4, request_572_3, [361.17, 364.17] (arr, dep), 3.00 min, 0.00 min, customers waited 13.17 min
# 	--> stop 5251400212, npass 4 -> 1, request_572_3, [370.19, 373.19] (arr, dep), 3.00 min, 0.00 min
# 	--> stop 925611130106, npass 1 -> 0, request_544_1, [384.03, 385.03] (arr, dep), 1.00 min, 0.00 min
# 	End in stop 925611130111 at time 389.96
# 	Vehicle currently at stop 925611130111
# 	Busy time: 319.80 (76.14%), Waiting time: 60.93 (14.51%), Busy+Wait: 90.65%
# Itinerary km: 178.14, cost: 178.14
# Total customers: 20, total waiting: 293.66 min, avg: 14.68 min, stdev: 5.91 min
#
#
# Itinerary veh_07_925611130111: [925611130111, 5252050117, 5252040136, 925114700201, 5251400122, 92501650202, 5251300109, 5201110118, 5251300103, 5251300109, 925611130108, 925611130107, 925114700111, 5251400116, 5254010221, 5250060117, 5250060117, 92501620103, 5250740213, 5250600109, 5206020126, 5253010213, 925114220110, 5251300103, 5251300108, 5251400114, 5254020225, 5254020114, 5250060205, 5250060123, 92501620208, 5250610202, 925114010111, 925611130107, 5256120119, 5256120203, 5252040210, 5201110203, 5251400112, 925114700201, 5251300105, 5251400212, 925611130106, 925611130111]
# 	with a cost increment 176.79
# Vehicle with ID veh_07_925611130111 has 44 stops scheduled
# 	Departure from stop 925611130111 at time 60.82
# 	--> stop 5252050117, npass 0 -> 1, request_019_1, [76.00, 77.00] (arr, dep), 1.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 5252040136, npass 1 -> 0, request_019_1, [80.25, 81.25] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114700201, npass 0 -> 1, request_018_1, [94.52, 95.52] (arr, dep), 1.00 min, 0.00 min, customers waited 19.52 min
# 	--> stop 5251400122, npass 1 -> 2, request_026_1, [98.31, 99.31] (arr, dep), 1.00 min, 0.00 min, customers waited 19.31 min
# 	--> stop 92501650202, npass 2 -> 1, request_018_1, [106.70, 107.70] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 1 -> 3, request_055_2, [109.18, 111.18] (arr, dep), 2.00 min, 0.00 min, customers waited 15.18 min
# 	--> stop 5201110118, npass 3 -> 4, request_080_1, [116.49, 117.49] (arr, dep), 1.00 min, 0.00 min, customers waited 7.49 min
# 	--> stop 5251300103, npass 4 -> 3, request_026_1, [121.72, 122.72] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300109, npass 3 -> 2, request_080_1, [126.96, 127.96] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925611130108, npass 2 -> 0, request_055_2, [139.22, 141.33] (arr, dep), 2.11 min, 0.11 min
# 	--> stop 925611130107, npass 0 -> 2, request_140_2, [142.00, 144.00] (arr, dep), 2.00 min, 0.00 min, customers waited 0.00 min
# 	--> stop 925114700111, npass 2 -> 6, request_133_4, [157.31, 161.31] (arr, dep), 4.00 min, 0.00 min, customers waited 17.31 min
# 	--> stop 5251400116, npass 6 -> 2, request_133_4, [166.85, 170.85] (arr, dep), 4.00 min, 0.00 min
# 	--> stop 5254010221, npass 2 -> 3, request_182_1, [182.97, 183.97] (arr, dep), 1.00 min, 0.00 min, customers waited 19.97 min
# 	--> stop 5250060117, npass 3 -> 4, request_205_1, [187.74, 188.74] (arr, dep), 1.00 min, 0.00 min, customers waited 14.74 min
# 	--> stop 5250060117, npass 4 -> 5, request_204_1, [188.74, 189.74] (arr, dep), 1.00 min, 0.00 min, customers waited 16.74 min
# 	--> stop 92501620103, npass 5 -> 6, request_208_1, [190.77, 191.77] (arr, dep), 1.00 min, 0.00 min, customers waited 16.77 min
# 	--> stop 5250740213, npass 6 -> 4, request_140_2, [193.97, 195.97] (arr, dep), 2.00 min, 0.00 min
# 	--> stop 5250600109, npass 4 -> 3, request_204_1, [202.41, 203.41] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5206020126, npass 3 -> 2, request_205_1, [207.20, 208.20] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5253010213, npass 2 -> 1, request_182_1, [213.86, 214.86] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 925114220110, npass 1 -> 0, request_208_1, [226.35, 227.35] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5251300103, npass 0 -> 1, request_286_1, [229.43, 230.43] (arr, dep), 1.00 min, 0.00 min, customers waited 9.43 min
# 	--> stop 5251300108, npass 1 -> 3, request_279_1, [234.16, 235.16] (arr, dep), 1.00 min, 0.00 min, customers waited 18.16 min
# 	--> stop 5251400114, npass 3 -> 2, request_286_1, [240.76, 241.76] (arr, dep), 1.00 min, 0.00 min
# 	--> stop 5254020225, npass 2 -> 4, request_316_3, [249.09, 252.09] (arr, dep), 3.00 min, 0.00 min, customers waited 15.09 min
# 	--> stop 5254020114, npass 4 -> 3, request_279_1, [252.90, 251.35] (arr, dep), -1.55 min, -2.55 min
# 	--> stop 5250060205, npass 3 -> 0, request_316_3, [259.40, 259.85] (arr, dep), 0.45 min, -2.55 min
# 	--> stop 5250060123, npass 0 -> 1, request_375_1, [262.47, 260.92] (arr, dep), -1.55 min, -2.55 min, customers waited 4.47 min
# 	--> stop 92501620208, npass 1 -> 5, request_370_4, [268.06, 269.51] (arr, dep), 1.45 min, -2.55 min, customers waited 14.06 min
# 	--> stop 5250610202, npass 5 -> 7, request_398_2, [277.21, 276.66] (arr, dep), -0.55 min, -2.55 min, customers waited 9.21 min
# 	--> stop 925114010111, npass 7 -> 6, request_375_1, [289.22, 287.67] (arr, dep), -1.55 min, -2.55 min
# 	--> stop 925611130107, npass 6 -> 2, request_370_4, [299.77, 301.22] (arr, dep), 1.45 min, -2.55 min
# 	--> stop 5256120119, npass 2 -> 0, request_398_2, [307.33, 306.78] (arr, dep), -0.55 min, -2.55 min
# 	--> stop 5256120203, npass 0 -> 1, request_481_1, [311.94, 310.39] (arr, dep), -1.55 min, -2.55 min, customers waited 9.94 min
# 	--> stop 5252040210, npass 1 -> 2, request_493_1, [321.39, 319.84] (arr, dep), -1.55 min, -2.55 min, customers waited 13.39 min
# 	--> stop 5201110203, npass 2 -> 1, request_493_1, [330.52, 328.97] (arr, dep), -1.55 min, -2.55 min
# 	--> stop 5251400112, npass 1 -> 0, request_481_1, [338.44, 336.89] (arr, dep), -1.55 min, -2.55 min
# 	--> stop 925114700201, npass 0 -> 1, request_544_1, [346.80, 345.25] (arr, dep), -1.55 min, -2.55 min, customers waited 14.80 min
# 	--> stop 5251300105, npass 1 -> 4, request_572_3, [356.26, 356.71] (arr, dep), 0.45 min, -2.55 min, customers waited 8.26 min
# 	--> stop 5251400212, npass 4 -> 1, request_572_3, [365.28, 365.73] (arr, dep), 0.45 min, -2.55 min
# 	--> stop 925611130106, npass 1 -> 0, request_544_1, [379.12, 377.57] (arr, dep), -1.55 min, -2.55 min
# 	End in stop 925611130111 at time 385.06
# 	Vehicle currently at stop 925611130111
# 	Busy time: 324.13 (77.17%), Waiting time: 20.13 (4.79%), Busy+Wait: 81.97%
# Itinerary km: 176.79, cost: 176.79
# Total customers: 21, total waiting: 263.86 min, avg: 12.56 min, stdev: 5.84 min

# %% [markdown]
# # TO DO

# %%
p1 = (-0.4565131701, 39.4824055691)
p2 = (-0.4557867049, 39.4805017556)

p1 = (39.4824055691, -0.4565131701)
p2 = (39.4805017556, -0.4557867049)

# %%
db.get_stop(p1)

# %%
db.get_stop(p2)

# %%
db.get_route(p1, p2)

# %%
geopy.distance.distance(p1, p2).km

# %% [markdown]
# ### Check Itinerary integrity and cost reduction

# %% [markdown]
# # Discarded cells

# %%
# # Sort route legs according to cost
# sorted_legs = sorted(legs, key=lambda leg: leg.cost, reverse=True)
# # Select a costly leg
# leg = sorted_legs[0]
# print(leg.__str__())
# # Check if the leg is for passenger pickup or setdown
# leg_stop_id = leg.dest_stop.id
# # customer origin stop id
# origin_coords = db.get_customer_origin(leg.passenger_id)
# origin_id = db.get_stop_id([origin_coords[1], origin_coords[0]])
# # customer destination stop id
# destination_coords = db.get_customer_destination(leg.passenger_id)
# destination_id = db.get_stop_id([destination_coords[1], destination_coords[0]])
# print(f"Customer trip from {origin_id:3d} --> {destination_id:3d}")
# pickup = True
# if leg.dest_stop.id == origin_id:
#     print(f"\tLeg corresponds to customer pickup")
# else:
#     pickup = False
#     print(f"\tLeg corresponds to customer setdown")
#
# # Look for alternative stops within the neighbours
# if pickup:
#     # Stop to be modified
#     stop_id = origin_id
# else:
#     stop_id = destination_id
#
# neighbours = db.get_neighbouring_stops(stop_id)
# print(neighbours)
#
# # Calculate costs if going to any of the neighbours:
# #   S -> neighbour (can be calculated from current leg)
# #   neighbour -> T (must extract next leg and see the subsequent stop)
# leg_origin_stop_id = leg.origin_stop.id
# for id, distance in neighbours:
#     print(db.get_route_time_min(leg_origin_stop_id, id))
#
# # SEGUIR ACI

# %%
# stop_customer_list = []
# print("stop_id, setdown, pickup")
# for S in I.stop_list:
#     if S.snext is not None:
#         stop_customer_list.append((S.id, S.passenger_id, S.snext.passenger_id))
#     else:
#         stop_customer_list.append((S.id, S.passenger_id, None))

# %%
# stop_customer_list

# %% [markdown]
# ### Sii apareixen dues parades amb la mateixa id seguides, més d'un client ha sigut servit amb eixa visita. Encara que coste arribar a eixa parada, ja tenim demanda agrupada, així que no es deuria detectar com a una mala ruta.

# %% [markdown]
# ### Necessite representar, doncs, el benefici associat a cada "leg", encara que siga per mitjà del nombre de clients servits amb cada trajecte

# %%
# # Load stops file
# # Load routes file
# db = Database(config_file)

# %%
# def get_neighbouring_stops(stop_id, max_distance_km=1):
#     distance_matrix = db.get_distance_matrix()
#     neighbours = []
#     for i in range(0, len(distance_matrix[stop_id])):
#         if i != stop_id:
#             if distance_matrix[stop_id][i] <= max_distance_km:
#                 neighbours.append((i, distance_matrix[stop_id][i]))
#     return neighbours

# %%
# Testing geopy.distance
import geopy.distance
s1 = database.stops_dic['features'][0]
s2 = database.stops_dic['features'][1]


p1 = s1['geometry']['coordinates']
p2 = s2['geometry']['coordinates']

id1 = s1['properties']['id']
id2 = s2['properties']['id']
print(id1, id2)

print("Geopy", geopy.distance.distance(p1, p2).km)
print("OSRM", database.get_route_distance_km(int(id1), int(id2)))
